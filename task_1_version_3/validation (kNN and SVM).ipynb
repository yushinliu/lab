# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append(r"C:\Users\yangshanqi\Documents\lab\labgithubcopy\task_1_version_2")
from SVC_function_with_kFold import SVM_validation
from kNN_function_with_kFold import kNN_validation
from plot_prediction import kNN_plot_prediction

# %%
X_scaled_CNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\X_scaled_CNN.csv")
y_scaled_CNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\y_scaled_CNN.csv")
X_val=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\scaled_validation_feature.csv")
y_val=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\validation_label.csv")
X_val=X_val.drop("Unnamed: 0",1)
y_val=y_val.drop("Unnamed: 0",1)
X_scaled=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\scaled_train_feature.csv")
y_scaled=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\train_label.csv")

# %%
X_scaled_kMeans=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\X_scaled_kMeans.csv")
y_scaled_kMeans=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\y_scaled_kMeans.csv")
X_scaled_kMeans=X_scaled_kMeans.drop("predict_cluster",1)
y_scaled_kMeans=y_scaled_kMeans.drop("predict_cluster",1)

# %%
validation_label_expert = pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\validation_label_expert.csv")
validation_feature_expert = pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\scaled_validation_feature_expert.csv")                                      
validation_label_expert=validation_label_expert.drop("Unnamed: 0",1)
validation_feature_expert=validation_feature_expert.drop("Unnamed: 0",1)

# %% [markdown]
# ## validation for kNN classifer ##

# %%
sample_amount=10000
data_ratio=1
kValue = 19
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_CNN,y_scaled_CNN,X_val,y_val,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.6107142857142858,
#  0.157828352966164,
#  0.27355703362593914,
#  0.45137553378682077)

# %%
# expert label

# %%
sample_amount=10000
data_ratio=1
kValue = 19
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_CNN,y_scaled_CNN,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,kValue)

# %%
stuck,slices,features=11,22,3
kNN_plot_prediction(stuck,slices,features,X_scaled_CNN,y_scaled_CNN,X_val,y_val,19,1)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.6743913857677903,
#  0.08965783914290024,
#  0.207633226687555,
#  0.6594163778877359)

# %%
sample_amount=10000
data_ratio=1.1
kValue = 17
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_CNN,y_scaled_CNN,X_val,y_val,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.5828684807256236,
#  0.14233012563922426,
#  0.27973082245680037,
#  0.45354838362202543)

# %%
sample_amount=10000
data_ratio=1.1
kValue = 17
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_CNN,y_scaled_CNN,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.655766229712859,
#  0.07585823147728987,
#  0.2100460008822155,
#  0.6659002470721735)

# %%
stuck,slices,features=11,22,3
kNN_plot_prediction(stuck,slices,features,X_scaled_CNN,y_scaled_CNN,X_val,y_val,17,1.1)

# %%
sample_amount=10000
data_ratio=1
kValue = 37
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_kMeans,y_scaled_kMeans,X_val,y_val,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.7255895691609977,
#  0.22810299475550178,
#  0.25125671279725204,
#  0.4387541638242086)

# %%
sample_amount=10000
data_ratio=1
kValue = 37
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_kMeans,y_scaled_kMeans,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.7792368913857678,
#  0.15510034706503698,
#  0.18793172783963458,
#  0.6439000461161479)

# %%
stuck,slices,features=11,22,3
kNN_plot_prediction(stuck,slices,features,X_scaled_kMeans,y_scaled_kMeans,X_val,y_val,37,1)

# %%
sample_amount=10000
data_ratio=1.2
kValue = 32
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_kMeans,y_scaled_kMeans,X_val,y_val,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.6833106575963719,
#  0.1915450847125329,
#  0.2541172135580804,
#  0.4537437620861236)

# %%
sample_amount=10000
data_ratio=1.2
kValue = 32
tpr,fpr,BER,f1_score = kNN_validation (X_scaled_kMeans,y_scaled_kMeans,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,kValue)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.7432506242197252,
#  0.12927040893315225,
#  0.19300989235671348,
#  0.6525721984570503)

# %%
stuck,slices,features=11,22,3
kNN_plot_prediction(stuck,slices,features,X_scaled_kMeans,y_scaled_kMeans,X_val,y_val,32,1.2)

# %% [markdown]
# ## validation for SVM classifer ##

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=11
gamma_parameter=-5
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,X_val,y_val,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.4941043083900227,
#  0.10154475795252177,
#  0.3037202247812496,
#  0.4491154086753124)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=11
gamma_parameter=-5
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.5884441323345818,
#  0.03227327599215331,
#  0.22191457182878577,
#  0.6834447582506502)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=-1
gamma_parameter=-1
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,X_val,y_val,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.5077380952380952,
#  0.10570686359403336,
#  0.2989843841779691,
#  0.45284353910422737)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=-1
gamma_parameter=-1
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.6127887016229714,
#  0.042925720537196316,
#  0.2150685094571125,
#  0.6843836924241828)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=3
gamma_parameter=-1
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,X_val,y_val,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.5145975056689343,
#  0.11376149786789092,
#  0.29958199609947833,
#  0.4467432867700988)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=3
gamma_parameter=-1
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.5961103308364545,
#  0.04864097630903878,
#  0.22626532273629218,
#  0.6633507022546223)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=5
gamma_parameter=-1
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,X_val,y_val,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.4821712018140589,
#  0.09911448036989234,
#  0.30847163927791665,
#  0.44436965715559584)

# %%
sample_amount=10000
data_ratio=1.2
C_parameter=5
gamma_parameter=-1
tpr,fpr,BER,f1_score = SVM_validation (X_scaled_CNN,y_scaled_CNN,validation_feature_expert,validation_label_expert,sample_amount,data_ratio,C_parameter,gamma_parameter)

# %%
tpr,fpr,BER,f1_score
# Out:
# (0.5779494382022472,
#  0.05163063980685076,
#  0.2368406008023018,
#  0.6450485841902583)
