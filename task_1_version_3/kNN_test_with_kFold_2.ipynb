# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append(r"C:\Users\yangshanqi\Documents\lab\labgithubcopy\task_1_version_2")

# %%
from kNN_function_with_kFold import kNN_k_parameter_adjust
from kNN_function_with_kFold import kNN_data_ratio_adjust
#from kNN_function import kNN_data_ratio_adjust_2
from kNN_function_with_kFold import kNN_k_parameter_adjust_with_specific_data_ratio 
from plot_prediction import kNN_plot_prediction

# %%
from kNN_function_with_kFold import kNN_base_function

# %%
#X_scaled_FCNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\X_scaled_FCNN.csv")
#y_scaled_FCNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\y_scaled_FCNN.csv")
X_scaled_CNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\X_scaled_CNN.csv")
y_scaled_CNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\y_scaled_CNN.csv")
X_scaled_kMeans=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\X_scaled_kMeans.csv")
y_scaled_kMeans=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\y_scaled_kMeans.csv")
X_val=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\scaled_validation_feature.csv")
y_val=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\validation_label.csv")
X_scaled_kMeans=X_scaled_kMeans.drop("predict_cluster",1)
y_scaled_kMeans=y_scaled_kMeans.drop("predict_cluster",1)
X_val=X_val.drop("Unnamed: 0",1)
y_val=y_val.drop("Unnamed: 0",1)
X_scaled=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\scaled_train_feature.csv")
y_scaled=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\train_label.csv")

# %%
k_value=20
kNN_scaled_CNN_result_data_ratio=kNN_data_ratio_adjust(X_scaled_CNN,y_scaled_CNN,k_value)
kNN_scaled_result_data_ratio=kNN_data_ratio_adjust(X_scaled,y_scaled,k_value)
kNN_scaled_kMeans_result_data_ratio=kNN_data_ratio_adjust(X_scaled_kMeans,y_scaled_kMeans,k_value)
# Out:
# the total executing time:  1.4minute
# the total executing time:  1.4minute
# the total executing time:  1.4minute

# %%
plt.title("kNN ROC with data ratio changing (k=20) - cross validation stage")
plt.plot(kNN_scaled_CNN_result_data_ratio['FPR'],kNN_scaled_CNN_result_data_ratio['TPR'],"r-",label='scaled_CNN_data')
plt.plot(kNN_scaled_result_data_ratio['FPR'],kNN_scaled_result_data_ratio['TPR'],"k-",label='scaled_data')
plt.plot(kNN_scaled_kMeans_result_data_ratio['FPR'],kNN_scaled_kMeans_result_data_ratio['TPR'],"b-",label='scaled_kMeans_data')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.show()

# %%
plt.title("kNN f1_score with data ratio changing (k=20) - cross validation stage")
plt.plot(kNN_scaled_CNN_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_CNN_result_data_ratio['f1_score'],"r-",label='scaled_CNN_data')
plt.plot(kNN_scaled_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_result_data_ratio['f1_score'],"k-",label='scaled_data')
plt.plot(kNN_scaled_kMeans_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_kMeans_result_data_ratio['f1_score'],"b-",label='scaled_kMeans_data')
plt.xlabel('label 1: label 2 ratio')
plt.ylabel('f1_score')
plt.legend()
plt.show()

# %%
plt.title("kNN BER with data ratio changing (k=20) - cross validation stage")
plt.plot(kNN_scaled_CNN_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_CNN_result_data_ratio['BER'],"r-",label='scaled_CNN_data')
plt.plot(kNN_scaled_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_result_data_ratio['BER'],"k-",label='scaled_data')
plt.plot(kNN_scaled_kMeans_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_kMeans_result_data_ratio['BER'],"b-",label='scaled_kMeans_data')
plt.xlabel('label 1: label 2 ratio')
plt.ylabel('BER')
plt.legend()
plt.show()

# %%
k_value=100
#kNN_scaled_FCNN_result_data_ratio=kNN_data_ratio_adjust(X_scaled_FCNN,y_scaled_FCNN,k_value)
kNN_scaled_CNN_result_data_ratio=kNN_data_ratio_adjust(X_scaled_CNN,y_scaled_CNN,k_value)
kNN_scaled_kMeans_result_data_ratio=kNN_data_ratio_adjust(X_scaled_kMeans,y_scaled_kMeans,k_value)
kNN_scaled_result_data_ratio=kNN_data_ratio_adjust(X_scaled,y_scaled,k_value)
# Out:
# the total executing time:  2.7minute
# the total executing time:  2.7minute
# the total executing time:  2.8minute

# %%
plt.title("kNN ROC with data ratio changing (k=100) - cross validation stage")
#plt.plot(kNN_scaled_FCNN_result_data_ratio['FPR'],kNN_scaled_FCNN_result_data_ratio['TPR'],"b-",label='scaled_FCNN_data')
plt.plot(kNN_scaled_CNN_result_data_ratio['FPR'],kNN_scaled_CNN_result_data_ratio['TPR'],"r-",label='scaled_CNN_data')
plt.plot(kNN_scaled_kMeans_result_data_ratio['FPR'],kNN_scaled_kMeans_result_data_ratio['TPR'],"b-",label='scaled_kMeans_data')
plt.plot(kNN_scaled_result_data_ratio['FPR'],kNN_scaled_result_data_ratio['TPR'],"k-",label='scaled_data')
#plt.plot(kNN_scaled_outlier_detection_result_data_ratio['FPR'],kNN_scaled_outlier_detection_result_data_ratio['TPR'],"g-",label='scaled_outlier_detection_data')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.show()

# %%
plt.title("kNN f1_score with data ratio changing (k=100) - cross validation stage")
#plt.plot(kNN_scaled_FCNN_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_FCNN_result_data_ratio['f1_score'],"b-",label='scaled_FCNN_data')
plt.plot(kNN_scaled_CNN_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_CNN_result_data_ratio['f1_score'],"r-",label='scaled_CNN_data')
plt.plot(kNN_scaled_kMeans_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_kMeans_result_data_ratio['f1_score'],"b-",label='scaled_kMeans_data')
plt.plot(kNN_scaled_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_result_data_ratio['f1_score'],"k-",label='scaled_data')
#plt.plot(kNN_scaled_outlier_detection_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_outlier_detection_result_data_ratio['f1_score'],"g-",label='scaled_outlier_detection_data')
plt.xlabel('label 1: label 2 ratio')
plt.ylabel('f1_score')
plt.legend()
plt.show()

# %%
plt.title("kNN BER with data ratio changing (k=100) - cross validation stage")
#plt.plot(kNN_scaled_FCNN_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_FCNN_result_data_ratio['BER'],"b-",label='scaled_FCNN_data')
plt.plot(kNN_scaled_CNN_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_CNN_result_data_ratio['BER'],"r-",label='scaled_CNN_data')
plt.plot(kNN_scaled_kMeans_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_kMeans_result_data_ratio['BER'],"b-",label='scaled_kMeans_data')
plt.plot(kNN_scaled_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_result_data_ratio['BER'],"k-",label='scaled_data')
#plt.plot(kNN_scaled_outlier_detection_result_data_ratio['label 1: label 2 ratio'],kNN_scaled_outlier_detection_result_data_ratio['BER'],"g-",label='scaled_outlier_detection_data')
plt.xlabel('label 1: label 2 ratio')
plt.ylabel('BER')
plt.legend()
plt.show()

# %% [markdown]
# ## K ADJUSTMENT  kMeans data set##

# %%
kNN_scaled_kMeans_result_k_value_specific_1_ratio  =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_kMeans,y_scaled_kMeans,1)
kNN_scaled_kMeans_result_k_value_specific_11_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_kMeans,y_scaled_kMeans,1.1)
kNN_scaled_kMeans_result_k_value_specific_12_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_kMeans,y_scaled_kMeans,1.2)
kNN_scaled_kMeans_result_k_value_specific_13_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_kMeans,y_scaled_kMeans,1.3)
kNN_scaled_kMeans_result_k_value_specific_14_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_kMeans,y_scaled_kMeans,1.4)
kNN_scaled_kMeans_result_k_value_specific_15_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_kMeans,y_scaled_kMeans,1.5)

# %%
plt.title("kNN f1_score with k changing - cross validation stage")
plt.plot(kNN_scaled_kMeans_result_k_value_specific_1_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_1_ratio['f1_score'],"b-",label='scaled_kMeans_data (data ratio:1)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_11_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_11_ratio['f1_score'],"y-",label='scaled_kMeans_data data ratio:1.1)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_12_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_12_ratio['f1_score'],"g-",label='scaled_kMeans_data (data ratio:1.2)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_13_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_13_ratio['f1_score'],"r-",label='scaled_kMeans_data (data ratio:1.3)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_14_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_14_ratio['f1_score'],"k-",label='scaled_kMeans_data (data ratio:1.4)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_15_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_15_ratio['f1_score'],"m-",label='scaled_kMeans_data (data ratio:1.5)')
plt.xlabel('k_value')
plt.ylabel('f1_score')
plt.legend()
plt.show()

# %%
plt.title("kNN BER with k changing - cross validation stage")
plt.plot(kNN_scaled_kMeans_result_k_value_specific_1_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_1_ratio['BER'],"b-",label='scaled_kMeans_data (data ratio:1)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_11_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_11_ratio['BER'],"y-",label='scaled_kMeans_data data ratio:1.1)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_12_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_12_ratio['BER'],"g-",label='scaled_kMeans_data (data ratio:1.2)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_13_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_13_ratio['BER'],"r-",label='scaled_kMeans_data (data ratio:1.3)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_14_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_14_ratio['BER'],"k-",label='scaled_kMeans_data (data ratio:1.4)')
plt.plot(kNN_scaled_kMeans_result_k_value_specific_15_ratio['k_value'],kNN_scaled_kMeans_result_k_value_specific_15_ratio['BER'],"m-",label='scaled_kMeans_data (data ratio:1.5)')
plt.xlabel('k_value')
plt.ylabel('BER')
plt.legend()
plt.show()

# %%
kNN_scaled_kMeans_result_k_value_specific_1_ratio.loc[kNN_scaled_kMeans_result_k_value_specific_1_ratio['f1_score'].idxmax()]
# Out:
# k_value     15.000000
# f1_score     0.805942
# TPR          0.788750
# FPR          0.168550
# BER          0.189900
# Name: 5, dtype: float64

# %%
kNN_scaled_kMeans_result_k_value_specific_12_ratio.loc[kNN_scaled_kMeans_result_k_value_specific_12_ratio['f1_score'].idxmax()]
# Out:
# k_value     32.000000
# f1_score     0.789209
# TPR          0.766400
# FPR          0.146500
# BER          0.190050
# Name: 12, dtype: float64

# %%
kNN_scaled_kMeans_result_k_value_specific_1_ratio.loc[kNN_scaled_kMeans_result_k_value_specific_1_ratio['BER'].idxmin()]
# Out:
# k_value     37.00000
# f1_score     0.80591
# TPR          0.78830
# FPR          0.16800
# BER          0.18985
# Name: 13, dtype: float64

# %%
kNN_scaled_kMeans_result_k_value_specific_12_ratio.loc[kNN_scaled_kMeans_result_k_value_specific_12_ratio['BER'].idxmin()]
# Out:
# k_value     32.000000
# f1_score     0.789209
# TPR          0.766400
# FPR          0.146500
# BER          0.190050
# Name: 12, dtype: float64

# %% [markdown]
# ## K ADJUSTMENT  CNN data set##

# %%
kNN_scaled_CNN_result_k_value_specific_1_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_CNN,y_scaled_CNN,1)
kNN_scaled_CNN_result_k_value_specific_11_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_CNN,y_scaled_CNN,1.1)
kNN_scaled_CNN_result_k_value_specific_12_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_CNN,y_scaled_CNN,1.2)
kNN_scaled_CNN_result_k_value_specific_13_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_CNN,y_scaled_CNN,1.3)
kNN_scaled_CNN_result_k_value_specific_14_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_CNN,y_scaled_CNN,1.4)
kNN_scaled_CNN_result_k_value_specific_15_ratio =kNN_k_parameter_adjust_with_specific_data_ratio (X_scaled_CNN,y_scaled_CNN,1.5)

# %%
plt.title("kNN f1_score with k changing - cross validation stage")
plt.plot(kNN_scaled_CNN_result_k_value_specific_1_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_1_ratio['f1_score'],"b-",label='scaled_CNN_data (data ratio:1)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_11_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_11_ratio['f1_score'],"y-",label='scaled_CNN_data (data ratio:1.1)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_12_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_12_ratio['f1_score'],"g-",label='scaled_CNN_data (data ratio:1.2)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_13_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_13_ratio['f1_score'],"r-",label='scaled_CNN_data (data ratio:1.3)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_14_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_14_ratio['f1_score'],"k-",label='scaled_CNN_data (data ratio:1.4)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_15_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_15_ratio['f1_score'],"m-",label='scaled_CNN_data (data ratio:1.5)')
plt.xlabel('k_value')
plt.ylabel('f1_score')
plt.legend()
plt.show()

# %%
plt.title("kNN BER with k changing - cross validation stage")
plt.plot(kNN_scaled_CNN_result_k_value_specific_1_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_1_ratio['BER'],"b-",label='scaled_CNN_data (data ratio:1)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_11_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_11_ratio['BER'],"y-",label='scaled_CNN_data (data ratio:1.1)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_12_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_12_ratio['BER'],"g-",label='scaled_CNN_data (data ratio:1.2)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_13_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_13_ratio['BER'],"r-",label='scaled_CNN_data (data ratio:1.3)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_14_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_14_ratio['BER'],"k-",label='scaled_CNN_data (data ratio:1.4)')
plt.plot(kNN_scaled_CNN_result_k_value_specific_15_ratio['k_value'],kNN_scaled_CNN_result_k_value_specific_15_ratio['BER'],"m-",label='scaled_CNN_data (data ratio:1.5)')
plt.xlabel('k_value')
plt.ylabel('BER')
plt.legend()
plt.show()

# %%
kNN_scaled_CNN_result_k_value_specific_1_ratio.loc[kNN_scaled_CNN_result_k_value_specific_1_ratio['f1_score'].idxmax()]
# Out:
# k_value     19.000000
# f1_score     0.848089
# TPR          0.865050
# FPR          0.174950
# BER          0.154950
# Name: 7, dtype: float64

# %%
kNN_scaled_CNN_result_k_value_specific_1_ratio.loc[kNN_scaled_CNN_result_k_value_specific_1_ratio['BER'].idxmin()]
# Out:
# k_value     17.000000
# f1_score     0.847968
# TPR          0.863500
# FPR          0.173100
# BER          0.154800
# Name: 6, dtype: float64

# %%
kNN_scaled_CNN_result_k_value_specific_11_ratio.loc[kNN_scaled_CNN_result_k_value_specific_11_ratio['f1_score'].idxmax()]
# Out:
# k_value     17.000000
# f1_score     0.845644
# TPR          0.858100
# FPR          0.155818
# BER          0.148859
# Name: 6, dtype: float64

# %%
kNN_scaled_CNN_result_k_value_specific_11_ratio.loc[kNN_scaled_CNN_result_k_value_specific_11_ratio['BER'].idxmin()]
# Out:
# k_value     17.000000
# f1_score     0.845644
# TPR          0.858100
# FPR          0.155818
# BER          0.148859
# Name: 6, dtype: float64
