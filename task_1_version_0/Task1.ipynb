# %% [markdown]
# this is a classification problem and we got original data which contains 5 features and 3 labels, each pixel can regarded as a sample

# %% [markdown]
# # 1.Frame the problem

# %% [markdown]
# # 2.Input the data

# %%
#all packages which will be used
import numpy as np
import pandas as pd
from scipy.io import loadmat
import time
import random

#plot
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from matplotlib.axes import Axes

#sklearn
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
#from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import precision_score, recall_score,f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
#to plot more than 2 dimensions 
from mlxtend.plotting import plot_decision_regions

#scipy
from scipy.stats import chisquare
from scipy.stats import chi2
from scipy.spatial import distance


#math
from math import log
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# first we imported the data from the '.mat'

# %%
#data=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\dataset.mat")
dataset=loadmat("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\dataset.mat",mat_dtype=True)

# %%
data=dataset["dataset"]
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# then we try to plot one image to see what it looks like

# %%
data[12][0][0][0][3].shape
#for element in data[12][0][0][0][1][:,:,20].flat:
    #assert element == 0
# Out:
# (320, 320, 43)

# %%
for i in range(len(data)):
    print(data[i][0][0][0][0][:,:,3,1].shape)
    
len(data)
# Out:
# (34, 41)
# (80, 82)
# (82, 74)
# (89, 102)
# (66, 78)
# (69, 83)
# (50, 57)
# (55, 69)
# (64, 65)
# (99, 83)
# (107, 99)
# (320, 320)
# (320, 320)
# (320, 320)
# 14

# %%
#plot_image function to plot the image of different featrues
def plot_image(data,stuck,slices,features):
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    print(target_data.shape)
    target_image=target_data.reshape(target_data.shape[0],target_data.shape[1])
    plt.imshow(target_image,cmap = matplotlib.cm.binary)
    plt.axis("off") #close the axis number
    plt.show()

# %%
#plot the 5 images of features 
stuck,slices,features=1,10,0
plt.figure(figsize=(8,4))

plt.subplot(151)
plt.title("T2 weighted")
plot_image(data,stuck,slices,features)

plt.subplot(152)
plt.title("ADC")
plot_image(data,stuck,slices,features+1)

plt.subplot(153)
plt.title("Ktrans")
plot_image(data,stuck,slices,features+2)

plt.subplot(154)
plt.title("Kep")
plot_image(data,stuck,slices,features+3)

plt.subplot(155)
plt.title("PET")
plot_image(data,stuck,slices,features+4)
# Out:
# (80, 82)
# (80, 82)
# (80, 82)
# (80, 82)
# (80, 82)

# %% [markdown]
# then we try to find out the labels distribution

# %%
labelA=data[3][0][0][0][1]
labelA.shape
# Out:
# (89, 102, 85)

# %% [markdown]
# then we try to use a function to plot the prostate and cancer area on the feature image

# %%
cmap1 = matplotlib.colors.LinearSegmentedColormap.from_list('my_cmap',['black','red','blue'],256)
def plot_all(data,stuck,index,slices,features):
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image1=target_data.reshape(target_data.shape[0],target_data.shape[1])
    target_label=data[stuck][0][0][0][index][:,:,slices]
    target_image2=target_label.reshape(target_label.shape[0],target_label.shape[1])
    plt.imshow(target_image1,cmap = matplotlib.cm.binary,alpha=0.8)
    plt.imshow(target_image2,cmap = cmap1,interpolation="bilinear",alpha=0.2)
    plt.axis("off") #close the axis number
    plt.show()

# %%
#tuck: the index of patients
#slices: the slices of 3-D volumn image
#index : label A or label B or label historical
#features : one of five features
stuck,slices,index,features=1,40,1,0
#plot_image(data,stuck,slices,0)
#plot_label(data,stuck,2,slices)
plot_all(data,stuck,index,slices,features)

# %% [markdown]
# # 3. Exploring the features

# %% [markdown]
# ## 3.1 Extract prostate region

# %% [markdown]
# we can find that 1-11 strucks are expected by experts and 12-14 are histological analysis because it is more reliable than the experts,and later 1-11 strucks will be out training set and 12-14 will be out validation set

# %%
#extract prostate area from the original map 
experts_num,histo_num=11,3
label_final=[]
for i in range(experts_num):
    labelA=data[i][0][0][0][1]
    labelB=data[i][0][0][0][2]
    for index,(item_A,item_B) in enumerate(zip(labelA.flat,labelB.flat)):
        #use enumerate to iterate the items in labelA and labelB respectively
                if item_A == item_B:
                    pass
                else:
                    labelA.flat[index]=0
    label_final.append(labelA)

# %% [markdown]
# then append the histological struck

# %%
#for the 
for j in range(histo_num):
    labelC=data[j+11][0][0][0][3]
    label_final.append(labelC)

label=np.array(label_final)
label.shape
# Out:
# (14,)

# %% [markdown]
# then our task divided into two parts:
# - isolate the feature vector of prostate tissure from the whole set
# - try to transfer first feature TR wighted MR images

# %% [markdown]
# then let us create train data set and validation set respectively

# %%
train_data=data[:experts_num]
train_label=label[:experts_num]
val_data=data[:-experts_num]
val_label=label[:-experts_num]
val_label.shape
# Out:
# (3,)

# %%
train_isolated_feature=[]
train_isolated_label=[]
val_isolated_feature=[]
val_isolated_label=[]
def isolate_feature(data,label,isolated_feature,isolated_label):
    for i in range(len(data)):
        image=data[i][0][0][0][0]
        target_image=image.reshape(image.shape[0]*image.shape[1]*image.shape[2],image.shape[3])
        target_label=label[i].reshape(-1,1)
        for index,item in enumerate(target_label):
            if item == 0 :
                pass
            else:
                isolated_label.append(item)
                isolated_feature.append(target_image[index])
    return isolated_feature,isolated_label
        

isolate_feature(train_data,train_label,train_isolated_feature,train_isolated_label)
isolate_feature(val_data,val_label,val_isolated_feature,val_isolated_label)

print(len(train_isolated_feature))
# Out:
# 355455

# %% [markdown]
# 355455 is the number we extract

# %%
#save the extracted dataset
train_isolated_feature=pd.DataFrame(np.array(train_isolated_feature))
train_isolated_label=pd.DataFrame(np.array(train_isolated_label))
val_isolated_feature=pd.DataFrame(np.array(val_isolated_feature))
val_isolated_label=pd.DataFrame(np.array(val_isolated_label))
train_isolated_feature.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_feature.csv",index=False)
train_isolated_label.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_label.csv",index=False)
val_isolated_feature.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_feature.csv",index=False)
val_isolated_label.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_label.csv",index=False)
# Out:
# 355455

# %% [markdown]
# it means that prostate area has 355455 voxels

# %%
sum_d=0
for i in range(11):
    temp_data=data[i][0][0][0][0]
    temp_d=temp_data.reshape(temp_data.shape[0]*temp_data.shape[1]*temp_data.shape[2],temp_data.shape[3])
    sum_d +=temp_d.shape[0]
    
sum_d
# Out:
# 4696937

# %% [markdown]
# compared the 355455 with the total voxel is 4696937

# %% [markdown]
# ## 3.2 Normalization & Outliers detection

# %% [markdown]
# so we see we isolated the 355455 prostate features from the 4696937 the whole train set

# %% [markdown]
# then try to construct the whole pipeline of the features enginerring
# - Transform the first feature TR wighted
# - normalize all the features
# - Outlier detection and removal

# %%
#read data
X_train=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_feature.csv")
y_train=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_label.csv")
X_val=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_feature.csv")
y_val=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_label.csv")

# %%
#MinMaxScaler : rerange the value into (0,1)
scaler1=MinMaxScaler(feature_range=(0, 1), copy=True)
class Feature_scaling(BaseEstimator,TransformerMixin):
    def fit(self,X,y=None):
        scaler1.fit(X['0'])
        return self
    def transform(self,X,y=None):
        X['0']=scaler1.transform(X['0'])
        return X

# %%
#implement normalization : (X - mean)/sqrt(variance)
scaler2=StandardScaler()
class Normalization(BaseEstimator,TransformerMixin):
    def fit(self,X,y=None):
        scaler2.fit(X[["1","2","3","4"]])
        return self
    def transform(self,X,y=None):
        X[["1","2","3","4"]]=scaler2.transform(X[["1","2","3","4"]])
        return pd.DataFrame(X)

# %%
#build the pipeline
feature_eng=Pipeline([("feature_scale",Feature_scaling()),
                     ("normalization",Normalization())])

# %%
#fit and transform train set ( do not dit the test or val set)
feature_eng.fit_transform(X_train)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#                0         1         2         3         4
# 0       0.799095  0.912633 -0.144782 -1.213436  2.065894
# 1       0.790365  1.013452 -0.137170 -1.207106  2.118748
# 2       0.767685  0.602602 -0.177170 -1.120504  2.233095
# 3       0.752462  0.271475 -0.225923 -1.127930  2.153350
# 4       0.902552  1.153892 -0.190460 -1.184571  1.867942
# 5       0.889425  1.321699 -0.177952 -1.202120  0.839332
# 6       0.879032  1.427166 -0.167475 -1.234619  1.693697
# 7       0.867083  1.411221 -0.150459 -1.249641  2.451205
# 8       0.830395  1.338901 -0.174656 -1.248578  1.102973
# 9       0.843642  1.306003 -0.127406 -1.293149  1.065297
# 10      0.807913  1.299785 -0.143735 -1.315060  0.667758
# 11      0.817708  1.135524 -0.114216 -1.307761  2.532726
# 12      0.794877  1.176387 -0.120166 -1.306247  2.640368
# 13      0.791360  0.906219 -0.117251 -1.216726  1.827907
# 14      0.785500  0.983842 -0.117830 -1.210397  1.575812
# 15      0.779639  1.015804 -0.129757 -1.149728  1.356615
# 16      0.773779  1.079883 -0.134957 -1.136011  1.052395
# 17      0.758017  0.654923 -0.137179 -1.123794  1.348710
# 18      0.752157  0.697599 -0.144643 -1.078272  1.489419
# 19      0.748836  0.762977 -0.151218 -1.020049  1.661423
# 20      0.733981  0.423315 -0.171760 -1.117404  0.778433
# 21      0.728304  0.404326 -0.184714 -1.034148  0.623428
# 22      0.722627  0.433513 -0.195250 -1.042606  0.624032
# 23      0.714976  0.210240 -0.216054 -1.149177  0.439023
# 24      0.710207  0.137643 -0.228084 -1.140015  0.338649
# 25      0.717939 -0.016932 -0.262677 -1.227470  0.589286
# 26      0.867325  1.231372 -0.182882 -1.116324  1.607347
# 27      0.896334  1.150586 -0.176296 -1.159100  1.223118
# 28      0.865141  0.915555 -0.205729 -1.136489  1.156172
# 29      0.895834  1.076615 -0.168748 -1.166331  1.697747
# ...          ...       ...       ...       ...       ...
# 355425  0.490827 -0.520822 -0.245525 -0.235859  5.116633
# 355426  0.501335 -0.542918 -0.250985 -0.219739  4.359400
# 355427  0.567315 -0.657136 -0.289022 -0.214320  2.302540
# 355428  0.504929 -0.702062 -0.314519  0.019334  0.860796
# 355429  0.526109 -0.731429 -0.338207 -0.154733  0.399012
# 355430  0.543262 -0.711308 -0.345811 -0.346984  0.298987
# 355431  0.484305 -0.198227 -0.348701 -1.039174 -1.348825
# 355432  0.448872 -0.454647 -0.093148 -0.290127  3.957797
# 355433  0.459380 -0.469616 -0.132961 -0.324977  3.799644
# 355434  0.523964 -0.605086 -0.229720 -0.351556  2.788630
# 355435  0.544230 -0.669450 -0.281778 -0.180806  1.022741
# 355436  0.466871 -0.136977 -0.346080 -1.062168 -1.391314
# 355437  0.473544 -0.470627  0.041212 -0.510130  1.638553
# 355438  0.435550 -0.584469 -0.133742 -0.520747  1.369588
# 355439  0.456222 -0.132882 -0.337239 -1.056549 -1.491579
# 355440  0.419341 -0.393305  0.203149 -0.764787  0.780236
# 355441  0.420485 -0.132542 -0.345993 -0.955250 -1.259586
# 355442  0.414645 -0.027342 -0.342591 -0.985560 -1.630678
# 355443  0.412536  0.084233 -0.340610 -0.937677 -1.363358
# 355444  0.439288  0.087057 -0.340702 -0.899685 -1.284543
# 355445  0.504701 -0.374892 -0.341598 -0.580192 -0.723252
# 355446  0.500293  0.019597 -0.341463 -0.842129 -1.172381
# 355447  0.522927 -0.427461 -0.345638 -0.599071 -0.828799
# 355448  0.518046  0.021828 -0.340681 -0.742781 -1.357263
# 355449  0.539053 -0.646457 -0.350364 -0.203931  1.102965
# 355450  0.543362  0.053851 -0.340853 -0.725117 -1.610030
# 355451  0.563692 -0.570177 -0.343698 -0.263214  1.154239
# 355452  0.535343  0.053032 -0.344005 -0.794393 -1.416812
# 355453  0.569904 -0.524512 -0.339339 -0.320463  1.128367
# 355454  0.486973  0.422018 -0.324904 -0.700083 -1.631629
#
# [355455 rows x 5 columns]

# %% [markdown]
# now, we try to apply the outliers detection first try the chi-square distribution$$\chi^2=\sum\frac{(A-E)^2}{E}$$

# %%
#copy the mahalanobis dataset to test chi2 
MD1=np.array([1.01,0.70,0.30,0.38,1.15,
            2.64,1.71,0.71,0.86,0.80,0.69,0.87,
            0.68,1.72,1.76,2.37,1.22,0.20,
            1.86,2.27,0.83,0.42,0.26,1.05,
            2.91,1.59,1.58,0.40])
#the second column in the Table in article[13]
MD2=np.array([2.25,2.32,1.59,1.27,0.30,0.77,
             1.85,1.85,1.36,1.75,1.47,1.84,
             1.48,1.78,1.69,1.29,2.70,1.50,
             1.59,0.81,2.18])
chi2.fit(MD1,2)
np.sqrt(chi2.ppf(0.975,2))
# Out:
# 2.7162030314812387

# %% [markdown]
# the result is 2.7162030314812387 and the result in the article is 2.72 , they are almost the same

# %% [markdown]
# **there are two ways to approxiamte the MVE(minimum volume elliposid estimator)**
# - the resampling algorithm
# - the projection algorithm
#
# we can wirte three approxiamtion respectively,first calculate **mahalanbios distance** $$MD_i=\sqrt{(x_i-\mu)C^{-1}(x_i-\mu)^T}$$
# and after we get chi value of $MD$ we have can calculate $RD$(Robust distances) in the same equation but different approximation

# %%
#direct algorithm(with out robust estimation)
#calculate the mahalanbios distance
#create a normal distribution dataset temp1 to test the code
np.random.seed(42)
temp1=np.random.randn(100,5)*10
temp1=pd.DataFrame(temp1)
temp2=pd.DataFrame(np.ones((100,1)))

# %%
def mahalanbios_dis(temp1):
    return distance.cdist(temp1,np.array([temp1.mean()]),metric='mahalanobis',VI=np.mat(temp1.cov()).I).ravel()

mahalanbios_dis(temp1)
# Out:
# array([ 1.80735022,  1.86254961,  2.872682  ,  2.29450181,  2.2390532 ,
#         1.59138781,  2.37295093,  2.79690286,  1.59026438,  2.41650676,
#         1.46907549,  1.77813959,  1.98639564,  1.96365989,  3.31187249,
#         1.99171148,  1.95832329,  1.31774636,  1.34776911,  1.71213115,
#         2.05568064,  2.01467137,  3.13572134,  1.82485625,  2.62819218,
#         2.63798932,  2.16675694,  2.26821553,  2.23285737,  2.0381425 ,
#         0.89838039,  2.47782806,  2.18326474,  2.30075561,  1.46283758,
#         3.22362399,  1.52960256,  1.89878039,  1.74931974,  1.45466784,
#         2.09675996,  3.7054333 ,  1.76311086,  1.29792269,  3.53076835,
#         2.03537779,  2.2815249 ,  2.54599507,  1.80720101,  1.94389537,
#         3.28376942,  1.63353109,  3.54775133,  2.54641973,  2.60507386,
#         0.86830014,  3.01026638,  2.51168875,  1.14232669,  1.33970177,
#         1.6159812 ,  1.52461077,  1.87884294,  0.74474362,  2.4695653 ,
#         1.86782565,  1.65057969,  1.11566737,  1.32582489,  2.09906596,
#         1.75792667,  1.40916682,  1.90637382,  0.8685709 ,  2.67719557,
#         2.48694991,  2.49399796,  2.25979378,  2.55552617,  2.89464989,
#         2.10433075,  1.44681567,  2.41951   ,  1.87865797,  3.4907714 ,
#         2.68368808,  3.08047783,  2.95399884,  2.3483536 ,  1.66954554,
#         1.49716616,  1.87401432,  2.41455896,  1.36054398,  3.48510515,
#         3.27991486,  1.8724307 ,  2.60863119,  2.29342919,  1.93454227])

# %%
#implement outliers clean function according to the mahalanobis function
class outliers_clean_direct(BaseEstimator,TransformerMixin):
    def __init__(self,p_free,labels,md_dis=pd.Series([]),p_value=0.):
        self.md_dis=md_dis
        self.p_value=p_value
        self.p_free=p_free
        self.labels=labels
    def fit(self,X,y=None):
        mean_value=np.array([X.mean()])
        covar_value=np.mat(X.cov().as_matrix()).I  #calculate the inverse covariance 
        print("MD Start")
        self.md_dis=distance.cdist(X,mean_value,metric='mahalanobis',VI=covar_value).ravel()
        print("MD end")
        chi2.fit(self.md_dis,self.p_free)
        self.p_value=np.sqrt(chi2.ppf(0.975,self.p_free))#calculate chi-square distribution
        return self
    def transform(self,X,y=None): #should be changed to y_train
        count,count1,count2=0,0,0
        count1=X.shape[0]
        print("mahalanbios distance: ",self.md_dis)
        print("cutoff value: ",self.p_value)
        print("Drop Start")
        self.md_dis=pd.DataFrame(self.md_dis,columns=['maha_dis'])
        X=pd.concat([X,self.md_dis],axis=1)
        self.labels=pd.concat([self.labels,self.md_dis],axis=1)
        X=X[X['maha_dis']<=self.p_value]
        self.labels=self.labels[self.labels['maha_dis']<=self.p_value]
        X=pd.DataFrame.reset_index(X).drop('index',axis=1)
        self.labels=pd.DataFrame.reset_index(self.labels).drop('index',axis=1)
        count2=X.shape[0]
        count=count1-count2
        print("Drop End")
        print("drop count:",count)
        return X,self.labels,self.md_dis

# %%
#plot all the distances point and to figure out which points we should abandon
def plot_outliers(maha_dis,cdf1,cdf2,cdf3):
    x=range(len(maha_dis))
    plt.figure(figsize=(16,12))
    plt.scatter( x, maha_dis ,s=1)

    plt.hlines( np.sqrt(chi2.ppf(cdf1, 5)), 0, len(maha_dis), label ="%5f $\chi^2$ quantile"%(cdf1), linestyles = "solid" ) 
    plt.hlines( np.sqrt(chi2.ppf(cdf2, 5)), 0, len(maha_dis), label ="%5f $\chi^2$ quantile"%(cdf2), linestyles="dashed" ) 
    plt.hlines( np.sqrt(chi2.ppf(cdf3, 5)), 0, len(maha_dis), label ="%5f $\chi^2$ quantile"%(cdf3), linestyles = "dotted" )

    plt.legend()
    plt.ylabel("recorded value",fontsize=20)
    plt.xlabel("observation",fontsize=20)
    plt.title( 'Detection of outliers at different $\chi^2$ quantiles',fontsize=25 )

    plt.show()

# %%
#sample test
sample,labelset,maha_dis=outliers_clean_direct(p_free=5,labels=temp2).fit_transform(temp1)
# Out:
# MD Start
# MD end
# mahalanbios distance:  [ 1.80735022  1.86254961  2.872682    2.29450181  2.2390532   1.59138781
#   2.37295093  2.79690286  1.59026438  2.41650676  1.46907549  1.77813959
#   1.98639564  1.96365989  3.31187249  1.99171148  1.95832329  1.31774636
#   1.34776911  1.71213115  2.05568064  2.01467137  3.13572134  1.82485625
#   2.62819218  2.63798932  2.16675694  2.26821553  2.23285737  2.0381425
#   0.89838039  2.47782806  2.18326474  2.30075561  1.46283758  3.22362399
#   1.52960256  1.89878039  1.74931974  1.45466784  2.09675996  3.7054333
#   1.76311086  1.29792269  3.53076835  2.03537779  2.2815249   2.54599507
#   1.80720101  1.94389537  3.28376942  1.63353109  3.54775133  2.54641973
#   2.60507386  0.86830014  3.01026638  2.51168875  1.14232669  1.33970177
#   1.6159812   1.52461077  1.87884294  0.74474362  2.4695653   1.86782565
#   1.65057969  1.11566737  1.32582489  2.09906596  1.75792667  1.40916682
#   1.90637382  0.8685709   2.67719557  2.48694991  2.49399796  2.25979378
#   2.55552617  2.89464989  2.10433075  1.44681567  2.41951     1.87865797
#   3.4907714   2.68368808  3.08047783  2.95399884  2.3483536   1.66954554
#   1.49716616  1.87401432  2.41455896  1.36054398  3.48510515  3.27991486
#   1.8724307   2.60863119  2.29342919  1.93454227]
# cutoff value:  3.58224817594
# Drop Start
# Drop End
# drop count: 1

# %%
plot_outliers(maha_dis,0.95,0.975,0.99) #here recorded value is mahalanobis distance

# %% [markdown]
# Then we try to split the whole the dataset into 1000 subsets

# %%
#outliers clean rely on mahalanobis distances
X_train_scaled=feature_eng.fit_transform(X_train)
X_train_new,y_train_new,maha_dis=outliers_clean_direct(p_free=5,labels=y_train.copy()).fit_transform(X_train_scaled)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# MD Start
# MD end
# mahalanbios distance:  [ 3.3379388   3.37713725  3.03612973 ...,  1.8644143   1.26067642
#   2.14461159]
# cutoff value:  3.58224817594
# Drop Start
# Drop End
# drop count: 23139

# %%
plot_outliers(maha_dis,0.975,0.999,0.99999)

# %% [markdown]
# in the first approach , there are 23139 outliers has been droped, then we implement robust algorithm and see

# %%
#resampling algorithm
p_distr=0.975
n_subsamples=np.ceil(log((1-p_distr),1-(0.5)**6)).astype(int)
n_subsamples
# Out:
# 235

# %% [markdown]
# because the number of the subsample set $m$ satisfy $$1-(1-(1-0.5)^{p+1})^m\geq p_{distribution}$$ but this is a large number of groups and it will take a long time to calculate. Due to the paper we know the statistic order of the subset distance $m^2_{k+1}$ satisfly $$m^2_{k+1}\leq(\frac{V_k}{det(C_{k+1})})^{1/p}=M$$ so if $m^2_{k+1}$ exceed, then stop

# %%
class outliers_clean_resampling(BaseEstimator,TransformerMixin):
    def __init__(self,p_free,labels,md_dis=pd.Series([]),p_value_1=0.,p_value_2=0.,h_value=0):
        self.md_dis=md_dis
        self.p_value_1=p_value_1
        self.p_value_2=p_value_2
        self.p_free=p_free
        self.h_value=h_value
        self.labels=labels
    def fit(self,X,y=None):
        self.h_value=np.int((X.shape[0]+self.p_free+1)/2)
        mean_value=np.array([X.mean()])
        cov_value=np.mat(X.cov().as_matrix()).I
        print("MD Start")
        self.md_dis=distance.cdist(X,mean_value,metric='mahalanobis',VI=cov_value).ravel()
        print("MD end")
        chi2.fit(self.md_dis,self.p_free)
        self.p_value_1=np.sqrt(chi2.ppf(0.9999999999,self.p_free))
        self.p_value_2=np.sqrt(chi2.ppf(0.5,self.p_free))
        return self
    def transform(self,X,y=None):
        np.random.seed(30)
        mean_set,cov_set,m_dis_order,V_j=[],[],[],[]
        print("Resampling begin")
        start1=time.time()
        for subset in range(n_subsamples):
            if subset%50==0:
                print("replications number:%d time:%5.1f minute"%(subset,(time.time()-start1)/60))
            sample_ID=[]
            for index in range(self.p_free+1):
                sample_ID.append(np.random.choice(range(len(X)),replace=False))
            X_tr=np.array(X.iloc[sample_ID])
            sub_mean=np.array([(1/(self.p_free+1))*np.sum(X_tr,axis=0)])
            mean_set.append(sub_mean)
            sub_cov=np.mat((1/(self.p_free))*np.dot((X_tr-sub_mean).T,(X_tr-sub_mean))).I
            cov_set.append(sub_cov)
            m_dis=pd.Series((distance.cdist(X,sub_mean,metric='mahalanobis',VI=sub_cov)**2).ravel())\
            .sort_values(ascending=True).iloc[self.h_value] #ascending=True : from small to big
            #if subset != 0 :
                #if m_dis>=(V_j[subset-1]/sub_cov.I.det())**(1/self.p_free):
                    #break
                #else:
                    #pass
            m_dis_order.append(m_dis)
            V_j.append(m_dis*np.linalg.det(sub_cov))
        print("Resampling end")
        #print(m_dis_order[])
        J_index=pd.Series(V_j).sort_values(ascending=True).index.tolist()[0]
        m_dis_value=m_dis_order[J_index]
        robust_mean=mean_set[J_index]
        robust_cov=((1+15/(X.shape[0]-self.p_free))**2)*(1/self.p_value_2)*m_dis_value*cov_set[J_index]
        print("RD Start")
        robust_dis=distance.cdist(X,robust_mean,metric='mahalanobis',VI=robust_cov).ravel()
        print("RD end")
        print("Robust distance: ",robust_dis)
        print("Cutoff value: ",self.p_value_1)
        count,count1,count2=0,0,0
        count1=X.shape[0]
        print("Drop Start")
        robust_dis=pd.DataFrame(robust_dis,columns=['robust_dis'])
        X=pd.concat([X,robust_dis],axis=1)
        self.labels=pd.concat([self.labels,robust_dis],axis=1)
        X=X[X['robust_dis']<=self.p_value_1].copy()
        self.labels=self.labels[self.labels['robust_dis']<=self.p_value_1].copy()
        X=pd.DataFrame.reset_index(X).drop('index',axis=1)
        self.labels=pd.DataFrame.reset_index(self.labels).drop('index',axis=1)
        count2=X.shape[0]
        count=count1-count2
        print("Drop End")
        print("drop count:",count)
        return X,self.labels,robust_dis

# %%
#use test temp set for testing
sample,labelset,robust_dis=outliers_clean_resampling(p_free=5,labels=temp2).fit_transform(temp1)
# Out:
# MD Start
# MD end
# Resampling begin
# replications number:0 time:  0.0 minute
# replications number:50 time:  0.0 minute
# replications number:100 time:  0.0 minute
# replications number:150 time:  0.0 minute
# replications number:200 time:  0.0 minute
# Resampling end
# RD Start
# RD end
# Robust distance:  [  1.12497266e+16   4.34368836e+16   2.88415780e+16   1.63201632e+16
#    2.73450005e+16   8.81269053e+15   4.25962678e+16   2.26923447e+15
#    9.73649053e+15   3.76334970e+16   3.91100784e+16   5.09510621e+16
#    1.27138370e+16   1.40065272e+16   1.57852446e+16   1.65957052e+16
#    4.69438286e+16   3.13931026e+16   2.07133329e+08   4.45270569e+16
#    2.48906171e+16   1.90248060e+16   3.04781585e+16   4.53529966e+16
#               nan   7.95400081e+16   1.65545099e+16   5.65408743e+16
#    2.35699457e+16   7.17801193e+16   1.99401560e+16   5.73465861e+16
#    5.74861851e+16   4.52459495e+16   1.96749001e+15   4.75882527e+15
#    5.40586655e+16   3.12675525e+08   3.32443356e+16   1.56581713e+16
#    2.08345842e+16   1.49810310e+16   1.85335116e+16   3.42036941e+16
#    5.90376356e+16   4.86837078e+16   1.25242593e+16   4.43363773e+16
#    2.68041391e+16   2.80895691e+16   8.77522072e+16   7.18342284e+15
#    3.94268090e+16   2.54162726e+16   2.92483787e+16   2.09272666e+16
#    3.44682019e+16   5.66761601e+16   2.39432841e+16   2.60649787e+16
#    2.12552225e+16   2.07416554e+14   2.46154419e+16   3.19540779e+08
#    2.02958700e+16   5.38026031e+16   1.45453469e+16   1.71175565e+16
#    3.24580867e+16   5.27136377e+16   3.15824811e+16   1.84287517e+16
#    2.75601201e+08   1.49120564e+16   1.71073078e+16   2.37902658e+16
#    2.70749229e+16   3.52757281e+16   1.82464129e+16   5.56902400e+15
#    2.98064480e+16   3.96373033e+16   7.78574017e+16   3.39485037e+16
#    4.02699190e+16   3.27992051e+16   2.23763968e+16   3.54247852e+15
#    4.68504543e+16   2.30446665e+16   6.80556730e+15   4.24476878e+15
#    6.42170492e+16   3.47950178e+16   7.89946851e+16   6.69958160e+15
#    4.36928714e+16   1.52652093e+16   1.94457610e+16   2.14861872e+16]
# Cutoff value:  3.58224817594
# Drop Start
# Drop End
# drop count: 100

# %%
plot_outliers(robust_dis,0.95,0.975,0.99)

# %%
#set up the sample set number'm'
n_subsamples=253 
X_train_scaled=feature_eng.fit_transform(X_train)
X_train_new,y_train_new,robust_dis=outliers_clean_resampling(p_free=5,labels=y_train).fit_transform(X_train_scaled)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# MD Start
# MD end
# Resampling begin
# replications number:0 time:  0.0 minute
# replications number:50 time:  0.6 minute
# replications number:100 time:  1.2 minute
# replications number:150 time:  1.8 minute
# replications number:200 time:  2.3 minute
# replications number:250 time:  2.9 minute
# Resampling end
# RD Start
# RD end
# Robust distance:  [ 6.90672993  7.42642383  5.88375227 ...,  4.07629182  3.38806106
#   5.5977355 ]
# Cutoff value:  7.45401893905
# Drop Start
# Drop End
# drop count: 31944

# %%
n_subsamples=3000
X_train_scaled=feature_eng.fit_transform(X_train)
X_train_new,y_train_new,robust_dis=outliers_clean_resampling(p_free=5,labels=y_train).fit_transform(X_train_scaled)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# MD Start
# MD end
# Resampling begin
# replications number:0 time:  0.0 minute
# replications number:50 time:  0.7 minute
# replications number:100 time:  1.3 minute
# replications number:150 time:  2.0 minute
# replications number:200 time:  2.6 minute
# replications number:250 time:  3.3 minute
# replications number:300 time:  4.0 minute
# replications number:350 time:  4.6 minute
# replications number:400 time:  5.2 minute
# replications number:450 time:  5.9 minute
# replications number:500 time:  6.5 minute
# replications number:550 time:  7.1 minute
# replications number:600 time:  7.8 minute
# replications number:650 time:  8.4 minute
# replications number:700 time:  9.0 minute
# replications number:750 time:  9.7 minute
# replications number:800 time: 10.3 minute
# replications number:850 time: 10.9 minute
# replications number:900 time: 11.5 minute
# replications number:950 time: 12.2 minute
# replications number:1000 time: 12.8 minute
# replications number:1050 time: 13.5 minute
# replications number:1100 time: 14.1 minute
# replications number:1150 time: 14.7 minute
# replications number:1200 time: 15.4 minute
# replications number:1250 time: 16.0 minute
# replications number:1300 time: 16.7 minute
# replications number:1350 time: 17.3 minute
# replications number:1400 time: 18.0 minute
# replications number:1450 time: 18.7 minute
# replications number:1500 time: 19.3 minute
# replications number:1550 time: 20.0 minute
# replications number:1600 time: 20.6 minute
# replications number:1650 time: 21.2 minute
# replications number:1700 time: 21.9 minute
# replications number:1750 time: 22.6 minute
# replications number:1800 time: 23.2 minute
# replications number:1850 time: 23.9 minute
# replications number:1900 time: 24.5 minute
# replications number:1950 time: 25.1 minute
# replications number:2000 time: 25.8 minute
# replications number:2050 time: 26.4 minute
# replications number:2100 time: 27.1 minute
# replications number:2150 time: 27.7 minute
# replications number:2200 time: 28.4 minute
# replications number:2250 time: 29.0 minute
# replications number:2300 time: 29.7 minute
# replications number:2350 time: 30.3 minute
# replications number:2400 time: 30.9 minute
# replications number:2450 time: 31.6 minute
# replications number:2500 time: 32.2 minute
# replications number:2550 time: 32.9 minute
# replications number:2600 time: 33.6 minute
# replications number:2650 time: 34.2 minute
# replications number:2700 time: 34.8 minute
# replications number:2750 time: 35.5 minute
# replications number:2800 time: 36.1 minute
# replications number:2850 time: 36.7 minute
# replications number:2900 time: 37.4 minute
# replications number:2950 time: 38.0 minute
# Resampling end
# RD Start
# RD end
# Robust distance:  [ 9.48848885  9.56760344  7.6065512  ...,  3.43805825  2.14907531
#   3.62026395]
# Cutoff value:  3.58224817594
# Drop Start
# Drop End
# drop count: 171664

# %%
#CAUTION!! don't overwirte this again
robust_dis=pd.Series(robust_dis)
robust_dis.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\mahalanobis_distance.csv",index=False)

# %%
robust_dis=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\mahalanobis_distance.csv")
robust_dis=np.array(maha_dis)

# %%
plot_outliers(robust_dis,0.975,0.999,0.9999999) #with n_subsamples=3000

# %%
plot_outliers(robust_dis,0.975,0.999,0.9999999999) #with n_subsamples=253

# %% [markdown]
# **Tuning conclusion** :from the plot 1 and plot 2 we can figure out n_subsample or replications better remain low value

# %%
#save the result
X_train_new.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_resampling_X.csv",index=False)
y_train_new.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_resampling_y.csv",index=False)

# %%
#the projection algorithm

# %% [markdown]
# ## 3.3 Boundray selection

# %%
X_train=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_resampling_X.csv")
y_train=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_resampling_y.csv")

# %%
X_train=X_train.drop(['robust_dis'],axis=1)
y_train=y_train.drop(['robust_dis'],axis=1)
y_train=y_train.rename(columns={'0':'label'})

# %% [markdown]
# first to apply kmeans algorithm to divide dataset into clusters

# %%
#create a test dataset testing our kmeans
temp_X=pd.DataFrame(np.random.randn(100,5)*10)
temp_y=pd.DataFrame(np.append(np.ones((80,1)),np.ones((20,1))*2),columns=['label'])
#temp_train=pd.concat([temp_X,temp_y],axis=1)

# %%
#test on the Kmeans
kmeans=KMeans(n_clusters=np.int((temp_X.shape[0])/5),random_state=42)
kmeans.fit(temp_X)
kmeans.predict(temp_X)
y=pd.Series(kmeans.fit_predict(temp_X))
temp_train=pd.concat([temp_X,temp_y],axis=1)
temp1=temp_train[y==0]
temp=temp_train[y==0]['label']
if 1 and 2 in list(temp):
    print('yes')
else:
    temp_train=temp_train.drop(temp_train[y==0].index,axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8530235e3273> in <module>()
# ----> 1 kmeans=KMeans(n_clusters=np.int((temp_X.shape[0])/5),random_state=42)
#       2 kmeans.fit(temp_X)
#       3 kmeans.predict(temp_X)
#       4 y=pd.Series(kmeans.fit_predict(temp_X))
#       5 temp_train=pd.concat([temp_X,temp_y],axis=1)
#
# NameError: name 'KMeans' is not defined

# %%
#boundary detection
class boundary_detection(BaseEstimator,TransformerMixin):
    def __init__(self,labels,kmeans):
        self.labels=labels
        self.kmeans=kmeans
    def fit(self,X,y=None):
        start=time.time()
        print("fit start")
        self.kmeans.fit(X)
        print("fit end")
        print("fit time:%5.1fminute"%((time.time()-start)/60))
        return self
    def transform(self,X,y=None):
        dataset=pd.concat([X,self.labels],axis=1)
        count1=dataset.shape[0]
        y=pd.Series(self.kmeans.predict(X))
        print("drop start")
        for cluster in range(np.int((X.shape[0])/30)):
            if cluster%500==0:
                print("cluster number:",cluster)
            if 1 and 2 in list(dataset[y==cluster]['label']):
                pass
            else:
                dataset=dataset.drop(dataset[y==cluster].index,axis=0)
        dataset.append(pd.DataFrame(self.kmeans.cluster_centers_))#save all the centers of abandoned clusters
        print("drop end")
        count2=dataset.shape[0]
        print("Drop count:",count1-count2)        
        return dataset

# %%
#test on the Kmeans algorithm
train_set=boundary_detection(labels=temp_y,kmeans=KMeans(n_clusters=np.int((temp_X.shape[0])/5),random_state=42)).fit_transform(temp_X)
# Out:
# fit start
# fit end
# fit time:  0.0minute
# drop start
# cluster number: 0
# cluster number: 10
# drop end
# Drop count: 15
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#test on the minibatchKmeans algorithm
train_set=boundary_detection(labels=temp_y,kmeans=MiniBatchKMeans(n_clusters=np.int((temp_X.shape[0])/5),\
                                                                  init_size=3*np.int((temp_X.shape[0])/5),verbose=-1,\
                                                                  random_state=42)).fit_transform(temp_X)
# Out:
# fit start
# fit end
# fit time:  0.0minute
# drop start
# cluster number: 0
# cluster number: 10
# drop end
# Drop count: 28
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#apply the function with 30 samples in one cluster
train_set=boundary_detection(labels=y_train,kmeans=MiniBatchKMeans(n_clusters=np.int((X_train.shape[0])/30),n_init=1,max_iter=100,\
                                                                  init_size=3*np.int((X_train.shape[0])/30),verbose=-1,\
                                                                  random_state=42)).fit_transform(X_train)
# Out:
# fit start
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 312.127038
# Minibatch iteration 1/323600: mean batch inertia: 0.022546, ewa inertia: 0.022546
# Minibatch iteration 2/323600: mean batch inertia: 0.025333, ewa inertia: 0.022548
# Minibatch iteration 3/323600: mean batch inertia: 0.024398, ewa inertia: 0.022549
# Minibatch iteration 4/323600: mean batch inertia: 0.033320, ewa inertia: 0.022555
# Minibatch iteration 5/323600: mean batch inertia: 0.018913, ewa inertia: 0.022553
# Minibatch iteration 6/323600: mean batch inertia: 0.017381, ewa inertia: 0.022550
# Minibatch iteration 7/323600: mean batch inertia: 0.016957, ewa inertia: 0.022546
# Minibatch iteration 8/323600: mean batch inertia: 0.014410, ewa inertia: 0.022541
# Minibatch iteration 9/323600: mean batch inertia: 0.012869, ewa inertia: 0.022535
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/323600: mean batch inertia: 0.023291, ewa inertia: 0.022536
# Minibatch iteration 11/323600: mean batch inertia: 0.016879, ewa inertia: 0.022532
# Minibatch iteration 12/323600: mean batch inertia: 0.021256, ewa inertia: 0.022532
# Minibatch iteration 13/323600: mean batch inertia: 0.012856, ewa inertia: 0.022526
# Minibatch iteration 14/323600: mean batch inertia: 0.019546, ewa inertia: 0.022524
# Minibatch iteration 15/323600: mean batch inertia: 0.019868, ewa inertia: 0.022522
# Minibatch iteration 16/323600: mean batch inertia: 0.020420, ewa inertia: 0.022521
# Minibatch iteration 17/323600: mean batch inertia: 0.018977, ewa inertia: 0.022519
# Minibatch iteration 18/323600: mean batch inertia: 0.017918, ewa inertia: 0.022516
# Minibatch iteration 19/323600: mean batch inertia: 0.018723, ewa inertia: 0.022513
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 20/323600: mean batch inertia: 0.017754, ewa inertia: 0.022510
# Minibatch iteration 21/323600: mean batch inertia: 0.014831, ewa inertia: 0.022506
# Minibatch iteration 22/323600: mean batch inertia: 0.022165, ewa inertia: 0.022506
# Minibatch iteration 23/323600: mean batch inertia: 0.017111, ewa inertia: 0.022502
# Minibatch iteration 24/323600: mean batch inertia: 0.014864, ewa inertia: 0.022497
# Minibatch iteration 25/323600: mean batch inertia: 0.020151, ewa inertia: 0.022496
# Minibatch iteration 26/323600: mean batch inertia: 0.017604, ewa inertia: 0.022493
# Minibatch iteration 27/323600: mean batch inertia: 0.016198, ewa inertia: 0.022489
# Minibatch iteration 28/323600: mean batch inertia: 0.019277, ewa inertia: 0.022487
# Minibatch iteration 29/323600: mean batch inertia: 0.015441, ewa inertia: 0.022483
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 30/323600: mean batch inertia: 0.018232, ewa inertia: 0.022480
# Minibatch iteration 31/323600: mean batch inertia: 0.015792, ewa inertia: 0.022476
# Minibatch iteration 32/323600: mean batch inertia: 0.019429, ewa inertia: 0.022474
# Minibatch iteration 33/323600: mean batch inertia: 0.024170, ewa inertia: 0.022475
# Minibatch iteration 34/323600: mean batch inertia: 0.013013, ewa inertia: 0.022469
# Minibatch iteration 35/323600: mean batch inertia: 0.020292, ewa inertia: 0.022468
# Minibatch iteration 36/323600: mean batch inertia: 0.022499, ewa inertia: 0.022468
# Minibatch iteration 37/323600: mean batch inertia: 0.018923, ewa inertia: 0.022466
# Minibatch iteration 38/323600: mean batch inertia: 0.017966, ewa inertia: 0.022463
# Minibatch iteration 39/323600: mean batch inertia: 0.019882, ewa inertia: 0.022461
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 40/323600: mean batch inertia: 0.021598, ewa inertia: 0.022461
# Minibatch iteration 41/323600: mean batch inertia: 0.019085, ewa inertia: 0.022459
# Minibatch iteration 42/323600: mean batch inertia: 0.024047, ewa inertia: 0.022460
# Minibatch iteration 43/323600: mean batch inertia: 0.020788, ewa inertia: 0.022459
# Minibatch iteration 44/323600: mean batch inertia: 0.023683, ewa inertia: 0.022460
# Minibatch iteration 45/323600: mean batch inertia: 0.021154, ewa inertia: 0.022459
# Minibatch iteration 46/323600: mean batch inertia: 0.016869, ewa inertia: 0.022455
# Minibatch iteration 47/323600: mean batch inertia: 0.016125, ewa inertia: 0.022451
# Minibatch iteration 48/323600: mean batch inertia: 0.025208, ewa inertia: 0.022453
# Minibatch iteration 49/323600: mean batch inertia: 0.015795, ewa inertia: 0.022449
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 50/323600: mean batch inertia: 0.014089, ewa inertia: 0.022444
# Minibatch iteration 51/323600: mean batch inertia: 0.018515, ewa inertia: 0.022441
# Minibatch iteration 52/323600: mean batch inertia: 0.019938, ewa inertia: 0.022440
# Minibatch iteration 53/323600: mean batch inertia: 0.015662, ewa inertia: 0.022436
# Minibatch iteration 54/323600: mean batch inertia: 0.016866, ewa inertia: 0.022432
# Minibatch iteration 55/323600: mean batch inertia: 0.020318, ewa inertia: 0.022431
# Minibatch iteration 56/323600: mean batch inertia: 0.022927, ewa inertia: 0.022431
# Minibatch iteration 57/323600: mean batch inertia: 0.017773, ewa inertia: 0.022428
# Minibatch iteration 58/323600: mean batch inertia: 0.020723, ewa inertia: 0.022427
# Minibatch iteration 59/323600: mean batch inertia: 0.017382, ewa inertia: 0.022424
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 60/323600: mean batch inertia: 0.017049, ewa inertia: 0.022421
# Minibatch iteration 61/323600: mean batch inertia: 0.016976, ewa inertia: 0.022417
# Minibatch iteration 62/323600: mean batch inertia: 0.021227, ewa inertia: 0.022417
# Minibatch iteration 63/323600: mean batch inertia: 0.017969, ewa inertia: 0.022414
# Minibatch iteration 64/323600: mean batch inertia: 0.016784, ewa inertia: 0.022410
# Minibatch iteration 65/323600: mean batch inertia: 0.017210, ewa inertia: 0.022407
# Minibatch iteration 66/323600: mean batch inertia: 0.015965, ewa inertia: 0.022403
# Minibatch iteration 67/323600: mean batch inertia: 0.021866, ewa inertia: 0.022403
# Minibatch iteration 68/323600: mean batch inertia: 0.017592, ewa inertia: 0.022400
# Minibatch iteration 69/323600: mean batch inertia: 0.016933, ewa inertia: 0.022397
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 70/323600: mean batch inertia: 0.015223, ewa inertia: 0.022392
# Minibatch iteration 71/323600: mean batch inertia: 0.018166, ewa inertia: 0.022390
# Minibatch iteration 72/323600: mean batch inertia: 0.019759, ewa inertia: 0.022388
# Minibatch iteration 73/323600: mean batch inertia: 0.016583, ewa inertia: 0.022384
# Minibatch iteration 74/323600: mean batch inertia: 0.021271, ewa inertia: 0.022384
# Minibatch iteration 75/323600: mean batch inertia: 0.017931, ewa inertia: 0.022381
# Minibatch iteration 76/323600: mean batch inertia: 0.020357, ewa inertia: 0.022380
# Minibatch iteration 77/323600: mean batch inertia: 0.015399, ewa inertia: 0.022375
# Minibatch iteration 78/323600: mean batch inertia: 0.016170, ewa inertia: 0.022371
# Minibatch iteration 79/323600: mean batch inertia: 0.018345, ewa inertia: 0.022369
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 80/323600: mean batch inertia: 0.014015, ewa inertia: 0.022364
# Minibatch iteration 81/323600: mean batch inertia: 0.019860, ewa inertia: 0.022362
# Minibatch iteration 82/323600: mean batch inertia: 0.017391, ewa inertia: 0.022359
# Minibatch iteration 83/323600: mean batch inertia: 0.016505, ewa inertia: 0.022356
# Minibatch iteration 84/323600: mean batch inertia: 0.014829, ewa inertia: 0.022351
# Minibatch iteration 85/323600: mean batch inertia: 0.018189, ewa inertia: 0.022348
# Minibatch iteration 86/323600: mean batch inertia: 0.018867, ewa inertia: 0.022346
# Minibatch iteration 87/323600: mean batch inertia: 0.023301, ewa inertia: 0.022347
# Minibatch iteration 88/323600: mean batch inertia: 0.021090, ewa inertia: 0.022346
# Minibatch iteration 89/323600: mean batch inertia: 0.022139, ewa inertia: 0.022346
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 90/323600: mean batch inertia: 0.020933, ewa inertia: 0.022345
# Minibatch iteration 91/323600: mean batch inertia: 0.026557, ewa inertia: 0.022348
# Minibatch iteration 92/323600: mean batch inertia: 0.015283, ewa inertia: 0.022343
# Minibatch iteration 93/323600: mean batch inertia: 0.014873, ewa inertia: 0.022339
# Minibatch iteration 94/323600: mean batch inertia: 0.016212, ewa inertia: 0.022335
# Minibatch iteration 95/323600: mean batch inertia: 0.014435, ewa inertia: 0.022330
# Minibatch iteration 96/323600: mean batch inertia: 0.014747, ewa inertia: 0.022325
# Minibatch iteration 97/323600: mean batch inertia: 0.018221, ewa inertia: 0.022323
# Minibatch iteration 98/323600: mean batch inertia: 0.014879, ewa inertia: 0.022318
# Minibatch iteration 99/323600: mean batch inertia: 0.017275, ewa inertia: 0.022315
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 100/323600: mean batch inertia: 0.016735, ewa inertia: 0.022312
# Minibatch iteration 101/323600: mean batch inertia: 0.019104, ewa inertia: 0.022310
# Minibatch iteration 102/323600: mean batch inertia: 0.019610, ewa inertia: 0.022308
# Minibatch iteration 103/323600: mean batch inertia: 0.017394, ewa inertia: 0.022305
# Minibatch iteration 104/323600: mean batch inertia: 0.018826, ewa inertia: 0.022303
# Minibatch iteration 105/323600: mean batch inertia: 0.013539, ewa inertia: 0.022297
# Minibatch iteration 106/323600: mean batch inertia: 0.014778, ewa inertia: 0.022293
# Minibatch iteration 107/323600: mean batch inertia: 0.015098, ewa inertia: 0.022288
# Minibatch iteration 108/323600: mean batch inertia: 0.021196, ewa inertia: 0.022288
# Minibatch iteration 109/323600: mean batch inertia: 0.026548, ewa inertia: 0.022290
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 110/323600: mean batch inertia: 0.022439, ewa inertia: 0.022290
# Minibatch iteration 111/323600: mean batch inertia: 0.014886, ewa inertia: 0.022286
# Minibatch iteration 112/323600: mean batch inertia: 0.022265, ewa inertia: 0.022286
# Minibatch iteration 113/323600: mean batch inertia: 0.016841, ewa inertia: 0.022282
# Minibatch iteration 114/323600: mean batch inertia: 0.018545, ewa inertia: 0.022280
# Minibatch iteration 115/323600: mean batch inertia: 0.022095, ewa inertia: 0.022280
# Minibatch iteration 116/323600: mean batch inertia: 0.017145, ewa inertia: 0.022277
# Minibatch iteration 117/323600: mean batch inertia: 0.015059, ewa inertia: 0.022272
# Minibatch iteration 118/323600: mean batch inertia: 0.018479, ewa inertia: 0.022270
# Minibatch iteration 119/323600: mean batch inertia: 0.016477, ewa inertia: 0.022266
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 120/323600: mean batch inertia: 0.017246, ewa inertia: 0.022263
# Minibatch iteration 121/323600: mean batch inertia: 0.018736, ewa inertia: 0.022261
# Minibatch iteration 122/323600: mean batch inertia: 0.014075, ewa inertia: 0.022256
# Minibatch iteration 123/323600: mean batch inertia: 0.017412, ewa inertia: 0.022253
# Minibatch iteration 124/323600: mean batch inertia: 0.014775, ewa inertia: 0.022248
# Minibatch iteration 125/323600: mean batch inertia: 0.020371, ewa inertia: 0.022247
# Minibatch iteration 126/323600: mean batch inertia: 0.013405, ewa inertia: 0.022242
# Minibatch iteration 127/323600: mean batch inertia: 0.018607, ewa inertia: 0.022239
# Minibatch iteration 128/323600: mean batch inertia: 0.014624, ewa inertia: 0.022235
# Minibatch iteration 129/323600: mean batch inertia: 0.016799, ewa inertia: 0.022231
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 130/323600: mean batch inertia: 0.019161, ewa inertia: 0.022229
# Minibatch iteration 131/323600: mean batch inertia: 0.020439, ewa inertia: 0.022228
# Minibatch iteration 132/323600: mean batch inertia: 0.015900, ewa inertia: 0.022224
# Minibatch iteration 133/323600: mean batch inertia: 0.016414, ewa inertia: 0.022221
# Minibatch iteration 134/323600: mean batch inertia: 0.013779, ewa inertia: 0.022216
# Minibatch iteration 135/323600: mean batch inertia: 0.017338, ewa inertia: 0.022213
# Minibatch iteration 136/323600: mean batch inertia: 0.013286, ewa inertia: 0.022207
# Minibatch iteration 137/323600: mean batch inertia: 0.015918, ewa inertia: 0.022203
# Minibatch iteration 138/323600: mean batch inertia: 0.017150, ewa inertia: 0.022200
# Minibatch iteration 139/323600: mean batch inertia: 0.021831, ewa inertia: 0.022200
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 140/323600: mean batch inertia: 0.014393, ewa inertia: 0.022195
# Minibatch iteration 141/323600: mean batch inertia: 0.018251, ewa inertia: 0.022193
# Minibatch iteration 142/323600: mean batch inertia: 0.020550, ewa inertia: 0.022192
# Minibatch iteration 143/323600: mean batch inertia: 0.018010, ewa inertia: 0.022189
# Minibatch iteration 144/323600: mean batch inertia: 0.019705, ewa inertia: 0.022187
# Minibatch iteration 145/323600: mean batch inertia: 0.018819, ewa inertia: 0.022185
# Minibatch iteration 146/323600: mean batch inertia: 0.018468, ewa inertia: 0.022183
# Minibatch iteration 147/323600: mean batch inertia: 0.014247, ewa inertia: 0.022178
# Minibatch iteration 148/323600: mean batch inertia: 0.019535, ewa inertia: 0.022177
# Minibatch iteration 149/323600: mean batch inertia: 0.015802, ewa inertia: 0.022173
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 150/323600: mean batch inertia: 0.017521, ewa inertia: 0.022170
# Minibatch iteration 151/323600: mean batch inertia: 0.018317, ewa inertia: 0.022167
# Minibatch iteration 152/323600: mean batch inertia: 0.017332, ewa inertia: 0.022164
# Minibatch iteration 153/323600: mean batch inertia: 0.019400, ewa inertia: 0.022163
# Minibatch iteration 154/323600: mean batch inertia: 0.019380, ewa inertia: 0.022161
# Minibatch iteration 155/323600: mean batch inertia: 0.018656, ewa inertia: 0.022159
# Minibatch iteration 156/323600: mean batch inertia: 0.017527, ewa inertia: 0.022156
# Minibatch iteration 157/323600: mean batch inertia: 0.017766, ewa inertia: 0.022153
# Minibatch iteration 158/323600: mean batch inertia: 0.015452, ewa inertia: 0.022149
# Minibatch iteration 159/323600: mean batch inertia: 0.012470, ewa inertia: 0.022143
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 160/323600: mean batch inertia: 0.017729, ewa inertia: 0.022140
# Minibatch iteration 161/323600: mean batch inertia: 0.014188, ewa inertia: 0.022135
# Minibatch iteration 162/323600: mean batch inertia: 0.014570, ewa inertia: 0.022131
# Minibatch iteration 163/323600: mean batch inertia: 0.023826, ewa inertia: 0.022132
# Minibatch iteration 164/323600: mean batch inertia: 0.021549, ewa inertia: 0.022131
# Minibatch iteration 165/323600: mean batch inertia: 0.017229, ewa inertia: 0.022128
# Minibatch iteration 166/323600: mean batch inertia: 0.018564, ewa inertia: 0.022126
# Minibatch iteration 167/323600: mean batch inertia: 0.017933, ewa inertia: 0.022124
# Minibatch iteration 168/323600: mean batch inertia: 0.014103, ewa inertia: 0.022119
# Minibatch iteration 169/323600: mean batch inertia: 0.017756, ewa inertia: 0.022116
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 170/323600: mean batch inertia: 0.013756, ewa inertia: 0.022111
# Minibatch iteration 171/323600: mean batch inertia: 0.020871, ewa inertia: 0.022110
# Minibatch iteration 172/323600: mean batch inertia: 0.023859, ewa inertia: 0.022111
# Minibatch iteration 173/323600: mean batch inertia: 0.021012, ewa inertia: 0.022110
# Minibatch iteration 174/323600: mean batch inertia: 0.016993, ewa inertia: 0.022107
# Minibatch iteration 175/323600: mean batch inertia: 0.020887, ewa inertia: 0.022107
# Minibatch iteration 176/323600: mean batch inertia: 0.014312, ewa inertia: 0.022102
# Minibatch iteration 177/323600: mean batch inertia: 0.015958, ewa inertia: 0.022098
# Minibatch iteration 178/323600: mean batch inertia: 0.025759, ewa inertia: 0.022100
# Minibatch iteration 179/323600: mean batch inertia: 0.019629, ewa inertia: 0.022099
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 180/323600: mean batch inertia: 0.018099, ewa inertia: 0.022096
# Minibatch iteration 181/323600: mean batch inertia: 0.017787, ewa inertia: 0.022093
# Minibatch iteration 182/323600: mean batch inertia: 0.020091, ewa inertia: 0.022092
# Minibatch iteration 183/323600: mean batch inertia: 0.014559, ewa inertia: 0.022088
# Minibatch iteration 184/323600: mean batch inertia: 0.017354, ewa inertia: 0.022085
# Minibatch iteration 185/323600: mean batch inertia: 0.016756, ewa inertia: 0.022081
# Minibatch iteration 186/323600: mean batch inertia: 0.020710, ewa inertia: 0.022081
# Minibatch iteration 187/323600: mean batch inertia: 0.016218, ewa inertia: 0.022077
# Minibatch iteration 188/323600: mean batch inertia: 0.016692, ewa inertia: 0.022074
# Minibatch iteration 189/323600: mean batch inertia: 0.015616, ewa inertia: 0.022070
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 190/323600: mean batch inertia: 0.021197, ewa inertia: 0.022069
# Minibatch iteration 191/323600: mean batch inertia: 0.016957, ewa inertia: 0.022066
# Minibatch iteration 192/323600: mean batch inertia: 0.015143, ewa inertia: 0.022062
# Minibatch iteration 193/323600: mean batch inertia: 0.016970, ewa inertia: 0.022058
# Minibatch iteration 194/323600: mean batch inertia: 0.022009, ewa inertia: 0.022058
# Minibatch iteration 195/323600: mean batch inertia: 0.016976, ewa inertia: 0.022055
# Minibatch iteration 196/323600: mean batch inertia: 0.017825, ewa inertia: 0.022053
# Minibatch iteration 197/323600: mean batch inertia: 0.017422, ewa inertia: 0.022050
# Minibatch iteration 198/323600: mean batch inertia: 0.015612, ewa inertia: 0.022046
# Minibatch iteration 199/323600: mean batch inertia: 0.015547, ewa inertia: 0.022042
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 200/323600: mean batch inertia: 0.016672, ewa inertia: 0.022038
# Minibatch iteration 201/323600: mean batch inertia: 0.014193, ewa inertia: 0.022034
# Minibatch iteration 202/323600: mean batch inertia: 0.020106, ewa inertia: 0.022032
# Minibatch iteration 203/323600: mean batch inertia: 0.017534, ewa inertia: 0.022030
# Minibatch iteration 204/323600: mean batch inertia: 0.017989, ewa inertia: 0.022027
# Minibatch iteration 205/323600: mean batch inertia: 0.021935, ewa inertia: 0.022027
# Minibatch iteration 206/323600: mean batch inertia: 0.018102, ewa inertia: 0.022025
# Minibatch iteration 207/323600: mean batch inertia: 0.027578, ewa inertia: 0.022028
# Minibatch iteration 208/323600: mean batch inertia: 0.014516, ewa inertia: 0.022023
# Minibatch iteration 209/323600: mean batch inertia: 0.014868, ewa inertia: 0.022019
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 210/323600: mean batch inertia: 0.019149, ewa inertia: 0.022017
# Minibatch iteration 211/323600: mean batch inertia: 0.019866, ewa inertia: 0.022016
# Minibatch iteration 212/323600: mean batch inertia: 0.017423, ewa inertia: 0.022013
# Minibatch iteration 213/323600: mean batch inertia: 0.013363, ewa inertia: 0.022008
# Minibatch iteration 214/323600: mean batch inertia: 0.013098, ewa inertia: 0.022002
# Minibatch iteration 215/323600: mean batch inertia: 0.017566, ewa inertia: 0.021999
# Minibatch iteration 216/323600: mean batch inertia: 0.015890, ewa inertia: 0.021996
# Minibatch iteration 217/323600: mean batch inertia: 0.019022, ewa inertia: 0.021994
# Minibatch iteration 218/323600: mean batch inertia: 0.018195, ewa inertia: 0.021992
# Minibatch iteration 219/323600: mean batch inertia: 0.019422, ewa inertia: 0.021990
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 220/323600: mean batch inertia: 0.018067, ewa inertia: 0.021988
# Minibatch iteration 221/323600: mean batch inertia: 0.015928, ewa inertia: 0.021984
# Minibatch iteration 222/323600: mean batch inertia: 0.015368, ewa inertia: 0.021980
# Minibatch iteration 223/323600: mean batch inertia: 0.023073, ewa inertia: 0.021980
# Minibatch iteration 224/323600: mean batch inertia: 0.013700, ewa inertia: 0.021975
# Minibatch iteration 225/323600: mean batch inertia: 0.019371, ewa inertia: 0.021974
# Minibatch iteration 226/323600: mean batch inertia: 0.014634, ewa inertia: 0.021969
# Minibatch iteration 227/323600: mean batch inertia: 0.015739, ewa inertia: 0.021965
# Minibatch iteration 228/323600: mean batch inertia: 0.016764, ewa inertia: 0.021962
# Minibatch iteration 229/323600: mean batch inertia: 0.019809, ewa inertia: 0.021961
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 230/323600: mean batch inertia: 0.020111, ewa inertia: 0.021960
# Minibatch iteration 231/323600: mean batch inertia: 0.019341, ewa inertia: 0.021958
# Minibatch iteration 232/323600: mean batch inertia: 0.014448, ewa inertia: 0.021953
# Minibatch iteration 233/323600: mean batch inertia: 0.016927, ewa inertia: 0.021950
# Minibatch iteration 234/323600: mean batch inertia: 0.017169, ewa inertia: 0.021947
# Minibatch iteration 235/323600: mean batch inertia: 0.015846, ewa inertia: 0.021943
# Minibatch iteration 236/323600: mean batch inertia: 0.017857, ewa inertia: 0.021941
# Minibatch iteration 237/323600: mean batch inertia: 0.012240, ewa inertia: 0.021935
# Minibatch iteration 238/323600: mean batch inertia: 0.016058, ewa inertia: 0.021931
# Minibatch iteration 239/323600: mean batch inertia: 0.015026, ewa inertia: 0.021927
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 240/323600: mean batch inertia: 0.022504, ewa inertia: 0.021927
# Minibatch iteration 241/323600: mean batch inertia: 0.029059, ewa inertia: 0.021932
# Minibatch iteration 242/323600: mean batch inertia: 0.021298, ewa inertia: 0.021931
# Minibatch iteration 243/323600: mean batch inertia: 0.022154, ewa inertia: 0.021932
# Minibatch iteration 244/323600: mean batch inertia: 0.013854, ewa inertia: 0.021927
# Minibatch iteration 245/323600: mean batch inertia: 0.020276, ewa inertia: 0.021926
# Minibatch iteration 246/323600: mean batch inertia: 0.028058, ewa inertia: 0.021929
# Minibatch iteration 247/323600: mean batch inertia: 0.016376, ewa inertia: 0.021926
# Minibatch iteration 248/323600: mean batch inertia: 0.019416, ewa inertia: 0.021924
# Minibatch iteration 249/323600: mean batch inertia: 0.017169, ewa inertia: 0.021921
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 250/323600: mean batch inertia: 0.016391, ewa inertia: 0.021918
# Minibatch iteration 251/323600: mean batch inertia: 0.022223, ewa inertia: 0.021918
# Minibatch iteration 252/323600: mean batch inertia: 0.026072, ewa inertia: 0.021921
# Minibatch iteration 253/323600: mean batch inertia: 0.016256, ewa inertia: 0.021917
# Minibatch iteration 254/323600: mean batch inertia: 0.014867, ewa inertia: 0.021913
# Minibatch iteration 255/323600: mean batch inertia: 0.020018, ewa inertia: 0.021912
# Minibatch iteration 256/323600: mean batch inertia: 0.018619, ewa inertia: 0.021910
# Minibatch iteration 257/323600: mean batch inertia: 0.021466, ewa inertia: 0.021909
# Minibatch iteration 258/323600: mean batch inertia: 0.013615, ewa inertia: 0.021904
# Minibatch iteration 259/323600: mean batch inertia: 0.021857, ewa inertia: 0.021904
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 260/323600: mean batch inertia: 0.014882, ewa inertia: 0.021900
# Minibatch iteration 261/323600: mean batch inertia: 0.017087, ewa inertia: 0.021897
# Minibatch iteration 262/323600: mean batch inertia: 0.015377, ewa inertia: 0.021893
# Minibatch iteration 263/323600: mean batch inertia: 0.016531, ewa inertia: 0.021890
# Minibatch iteration 264/323600: mean batch inertia: 0.019536, ewa inertia: 0.021888
# Minibatch iteration 265/323600: mean batch inertia: 0.018058, ewa inertia: 0.021886
# Minibatch iteration 266/323600: mean batch inertia: 0.022458, ewa inertia: 0.021886
# Minibatch iteration 267/323600: mean batch inertia: 0.017799, ewa inertia: 0.021884
# Minibatch iteration 268/323600: mean batch inertia: 0.016721, ewa inertia: 0.021880
# Minibatch iteration 269/323600: mean batch inertia: 0.019844, ewa inertia: 0.021879
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 270/323600: mean batch inertia: 0.029142, ewa inertia: 0.021884
# Minibatch iteration 271/323600: mean batch inertia: 0.015139, ewa inertia: 0.021879
# Minibatch iteration 272/323600: mean batch inertia: 0.014225, ewa inertia: 0.021875
# Minibatch iteration 273/323600: mean batch inertia: 0.018530, ewa inertia: 0.021873
# Minibatch iteration 274/323600: mean batch inertia: 0.017669, ewa inertia: 0.021870
# Minibatch iteration 275/323600: mean batch inertia: 0.018075, ewa inertia: 0.021868
# Minibatch iteration 276/323600: mean batch inertia: 0.018339, ewa inertia: 0.021866
# Minibatch iteration 277/323600: mean batch inertia: 0.017789, ewa inertia: 0.021863
# Minibatch iteration 278/323600: mean batch inertia: 0.018113, ewa inertia: 0.021861
# Minibatch iteration 279/323600: mean batch inertia: 0.016389, ewa inertia: 0.021857
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 280/323600: mean batch inertia: 0.015490, ewa inertia: 0.021853
# Minibatch iteration 281/323600: mean batch inertia: 0.018213, ewa inertia: 0.021851
# Minibatch iteration 282/323600: mean batch inertia: 0.017956, ewa inertia: 0.021849
# Minibatch iteration 283/323600: mean batch inertia: 0.015180, ewa inertia: 0.021845
# Minibatch iteration 284/323600: mean batch inertia: 0.013397, ewa inertia: 0.021839
# Minibatch iteration 285/323600: mean batch inertia: 0.018142, ewa inertia: 0.021837
# Minibatch iteration 286/323600: mean batch inertia: 0.015621, ewa inertia: 0.021833
# Minibatch iteration 287/323600: mean batch inertia: 0.019715, ewa inertia: 0.021832
# Minibatch iteration 288/323600: mean batch inertia: 0.016688, ewa inertia: 0.021829
# Minibatch iteration 289/323600: mean batch inertia: 0.019353, ewa inertia: 0.021827
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 290/323600: mean batch inertia: 0.014818, ewa inertia: 0.021823
# Minibatch iteration 291/323600: mean batch inertia: 0.021078, ewa inertia: 0.021822
# Minibatch iteration 292/323600: mean batch inertia: 0.015932, ewa inertia: 0.021819
# Minibatch iteration 293/323600: mean batch inertia: 0.015263, ewa inertia: 0.021815
# Minibatch iteration 294/323600: mean batch inertia: 0.018343, ewa inertia: 0.021813
# Minibatch iteration 295/323600: mean batch inertia: 0.020518, ewa inertia: 0.021812
# Minibatch iteration 296/323600: mean batch inertia: 0.014053, ewa inertia: 0.021807
# Minibatch iteration 297/323600: mean batch inertia: 0.012968, ewa inertia: 0.021802
# Minibatch iteration 298/323600: mean batch inertia: 0.016398, ewa inertia: 0.021798
# Minibatch iteration 299/323600: mean batch inertia: 0.016125, ewa inertia: 0.021795
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 300/323600: mean batch inertia: 0.019195, ewa inertia: 0.021793
# Minibatch iteration 301/323600: mean batch inertia: 0.015995, ewa inertia: 0.021789
# Minibatch iteration 302/323600: mean batch inertia: 0.018829, ewa inertia: 0.021788
# Minibatch iteration 303/323600: mean batch inertia: 0.021615, ewa inertia: 0.021788
# Minibatch iteration 304/323600: mean batch inertia: 0.017078, ewa inertia: 0.021785
# Minibatch iteration 305/323600: mean batch inertia: 0.016500, ewa inertia: 0.021781
# Minibatch iteration 306/323600: mean batch inertia: 0.019645, ewa inertia: 0.021780
# Minibatch iteration 307/323600: mean batch inertia: 0.017140, ewa inertia: 0.021777
# Minibatch iteration 308/323600: mean batch inertia: 0.018894, ewa inertia: 0.021775
# Minibatch iteration 309/323600: mean batch inertia: 0.019989, ewa inertia: 0.021774
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 310/323600: mean batch inertia: 0.018033, ewa inertia: 0.021772
# Minibatch iteration 311/323600: mean batch inertia: 0.021025, ewa inertia: 0.021772
# Minibatch iteration 312/323600: mean batch inertia: 0.015056, ewa inertia: 0.021767
# Minibatch iteration 313/323600: mean batch inertia: 0.016451, ewa inertia: 0.021764
# Minibatch iteration 314/323600: mean batch inertia: 0.020590, ewa inertia: 0.021763
# Minibatch iteration 315/323600: mean batch inertia: 0.017133, ewa inertia: 0.021760
# Minibatch iteration 316/323600: mean batch inertia: 0.017349, ewa inertia: 0.021758
# Minibatch iteration 317/323600: mean batch inertia: 0.018360, ewa inertia: 0.021756
# Minibatch iteration 318/323600: mean batch inertia: 0.017412, ewa inertia: 0.021753
# Minibatch iteration 319/323600: mean batch inertia: 0.026910, ewa inertia: 0.021756
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 320/323600: mean batch inertia: 0.016535, ewa inertia: 0.021753
# Minibatch iteration 321/323600: mean batch inertia: 0.021479, ewa inertia: 0.021753
# Minibatch iteration 322/323600: mean batch inertia: 0.016084, ewa inertia: 0.021749
# Minibatch iteration 323/323600: mean batch inertia: 0.015866, ewa inertia: 0.021746
# Minibatch iteration 324/323600: mean batch inertia: 0.015927, ewa inertia: 0.021742
# Minibatch iteration 325/323600: mean batch inertia: 0.016434, ewa inertia: 0.021739
# Minibatch iteration 326/323600: mean batch inertia: 0.012734, ewa inertia: 0.021733
# Minibatch iteration 327/323600: mean batch inertia: 0.019128, ewa inertia: 0.021732
# Minibatch iteration 328/323600: mean batch inertia: 0.014805, ewa inertia: 0.021727
# Minibatch iteration 329/323600: mean batch inertia: 0.014575, ewa inertia: 0.021723
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 330/323600: mean batch inertia: 0.015661, ewa inertia: 0.021719
# Minibatch iteration 331/323600: mean batch inertia: 0.017287, ewa inertia: 0.021716
# Minibatch iteration 332/323600: mean batch inertia: 0.017586, ewa inertia: 0.021714
# Minibatch iteration 333/323600: mean batch inertia: 0.020889, ewa inertia: 0.021713
# Minibatch iteration 334/323600: mean batch inertia: 0.017921, ewa inertia: 0.021711
# Minibatch iteration 335/323600: mean batch inertia: 0.016404, ewa inertia: 0.021708
# Minibatch iteration 336/323600: mean batch inertia: 0.014369, ewa inertia: 0.021703
# Minibatch iteration 337/323600: mean batch inertia: 0.013774, ewa inertia: 0.021698
# Minibatch iteration 338/323600: mean batch inertia: 0.021212, ewa inertia: 0.021698
# Minibatch iteration 339/323600: mean batch inertia: 0.019953, ewa inertia: 0.021697
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 340/323600: mean batch inertia: 0.017773, ewa inertia: 0.021694
# Minibatch iteration 341/323600: mean batch inertia: 0.022309, ewa inertia: 0.021695
# Minibatch iteration 342/323600: mean batch inertia: 0.015933, ewa inertia: 0.021691
# Minibatch iteration 343/323600: mean batch inertia: 0.019787, ewa inertia: 0.021690
# Minibatch iteration 344/323600: mean batch inertia: 0.018732, ewa inertia: 0.021688
# Minibatch iteration 345/323600: mean batch inertia: 0.016012, ewa inertia: 0.021685
# Minibatch iteration 346/323600: mean batch inertia: 0.016108, ewa inertia: 0.021681
# Minibatch iteration 347/323600: mean batch inertia: 0.018054, ewa inertia: 0.021679
# Minibatch iteration 348/323600: mean batch inertia: 0.014547, ewa inertia: 0.021675
# Minibatch iteration 349/323600: mean batch inertia: 0.015478, ewa inertia: 0.021671
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 350/323600: mean batch inertia: 0.017359, ewa inertia: 0.021668
# Minibatch iteration 351/323600: mean batch inertia: 0.023567, ewa inertia: 0.021669
# Minibatch iteration 352/323600: mean batch inertia: 0.017835, ewa inertia: 0.021667
# Minibatch iteration 353/323600: mean batch inertia: 0.014447, ewa inertia: 0.021662
# Minibatch iteration 354/323600: mean batch inertia: 0.021532, ewa inertia: 0.021662
# Minibatch iteration 355/323600: mean batch inertia: 0.017115, ewa inertia: 0.021660
# Minibatch iteration 356/323600: mean batch inertia: 0.016395, ewa inertia: 0.021656
# Minibatch iteration 357/323600: mean batch inertia: 0.015983, ewa inertia: 0.021653
# Minibatch iteration 358/323600: mean batch inertia: 0.023194, ewa inertia: 0.021654
# Minibatch iteration 359/323600: mean batch inertia: 0.019184, ewa inertia: 0.021652
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 360/323600: mean batch inertia: 0.013420, ewa inertia: 0.021647
# Minibatch iteration 361/323600: mean batch inertia: 0.017037, ewa inertia: 0.021644
# Minibatch iteration 362/323600: mean batch inertia: 0.013187, ewa inertia: 0.021639
# Minibatch iteration 363/323600: mean batch inertia: 0.017174, ewa inertia: 0.021636
# Minibatch iteration 364/323600: mean batch inertia: 0.014809, ewa inertia: 0.021632
# Minibatch iteration 365/323600: mean batch inertia: 0.019784, ewa inertia: 0.021631
# Minibatch iteration 366/323600: mean batch inertia: 0.015217, ewa inertia: 0.021627
# Minibatch iteration 367/323600: mean batch inertia: 0.018657, ewa inertia: 0.021625
# Minibatch iteration 368/323600: mean batch inertia: 0.015118, ewa inertia: 0.021621
# Minibatch iteration 369/323600: mean batch inertia: 0.017427, ewa inertia: 0.021619
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 370/323600: mean batch inertia: 0.017294, ewa inertia: 0.021616
# Minibatch iteration 371/323600: mean batch inertia: 0.015631, ewa inertia: 0.021612
# Minibatch iteration 372/323600: mean batch inertia: 0.019934, ewa inertia: 0.021611
# Minibatch iteration 373/323600: mean batch inertia: 0.017148, ewa inertia: 0.021608
# Minibatch iteration 374/323600: mean batch inertia: 0.019282, ewa inertia: 0.021607
# Minibatch iteration 375/323600: mean batch inertia: 0.016436, ewa inertia: 0.021604
# Minibatch iteration 376/323600: mean batch inertia: 0.018893, ewa inertia: 0.021602
# Minibatch iteration 377/323600: mean batch inertia: 0.018209, ewa inertia: 0.021600
# Minibatch iteration 378/323600: mean batch inertia: 0.017025, ewa inertia: 0.021597
# Minibatch iteration 379/323600: mean batch inertia: 0.021635, ewa inertia: 0.021597
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 380/323600: mean batch inertia: 0.015736, ewa inertia: 0.021594
# Minibatch iteration 381/323600: mean batch inertia: 0.021746, ewa inertia: 0.021594
# Minibatch iteration 382/323600: mean batch inertia: 0.014971, ewa inertia: 0.021590
# Minibatch iteration 383/323600: mean batch inertia: 0.016557, ewa inertia: 0.021586
# Minibatch iteration 384/323600: mean batch inertia: 0.016359, ewa inertia: 0.021583
# Minibatch iteration 385/323600: mean batch inertia: 0.017713, ewa inertia: 0.021581
# Minibatch iteration 386/323600: mean batch inertia: 0.017354, ewa inertia: 0.021578
# Minibatch iteration 387/323600: mean batch inertia: 0.015937, ewa inertia: 0.021575
# Minibatch iteration 388/323600: mean batch inertia: 0.016527, ewa inertia: 0.021572
# Minibatch iteration 389/323600: mean batch inertia: 0.015635, ewa inertia: 0.021568
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 390/323600: mean batch inertia: 0.014565, ewa inertia: 0.021564
# Minibatch iteration 391/323600: mean batch inertia: 0.016646, ewa inertia: 0.021561
# Minibatch iteration 392/323600: mean batch inertia: 0.017513, ewa inertia: 0.021558
# Minibatch iteration 393/323600: mean batch inertia: 0.018298, ewa inertia: 0.021556
# Minibatch iteration 394/323600: mean batch inertia: 0.022556, ewa inertia: 0.021557
# Minibatch iteration 395/323600: mean batch inertia: 0.015281, ewa inertia: 0.021553
# Minibatch iteration 396/323600: mean batch inertia: 0.017761, ewa inertia: 0.021550
# Minibatch iteration 397/323600: mean batch inertia: 0.020224, ewa inertia: 0.021550
# Minibatch iteration 398/323600: mean batch inertia: 0.014218, ewa inertia: 0.021545
# Minibatch iteration 399/323600: mean batch inertia: 0.014040, ewa inertia: 0.021540
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 400/323600: mean batch inertia: 0.017162, ewa inertia: 0.021538
# Minibatch iteration 401/323600: mean batch inertia: 0.024229, ewa inertia: 0.021539
# Minibatch iteration 402/323600: mean batch inertia: 0.014499, ewa inertia: 0.021535
# Minibatch iteration 403/323600: mean batch inertia: 0.018022, ewa inertia: 0.021533
# Minibatch iteration 404/323600: mean batch inertia: 0.021960, ewa inertia: 0.021533
# Minibatch iteration 405/323600: mean batch inertia: 0.015699, ewa inertia: 0.021530
# Minibatch iteration 406/323600: mean batch inertia: 0.024309, ewa inertia: 0.021531
# Minibatch iteration 407/323600: mean batch inertia: 0.014522, ewa inertia: 0.021527
# Minibatch iteration 408/323600: mean batch inertia: 0.016871, ewa inertia: 0.021524
# Minibatch iteration 409/323600: mean batch inertia: 0.022539, ewa inertia: 0.021525
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 410/323600: mean batch inertia: 0.020580, ewa inertia: 0.021524
# Minibatch iteration 411/323600: mean batch inertia: 0.015460, ewa inertia: 0.021520
# Minibatch iteration 412/323600: mean batch inertia: 0.020414, ewa inertia: 0.021520
# Minibatch iteration 413/323600: mean batch inertia: 0.017298, ewa inertia: 0.021517
# Minibatch iteration 414/323600: mean batch inertia: 0.017001, ewa inertia: 0.021514
# Minibatch iteration 415/323600: mean batch inertia: 0.016114, ewa inertia: 0.021511
# Minibatch iteration 416/323600: mean batch inertia: 0.016873, ewa inertia: 0.021508
# Minibatch iteration 417/323600: mean batch inertia: 0.023270, ewa inertia: 0.021509
# Minibatch iteration 418/323600: mean batch inertia: 0.015990, ewa inertia: 0.021506
# Minibatch iteration 419/323600: mean batch inertia: 0.015289, ewa inertia: 0.021502
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 420/323600: mean batch inertia: 0.021103, ewa inertia: 0.021502
# Minibatch iteration 421/323600: mean batch inertia: 0.016371, ewa inertia: 0.021498
# Minibatch iteration 422/323600: mean batch inertia: 0.015405, ewa inertia: 0.021495
# Minibatch iteration 423/323600: mean batch inertia: 0.018786, ewa inertia: 0.021493
# Minibatch iteration 424/323600: mean batch inertia: 0.016236, ewa inertia: 0.021490
# Minibatch iteration 425/323600: mean batch inertia: 0.016168, ewa inertia: 0.021486
# Minibatch iteration 426/323600: mean batch inertia: 0.018133, ewa inertia: 0.021484
# Minibatch iteration 427/323600: mean batch inertia: 0.016960, ewa inertia: 0.021482
# Minibatch iteration 428/323600: mean batch inertia: 0.018465, ewa inertia: 0.021480
# Minibatch iteration 429/323600: mean batch inertia: 0.015376, ewa inertia: 0.021476
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 430/323600: mean batch inertia: 0.014021, ewa inertia: 0.021471
# Minibatch iteration 431/323600: mean batch inertia: 0.018156, ewa inertia: 0.021469
# Minibatch iteration 432/323600: mean batch inertia: 0.016556, ewa inertia: 0.021466
# Minibatch iteration 433/323600: mean batch inertia: 0.015880, ewa inertia: 0.021463
# Minibatch iteration 434/323600: mean batch inertia: 0.019352, ewa inertia: 0.021461
# Minibatch iteration 435/323600: mean batch inertia: 0.019581, ewa inertia: 0.021460
# Minibatch iteration 436/323600: mean batch inertia: 0.016971, ewa inertia: 0.021458
# Minibatch iteration 437/323600: mean batch inertia: 0.018218, ewa inertia: 0.021456
# Minibatch iteration 438/323600: mean batch inertia: 0.020189, ewa inertia: 0.021455
# Minibatch iteration 439/323600: mean batch inertia: 0.016373, ewa inertia: 0.021452
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 440/323600: mean batch inertia: 0.017546, ewa inertia: 0.021449
# Minibatch iteration 441/323600: mean batch inertia: 0.014238, ewa inertia: 0.021445
# Minibatch iteration 442/323600: mean batch inertia: 0.017435, ewa inertia: 0.021442
# Minibatch iteration 443/323600: mean batch inertia: 0.019210, ewa inertia: 0.021441
# Minibatch iteration 444/323600: mean batch inertia: 0.021259, ewa inertia: 0.021441
# Minibatch iteration 445/323600: mean batch inertia: 0.018704, ewa inertia: 0.021439
# Minibatch iteration 446/323600: mean batch inertia: 0.012318, ewa inertia: 0.021433
# Minibatch iteration 447/323600: mean batch inertia: 0.020853, ewa inertia: 0.021433
# Minibatch iteration 448/323600: mean batch inertia: 0.015945, ewa inertia: 0.021430
# Minibatch iteration 449/323600: mean batch inertia: 0.013886, ewa inertia: 0.021425
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 450/323600: mean batch inertia: 0.015425, ewa inertia: 0.021421
# Minibatch iteration 451/323600: mean batch inertia: 0.015727, ewa inertia: 0.021418
# Minibatch iteration 452/323600: mean batch inertia: 0.020780, ewa inertia: 0.021417
# Minibatch iteration 453/323600: mean batch inertia: 0.019149, ewa inertia: 0.021416
# Minibatch iteration 454/323600: mean batch inertia: 0.016553, ewa inertia: 0.021413
# Minibatch iteration 455/323600: mean batch inertia: 0.017022, ewa inertia: 0.021410
# Minibatch iteration 456/323600: mean batch inertia: 0.013243, ewa inertia: 0.021405
# Minibatch iteration 457/323600: mean batch inertia: 0.017745, ewa inertia: 0.021403
# Minibatch iteration 458/323600: mean batch inertia: 0.018045, ewa inertia: 0.021401
# Minibatch iteration 459/323600: mean batch inertia: 0.018612, ewa inertia: 0.021399
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 460/323600: mean batch inertia: 0.017138, ewa inertia: 0.021397
# Minibatch iteration 461/323600: mean batch inertia: 0.019135, ewa inertia: 0.021395
# Minibatch iteration 462/323600: mean batch inertia: 0.018072, ewa inertia: 0.021393
# Minibatch iteration 463/323600: mean batch inertia: 0.016088, ewa inertia: 0.021390
# Minibatch iteration 464/323600: mean batch inertia: 0.021687, ewa inertia: 0.021390
# Minibatch iteration 465/323600: mean batch inertia: 0.021896, ewa inertia: 0.021390
# Minibatch iteration 466/323600: mean batch inertia: 0.015853, ewa inertia: 0.021387
# Minibatch iteration 467/323600: mean batch inertia: 0.022842, ewa inertia: 0.021388
# Minibatch iteration 468/323600: mean batch inertia: 0.020338, ewa inertia: 0.021387
# Minibatch iteration 469/323600: mean batch inertia: 0.018775, ewa inertia: 0.021386
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 470/323600: mean batch inertia: 0.016644, ewa inertia: 0.021383
# Minibatch iteration 471/323600: mean batch inertia: 0.014037, ewa inertia: 0.021378
# Minibatch iteration 472/323600: mean batch inertia: 0.013644, ewa inertia: 0.021373
# Minibatch iteration 473/323600: mean batch inertia: 0.019124, ewa inertia: 0.021372
# Minibatch iteration 474/323600: mean batch inertia: 0.015167, ewa inertia: 0.021368
# Minibatch iteration 475/323600: mean batch inertia: 0.018928, ewa inertia: 0.021367
# Minibatch iteration 476/323600: mean batch inertia: 0.013900, ewa inertia: 0.021362
# Minibatch iteration 477/323600: mean batch inertia: 0.014457, ewa inertia: 0.021358
# Minibatch iteration 478/323600: mean batch inertia: 0.014242, ewa inertia: 0.021353
# Minibatch iteration 479/323600: mean batch inertia: 0.015730, ewa inertia: 0.021350
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 480/323600: mean batch inertia: 0.014093, ewa inertia: 0.021345
# Minibatch iteration 481/323600: mean batch inertia: 0.016656, ewa inertia: 0.021342
# Minibatch iteration 482/323600: mean batch inertia: 0.016894, ewa inertia: 0.021340
# Minibatch iteration 483/323600: mean batch inertia: 0.017233, ewa inertia: 0.021337
# Minibatch iteration 484/323600: mean batch inertia: 0.016871, ewa inertia: 0.021334
# Minibatch iteration 485/323600: mean batch inertia: 0.019311, ewa inertia: 0.021333
# Minibatch iteration 486/323600: mean batch inertia: 0.021495, ewa inertia: 0.021333
# Minibatch iteration 487/323600: mean batch inertia: 0.022615, ewa inertia: 0.021334
# Minibatch iteration 488/323600: mean batch inertia: 0.016538, ewa inertia: 0.021331
# Minibatch iteration 489/323600: mean batch inertia: 0.017153, ewa inertia: 0.021328
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 490/323600: mean batch inertia: 0.018006, ewa inertia: 0.021326
# Minibatch iteration 491/323600: mean batch inertia: 0.017167, ewa inertia: 0.021324
# Minibatch iteration 492/323600: mean batch inertia: 0.019924, ewa inertia: 0.021323
# Minibatch iteration 493/323600: mean batch inertia: 0.018160, ewa inertia: 0.021321
# Minibatch iteration 494/323600: mean batch inertia: 0.016164, ewa inertia: 0.021318
# Minibatch iteration 495/323600: mean batch inertia: 0.013465, ewa inertia: 0.021313
# Minibatch iteration 496/323600: mean batch inertia: 0.019726, ewa inertia: 0.021312
# Minibatch iteration 497/323600: mean batch inertia: 0.014451, ewa inertia: 0.021308
# Minibatch iteration 498/323600: mean batch inertia: 0.016449, ewa inertia: 0.021305
# Minibatch iteration 499/323600: mean batch inertia: 0.027230, ewa inertia: 0.021308
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 500/323600: mean batch inertia: 0.016063, ewa inertia: 0.021305
# Minibatch iteration 501/323600: mean batch inertia: 0.018318, ewa inertia: 0.021303
# Minibatch iteration 502/323600: mean batch inertia: 0.016326, ewa inertia: 0.021300
# Minibatch iteration 503/323600: mean batch inertia: 0.015829, ewa inertia: 0.021297
# Minibatch iteration 504/323600: mean batch inertia: 0.021870, ewa inertia: 0.021297
# Minibatch iteration 505/323600: mean batch inertia: 0.017932, ewa inertia: 0.021295
# Minibatch iteration 506/323600: mean batch inertia: 0.014629, ewa inertia: 0.021291
# Minibatch iteration 507/323600: mean batch inertia: 0.018049, ewa inertia: 0.021289
# Minibatch iteration 508/323600: mean batch inertia: 0.013716, ewa inertia: 0.021284
# Minibatch iteration 509/323600: mean batch inertia: 0.017936, ewa inertia: 0.021282
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 510/323600: mean batch inertia: 0.019378, ewa inertia: 0.021281
# Minibatch iteration 511/323600: mean batch inertia: 0.017055, ewa inertia: 0.021278
# Minibatch iteration 512/323600: mean batch inertia: 0.019116, ewa inertia: 0.021277
# Minibatch iteration 513/323600: mean batch inertia: 0.019332, ewa inertia: 0.021276
# Minibatch iteration 514/323600: mean batch inertia: 0.016342, ewa inertia: 0.021273
# Minibatch iteration 515/323600: mean batch inertia: 0.015042, ewa inertia: 0.021269
# Minibatch iteration 516/323600: mean batch inertia: 0.017695, ewa inertia: 0.021267
# Minibatch iteration 517/323600: mean batch inertia: 0.014438, ewa inertia: 0.021263
# Minibatch iteration 518/323600: mean batch inertia: 0.010635, ewa inertia: 0.021256
# Minibatch iteration 519/323600: mean batch inertia: 0.013772, ewa inertia: 0.021251
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 520/323600: mean batch inertia: 0.014557, ewa inertia: 0.021247
# Minibatch iteration 521/323600: mean batch inertia: 0.022301, ewa inertia: 0.021248
# Minibatch iteration 522/323600: mean batch inertia: 0.016095, ewa inertia: 0.021245
# Minibatch iteration 523/323600: mean batch inertia: 0.015351, ewa inertia: 0.021241
# Minibatch iteration 524/323600: mean batch inertia: 0.018549, ewa inertia: 0.021239
# Minibatch iteration 525/323600: mean batch inertia: 0.015778, ewa inertia: 0.021236
# Minibatch iteration 526/323600: mean batch inertia: 0.018526, ewa inertia: 0.021234
# Minibatch iteration 527/323600: mean batch inertia: 0.014932, ewa inertia: 0.021230
# Minibatch iteration 528/323600: mean batch inertia: 0.026673, ewa inertia: 0.021234
# Minibatch iteration 529/323600: mean batch inertia: 0.016544, ewa inertia: 0.021231
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 530/323600: mean batch inertia: 0.015082, ewa inertia: 0.021227
# Minibatch iteration 531/323600: mean batch inertia: 0.020548, ewa inertia: 0.021227
# Minibatch iteration 532/323600: mean batch inertia: 0.014570, ewa inertia: 0.021223
# Minibatch iteration 533/323600: mean batch inertia: 0.022933, ewa inertia: 0.021224
# ...
# Minibatch iteration 1620/323600: mean batch inertia: 0.012970, ewa inertia: 0.018845
# Minibatch iteration 1621/323600: mean batch inertia: 0.018012, ewa inertia: 0.018845
# Minibatch iteration 1622/323600: mean batch inertia: 0.014758, ewa inertia: 0.018842
# Minibatch iteration 1623/323600: mean batch inertia: 0.015231, ewa inertia: 0.018840
# Minibatch iteration 1624/323600: mean batch inertia: 0.017677, ewa inertia: 0.018839
# Minibatch iteration 1625/323600: mean batch inertia: 0.013775, ewa inertia: 0.018836
# Minibatch iteration 1626/323600: mean batch inertia: 0.020639, ewa inertia: 0.018837
# Minibatch iteration 1627/323600: mean batch inertia: 0.020608, ewa inertia: 0.018839
# Minibatch iteration 1628/323600: mean batch inertia: 0.016312, ewa inertia: 0.018837
# Minibatch iteration 1629/323600: mean batch inertia: 0.018945, ewa inertia: 0.018837
# Minibatch iteration 1630/323600: mean batch inertia: 0.013641, ewa inertia: 0.018834
# Minibatch iteration 1631/323600: mean batch inertia: 0.017039, ewa inertia: 0.018833
# Minibatch iteration 1632/323600: mean batch inertia: 0.018047, ewa inertia: 0.018832
# Minibatch iteration 1633/323600: mean batch inertia: 0.016713, ewa inertia: 0.018831
# Minibatch iteration 1634/323600: mean batch inertia: 0.014772, ewa inertia: 0.018828
# Minibatch iteration 1635/323600: mean batch inertia: 0.016901, ewa inertia: 0.018827
# Minibatch iteration 1636/323600: mean batch inertia: 0.019466, ewa inertia: 0.018828
# Minibatch iteration 1637/323600: mean batch inertia: 0.014146, ewa inertia: 0.018825
# Minibatch iteration 1638/323600: mean batch inertia: 0.014512, ewa inertia: 0.018822
# Minibatch iteration 1639/323600: mean batch inertia: 0.016688, ewa inertia: 0.018821
# Minibatch iteration 1640/323600: mean batch inertia: 0.016026, ewa inertia: 0.018819
# Minibatch iteration 1641/323600: mean batch inertia: 0.025102, ewa inertia: 0.018823
# Minibatch iteration 1642/323600: mean batch inertia: 0.014798, ewa inertia: 0.018820
# Minibatch iteration 1643/323600: mean batch inertia: 0.015647, ewa inertia: 0.018818
# Minibatch iteration 1644/323600: mean batch inertia: 0.015722, ewa inertia: 0.018817
# Minibatch iteration 1645/323600: mean batch inertia: 0.014997, ewa inertia: 0.018814
# Minibatch iteration 1646/323600: mean batch inertia: 0.018870, ewa inertia: 0.018814
# Minibatch iteration 1647/323600: mean batch inertia: 0.013156, ewa inertia: 0.018811
# Minibatch iteration 1648/323600: mean batch inertia: 0.011599, ewa inertia: 0.018806
# Minibatch iteration 1649/323600: mean batch inertia: 0.012597, ewa inertia: 0.018802
# Minibatch iteration 1650/323600: mean batch inertia: 0.018014, ewa inertia: 0.018802
# Minibatch iteration 1651/323600: mean batch inertia: 0.015610, ewa inertia: 0.018800
# Minibatch iteration 1652/323600: mean batch inertia: 0.016566, ewa inertia: 0.018799
# Minibatch iteration 1653/323600: mean batch inertia: 0.013337, ewa inertia: 0.018795
# Minibatch iteration 1654/323600: mean batch inertia: 0.017381, ewa inertia: 0.018794
# Minibatch iteration 1655/323600: mean batch inertia: 0.012399, ewa inertia: 0.018790
# Minibatch iteration 1656/323600: mean batch inertia: 0.013672, ewa inertia: 0.018787
# Minibatch iteration 1657/323600: mean batch inertia: 0.012755, ewa inertia: 0.018783
# Minibatch iteration 1658/323600: mean batch inertia: 0.015908, ewa inertia: 0.018782
# Minibatch iteration 1659/323600: mean batch inertia: 0.013123, ewa inertia: 0.018778
# Minibatch iteration 1660/323600: mean batch inertia: 0.013760, ewa inertia: 0.018775
# Minibatch iteration 1661/323600: mean batch inertia: 0.019602, ewa inertia: 0.018776
# Minibatch iteration 1662/323600: mean batch inertia: 0.018988, ewa inertia: 0.018776
# Minibatch iteration 1663/323600: mean batch inertia: 0.020632, ewa inertia: 0.018777
# Minibatch iteration 1664/323600: mean batch inertia: 0.013728, ewa inertia: 0.018774
# Minibatch iteration 1665/323600: mean batch inertia: 0.013095, ewa inertia: 0.018770
# Minibatch iteration 1666/323600: mean batch inertia: 0.016501, ewa inertia: 0.018769
# Minibatch iteration 1667/323600: mean batch inertia: 0.017144, ewa inertia: 0.018768
# Minibatch iteration 1668/323600: mean batch inertia: 0.017890, ewa inertia: 0.018767
# Minibatch iteration 1669/323600: mean batch inertia: 0.014383, ewa inertia: 0.018765
# Minibatch iteration 1670/323600: mean batch inertia: 0.016361, ewa inertia: 0.018763
# Minibatch iteration 1671/323600: mean batch inertia: 0.015644, ewa inertia: 0.018761
# Minibatch iteration 1672/323600: mean batch inertia: 0.019636, ewa inertia: 0.018762
# Minibatch iteration 1673/323600: mean batch inertia: 0.019463, ewa inertia: 0.018762
# Minibatch iteration 1674/323600: mean batch inertia: 0.017894, ewa inertia: 0.018762
# Minibatch iteration 1675/323600: mean batch inertia: 0.012443, ewa inertia: 0.018758
# Minibatch iteration 1676/323600: mean batch inertia: 0.011813, ewa inertia: 0.018753
# Minibatch iteration 1677/323600: mean batch inertia: 0.014620, ewa inertia: 0.018751
# Minibatch iteration 1678/323600: mean batch inertia: 0.014219, ewa inertia: 0.018748
# Minibatch iteration 1679/323600: mean batch inertia: 0.018374, ewa inertia: 0.018748
# Minibatch iteration 1680/323600: mean batch inertia: 0.016540, ewa inertia: 0.018746
# Minibatch iteration 1681/323600: mean batch inertia: 0.012718, ewa inertia: 0.018743
# Minibatch iteration 1682/323600: mean batch inertia: 0.013475, ewa inertia: 0.018739
# Minibatch iteration 1683/323600: mean batch inertia: 0.016057, ewa inertia: 0.018738
# Minibatch iteration 1684/323600: mean batch inertia: 0.015037, ewa inertia: 0.018736
# Minibatch iteration 1685/323600: mean batch inertia: 0.021170, ewa inertia: 0.018737
# Minibatch iteration 1686/323600: mean batch inertia: 0.014386, ewa inertia: 0.018734
# Minibatch iteration 1687/323600: mean batch inertia: 0.014122, ewa inertia: 0.018732
# Minibatch iteration 1688/323600: mean batch inertia: 0.019388, ewa inertia: 0.018732
# Minibatch iteration 1689/323600: mean batch inertia: 0.026703, ewa inertia: 0.018737
# Minibatch iteration 1690/323600: mean batch inertia: 0.013202, ewa inertia: 0.018733
# Minibatch iteration 1691/323600: mean batch inertia: 0.020891, ewa inertia: 0.018735
# Minibatch iteration 1692/323600: mean batch inertia: 0.013412, ewa inertia: 0.018731
# Minibatch iteration 1693/323600: mean batch inertia: 0.012291, ewa inertia: 0.018727
# Minibatch iteration 1694/323600: mean batch inertia: 0.013169, ewa inertia: 0.018724
# Minibatch iteration 1695/323600: mean batch inertia: 0.013037, ewa inertia: 0.018721
# Minibatch iteration 1696/323600: mean batch inertia: 0.014477, ewa inertia: 0.018718
# Minibatch iteration 1697/323600: mean batch inertia: 0.016158, ewa inertia: 0.018716
# Minibatch iteration 1698/323600: mean batch inertia: 0.017302, ewa inertia: 0.018715
# Minibatch iteration 1699/323600: mean batch inertia: 0.014720, ewa inertia: 0.018713
# Minibatch iteration 1700/323600: mean batch inertia: 0.015458, ewa inertia: 0.018711
# Minibatch iteration 1701/323600: mean batch inertia: 0.016132, ewa inertia: 0.018709
# Minibatch iteration 1702/323600: mean batch inertia: 0.017804, ewa inertia: 0.018709
# Minibatch iteration 1703/323600: mean batch inertia: 0.017060, ewa inertia: 0.018708
# Minibatch iteration 1704/323600: mean batch inertia: 0.020782, ewa inertia: 0.018709
# Minibatch iteration 1705/323600: mean batch inertia: 0.019552, ewa inertia: 0.018710
# Minibatch iteration 1706/323600: mean batch inertia: 0.014811, ewa inertia: 0.018707
# Minibatch iteration 1707/323600: mean batch inertia: 0.016173, ewa inertia: 0.018706
# Minibatch iteration 1708/323600: mean batch inertia: 0.013827, ewa inertia: 0.018703
# Minibatch iteration 1709/323600: mean batch inertia: 0.014055, ewa inertia: 0.018700
# Minibatch iteration 1710/323600: mean batch inertia: 0.014228, ewa inertia: 0.018697
# Minibatch iteration 1711/323600: mean batch inertia: 0.023460, ewa inertia: 0.018700
# Minibatch iteration 1712/323600: mean batch inertia: 0.015774, ewa inertia: 0.018698
# Minibatch iteration 1713/323600: mean batch inertia: 0.019602, ewa inertia: 0.018699
# Minibatch iteration 1714/323600: mean batch inertia: 0.015293, ewa inertia: 0.018697
# Minibatch iteration 1715/323600: mean batch inertia: 0.017243, ewa inertia: 0.018696
# Minibatch iteration 1716/323600: mean batch inertia: 0.017794, ewa inertia: 0.018695
# Minibatch iteration 1717/323600: mean batch inertia: 0.017630, ewa inertia: 0.018694
# Minibatch iteration 1718/323600: mean batch inertia: 0.019221, ewa inertia: 0.018695
# Minibatch iteration 1719/323600: mean batch inertia: 0.016870, ewa inertia: 0.018694
# Minibatch iteration 1720/323600: mean batch inertia: 0.019075, ewa inertia: 0.018694
# Minibatch iteration 1721/323600: mean batch inertia: 0.018027, ewa inertia: 0.018693
# Minibatch iteration 1722/323600: mean batch inertia: 0.014519, ewa inertia: 0.018691
# Minibatch iteration 1723/323600: mean batch inertia: 0.017302, ewa inertia: 0.018690
# Minibatch iteration 1724/323600: mean batch inertia: 0.013641, ewa inertia: 0.018687
# Minibatch iteration 1725/323600: mean batch inertia: 0.011479, ewa inertia: 0.018682
# Minibatch iteration 1726/323600: mean batch inertia: 0.014209, ewa inertia: 0.018680
# Minibatch iteration 1727/323600: mean batch inertia: 0.022188, ewa inertia: 0.018682
# Minibatch iteration 1728/323600: mean batch inertia: 0.013949, ewa inertia: 0.018679
# Minibatch iteration 1729/323600: mean batch inertia: 0.013978, ewa inertia: 0.018676
# Minibatch iteration 1730/323600: mean batch inertia: 0.015321, ewa inertia: 0.018674
# Minibatch iteration 1731/323600: mean batch inertia: 0.014275, ewa inertia: 0.018671
# Minibatch iteration 1732/323600: mean batch inertia: 0.013130, ewa inertia: 0.018668
# Minibatch iteration 1733/323600: mean batch inertia: 0.017386, ewa inertia: 0.018667
# Minibatch iteration 1734/323600: mean batch inertia: 0.014092, ewa inertia: 0.018664
# Minibatch iteration 1735/323600: mean batch inertia: 0.013204, ewa inertia: 0.018661
# Minibatch iteration 1736/323600: mean batch inertia: 0.014280, ewa inertia: 0.018658
# Minibatch iteration 1737/323600: mean batch inertia: 0.014540, ewa inertia: 0.018656
# Minibatch iteration 1738/323600: mean batch inertia: 0.012606, ewa inertia: 0.018652
# Minibatch iteration 1739/323600: mean batch inertia: 0.014773, ewa inertia: 0.018649
# Minibatch iteration 1740/323600: mean batch inertia: 0.016060, ewa inertia: 0.018648
# Minibatch iteration 1741/323600: mean batch inertia: 0.017577, ewa inertia: 0.018647
# Minibatch iteration 1742/323600: mean batch inertia: 0.015495, ewa inertia: 0.018645
# Minibatch iteration 1743/323600: mean batch inertia: 0.014986, ewa inertia: 0.018643
# Minibatch iteration 1744/323600: mean batch inertia: 0.018194, ewa inertia: 0.018643
# Minibatch iteration 1745/323600: mean batch inertia: 0.013278, ewa inertia: 0.018639
# Minibatch iteration 1746/323600: mean batch inertia: 0.015065, ewa inertia: 0.018637
# Minibatch iteration 1747/323600: mean batch inertia: 0.016921, ewa inertia: 0.018636
# Minibatch iteration 1748/323600: mean batch inertia: 0.015286, ewa inertia: 0.018634
# Minibatch iteration 1749/323600: mean batch inertia: 0.018614, ewa inertia: 0.018634
# Minibatch iteration 1750/323600: mean batch inertia: 0.017600, ewa inertia: 0.018633
# Minibatch iteration 1751/323600: mean batch inertia: 0.019131, ewa inertia: 0.018634
# Minibatch iteration 1752/323600: mean batch inertia: 0.015645, ewa inertia: 0.018632
# Minibatch iteration 1753/323600: mean batch inertia: 0.016733, ewa inertia: 0.018631
# Minibatch iteration 1754/323600: mean batch inertia: 0.014535, ewa inertia: 0.018628
# Minibatch iteration 1755/323600: mean batch inertia: 0.015452, ewa inertia: 0.018626
# Minibatch iteration 1756/323600: mean batch inertia: 0.012772, ewa inertia: 0.018623
# Minibatch iteration 1757/323600: mean batch inertia: 0.012913, ewa inertia: 0.018619
# Minibatch iteration 1758/323600: mean batch inertia: 0.018745, ewa inertia: 0.018619
# Minibatch iteration 1759/323600: mean batch inertia: 0.015872, ewa inertia: 0.018617
# Minibatch iteration 1760/323600: mean batch inertia: 0.014433, ewa inertia: 0.018615
# Minibatch iteration 1761/323600: mean batch inertia: 0.016273, ewa inertia: 0.018613
# Minibatch iteration 1762/323600: mean batch inertia: 0.010621, ewa inertia: 0.018608
# Minibatch iteration 1763/323600: mean batch inertia: 0.018526, ewa inertia: 0.018608
# Minibatch iteration 1764/323600: mean batch inertia: 0.016282, ewa inertia: 0.018607
# Minibatch iteration 1765/323600: mean batch inertia: 0.022102, ewa inertia: 0.018609
# Minibatch iteration 1766/323600: mean batch inertia: 0.017213, ewa inertia: 0.018608
# Minibatch iteration 1767/323600: mean batch inertia: 0.016330, ewa inertia: 0.018607
# Minibatch iteration 1768/323600: mean batch inertia: 0.014456, ewa inertia: 0.018604
# Minibatch iteration 1769/323600: mean batch inertia: 0.020122, ewa inertia: 0.018605
# Minibatch iteration 1770/323600: mean batch inertia: 0.017769, ewa inertia: 0.018605
# Minibatch iteration 1771/323600: mean batch inertia: 0.014780, ewa inertia: 0.018602
# Minibatch iteration 1772/323600: mean batch inertia: 0.015600, ewa inertia: 0.018600
# Minibatch iteration 1773/323600: mean batch inertia: 0.015483, ewa inertia: 0.018599
# Minibatch iteration 1774/323600: mean batch inertia: 0.020135, ewa inertia: 0.018599
# Minibatch iteration 1775/323600: mean batch inertia: 0.019681, ewa inertia: 0.018600
# Minibatch iteration 1776/323600: mean batch inertia: 0.014882, ewa inertia: 0.018598
# Minibatch iteration 1777/323600: mean batch inertia: 0.018162, ewa inertia: 0.018598
# Minibatch iteration 1778/323600: mean batch inertia: 0.016175, ewa inertia: 0.018596
# Minibatch iteration 1779/323600: mean batch inertia: 0.016729, ewa inertia: 0.018595
# Minibatch iteration 1780/323600: mean batch inertia: 0.013842, ewa inertia: 0.018592
# Minibatch iteration 1781/323600: mean batch inertia: 0.018856, ewa inertia: 0.018592
# Minibatch iteration 1782/323600: mean batch inertia: 0.012475, ewa inertia: 0.018588
# Minibatch iteration 1783/323600: mean batch inertia: 0.011339, ewa inertia: 0.018584
# Minibatch iteration 1784/323600: mean batch inertia: 0.019378, ewa inertia: 0.018584
# Minibatch iteration 1785/323600: mean batch inertia: 0.019971, ewa inertia: 0.018585
# Minibatch iteration 1786/323600: mean batch inertia: 0.051355, ewa inertia: 0.018605
# Minibatch iteration 1787/323600: mean batch inertia: 0.018856, ewa inertia: 0.018606
# Minibatch iteration 1788/323600: mean batch inertia: 0.014768, ewa inertia: 0.018603
# Minibatch iteration 1789/323600: mean batch inertia: 0.015104, ewa inertia: 0.018601
# Minibatch iteration 1790/323600: mean batch inertia: 0.014228, ewa inertia: 0.018598
# Minibatch iteration 1791/323600: mean batch inertia: 0.016095, ewa inertia: 0.018597
# Minibatch iteration 1792/323600: mean batch inertia: 0.017729, ewa inertia: 0.018596
# Minibatch iteration 1793/323600: mean batch inertia: 0.010789, ewa inertia: 0.018591
# Converged (lack of improvement in inertia) at iteration 1793/323600
# Computing label assignment and total inertia
# fit end
# fit time:  4.5minute
# Computing label assignment and total inertia
# drop start
# cluster number: 0
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# cluster number: 500
# cluster number: 1000
# cluster number: 1500
# cluster number: 2000
# cluster number: 2500
# cluster number: 3000
# cluster number: 3500
# cluster number: 4000
# cluster number: 4500
# cluster number: 5000
# cluster number: 5500
# cluster number: 6000
# cluster number: 6500
# cluster number: 7000
# cluster number: 7500
# cluster number: 8000
# cluster number: 8500
# cluster number: 9000
# cluster number: 9500
# cluster number: 10000
# cluster number: 10500
# drop end
# Drop count: 101382

# %%
#apply the function with 10 samples in one cluster
train_set=boundary_detection(labels=y_train,kmeans=MiniBatchKMeans(n_clusters=np.int((X_train.shape[0])/10),n_init=3,max_iter=100,\
                                                                  init_size=3*np.int((X_train.shape[0])/10),verbose=-1,\
                                                                  random_state=42)).fit_transform(X_train)
# Out:
# fit start
# Init 1/3 with method: k-means++
# Inertia for init 1/3: 515.555794
# Init 2/3 with method: k-means++
# Inertia for init 2/3: 517.568871
# Init 3/3 with method: k-means++
# Inertia for init 3/3: 520.837646
# Minibatch iteration 1/323600: mean batch inertia: 0.010051, ewa inertia: 0.010051
# Minibatch iteration 2/323600: mean batch inertia: 0.011338, ewa inertia: 0.010052
# Minibatch iteration 3/323600: mean batch inertia: 0.008977, ewa inertia: 0.010052
# Minibatch iteration 4/323600: mean batch inertia: 0.012109, ewa inertia: 0.010053
# Minibatch iteration 5/323600: mean batch inertia: 0.009666, ewa inertia: 0.010053
# Minibatch iteration 6/323600: mean batch inertia: 0.011481, ewa inertia: 0.010054
# Minibatch iteration 7/323600: mean batch inertia: 0.009466, ewa inertia: 0.010053
# Minibatch iteration 8/323600: mean batch inertia: 0.007315, ewa inertia: 0.010051
# Minibatch iteration 9/323600: mean batch inertia: 0.008762, ewa inertia: 0.010051
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/323600: mean batch inertia: 0.009576, ewa inertia: 0.010050
# Minibatch iteration 11/323600: mean batch inertia: 0.007876, ewa inertia: 0.010049
# Minibatch iteration 12/323600: mean batch inertia: 0.009421, ewa inertia: 0.010049
# Minibatch iteration 13/323600: mean batch inertia: 0.009234, ewa inertia: 0.010048
# Minibatch iteration 14/323600: mean batch inertia: 0.008393, ewa inertia: 0.010047
# Minibatch iteration 15/323600: mean batch inertia: 0.008804, ewa inertia: 0.010046
# Minibatch iteration 16/323600: mean batch inertia: 0.009522, ewa inertia: 0.010046
# Minibatch iteration 17/323600: mean batch inertia: 0.008734, ewa inertia: 0.010045
# Minibatch iteration 18/323600: mean batch inertia: 0.007395, ewa inertia: 0.010044
# Minibatch iteration 19/323600: mean batch inertia: 0.010253, ewa inertia: 0.010044
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 20/323600: mean batch inertia: 0.008820, ewa inertia: 0.010043
# Minibatch iteration 21/323600: mean batch inertia: 0.008371, ewa inertia: 0.010042
# Minibatch iteration 22/323600: mean batch inertia: 0.009617, ewa inertia: 0.010042
# Minibatch iteration 23/323600: mean batch inertia: 0.010678, ewa inertia: 0.010042
# Minibatch iteration 24/323600: mean batch inertia: 0.009761, ewa inertia: 0.010042
# Minibatch iteration 25/323600: mean batch inertia: 0.007612, ewa inertia: 0.010040
# Minibatch iteration 26/323600: mean batch inertia: 0.007437, ewa inertia: 0.010039
# Minibatch iteration 27/323600: mean batch inertia: 0.007806, ewa inertia: 0.010037
# Minibatch iteration 28/323600: mean batch inertia: 0.009220, ewa inertia: 0.010037
# Minibatch iteration 29/323600: mean batch inertia: 0.010469, ewa inertia: 0.010037
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 30/323600: mean batch inertia: 0.011740, ewa inertia: 0.010038
# Minibatch iteration 31/323600: mean batch inertia: 0.007511, ewa inertia: 0.010037
# Minibatch iteration 32/323600: mean batch inertia: 0.009398, ewa inertia: 0.010036
# Minibatch iteration 33/323600: mean batch inertia: 0.008332, ewa inertia: 0.010035
# Minibatch iteration 34/323600: mean batch inertia: 0.010618, ewa inertia: 0.010036
# Minibatch iteration 35/323600: mean batch inertia: 0.009274, ewa inertia: 0.010035
# Minibatch iteration 36/323600: mean batch inertia: 0.010486, ewa inertia: 0.010035
# Minibatch iteration 37/323600: mean batch inertia: 0.008834, ewa inertia: 0.010035
# Minibatch iteration 38/323600: mean batch inertia: 0.008695, ewa inertia: 0.010034
# Minibatch iteration 39/323600: mean batch inertia: 0.012653, ewa inertia: 0.010035
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 40/323600: mean batch inertia: 0.008468, ewa inertia: 0.010034
# Minibatch iteration 41/323600: mean batch inertia: 0.011037, ewa inertia: 0.010035
# Minibatch iteration 42/323600: mean batch inertia: 0.008804, ewa inertia: 0.010034
# Minibatch iteration 43/323600: mean batch inertia: 0.009172, ewa inertia: 0.010034
# Minibatch iteration 44/323600: mean batch inertia: 0.010123, ewa inertia: 0.010034
# Minibatch iteration 45/323600: mean batch inertia: 0.010207, ewa inertia: 0.010034
# Minibatch iteration 46/323600: mean batch inertia: 0.009882, ewa inertia: 0.010034
# Minibatch iteration 47/323600: mean batch inertia: 0.009073, ewa inertia: 0.010033
# Minibatch iteration 48/323600: mean batch inertia: 0.009911, ewa inertia: 0.010033
# Minibatch iteration 49/323600: mean batch inertia: 0.011799, ewa inertia: 0.010034
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 50/323600: mean batch inertia: 0.012409, ewa inertia: 0.010036
# Minibatch iteration 51/323600: mean batch inertia: 0.008075, ewa inertia: 0.010035
# Minibatch iteration 52/323600: mean batch inertia: 0.009791, ewa inertia: 0.010034
# Minibatch iteration 53/323600: mean batch inertia: 0.007971, ewa inertia: 0.010033
# Minibatch iteration 54/323600: mean batch inertia: 0.010696, ewa inertia: 0.010033
# Minibatch iteration 55/323600: mean batch inertia: 0.009809, ewa inertia: 0.010033
# Minibatch iteration 56/323600: mean batch inertia: 0.009327, ewa inertia: 0.010033
# Minibatch iteration 57/323600: mean batch inertia: 0.008851, ewa inertia: 0.010032
# Minibatch iteration 58/323600: mean batch inertia: 0.008925, ewa inertia: 0.010031
# Minibatch iteration 59/323600: mean batch inertia: 0.013279, ewa inertia: 0.010034
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 60/323600: mean batch inertia: 0.009977, ewa inertia: 0.010033
# Minibatch iteration 61/323600: mean batch inertia: 0.010377, ewa inertia: 0.010034
# Minibatch iteration 62/323600: mean batch inertia: 0.008886, ewa inertia: 0.010033
# Minibatch iteration 63/323600: mean batch inertia: 0.008168, ewa inertia: 0.010032
# Minibatch iteration 64/323600: mean batch inertia: 0.009723, ewa inertia: 0.010032
# Minibatch iteration 65/323600: mean batch inertia: 0.013290, ewa inertia: 0.010034
# Minibatch iteration 66/323600: mean batch inertia: 0.018772, ewa inertia: 0.010039
# Minibatch iteration 67/323600: mean batch inertia: 0.007103, ewa inertia: 0.010037
# Minibatch iteration 68/323600: mean batch inertia: 0.009535, ewa inertia: 0.010037
# Converged (lack of improvement in inertia) at iteration 68/323600
# Computing label assignment and total inertia
# fit end
# fit time: 39.4minute
# Computing label assignment and total inertia
# drop start
# cluster number: 0
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# cluster number: 500
# cluster number: 1000
# cluster number: 1500
# cluster number: 2000
# cluster number: 2500
# cluster number: 3000
# cluster number: 3500
# cluster number: 4000
# cluster number: 4500
# cluster number: 5000
# cluster number: 5500
# cluster number: 6000
# cluster number: 6500
# cluster number: 7000
# cluster number: 7500
# cluster number: 8000
# cluster number: 8500
# cluster number: 9000
# cluster number: 9500
# cluster number: 10000
# cluster number: 10500
# drop end
# Drop count: 55330

# %%
train_set.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_set.csv",index=False)

# %% [markdown]
# # 4. Build the model

# %% [markdown]
# In the model construction part ,**our plan ** is that:
# - train servarl models
# - calculate the f1-scores,accuracy,roc_curve
# - choose the best model
# - tuning the parameters of the model

# %%
train_set=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_set.csv")
X_val=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_feature.csv")
y_val=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_label.csv")
X_train=train_set.drop(["label"],axis=1)
y_train=train_set["label"]

# %%
class nearst_mean(BaseEstimator,TransformerMixin):
    def __init__(self,labels,k=10000,center_feature=[],center_label=[],center_col=[]):
        self.center_feature=center_feature
        self.center_label=center_label
        self.labels=labels
        self.center_col=center_col
        self.k=k
    def fit(self,X,y=None):
        cluster_size=X.shape[0]//self.k
        print("fit start")
        for i in range(self.k):
            if i%100==0:
                print("i is",i,"maha_dis'shape ",len(self.maha_dis))
            index=np.random.choice(len(X),size=cluster_size,replace=False)
            X_k,y_k=X.iloc[index],self.labels.iloc[index]
            mean_k=np.array([X_k.mean()])
            self.center_feature.append(mean_k)
            col_k=np.mat(X_k.cov().as_matrix()).I
            self.center_col.append(col_k)
            m_dis_index=pd.Series((distance.cdist(X,mean_k,metric='mahalanobis',VI=col_k)).ravel())\
                .sort_values(ascending=True).index[0]
            k_label=self.labels.loc[m_dis_index]
            self.center_label.append(k_label)
        print("fit end")
        return self
    def transform(self,X,y=None):
        maha_set=[]
        for i in range(self.k):
            center_mean=self.center_feature[i]
            center_val=self.center_col[i]
            center_label=self.center_label[i]
            m_dis=pd.Series((distance.cdist(X,mean_k,metric='mahalanobis',VI=col_k)).ravel())
            maha_set.append(m_dis)
        maha_set
            
            
            

            
        
        return(X)

# %%
temp1=nearst_mean(labels=y_train).fit(X_train)
# Out:
# fit start
# i is 0 maha_dis'shape  0
# i is 100 maha_dis'shape  100
# i is 200 maha_dis'shape  200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-72bd4e74edce> in <module>()
# ----> 1 temp1=nearst_mean(labels=y_train).fit(X_train)
#
# <ipython-input-36-34acce1dd1c1> in fit(self, X, y)
#      19             m_dis=distance.cdist(X,mean_k,metric='mahalanobis',VI=col_k).ravel()
#      20             self.maha_dis.append(m_dis)
# ---> 21             m_dis_index=pd.Series((distance.cdist(X,mean_k,metric='mahalanobis',VI=col_k)).ravel())                .sort_values(ascending=True).index[0]
#      22             k_label=self.labels.loc[m_dis_index]
#      23             self.center_label.append(k_label)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    1708         idx = _default_index(len(self))
#    1709
# -> 1710         argsorted = _try_kind_sort(arr[good])
#    1711
#    1712         if is_list_like(ascending):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _try_kind_sort(arr)
#    1694             try:
#    1695                 # if kind==mergesort, it can fail for object dtype
# -> 1696                 return arr.argsort(kind=kind)
#    1697             except TypeError:
#    1698                 # stable sort not available for object dtype
#
# KeyboardInterrupt:

# %%
#first apply nearest mean classifier
nn_clf=KNeighborsClassifier(n_neighbors=1,weights='distance',metric="mahalanobis",metric_params={'V':X_train.cov()},n_jobs=-1)
nn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='mahalanobis',
#            metric_params={'V':           0         1         2         3         4
# 0  0.012394 -0.018409 -0.009229 -0.051703  0.033214
# 1 -0.018409  0.310909  0.062330  0.285187  0.029046
# 2 -0.009229  0.062330  0.146432  0.079157 -0.007718
# 3 -0.051703  0.285187  0.079157  0.852209 -0.038779
# 4  0.033214  0.029046 -0.007718 -0.038779  0.775245},
#            n_jobs=-1, n_neighbors=1, p=2, weights='distance')

# %%
np.random.seed(42)
index=np.random.choice(X_train.shape[0],size=np.int(X_train.shape[0]*0.001),replace=False)

# %% [markdown]
# we use the f1 score to analysis our model, $$P_{f1}=2*\frac{1}{\frac{1}{P_{recall}}+\frac{1}{P_{precision}}}$$

# %%
X_train_select,y_train_select=X_train.loc[index],y_train.loc[index]
#f1 scores
y_pred=nn_clf.predict(X_train)
y_proba=nn_clf.predict_proba(X_train)
f1_score(y_train,y_pred)

# %%
y_train_select=np.array(y_train_select.tolist())

# %%
#calculate tp amd fp
y_score=y_proba[:,1]
fp_nn,tp_nn,thresholds_nn=roc_curve(y_train_select,y_score,pos_label=2)

# %%
#plot the ROC
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    
plot_roc_curve(fp_nn,tp_nn,label='Nearest Mean')
plt.show()

# %%
#then apply k nearest mean classifier
knn_clf=KNeighborsClassifier(n_neighbors=5,weights='distance',metric="mahalanobis",metric_params={'V':X_train.cov()},n_jobs=-1)
knn_clf.fit(X_train,y_train)

# %%
X_train_select,y_train_select=X_train.loc[index],y_train.loc[index
X_train_select.shape

# %%
#f1 scores
y_pred=knn_clf.predict(X_train_select)
y_proba=knn_clf.predict_proba(X_train_select)
f1_score(y_train_select,y_pred)

# %%
#calculate tp amd fp
y_score=y_proba[:,1]
fp_knn,tp_knn,thresholds_knn=roc_curve(y_train_select,y_score,pos_label=2)

# %%
plt.plot(fp_knn,tp_knn,"b-",label="K nearest mean")
plot_roc_curve(fp_nn,tp_nn,label='Nearest Mean')
plt.legend()
plt.show()

# %%
#accuracy
accuracy_score(y_train_select,y_pred)

# %% [markdown]
# from above we see the f1 scores of training set is 0.9279

# %%
X_val=feature_eng.transform(X_val)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
index_val=np.random.choice(X_val.shape[0],size=np.int(X_val.shape[0]*0.1),replace=False)
X_val_select,y_val_select=X_val.loc[index_val],y_val.loc[index_val]

# %%
y_pred=nn_clf.predict(X_val_select)
f1_score(y_val_select,y_pred)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py:131: RuntimeWarning: invalid value encountered in sqrt
#   return [func(*args, **kwargs) for func, args, kwargs in self.items]
# 0.9742102665350445

# %%
#use random forest to make a test
rdf_clf=RandomForestClassifier(random_state=42)
y_proba=cross_val_predict(rdf_clf,X_train,y_train,cv=3,method="predict_proba")

# %%
y_score=y_proba[:,1]
fp_rdf,tp_rdf,thresholds_rdf=roc_curve(y_train,y_score,pos_label=2)

# %%
plot_roc_curve(fp_rdf,tp_rdf,label='randomforest')

# %% [markdown]
# then we use the attributes of random forest **feature importance** to analysis features

# %%
rdf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=42,
#             verbose=0, warm_start=False)

# %%
importance=rdf_clf.feature_importances_
features=["T2 weighted","ADC","Ktrans","Kep","PET"]

# %%
#using the attribute of random forest to analysis the importances of features
def plot_feature_imp(importance,features):
    trace2 = go.Bar(
        x=importance,
        y=features,
        marker=dict(
            color=importance,
            colorscale = 'Viridis',
            reversescale = True
        ),
        name='Random Forest Feature importance',
        orientation='h',
    )
    layout = dict(
        title='Barplot of Feature importances',
         width = 700, height = 400,
        yaxis=dict(
            showgrid=False,
            showline=False,
            showticklabels=True,
#             domain=[0, 0.85],
        ))

    fig1 = go.Figure(data=[trace2])
    fig1['layout'].update(layout)
    py.iplot(fig1, filename='plots')

# %%
 plot_feature_imp(importance,features)
# Out:
# <div id="0afe991f-8b65-463c-9b5d-38d165c2fc0f" style="height: 400px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0afe991f-8b65-463c-9b5d-38d165c2fc0f", [{"type": "bar", "x": [0.3680273328247416, 0.1506854141033239, 0.13552236449776972, 0.2079107374461479, 0.1378541511280169], "y": ["T2 weighted", "ADC", "Ktrans", "Kep", "PET"], "marker": {"color": [0.3680273328247416, 0.1506854141033239, 0.13552236449776972, 0.2079107374461479, 0.1378541511280169], "colorscale": "Viridis", "reversescale": true}, "name": "Random Forest Feature importance", "orientation": "h"}], {"title": "Barplot of Feature importances", "width": 700, "height": 400, "yaxis": {"showgrid": false, "showline": false, "showticklabels": true}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # 5.Feature selection

# %% [markdown]
# # 6. Prediction & Visualization

# %% [markdown]
# ## 6.1 plot prediction on the image

# %% [markdown]
# first we try to plot the prediction and plot it on the T2 weighted

# %%
#set up a test_sample(one slice feature image)
test_sample=data[1][0][0][0][0][:,:,40,:]
test_sample=pd.DataFrame(test_sample.reshape(test_sample.shape[0]*test_sample.shape[1],5),\
                         columns=["0","1","2","3","4"])
#test_sample.isnull()
feature_eng.transform(test_sample)
test_label=data[1][0][0][0][1][:,:,40]
test_shape=test_label.shape
test_label=pd.DataFrame(test_label.reshape(-1,1),columns=['columns'])
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.

# %%
#predict function
def predict_sample(X,y,clf):
    label=[]
    for i in range(len(X)):
        if np.int(y.iloc[i]) == 0:
            label.append(np.float64(0.0))
        else:
            label.append(np.float64(clf.predict(X.iloc[i])))
    label=pd.DataFrame(label,columns=['label'])
    return label

# %%
#the predicted label
new_label=predict_sample(test_sample,test_label,rdf_clf)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# ...
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.

# %%
#plot the test sample(image and label)
def plot_prediction(test_shape,test_sample,new_label,feature): 
    #the feature contains ['0','1','2','3','4'] represent five features respectively
    #change the dataframe to ndarray
    image_size=test_sample[feature].values.reshape(test_shape[0],test_shape[1])
    image_label=new_label.values.reshape(test_shape[0],test_shape[1])
    
    #set up cmap
    cmap1 = matplotlib.colors.LinearSegmentedColormap.\
    from_list('my_cmap',['black','red','blue'],256)
    plt.imshow(image_size,cmap = matplotlib.cm.binary,alpha=0.8)
    plt.imshow(image_label,cmap = cmap1,interpolation="bilinear",alpha=0.2)
    plt.axis("off") #close the axis number
    plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title("original label")
plot_prediction(test_shape,test_sample,test_label,'0')
plt.figure(figsize=(8,4))
plt.subplot(122)
plt.title("our prediction")
plot_prediction(test_shape,test_sample,new_label,'0')

# %% [markdown]
# ## 6.2 plot the decision boundary on 2 features

# %%
def plot_decision_boundary(test_sample,feature,clf):
    
    step=0.01
    f0_min,f0_max=test_sample.values[:,0].min(),test_sample.values[:,0].max()
    f1_min,f1_max=test_sample.values[:,1].min(),test_sample.values[:,1].max()
    f2_min,f2_max=test_sample.values[:,2].min(),test_sample.values[:,2].max()
    f3_min,f3_max=test_sample.values[:,3].min(),test_sample.values[:,3].max()
    f4_min,f4_max=test_sample.values[:,4].min(),test_sample.values[:,4].max()
    
    f_0,f_1=np.meshgrid(np.arange(f0_min,f0_max,step),np.arange(f1_min,f1_max,step))#,\
                     #np.arange(f2_min,f2_max,step),np.arange(f3_min,f3_max,step),\
                     #np.arange(f4_min,f4_max,step))
    return f_0

# %%
step=0.1
X_min,X_max=test_sample.values[:,0].min()-1,test_sample.values[:,0].max()+1
Y_min,Y_max=test_sample.values[:,3].min()-1,test_sample.values[:,1].max()+1
xx,yy=np.meshgrid(np.arange(X_min,X_max,step),np.arange(Y_min,Y_max,step))

X_grid=np.array([xx.ravel(),yy.ravel()]).T

# %%
X_grid.shape
# Out:
# (7308, 2)

# %%
X_predict=np.zeros((X_grid.shape[0],5))
X_predict[:,0]=X_grid[:,0]
X_predict[:,3]=X_grid[:,1]
X_predict[:,1],X_predict[:,2],X_predict[:,4]=1,1,2
Z=rdf_clf.predict(X_predict)
Z=Z.reshape(xx.shape)

plt.contourf(xx,yy,Z,cmap=plt.cm.coolwarm,alpha=1)

# %%
plot_decision_boundary(test_sample).shape
# Out:
# (2260, 89)

# %%
test_label.astype('int').values.ravel()
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
sample=pd.concat([test_sample,new_label],axis=1)
set_1=sample.loc[sample['label']==1]
set_2=sample.loc[sample['label']==2]

# %%
test_sample.values.min()
# Out:
# -2.497139866393371
