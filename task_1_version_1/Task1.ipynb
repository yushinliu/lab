# %% [markdown]
# this is a classification problem and we got original data which contains 5 features and 3 labels, each pixel can regarded as a sample

# %% [markdown]
# # 1.Frame the problem

# %% [markdown]
# # 2.Input the data

# %%
#all packages which will be used
import numpy as np
import pandas as pd
from scipy.io import loadmat
import time
import random

#plot
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from matplotlib.axes import Axes

#sklearn
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

#from sklearn.cluster import KMeans
from sklearn import neighbors
from sklearn.cluster import MiniBatchKMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestNeighbors
#from sklearn.metrics import precision_score, recall_score,f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.kernel_approximation import RBFSampler #change the linear kernel into RBF
#to plot more than 2 dimensions 
from mlxtend.plotting import plot_decision_regions

#scipy
from scipy.stats import chisquare
from scipy.stats import chi2
from scipy.spatial import distance

#good performance classifier
from xgboost import XGBClassifier

#Tensorflow
import tensorflow as tf


#math
from math import log
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# first we imported the data from the '.mat'

# %%
dataset = loadmat ("D:\\lab; signal processing\\forStudents\\medData\\dataset.mat",mat_dtype=True)

# %%
data=dataset["dataset"]
type(data)
# Out:
# numpy.ndarray

# %% [markdown]
# then we try to plot one image to see what it looks like

# %%
data[12][0][0][0][3].shape
#for element in data[12][0][0][0][1][:,:,20].flat:
    #assert element == 0
# Out:
# (320, 320, 43)

# %%
for i in range(len(data)):
    print(data[i][0][0][0][0][:,:,:,1].shape)
    
len(data)
# Out:
# (34, 41, 31)
# (80, 82, 82)
# (82, 74, 80)
# (89, 102, 85)
# (66, 78, 62)
# (69, 83, 66)
# (50, 57, 48)
# (55, 69, 54)
# (64, 65, 63)
# (99, 83, 80)
# (107, 99, 85)
# (320, 320, 39)
# (320, 320, 43)
# (320, 320, 39)
# 14

# %%
sum = 0
for i in range (len(data)):
    sum = sum + data[i][0][0][0][0].size
sum
# Out:
# 85436685

# %%
def plot_image(data,stuck,slices,features,alphapara,cmap):
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image=target_data.reshape(target_data.shape[0],target_data.shape[1])
    plt.imshow(target_image,cmap,alpha=alphapara)
    plt.axis("off") #close the axis number

# %%
def plot_setimage(stuck,slices):
    features = 0
    plt.figure(figsize=(8,4))
    alphapara = 1;
    cmap = matplotlib.cm.binary
    plt.subplot(151)
    plt.title("T2 weighted")
    plot_image(data,stuck,slices,features,alphapara,cmap)
    plt.show()

    plt.subplot(152)
    plt.title("ADC")
    plot_image(data,stuck,slices,features+1,alphapara,cmap)
    plt.show()

    plt.subplot(153)
    plt.title("Ktrans")
    plot_image(data,stuck,slices,features+2,alphapara,cmap)
    plt.show()

    plt.subplot(154)
    plt.title("Kep")
    plot_image(data,stuck,slices,features+3,alphapara,cmap)
    plt.show()

    plt.subplot(155)
    plt.title("PET")
    plot_image(data,stuck,slices,features+4,alphapara,cmap)
    plt.show()

# %%
stuck,slices= 1, 12
plot_setimage(stuck,slices)

# %% [markdown]
# then we try to find out the labels distribution

# %% [markdown]
# then we try to use a function to plot the prostate and cancer area on the feature image

# %%
cmap1 = matplotlib.colors.LinearSegmentedColormap.from_list('my_cmap',['black','green','blue'],256)
def plot_all(data,stuck,index,slices,features):
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image1=target_data.reshape(target_data.shape[0],target_data.shape[1])
    target_label=data[stuck][0][0][0][index][:,:,slices]
    target_image2=target_label.reshape(target_label.shape[0],target_label.shape[1])
    plt.imshow(target_image1,cmap = matplotlib.cm.binary,alpha=0.8)
    plt.imshow(target_image2,cmap = cmap1,interpolation="bilinear",alpha=0.2)
    plt.axis("off") #close the axis number

# %%
stuck,slices,index,features=8,24,1,4
#plot_image(data,stuck,slices,0)
#plot_label(data,stuck,2,slices)
plot_all(data,stuck,index,slices,features)
plt.show()

# %% [markdown]
# # 3. Exploring the features

# %% [markdown]
# ## 3.1 Extract prostate region

# %% [markdown]
# we can find that 1-11 strucks are expected by experts and 12-14 are histological analysis because it is more reliable than the experts,and later 1-11 strucks will be out training set and 12-14 will be out validation set

# %%
'''
#extract prostate area from the original map 
experts_num,histo_num=11,3
label_final=[]
for i in range(experts_num):
    labelA=data[i][0][0][0][1]
    labelB=data[i][0][0][0][2]
    for index,(item_A,item_B) in enumerate(zip(labelA.flat,labelB.flat)):
        #use enumerate to iterate the items in labelA and labelB respectively
                if item_A == item_B:
                    pass
                else:
                    labelA.flat[index]=0
    label_final.append(labelA)
'''
# Out:
# '\n#extract prostate area from the original map \nexperts_num,histo_num=11,3\nlabel_final=[]\nfor i in range(experts_num):\n    labelA=data[i][0][0][0][1]\n    labelB=data[i][0][0][0][2]\n    for index,(item_A,item_B) in enumerate(zip(labelA.flat,labelB.flat)):\n        #use enumerate to iterate the items in labelA and labelB respectively\n                if item_A == item_B:\n                    pass\n                else:\n                    labelA.flat[index]=0\n    label_final.append(labelA)\n'

# %% [markdown]
# then append the histological struck

# %%
'''
#for the 
for j in range(histo_num):
    labelC=data[j+11][0][0][0][3]
    label_final.append(labelC)

label=np.array(label_final)
label.shape
'''
# Out:
# '\n#for the \nfor j in range(histo_num):\n    labelC=data[j+11][0][0][0][3]\n    label_final.append(labelC)\n\nlabel=np.array(label_final)\nlabel.shape\n'

# %% [markdown]
# then our task divided into two parts:
# - isolate the feature vector of prostate tissure from the whole set
# - try to transfer first feature TR wighted MR images

# %% [markdown]
# then let us create train data set and validation set respectively

# %%
'''
train_data=data[:experts_num]
train_label=label[:experts_num]
val_data=data[:-experts_num]
val_label=label[:-experts_num]
val_label.shape
'''
# Out:
# '\ntrain_data=data[:experts_num]\ntrain_label=label[:experts_num]\nval_data=data[:-experts_num]\nval_label=label[:-experts_num]\nval_label.shape\n'

# %%
'''
train_isolated_feature=[]
train_isolated_label=[]
val_isolated_feature=[]
val_isolated_label=[]
def isolate_feature(data,label,isolated_feature,isolated_label):
    for i in range(len(data)):
        image=data[i][0][0][0][0]
        target_image=image.reshape(image.shape[0]*image.shape[1]*image.shape[2],image.shape[3])
        target_label=label[i].reshape(-1,1)
        for index,item in enumerate(target_label):
            if item == 0 :
                pass
            else:
                isolated_label.append(item)
                isolated_feature.append(target_image[index])
    return isolated_feature,isolated_label
        

isolate_feature(train_data,train_label,train_isolated_feature,train_isolated_label)
isolate_feature(val_data,val_label,val_isolated_feature,val_isolated_label)

print(len(train_isolated_feature))
'''
# Out:
# '\ntrain_isolated_feature=[]\ntrain_isolated_label=[]\nval_isolated_feature=[]\nval_isolated_label=[]\ndef isolate_feature(data,label,isolated_feature,isolated_label):\n    for i in range(len(data)):\n        image=data[i][0][0][0][0]\n        target_image=image.reshape(image.shape[0]*image.shape[1]*image.shape[2],image.shape[3])\n        target_label=label[i].reshape(-1,1)\n        for index,item in enumerate(target_label):\n            if item == 0 :\n                pass\n            else:\n                isolated_label.append(item)\n                isolated_feature.append(target_image[index])\n    return isolated_feature,isolated_label\n        \n\nisolate_feature(train_data,train_label,train_isolated_feature,train_isolated_label)\nisolate_feature(val_data,val_label,val_isolated_feature,val_isolated_label)\n\nprint(len(train_isolated_feature))\n'

# %%
experts_num,histo_num=11,3
train_index_matrix = []
train_isolated_feature0=[]
train_isolated_feature1=[]
train_isolated_feature2=[]
train_isolated_feature3=[]
train_isolated_feature4=[]
train_isolated_label=[]
train_sourceofpixels = []
for i in range(experts_num):
    feature0 = data [i][0][0][0][0][:,:,:,0]
    feature1 = data [i][0][0][0][0][:,:,:,1]
    feature2 = data [i][0][0][0][0][:,:,:,2]
    feature3 = data [i][0][0][0][0][:,:,:,3]
    feature4 = data [i][0][0][0][0][:,:,:,4]
    tempA = data[i][0][0][0][1]
    tempB = data[i][0][0][0][2]
    ita = np.nditer(tempA, flags =['multi_index'])
    itb = np.nditer(tempB, flags =['multi_index'])
    itf0 = np.nditer(feature0,flags =['multi_index'])
    itf1 = np.nditer(feature1,flags =['multi_index'])
    itf2 = np.nditer(feature2,flags =['multi_index'])
    itf3 = np.nditer(feature3,flags =['multi_index'])
    itf4 = np.nditer(feature4,flags =['multi_index'])
    while not ita.finished:
        if ((ita[0]==1)&(itb[0]==1)):
            train_isolated_feature0.append(itf0[0])
            train_isolated_feature1.append(itf1[0])
            train_isolated_feature2.append(itf2[0])
            train_isolated_feature3.append(itf3[0])
            train_isolated_feature4.append(itf4[0])
            train_isolated_label.append(ita[0])
            train_index_matrix.append(np.array(ita.multi_index))
            train_sourceofpixels.append(i)
        elif ((ita[0]==2)&(itb[0]==2)):
            train_isolated_feature0.append(itf0[0])
            train_isolated_feature1.append(itf1[0])
            train_isolated_feature2.append(itf2[0])
            train_isolated_feature3.append(itf3[0])
            train_isolated_feature4.append(itf4[0])
            train_isolated_label.append(ita[0])
            train_index_matrix.append(np.array(ita.multi_index))
            train_sourceofpixels.append(i)
        else:
            pass
        '''    
        elif((ita[0] == 1)&(itb[0]== 2)):
            train_isolated_feature0.append(itf0[0])
            train_isolated_feature1.append(itf1[0])
            train_isolated_feature2.append(itf2[0])
            train_isolated_feature3.append(itf3[0])
            train_isolated_feature4.append(itf4[0])
            train_isolated_label.append(ita[0])
            train_index_matrix.append(np.array(ita.multi_index))
            train_sourceofpixels.append(i)
        elif((ita[0] ==2) & (itb[0]==1)):
            train_isolated_feature0.append(itf0[0])
            train_isolated_feature1.append(itf1[0])
            train_isolated_feature2.append(itf2[0])
            train_isolated_feature3.append(itf3[0])
            train_isolated_feature4.append(itf4[0])
            train_isolated_label.append(itb[0])
            train_index_matrix.append(np.array(ita.multi_index))
            train_sourceofpixels.append(i)
        ''' 
        itf0.iternext()
        itf1.iternext()
        itf2.iternext()
        itf3.iternext()
        itf4.iternext()
        itb.iternext()
        ita.iternext()

# %%
tempdic_train = {'label':train_isolated_label, 'sourceofpixel':train_sourceofpixels, 'indexofpixel':train_index_matrix,'feature0':train_isolated_feature0,'feature1':train_isolated_feature1,'feature2':train_isolated_feature2,'feature3':train_isolated_feature3,'feature4':train_isolated_feature4}
train_data= pd.DataFrame(data=tempdic_train)

# %%
tempdic_train = {'feature0':train_isolated_feature0,'feature1':train_isolated_feature1,'feature2':train_isolated_feature2,'feature3':train_isolated_feature3,'feature4':train_isolated_feature4}
train_feature= pd.DataFrame(data=tempdic_train)

# %%
tempdic_train = {'label':train_isolated_label, 'sourceofpixel':train_sourceofpixels, 'indexofpixel':train_index_matrix}
train_label= pd.DataFrame(data=tempdic_train)

# %%
train_label
# Out:
#         indexofpixel label  sourceofpixel
# 0         [9, 10, 0]   1.0              0
# 1        [10, 10, 0]   1.0              0
# 2        [11, 10, 0]   1.0              0
# 3        [12, 10, 0]   1.0              0
# 4        [13, 10, 0]   1.0              0
# 5        [14, 10, 0]   1.0              0
# 6        [15, 10, 0]   1.0              0
# 7        [16, 10, 0]   1.0              0
# 8         [6, 11, 0]   1.0              0
# 9         [7, 11, 0]   1.0              0
# 10        [8, 11, 0]   1.0              0
# 11        [9, 11, 0]   1.0              0
# 12       [10, 11, 0]   1.0              0
# 13       [11, 11, 0]   1.0              0
# 14       [12, 11, 0]   1.0              0
# 15       [13, 11, 0]   1.0              0
# 16       [14, 11, 0]   1.0              0
# 17       [15, 11, 0]   1.0              0
# 18       [16, 11, 0]   1.0              0
# 19       [17, 11, 0]   1.0              0
# 20       [18, 11, 0]   1.0              0
# 21       [19, 11, 0]   1.0              0
# 22       [20, 11, 0]   1.0              0
# 23        [5, 12, 0]   1.0              0
# 24        [6, 12, 0]   1.0              0
# 25        [7, 12, 0]   1.0              0
# 26        [8, 12, 0]   1.0              0
# 27        [9, 12, 0]   1.0              0
# 28       [10, 12, 0]   1.0              0
# 29       [11, 12, 0]   1.0              0
# ...              ...   ...            ...
# 355425  [48, 58, 54]   2.0             10
# 355426  [49, 58, 54]   2.0             10
# 355427  [50, 58, 54]   2.0             10
# 355428  [51, 58, 54]   2.0             10
# 355429  [37, 59, 54]   1.0             10
# 355430  [38, 59, 54]   1.0             10
# 355431  [39, 59, 54]   1.0             10
# 355432  [40, 59, 54]   1.0             10
# 355433  [41, 59, 54]   1.0             10
# 355434  [44, 59, 54]   2.0             10
# 355435  [45, 59, 54]   2.0             10
# 355436  [46, 59, 54]   2.0             10
# 355437  [47, 59, 54]   2.0             10
# 355438  [48, 59, 54]   2.0             10
# 355439  [49, 59, 54]   2.0             10
# 355440  [50, 59, 54]   2.0             10
# 355441  [38, 60, 54]   1.0             10
# 355442  [39, 60, 54]   1.0             10
# 355443  [40, 60, 54]   1.0             10
# 355444  [41, 60, 54]   1.0             10
# 355445  [42, 60, 54]   1.0             10
# 355446  [43, 60, 54]   1.0             10
# 355447  [44, 60, 54]   1.0             10
# 355448  [46, 60, 54]   2.0             10
# 355449  [47, 60, 54]   2.0             10
# 355450  [48, 60, 54]   2.0             10
# 355451  [43, 61, 54]   1.0             10
# 355452  [44, 61, 54]   1.0             10
# 355453  [45, 61, 54]   1.0             10
# 355454  [46, 61, 54]   1.0             10
#
# [355455 rows x 3 columns]

# %%
validation_index_matrix = []
validation_isolated_feature0=[]
validation_isolated_feature1=[]
validation_isolated_feature2=[]
validation_isolated_feature3=[]
validation_isolated_feature4=[]
validation_isolated_label=[]
validation_sourceofpixel = []
for i in range(histo_num):
    temp_label = data[i+11][0][0][0][3]
    temp_feature0 = data[i+11][0][0][0][0][:,:,:,0]
    temp_feature1 = data[i+11][0][0][0][0][:,:,:,1]
    temp_feature2 = data[i+11][0][0][0][0][:,:,:,2]
    temp_feature3 = data[i+11][0][0][0][0][:,:,:,3]
    temp_feature4 = data[i+11][0][0][0][0][:,:,:,4]
    it_label = np.nditer(temp_label, flags=['multi_index'])
    it_feature0 = np.nditer(temp_feature0, flags=['multi_index'])
    it_feature1 = np.nditer(temp_feature1, flags=['multi_index'])
    it_feature2 = np.nditer(temp_feature2, flags=['multi_index'])
    it_feature3 = np.nditer(temp_feature3, flags=['multi_index'])
    it_feature4 = np.nditer(temp_feature4, flags=['multi_index'])
    while not it_label.finished:
        if (it_label[0] != 0 ):
            validation_isolated_feature0.append(it_feature0[0])
            validation_isolated_feature1.append(it_feature1[0])
            validation_isolated_feature2.append(it_feature2[0])
            validation_isolated_feature3.append(it_feature3[0])
            validation_isolated_feature4.append(it_feature4[0])
            validation_isolated_label.append(it_label[0])
            validation_index_matrix.append(np.array(it_label.multi_index))
            validation_sourceofpixel.append(i+11)
        else:
            pass
        it_feature0.iternext()
        it_feature1.iternext()
        it_feature2.iternext()
        it_feature3.iternext()
        it_feature4.iternext()
        it_label.iternext()

# %%
tempdic_validation = {'label':validation_isolated_label , 'sourceofpixel':validation_sourceofpixel, 'indexofpixel':validation_index_matrix,'feature0':validation_isolated_feature0,'feature1':validation_isolated_feature1,'feature2':validation_isolated_feature2,'feature3':validation_isolated_feature3,'feature4':validation_isolated_feature4}
validation_data = pd.DataFrame(data=tempdic_validation)

# %%
tempdic_validation = {'label':validation_isolated_label , 'sourceofpixel':validation_sourceofpixel, 'indexofpixel':validation_index_matrix}
validation_label = pd.DataFrame(data=tempdic_validation)

# %%
tempdic_validation = {'feature0':validation_isolated_feature0,'feature1':validation_isolated_feature1,'feature2':validation_isolated_feature2,'feature3':validation_isolated_feature3,'feature4':validation_isolated_feature4}
validation_feature=pd.DataFrame(data=tempdic_validation)

# %%
train_feature.to_csv("D:\\lab; signal processing\\forStudents\\medData\\train_feature.csv",index=True)
train_label.to_csv("D:\\lab; signal processing\\forStudents\\medData\\train_label.csv",index=True)
validation_feature.to_csv("D:\\lab; signal processing\\forStudents\\medData\\validation_feature.csv",index=True)
validation_label.to_csv("D:\\lab; signal processing\\forStudents\\medData\\validation_label.csv",index=True)

# %% [markdown]
# ## 3.2 Normalization & Outliers detection

# %% [markdown]
# so we see we isolated the 355455 prostate features from the 4696937 the whole train set

# %% [markdown]
# then try to construct the whole pipeline of the features enginerring
# - Transform the first feature TR wighted
# - normalize all the features
# - Outlier detection and removal

# %%
X_train=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\train_feature.csv")
y_train=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\train_label.csv")
X_val=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\validation_feature.csv")
y_val=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\validation_label.csv")

# %%
scaler1=MinMaxScaler(feature_range=(0, 1), copy=True)
class Feature_scaling(BaseEstimator,TransformerMixin):
    def fit(self,X,y=None):
        scaler1.fit(np.array(X['feature0']).reshape(-1,1))
        return self
    def transform(self,X,y=None):
        X['feature0']=scaler1.transform(np.array(X['feature0']).reshape(-1,1))
        return X

# %%
scaler2=StandardScaler()
class Normalization(BaseEstimator,TransformerMixin):
    def fit(self,X,y=None):
        scaler2.fit(X[['feature1','feature2','feature3','feature4']])
        return self
    def transform(self,X,y=None):
        X[['feature1','feature2','feature3','feature4']]=scaler2.transform(X[['feature1','feature2','feature3','feature4']])
        return pd.DataFrame(X)

# %%
feature_eng=Pipeline([("feature_scale",Feature_scaling()),
                     ("normalization",Normalization())])

# %%
feature_eng.fit_transform(X_train.drop('Unnamed: 0',1))
# Out:
#         feature0  feature1  feature2  feature3  feature4
# 0       0.557963  0.286907 -0.298482 -0.671537 -1.611109
# 1       0.526320  0.285209 -0.302723 -0.624315 -1.479327
# 2       0.529836  0.221792 -0.305188 -0.571669 -1.616350
# 3       0.529867  0.130994 -0.304649 -0.559207 -1.440395
# 4       0.545996  0.079095 -0.304922 -0.578629 -1.689022
# 5       0.541738  0.018793 -0.308985 -0.630179 -1.620275
# 6       0.549538 -0.065230 -0.311815 -0.679857 -1.797061
# 7       0.556883 -0.134095 -0.312235 -0.653669 -1.710650
# 8       0.682539  0.349727 -0.295720 -0.879661 -0.336726
# 9       0.660407  0.245014 -0.304999 -0.889284 -0.615679
# 10      0.627345  0.168739 -0.307814 -0.916704 -0.865166
# 11      0.593671  0.070854 -0.313008 -0.922771 -1.437015
# 12      0.559372 -0.078232 -0.321987 -0.870124 -1.582766
# 13      0.532778 -0.177533 -0.323227 -0.817478 -1.538269
# 14      0.519742 -0.209621 -0.317097 -0.826345 -1.182052
# 15      0.497474 -0.217494 -0.314132 -0.877895 -1.665984
# 16      0.502026 -0.265669 -0.317835 -0.927722 -1.781468
# 17      0.506485 -0.321122 -0.318356 -0.917181 -1.925174
# 18      0.517203 -0.359712 -0.315545 -0.924859 -1.777884
# 19      0.531328 -0.393264 -0.314956 -0.932011 -1.739438
# 20      0.535092 -0.433106 -0.317775 -0.938378 -1.641955
# 21      0.557842 -0.460713 -0.319514 -0.936185 -1.342174
# 22      0.559511 -0.472855 -0.322124 -0.948786 -1.607959
# 23      0.725600  0.463269 -0.263526 -0.946588 -0.431959
# 24      0.710279  0.274594 -0.291299 -0.975626  0.186065
# 25      0.682631  0.082605 -0.311219 -1.003047 -0.189016
# 26      0.647816 -0.043868 -0.318022 -0.985872 -0.465827
# 27      0.611766 -0.184835 -0.323059 -0.920372 -0.802791
# 28      0.565206 -0.333221 -0.329553 -0.867725 -0.803806
# 29      0.526444 -0.372172 -0.327494 -0.865706 -0.977214
# ...          ...       ...       ...       ...       ...
# 355425  0.327383  0.091953 -0.183634  0.232556 -0.272602
# 355426  0.314892 -0.025140 -0.185217  0.279726 -0.254665
# 355427  0.293122 -0.176049 -0.191378  0.308258 -0.195663
# 355428  0.301637 -0.274151 -0.198179  0.195853 -0.774327
# 355429  0.353686 -0.657679 -0.263937 -1.011251 -1.468269
# 355430  0.408403 -0.747587 -0.283365 -0.966125 -1.516685
# 355431  0.465097 -0.666342 -0.274411 -0.920104 -1.238921
# 355432  0.483357 -0.074371 -0.102765 -0.867521 -0.427034
# 355433  0.507474  0.312362  0.394473 -0.796231 -0.899133
# 355434  0.573753  0.185244  0.048731 -0.411751  0.374868
# 355435  0.462823  0.010702 -0.153059 -0.398403  0.023149
# 355436  0.441982  0.034060 -0.163581 -0.268640 -0.675780
# 355437  0.405921  0.025681 -0.149025 -0.067263 -0.319320
# 355438  0.345704 -0.025250 -0.143538  0.112185 -0.273994
# 355439  0.401108 -0.096394 -0.147321  0.096451 -0.349132
# 355440  0.337121 -0.167050 -0.154891  0.134492  0.017862
# 355441  0.373447 -0.771599 -0.273067 -0.954420 -1.488060
# 355442  0.432280 -0.630442 -0.260611 -0.946476 -0.753270
# 355443  0.480887 -0.159703 -0.128130 -0.922321  0.130828
# 355444  0.512444  0.245003  0.242872 -0.849670 -0.960804
# 355445  0.460757  0.323648  0.522798 -0.729719 -1.097740
# 355446  0.450866  0.236179  0.299115 -0.483843 -0.470654
# 355447  0.574457  0.057955 -0.044238 -0.470494  0.506151
# 355448  0.458157 -0.039751 -0.162826 -0.345786 -0.374283
# 355449  0.424242 -0.106848 -0.121872 -0.148711 -0.234780
# 355450  0.431921 -0.201468 -0.090835 -0.076490 -0.363643
# 355451  0.427281  0.088665  0.017449 -0.542586 -1.027009
# 355452  0.618107 -0.049392 -0.150487 -0.596451  0.706511
# 355453  0.432677 -0.073922 -0.203510 -0.601505  1.156466
# 355454  0.488784 -0.049809 -0.161370 -0.427234 -0.216379
#
# [355455 rows x 5 columns]

# %%
#X_train_scaled=feature_eng.fit_transform(X_train.drop('Unnamed: 0',1))
X_val_scaled=feature_eng.transform(X_val.drop('Unnamed: 0',1))

# %%
X_val_scaled
# Out:
#        feature0  feature1  feature2  feature3  feature4
# 0      0.688302 -0.508974 -0.266269 -0.708827  0.480083
# 1      0.687955 -0.549401 -0.243492 -0.774610  0.952082
# 2      0.539413 -0.260003 -0.285134 -0.441109  2.077617
# 3      0.578095 -0.086173 -0.267538 -0.495074  0.719713
# 4      0.610395  0.024761 -0.256189 -0.540253 -0.100838
# 5      0.646486 -0.006060 -0.250115 -0.581308  0.654360
# 6      0.684466 -0.016312 -0.236356 -0.624755  1.358727
# 7      0.707766 -0.096102 -0.216974 -0.682210  2.244632
# 8      0.710252 -0.201589 -0.201712 -0.750188  2.847339
# 9      0.747768 -0.292518 -0.185280 -0.807845  3.159584
# 10     0.756463 -0.287159 -0.157328 -0.855946  3.370168
# 11     0.685786 -0.299786 -0.134019 -0.890441  2.934477
# 12     0.555469 -0.596079 -0.295295 -0.257727  2.063094
# 13     0.558888 -0.505683 -0.294332 -0.300136  2.208325
# 14     0.551833 -0.309814 -0.281762 -0.347311  2.179279
# 15     0.554567 -0.045217 -0.256531 -0.397906  2.491524
# 16     0.573634  0.202115 -0.232157 -0.442137  2.150233
# 17     0.603591  0.317621 -0.210462 -0.488577  0.850421
# 18     0.636521  0.356534 -0.200430 -0.534422  0.414729
# 19     0.673048  0.273456 -0.198786 -0.574661  1.605619
# 20     0.704855  0.213395 -0.187885 -0.611858  2.462478
# 21     0.730456  0.073816 -0.177096 -0.659502  3.014353
# 22     0.745839 -0.076999 -0.172350 -0.721892  3.275768
# 23     0.762593 -0.174106 -0.164785 -0.772106  3.878474
# 24     0.767394 -0.196778 -0.147504 -0.819115  3.624321
# 25     0.721592 -0.238096 -0.130152 -0.853511  3.471829
# 26     0.697487 -0.281039 -0.089109 -0.868581  3.856690
# 27     0.675974 -0.305462 -0.011404 -0.879889  2.687585
# 28     0.477919 -0.067957  2.647858 -0.826847 -0.522007
# 29     0.466443  0.164721  3.187640 -0.786363 -0.478437
# ...         ...       ...       ...       ...       ...
# 69997  0.415756 -0.277120 -0.291357  0.340031 -0.885083
# 69998  0.423042 -0.367681 -0.300478  0.241384 -0.507484
# 69999  0.430186 -0.316832 -0.294800  0.191317 -0.834252
# 70000  0.430427 -0.215662 -0.280600  0.177809 -0.885083
# 70001  0.423817 -0.056715 -0.260172  0.176767 -0.311422
# 70002  0.435511  0.093448 -0.234845  0.181352  0.044392
# 70003  0.454821  0.252293 -0.207990  0.186797 -0.202500
# 70004  0.461755  0.337265 -0.186019  0.287328 -0.079054
# 70005  0.467629  0.394089 -0.165403  0.374792 -0.456653
# 70006  0.478941  0.424553 -0.147644  0.396486 -0.420345
# 70007  0.485046  0.417059 -0.132302  0.418180  0.327591
# 70008  0.486213  0.389527 -0.129047  0.398079  1.925126
# 70009  0.487443  0.337298 -0.119041  0.349615  1.271589
# 70010  0.487141  0.273598 -0.125409  0.311278  0.501868
# 70011  0.347260  2.508033  0.034423  1.237654 -0.405822
# 70012  0.363127  2.049512 -0.034358  1.033319 -0.841513
# 70013  0.377051  1.504497 -0.105822  0.828983 -0.979482
# 70014  0.393482  0.830869 -0.182625  0.627913 -0.986744
# 70015  0.403796  0.438601 -0.222124  0.530819 -1.386127
# 70016  0.406320  0.036148 -0.263484  0.431074 -1.364343
# 70017  0.411968 -0.159727 -0.284797  0.332426 -0.943175
# 70018  0.421496 -0.233024 -0.292604  0.233779 -0.703545
# 70019  0.425383 -0.178528 -0.287453  0.188861 -0.543791
# 70020  0.419718 -0.078181 -0.274291  0.185718 -0.478437
# 70021  0.418928  0.051875 -0.258570  0.190303 -0.260592
# 70022  0.436336  0.188039 -0.236108  0.194887 -0.187977
# 70023  0.453522  0.292353 -0.216400  0.206936 -0.587360
# 70024  0.394595  0.823154 -0.197848  0.612366 -0.834252
# 70025  0.403147  0.528020 -0.218758  0.515336 -1.182805
# 70026  0.404985  0.125501 -0.258990  0.416688 -1.313512
#
# [70027 rows x 5 columns]

# %%
X_val_scaled.to_csv("D:\\lab; signal processing\\forStudents\\medData\\scaled_validation_feature.csv",index=True)
y_val.to_csv("D:\\lab; signal processing\\forStudents\\medData\\validation_label.csv",index=False)

# %%
#scaled transform and X_val and outpuy X_val
#X_val_scaled=feature_eng.transform(X_val)
#X_val_scaled.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_feature.csv",index=False)
#y_val.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\val_label.csv",index=False)

# %% [markdown]
# now, we try to apply the outliers detection first try the chi-square distribution$$\chi^2=\sum\frac{(A-E)^2}{E}$$

# %% [markdown]
# **there are two ways to approxiamte the MVE(minimum volume elliposid estimator)**
# - the resampling algorithm
# - the projection algorithm
#
# we can wirte three approxiamtion respectively,first calculate **mahalanbios distance** $$MD_i=\sqrt{(x_i-\mu)C^{-1}(x_i-\mu)^T}$$
# and after we get chi value of $MD$ we have can calculate $RD$(Robust distances) in the same equation but different approximation

# %%
class outliers_clean_direct(BaseEstimator,TransformerMixin):
    def __init__(self,p_free,labels,md_dis=pd.Series([]),y_dropped=pd.Series([]),p_value=0.):
        self.md_dis=md_dis
        self.y_dropped=labels
        self.p_value=p_value
        self.p_free=p_free
        self.labels=labels
    def fit(self,X,y=None):
        mean_value=np.array([X.mean()])
        covar_value=np.mat(X.cov().as_matrix()).I
        print("MD Start")
        self.md_dis=distance.cdist(X,mean_value,metric='mahalanobis',VI=covar_value).ravel()
        print("MD end")
        chi2.fit(self.md_dis,self.p_free)
        self.p_value=np.sqrt(chi2.ppf(0.975,self.p_free))
        return self
    def transform(self,X,y=None): #should be changed to y_train
        count,count1,count2=0,0,0
        count1=X.shape[0]
        print("mahalanbios distance: ",self.md_dis)
        print("cutoff value: ",self.p_value)
        print("Drop Start")
        self.md_dis=pd.DataFrame(self.md_dis,columns=['maha_dis'])
        X=pd.concat([X,self.md_dis],axis=1)
        self.labels=pd.concat([self.labels,self.md_dis],axis=1)
        X=X[X['maha_dis']<=self.p_value]
        self.y_dropped=self.labels[self.labels['maha_dis']>self.p_value]
        self.labels=self.labels[self.labels['maha_dis']<=self.p_value]
        X=pd.DataFrame.reset_index(X).drop('index',axis=1)
        self.labels=pd.DataFrame.reset_index(self.labels).drop('index',axis=1)
        self.y_dropped=pd.DataFrame.reset_index(self.y_dropped).drop('index',axis=1)
        count2=X.shape[0]
        count=count1-count2
        print("Drop End")
        print("drop count:",count)
        return X,self.labels,self.y_dropped,self.md_dis

# %%
def plot_outliers(maha_dis,cdf1,cdf2,cdf3):
    x=range(len(maha_dis))
    plt.figure(figsize=(16,12))
    plt.scatter( x, maha_dis ,s=1)

    plt.hlines( np.sqrt(chi2.ppf(cdf1, 5)), 0, len(maha_dis), label ="%5f $\chi^2$ quantile"%(cdf1), linestyles = "solid" ) 
    plt.hlines( np.sqrt(chi2.ppf(cdf2, 5)), 0, len(maha_dis), label ="%5f $\chi^2$ quantile"%(cdf2), linestyles="dashed" ) 
    plt.hlines( np.sqrt(chi2.ppf(cdf3, 5)), 0, len(maha_dis), label ="%5f $\chi^2$ quantile"%(cdf3), linestyles = "dotted" )

    plt.legend()
    plt.ylabel("recorded value",fontsize=20)
    plt.xlabel("observation",fontsize=20)
    plt.title( 'Detection of outliers at different $\chi^2$ quantiles',fontsize=25 )

    plt.show()

# %%
X_train_scaled=feature_eng.fit_transform(X_train)
X_train_direct,y_train_direct,y_directlydropped,maha_dis=outliers_clean_direct(p_free=5,labels=y_train.copy()).fit_transform(X_train_scaled)
# Out:
# MD Start
# MD end
# mahalanbios distance:  [ 2.52783671  2.42392853  2.46421446 ...,  2.44573182  2.44797091
#   1.97057822]
# cutoff value:  3.58224817594
# Drop Start
# Drop End
# drop count: 26706

# %%
import re
dataset = loadmat ("D:\\lab; signal processing\\forStudents\\medData\\dataset.mat",mat_dtype=True)
data = dataset ["dataset"]
cmap1 = matplotlib.colors.LinearSegmentedColormap.from_list('my_cmap',['black','green','blue'],256)
def check_resultofdropping (data,stuck,index,slices,features,selected,dropped):
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image1=target_data.reshape(target_data.shape[0],target_data.shape[1])
    target_label=data[stuck][0][0][0][index][:,:,slices]
    target_image2=target_label.reshape(target_label.shape[0],target_label.shape[1])
    plt.imshow(target_image1,cmap = matplotlib.cm.binary,alpha=0.4)
    plt.imshow(target_image2,cmap = cmap1,interpolation="bilinear",alpha=0.4)
    plt.axis("off") #close the axis number

    selected_x=[]
    selected_y=[]
    selected_matrix = selected[selected['sourceofpixel']==stuck]
    selected_matrix=pd.DataFrame.reset_index(selected_matrix).drop('index',axis=1)
    for i in range(len(selected_matrix)):
        temparr = re.findall("\d+",selected_matrix.iloc[i]['indexofpixel'])
        if (int(temparr[2]) == slices):
            selected_x.append(int(temparr[0]))
            selected_y.append(int(temparr[1]))
    plt.scatter(selected_y,selected_x, s = 3)
    
    dropped_x=[]
    dropped_y=[]
    dropped_matrix = dropped[dropped['sourceofpixel']==stuck]
    dropped_matrix = pd.DataFrame.reset_index(dropped_matrix).drop('index',axis=1)
    for i in range(len(dropped_matrix)):
        temparr = re.findall("\d+",dropped_matrix.iloc[i]['indexofpixel'])
        if (int(temparr[2]) == slices):
            dropped_x.append(int(temparr[0]))
            dropped_y.append(int(temparr[1]))
    plt.scatter(dropped_y,dropped_x, s = 2)
    plt.show()
    
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image1=target_data.reshape(target_data.shape[0],target_data.shape[1])
    target_label=data[stuck][0][0][0][index][:,:,slices]
    target_image2=target_label.reshape(target_label.shape[0],target_label.shape[1])
    plt.imshow(target_image1,cmap = matplotlib.cm.binary,alpha=0.4)
    plt.imshow(target_image2,cmap = cmap1,interpolation="bilinear",alpha=0.4)
    plt.axis("off") #close the axis number
    plt.show()

# %%
# the blue points are those we keep， and the orange points are those we drop.

# %%
stuck,slices,index,features=7,27,1,0
check_resultofdropping(data,stuck,index,slices,features,y_train_direct,y_directlydropped)

# %% [markdown]
# because the number of the subsample set $m$ satisfy $$1-(1-(1-0.5)^{p+1})^m\geq p_{distribution}$$ but this is a large number of groups and it will take a long time to calculate. Due to the paper we know the statistic order of the subset distance $m^2_{k+1}$ satisfly $$m^2_{k+1}\leq(\frac{V_k}{det(C_{k+1})})^{1/p}=M$$ so if $m^2_{k+1}$ exceed, then stop

# %%
#resampling algorithm
p_distr=0.975
n_subsamples=np.ceil(log((1-p_distr),1-(0.5)**6)).astype(int)
n_subsamples
# Out:
# 235

# %%
# robust distance
class outliers_clean_resampling(BaseEstimator,TransformerMixin):
    def __init__(self,p_free,labels,y_dropped=pd.Series([]),md_dis=pd.Series([]),p_value_1=0.,p_value_2=0.,h_value=0):
        self.md_dis=md_dis
        self.p_value_1=p_value_1
        self.p_value_2=p_value_2
        self.p_free=p_free
        self.h_value=h_value
        self.labels=labels
        self.y_dropped=labels
    def fit(self,X,y=None):
        self.h_value=np.int((X.shape[0]+self.p_free+1)/2)
        mean_value=np.array([X.mean()])
        cov_value=np.mat(X.cov().as_matrix()).I
        print("MD Start")
        self.md_dis=distance.cdist(X,mean_value,metric='mahalanobis',VI=cov_value).ravel()
        print("MD end")
        chi2.fit(self.md_dis,self.p_free)
        self.p_value_1=np.sqrt(chi2.ppf(0.99999999,self.p_free))
        self.p_value_2=np.sqrt(chi2.ppf(0.5,self.p_free))
        return self
    def transform(self,X,y=None):
        np.random.seed(30)
        mean_set,cov_set,m_dis_order,V_j=[],[],[],[]
        print("Resampling begin")
        start1=time.time()
        for subset in range(n_subsamples):
            if subset%1000==0:
                print("replications number:%d time:%5.1f minute"%(subset,(time.time()-start1)/60))
            sample_ID=[]
            for index in range(self.p_free+1):
                sample_ID.append(np.random.choice(range(len(X)),replace=False))
            X_tr=np.array(X.iloc[sample_ID])
            sub_mean=np.array([(1/(self.p_free+1))*np.sum(X_tr,axis=0)])
            mean_set.append(sub_mean)
            sub_cov=np.mat((1/(self.p_free))*np.dot((X_tr-sub_mean).T,(X_tr-sub_mean))).I
            cov_set.append(sub_cov) 
            m_dis=pd.Series((distance.cdist(X,sub_mean,metric='mahalanobis',VI=sub_cov)**2).ravel())\
            .sort_values(ascending=True).iloc[self.h_value] #ascending=True : from small to big
            #if subset != 0 :
                #if m_dis>=(V_j[subset-1]/sub_cov.I.det())**(1/self.p_free):
                    #break
                #else:
                    #pass
            m_dis_order.append(m_dis)
            V_j.append(m_dis*np.linalg.det(sub_cov))
        print("Resampling end")
        #print(m_dis_order[])
        J_index=pd.Series(V_j).sort_values(ascending=True).index.tolist()[0]
        m_dis_value=m_dis_order[J_index]
        robust_mean=mean_set[J_index]
        robust_cov=((1+15/(X.shape[0]-self.p_free))**2)*(1/self.p_value_2)*m_dis_value*cov_set[J_index]
        print("RD Start")
        robust_dis=distance.cdist(X,robust_mean,metric='mahalanobis',VI=robust_cov).ravel()
        print("RD end")
        print("Robust distance: ",robust_dis)
        print("Cutoff value: ",self.p_value_1)
        count,count1,count2=0,0,0
        count1=X.shape[0]
        print("Drop Start")
        robust_dis=pd.DataFrame(robust_dis,columns=['robust_dis'])
        X=pd.concat([X,robust_dis],axis=1)
        self.labels=pd.concat([self.labels,robust_dis],axis=1)
        self.y_dropped=pd.concat([self.y_dropped,robust_dis],axis=1)
        X=X[X['robust_dis']<=self.p_value_1].copy()
        self.labels=self.labels[self.labels['robust_dis']<=self.p_value_1].copy()
        self.y_dropped=self.y_dropped[self.y_dropped['robust_dis']>self.p_value_1].copy()
        X=pd.DataFrame.reset_index(X).drop('index',axis=1)
        self.labels=pd.DataFrame.reset_index(self.labels).drop('index',axis=1)
        self.y_dropped=pd.DataFrame.reset_index(self.y_dropped).drop('index',axis=1)
        count2=X.shape[0]
        count=count1-count2
        print("Drop End")
        print("drop count:",count)
        return X,self.labels,self.y_dropped,robust_dis

# %%
n_subsamples=253
X_train_scaled=feature_eng.fit_transform(X_train.drop('Unnamed: 0',1))
X_train_new,y_train_resample,y_dropped_resample,robust_dis=outliers_clean_resampling(p_free=5,labels=y_train).fit_transform(X_train_scaled)
# Out:
# MD Start
# MD end
# Resampling begin
# replications number:0 time:  0.0 minute
# Resampling end
# RD Start
# RD end
# Robust distance:  [ 4.30574976  3.85514165  4.03134111 ...,  2.47902027  3.67414771
#   1.69394282]
# Cutoff value:  6.76716980076
# Drop Start
# Drop End
# drop count: 31936

# %%
stuck,slices,index,features=1,25,1,0
check_resultofdropping(data,stuck,index,slices,features,y_train_resample,y_dropped_resample)

# %%
n_subsamples=3000
X_train_scaled=feature_eng.fit_transform(X_train.drop('Unnamed: 0',1))
X_train_new,y_train_new,y_dropped_new,robust_dis=outliers_clean_resampling(p_free=5,labels=y_train).fit_transform(X_train_scaled)
# Out:
# MD Start
# MD end
# Resampling begin
# replications number:0 time:  0.0 minute
# replications number:1000 time:  7.7 minute
# replications number:2000 time: 15.2 minute
# Resampling end
# RD Start
# RD end
# Robust distance:  [ 4.26357033  3.76741953  3.98327861 ...,  5.39999458  4.38063034
#   2.34916689]
# Cutoff value:  6.76716980076
# Drop Start
# Drop End
# drop count: 43542

# %%
stuck,slices,index,features=1,25,1,0
check_resultofdropping(data,stuck,index,slices,features,y_train_new,y_dropped_new)

# %%
#save the result
#use the result of 3000 groups
X_train_new.to_csv("D:\\lab; signal processing\\forStudents\\medData\\train_resampling_X.csv",index=False)
y_train_new.to_csv("D:\\lab; signal processing\\forStudents\\medData\\train_resampling_y.csv",index=False)

# %% [markdown]
# **Tuning conclusion** :from the plot 1 and plot 2 we can figure out n_subsample or replications better remain low value

# %% [markdown]
# ## 3.3 Boundray selection

# %%
X_train=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\train_resampling_X.csv")
y_train=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\train_resampling_y.csv")

# %%
X_train=X_train.drop(['robust_dis'],axis=1)
y_train=y_train.drop(['robust_dis'],axis=1)
y_train=y_train.rename(columns={'0':'label'})

# %% [markdown]
# first to apply kmeans algorithm to divide dataset into clusters

# %%
#boundary detection
class boundary_detection(BaseEstimator,TransformerMixin):
    def __init__(self,labels,kmeans):
        self.labels=labels
        self.kmeans=kmeans
    def fit(self,X,y=None):
        start=time.time()
        print("fit start")
        self.kmeans.fit(X)
        print("fit end")
        print("fit time:%5.1fminute"%((time.time()-start)/60))
        return self
    def transform(self,X,y=None):
        #dataset=pd.concat([X,self.labels],axis=1)
        count1=X.shape[0]
        predict_cluster = self.kmeans.predict(X)
        predict_cluster=pd.DataFrame( predict_cluster,columns=['predict_cluster'])
        X=pd.concat([X,predict_cluster],axis=1)
        self.labels=pd.concat([self.labels,predict_cluster],axis=1)
        #center_set = pd.DataFrame(columns = ['feature0','feature1','feature2','feature3','feature4','predict_label'])
        center_set = list()
        i = 0
        #print (X)
        #print (self.kmeans.cluster_centers_)
        print("drop start")
        for cluster in range(np.int((X.shape[0])/50)):
            if cluster%1000==0:
                print("cluster number:",cluster)
            temp_list = list(self.labels[self.labels['predict_cluster']==cluster]['label'])
            if 1 and 2 in temp_list:
                pass
            elif temp_list == []:  
                pass
            else:
                #temp =temp_list[0]
                #temp_center = np.append(self.kmeans.cluster_centers_[cluster],temp)
                temp_center_set = {'feature0':self.kmeans.cluster_centers_[cluster][0],\
                                  'feature1':self.kmeans.cluster_centers_[cluster][1],\
                                  'feature2':self.kmeans.cluster_centers_[cluster][2],\
                                  'feature3':self.kmeans.cluster_centers_[cluster][3],\
                                  'feature4':self.kmeans.cluster_centers_[cluster][4],\
                                  'predict_label':temp_list[0]}
                #temp = pd.DataFrame(data=temp_center_set,index = cluster)
                #center_set = pd.concat(center_set,temp_center_set)
                center_set.append(temp_center_set)
                self.labels = self.labels[self.labels.predict_cluster !=cluster]
                X = X[X.predict_cluster != cluster]
        #dataset.append(pd.DataFrame(self.kmeans.cluster_centers_))#save all the centers of abandoned clusters
        print("drop end")
        count2=X.shape[0]
        print("Drop count:",count1-count2)        
        return X,self.labels,center_set

# %%
#apply the function with 30 samples in one cluster
X_boundary,y_boundary,center=boundary_detection(labels=y_train.drop('Unnamed: 0',1),kmeans=MiniBatchKMeans(n_clusters=np.int((X_train.shape[0])/50),\
                                                                  n_init=1,max_iter=100,\
                                                                  init_size=3*np.int((X_train.shape[0])/50),verbose=-1,\
                                                                  random_state=42)).fit_transform(X_train)
# Out:
# fit start
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 291.047006
# Minibatch iteration 1/312000: mean batch inertia: 0.032758, ewa inertia: 0.032758
# Minibatch iteration 2/312000: mean batch inertia: 0.024678, ewa inertia: 0.032753
# Minibatch iteration 3/312000: mean batch inertia: 0.029749, ewa inertia: 0.032751
# Minibatch iteration 4/312000: mean batch inertia: 0.031670, ewa inertia: 0.032751
# Minibatch iteration 5/312000: mean batch inertia: 0.024265, ewa inertia: 0.032745
# Minibatch iteration 6/312000: mean batch inertia: 0.023280, ewa inertia: 0.032739
# Minibatch iteration 7/312000: mean batch inertia: 0.028923, ewa inertia: 0.032737
# Minibatch iteration 8/312000: mean batch inertia: 0.022860, ewa inertia: 0.032730
# Minibatch iteration 9/312000: mean batch inertia: 0.028742, ewa inertia: 0.032728
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 10/312000: mean batch inertia: 0.030326, ewa inertia: 0.032726
# Minibatch iteration 11/312000: mean batch inertia: 0.026197, ewa inertia: 0.032722
# Minibatch iteration 12/312000: mean batch inertia: 0.027306, ewa inertia: 0.032719
# Minibatch iteration 13/312000: mean batch inertia: 0.022672, ewa inertia: 0.032712
# Minibatch iteration 14/312000: mean batch inertia: 0.032479, ewa inertia: 0.032712
# Minibatch iteration 15/312000: mean batch inertia: 0.025631, ewa inertia: 0.032707
# Minibatch iteration 16/312000: mean batch inertia: 0.030480, ewa inertia: 0.032706
# Minibatch iteration 17/312000: mean batch inertia: 0.028123, ewa inertia: 0.032703
# Minibatch iteration 18/312000: mean batch inertia: 0.030834, ewa inertia: 0.032702
# Minibatch iteration 19/312000: mean batch inertia: 0.032241, ewa inertia: 0.032702
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 20/312000: mean batch inertia: 0.023236, ewa inertia: 0.032696
# Minibatch iteration 21/312000: mean batch inertia: 0.022725, ewa inertia: 0.032689
# Minibatch iteration 22/312000: mean batch inertia: 0.028697, ewa inertia: 0.032687
# Minibatch iteration 23/312000: mean batch inertia: 0.037995, ewa inertia: 0.032690
# Minibatch iteration 24/312000: mean batch inertia: 0.028855, ewa inertia: 0.032687
# Minibatch iteration 25/312000: mean batch inertia: 0.031918, ewa inertia: 0.032687
# Minibatch iteration 26/312000: mean batch inertia: 0.033764, ewa inertia: 0.032688
# Minibatch iteration 27/312000: mean batch inertia: 0.022562, ewa inertia: 0.032681
# Minibatch iteration 28/312000: mean batch inertia: 0.041820, ewa inertia: 0.032687
# Minibatch iteration 29/312000: mean batch inertia: 0.026376, ewa inertia: 0.032683
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 30/312000: mean batch inertia: 0.026070, ewa inertia: 0.032679
# Minibatch iteration 31/312000: mean batch inertia: 0.027301, ewa inertia: 0.032675
# Minibatch iteration 32/312000: mean batch inertia: 0.026764, ewa inertia: 0.032672
# Minibatch iteration 33/312000: mean batch inertia: 0.024669, ewa inertia: 0.032666
# Minibatch iteration 34/312000: mean batch inertia: 0.020592, ewa inertia: 0.032659
# Minibatch iteration 35/312000: mean batch inertia: 0.032579, ewa inertia: 0.032659
# Minibatch iteration 36/312000: mean batch inertia: 0.023895, ewa inertia: 0.032653
# Minibatch iteration 37/312000: mean batch inertia: 0.024732, ewa inertia: 0.032648
# Minibatch iteration 38/312000: mean batch inertia: 0.027223, ewa inertia: 0.032644
# Minibatch iteration 39/312000: mean batch inertia: 0.021793, ewa inertia: 0.032637
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 40/312000: mean batch inertia: 0.018735, ewa inertia: 0.032629
# Minibatch iteration 41/312000: mean batch inertia: 0.024767, ewa inertia: 0.032624
# Minibatch iteration 42/312000: mean batch inertia: 0.024782, ewa inertia: 0.032618
# Minibatch iteration 43/312000: mean batch inertia: 0.027977, ewa inertia: 0.032616
# Minibatch iteration 44/312000: mean batch inertia: 0.033634, ewa inertia: 0.032616
# Minibatch iteration 45/312000: mean batch inertia: 0.026669, ewa inertia: 0.032612
# Minibatch iteration 46/312000: mean batch inertia: 0.025018, ewa inertia: 0.032607
# Minibatch iteration 47/312000: mean batch inertia: 0.022394, ewa inertia: 0.032601
# Minibatch iteration 48/312000: mean batch inertia: 0.030362, ewa inertia: 0.032600
# Minibatch iteration 49/312000: mean batch inertia: 0.021995, ewa inertia: 0.032593
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 50/312000: mean batch inertia: 0.027003, ewa inertia: 0.032589
# Minibatch iteration 51/312000: mean batch inertia: 0.033843, ewa inertia: 0.032590
# Minibatch iteration 52/312000: mean batch inertia: 0.029981, ewa inertia: 0.032588
# Minibatch iteration 53/312000: mean batch inertia: 0.029803, ewa inertia: 0.032586
# Minibatch iteration 54/312000: mean batch inertia: 0.028276, ewa inertia: 0.032584
# Minibatch iteration 55/312000: mean batch inertia: 0.028234, ewa inertia: 0.032581
# Minibatch iteration 56/312000: mean batch inertia: 0.026208, ewa inertia: 0.032577
# Minibatch iteration 57/312000: mean batch inertia: 0.026542, ewa inertia: 0.032573
# Minibatch iteration 58/312000: mean batch inertia: 0.026758, ewa inertia: 0.032569
# Minibatch iteration 59/312000: mean batch inertia: 0.019725, ewa inertia: 0.032561
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 60/312000: mean batch inertia: 0.027039, ewa inertia: 0.032557
# Minibatch iteration 61/312000: mean batch inertia: 0.025695, ewa inertia: 0.032553
# Minibatch iteration 62/312000: mean batch inertia: 0.024167, ewa inertia: 0.032548
# Minibatch iteration 63/312000: mean batch inertia: 0.041996, ewa inertia: 0.032554
# Minibatch iteration 64/312000: mean batch inertia: 0.026172, ewa inertia: 0.032550
# Minibatch iteration 65/312000: mean batch inertia: 0.021634, ewa inertia: 0.032543
# Minibatch iteration 66/312000: mean batch inertia: 0.030875, ewa inertia: 0.032542
# Minibatch iteration 67/312000: mean batch inertia: 0.019940, ewa inertia: 0.032533
# Minibatch iteration 68/312000: mean batch inertia: 0.026906, ewa inertia: 0.032530
# Minibatch iteration 69/312000: mean batch inertia: 0.030402, ewa inertia: 0.032529
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 70/312000: mean batch inertia: 0.027409, ewa inertia: 0.032525
# Minibatch iteration 71/312000: mean batch inertia: 0.023863, ewa inertia: 0.032520
# Minibatch iteration 72/312000: mean batch inertia: 0.030338, ewa inertia: 0.032518
# Minibatch iteration 73/312000: mean batch inertia: 0.025893, ewa inertia: 0.032514
# Minibatch iteration 74/312000: mean batch inertia: 0.038456, ewa inertia: 0.032518
# Minibatch iteration 75/312000: mean batch inertia: 0.021916, ewa inertia: 0.032511
# Minibatch iteration 76/312000: mean batch inertia: 0.024369, ewa inertia: 0.032506
# Minibatch iteration 77/312000: mean batch inertia: 0.029375, ewa inertia: 0.032504
# Minibatch iteration 78/312000: mean batch inertia: 0.027411, ewa inertia: 0.032501
# Minibatch iteration 79/312000: mean batch inertia: 0.028334, ewa inertia: 0.032498
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 80/312000: mean batch inertia: 0.022536, ewa inertia: 0.032491
# Minibatch iteration 81/312000: mean batch inertia: 0.024929, ewa inertia: 0.032487
# Minibatch iteration 82/312000: mean batch inertia: 0.032415, ewa inertia: 0.032487
# Minibatch iteration 83/312000: mean batch inertia: 0.021654, ewa inertia: 0.032480
# Minibatch iteration 84/312000: mean batch inertia: 0.041288, ewa inertia: 0.032485
# Minibatch iteration 85/312000: mean batch inertia: 0.019939, ewa inertia: 0.032477
# Minibatch iteration 86/312000: mean batch inertia: 0.022171, ewa inertia: 0.032471
# Minibatch iteration 87/312000: mean batch inertia: 0.025058, ewa inertia: 0.032466
# Minibatch iteration 88/312000: mean batch inertia: 0.019592, ewa inertia: 0.032458
# Minibatch iteration 89/312000: mean batch inertia: 0.030709, ewa inertia: 0.032457
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 90/312000: mean batch inertia: 0.025666, ewa inertia: 0.032452
# Minibatch iteration 91/312000: mean batch inertia: 0.027619, ewa inertia: 0.032449
# Minibatch iteration 92/312000: mean batch inertia: 0.030765, ewa inertia: 0.032448
# Minibatch iteration 93/312000: mean batch inertia: 0.026984, ewa inertia: 0.032444
# Minibatch iteration 94/312000: mean batch inertia: 0.035865, ewa inertia: 0.032447
# Minibatch iteration 95/312000: mean batch inertia: 0.021431, ewa inertia: 0.032440
# Minibatch iteration 96/312000: mean batch inertia: 0.033507, ewa inertia: 0.032440
# Minibatch iteration 97/312000: mean batch inertia: 0.041882, ewa inertia: 0.032446
# Minibatch iteration 98/312000: mean batch inertia: 0.028800, ewa inertia: 0.032444
# Minibatch iteration 99/312000: mean batch inertia: 0.021876, ewa inertia: 0.032437
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 100/312000: mean batch inertia: 0.036153, ewa inertia: 0.032440
# Minibatch iteration 101/312000: mean batch inertia: 0.032350, ewa inertia: 0.032440
# Minibatch iteration 102/312000: mean batch inertia: 0.023624, ewa inertia: 0.032434
# Minibatch iteration 103/312000: mean batch inertia: 0.058629, ewa inertia: 0.032451
# Minibatch iteration 104/312000: mean batch inertia: 0.021833, ewa inertia: 0.032444
# Minibatch iteration 105/312000: mean batch inertia: 0.022550, ewa inertia: 0.032438
# Minibatch iteration 106/312000: mean batch inertia: 0.029974, ewa inertia: 0.032436
# Minibatch iteration 107/312000: mean batch inertia: 0.039039, ewa inertia: 0.032440
# Minibatch iteration 108/312000: mean batch inertia: 0.022521, ewa inertia: 0.032434
# Minibatch iteration 109/312000: mean batch inertia: 0.038002, ewa inertia: 0.032437
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 110/312000: mean batch inertia: 0.021994, ewa inertia: 0.032431
# Minibatch iteration 111/312000: mean batch inertia: 0.022178, ewa inertia: 0.032424
# Minibatch iteration 112/312000: mean batch inertia: 0.024802, ewa inertia: 0.032419
# Minibatch iteration 113/312000: mean batch inertia: 0.022929, ewa inertia: 0.032413
# Minibatch iteration 114/312000: mean batch inertia: 0.016282, ewa inertia: 0.032403
# Minibatch iteration 115/312000: mean batch inertia: 0.026014, ewa inertia: 0.032399
# Minibatch iteration 116/312000: mean batch inertia: 0.034838, ewa inertia: 0.032400
# Minibatch iteration 117/312000: mean batch inertia: 0.023715, ewa inertia: 0.032395
# Minibatch iteration 118/312000: mean batch inertia: 0.030199, ewa inertia: 0.032393
# Minibatch iteration 119/312000: mean batch inertia: 0.020506, ewa inertia: 0.032386
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 120/312000: mean batch inertia: 0.024108, ewa inertia: 0.032380
# Minibatch iteration 121/312000: mean batch inertia: 0.026703, ewa inertia: 0.032377
# Minibatch iteration 122/312000: mean batch inertia: 0.028432, ewa inertia: 0.032374
# Minibatch iteration 123/312000: mean batch inertia: 0.026050, ewa inertia: 0.032370
# Minibatch iteration 124/312000: mean batch inertia: 0.030352, ewa inertia: 0.032369
# Minibatch iteration 125/312000: mean batch inertia: 0.029347, ewa inertia: 0.032367
# Minibatch iteration 126/312000: mean batch inertia: 0.022740, ewa inertia: 0.032361
# Minibatch iteration 127/312000: mean batch inertia: 0.034938, ewa inertia: 0.032362
# Minibatch iteration 128/312000: mean batch inertia: 0.035300, ewa inertia: 0.032364
# Minibatch iteration 129/312000: mean batch inertia: 0.028818, ewa inertia: 0.032362
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 130/312000: mean batch inertia: 0.026062, ewa inertia: 0.032358
# Minibatch iteration 131/312000: mean batch inertia: 0.024949, ewa inertia: 0.032353
# Minibatch iteration 132/312000: mean batch inertia: 0.022507, ewa inertia: 0.032347
# Minibatch iteration 133/312000: mean batch inertia: 0.027068, ewa inertia: 0.032344
# Minibatch iteration 134/312000: mean batch inertia: 0.033719, ewa inertia: 0.032344
# Minibatch iteration 135/312000: mean batch inertia: 0.027382, ewa inertia: 0.032341
# Minibatch iteration 136/312000: mean batch inertia: 0.027694, ewa inertia: 0.032338
# Minibatch iteration 137/312000: mean batch inertia: 0.030768, ewa inertia: 0.032337
# Minibatch iteration 138/312000: mean batch inertia: 0.023610, ewa inertia: 0.032332
# Minibatch iteration 139/312000: mean batch inertia: 0.026293, ewa inertia: 0.032328
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 140/312000: mean batch inertia: 0.034676, ewa inertia: 0.032329
# Minibatch iteration 141/312000: mean batch inertia: 0.020676, ewa inertia: 0.032322
# Minibatch iteration 142/312000: mean batch inertia: 0.025466, ewa inertia: 0.032317
# Minibatch iteration 143/312000: mean batch inertia: 0.025231, ewa inertia: 0.032313
# Minibatch iteration 144/312000: mean batch inertia: 0.028106, ewa inertia: 0.032310
# Minibatch iteration 145/312000: mean batch inertia: 0.040940, ewa inertia: 0.032316
# Minibatch iteration 146/312000: mean batch inertia: 0.026593, ewa inertia: 0.032312
# Minibatch iteration 147/312000: mean batch inertia: 0.031849, ewa inertia: 0.032312
# Minibatch iteration 148/312000: mean batch inertia: 0.035630, ewa inertia: 0.032314
# Minibatch iteration 149/312000: mean batch inertia: 0.026434, ewa inertia: 0.032310
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 150/312000: mean batch inertia: 0.024783, ewa inertia: 0.032305
# Minibatch iteration 151/312000: mean batch inertia: 0.033989, ewa inertia: 0.032306
# Minibatch iteration 152/312000: mean batch inertia: 0.028222, ewa inertia: 0.032304
# Minibatch iteration 153/312000: mean batch inertia: 0.026439, ewa inertia: 0.032300
# Minibatch iteration 154/312000: mean batch inertia: 0.029739, ewa inertia: 0.032298
# Minibatch iteration 155/312000: mean batch inertia: 0.037954, ewa inertia: 0.032302
# Minibatch iteration 156/312000: mean batch inertia: 0.021079, ewa inertia: 0.032295
# Minibatch iteration 157/312000: mean batch inertia: 0.025923, ewa inertia: 0.032291
# Minibatch iteration 158/312000: mean batch inertia: 0.024107, ewa inertia: 0.032285
# Minibatch iteration 159/312000: mean batch inertia: 0.026675, ewa inertia: 0.032282
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 160/312000: mean batch inertia: 0.046108, ewa inertia: 0.032291
# Minibatch iteration 161/312000: mean batch inertia: 0.031574, ewa inertia: 0.032290
# Minibatch iteration 162/312000: mean batch inertia: 0.021855, ewa inertia: 0.032284
# Minibatch iteration 163/312000: mean batch inertia: 0.029440, ewa inertia: 0.032282
# Minibatch iteration 164/312000: mean batch inertia: 0.027874, ewa inertia: 0.032279
# Minibatch iteration 165/312000: mean batch inertia: 0.041592, ewa inertia: 0.032285
# Minibatch iteration 166/312000: mean batch inertia: 0.025256, ewa inertia: 0.032280
# Minibatch iteration 167/312000: mean batch inertia: 0.022926, ewa inertia: 0.032274
# Minibatch iteration 168/312000: mean batch inertia: 0.032650, ewa inertia: 0.032275
# Minibatch iteration 169/312000: mean batch inertia: 0.032703, ewa inertia: 0.032275
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 170/312000: mean batch inertia: 0.024405, ewa inertia: 0.032270
# Minibatch iteration 171/312000: mean batch inertia: 0.025526, ewa inertia: 0.032266
# Minibatch iteration 172/312000: mean batch inertia: 0.031442, ewa inertia: 0.032265
# Minibatch iteration 173/312000: mean batch inertia: 0.019376, ewa inertia: 0.032257
# Minibatch iteration 174/312000: mean batch inertia: 0.024370, ewa inertia: 0.032252
# Minibatch iteration 175/312000: mean batch inertia: 0.020973, ewa inertia: 0.032244
# Minibatch iteration 176/312000: mean batch inertia: 0.027225, ewa inertia: 0.032241
# Minibatch iteration 177/312000: mean batch inertia: 0.024233, ewa inertia: 0.032236
# Minibatch iteration 178/312000: mean batch inertia: 0.022493, ewa inertia: 0.032230
# Minibatch iteration 179/312000: mean batch inertia: 0.044290, ewa inertia: 0.032238
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 180/312000: mean batch inertia: 0.027549, ewa inertia: 0.032235
# Minibatch iteration 181/312000: mean batch inertia: 0.025198, ewa inertia: 0.032230
# Minibatch iteration 182/312000: mean batch inertia: 0.021265, ewa inertia: 0.032223
# Minibatch iteration 183/312000: mean batch inertia: 0.027514, ewa inertia: 0.032220
# Minibatch iteration 184/312000: mean batch inertia: 0.028443, ewa inertia: 0.032218
# Minibatch iteration 185/312000: mean batch inertia: 0.022881, ewa inertia: 0.032212
# Minibatch iteration 186/312000: mean batch inertia: 0.029616, ewa inertia: 0.032210
# Minibatch iteration 187/312000: mean batch inertia: 0.029819, ewa inertia: 0.032208
# Minibatch iteration 188/312000: mean batch inertia: 0.027971, ewa inertia: 0.032206
# Minibatch iteration 189/312000: mean batch inertia: 0.025652, ewa inertia: 0.032201
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 190/312000: mean batch inertia: 0.024699, ewa inertia: 0.032197
# Minibatch iteration 191/312000: mean batch inertia: 0.032635, ewa inertia: 0.032197
# Minibatch iteration 192/312000: mean batch inertia: 0.030885, ewa inertia: 0.032196
# Minibatch iteration 193/312000: mean batch inertia: 0.037531, ewa inertia: 0.032200
# Minibatch iteration 194/312000: mean batch inertia: 0.032671, ewa inertia: 0.032200
# Minibatch iteration 195/312000: mean batch inertia: 0.026876, ewa inertia: 0.032196
# Minibatch iteration 196/312000: mean batch inertia: 0.032943, ewa inertia: 0.032197
# Minibatch iteration 197/312000: mean batch inertia: 0.026023, ewa inertia: 0.032193
# Minibatch iteration 198/312000: mean batch inertia: 0.039112, ewa inertia: 0.032197
# Minibatch iteration 199/312000: mean batch inertia: 0.024576, ewa inertia: 0.032192
# [MiniBatchKMeans] Reassigning 50 cluster centers.
# Minibatch iteration 200/312000: mean batch inertia: 0.044931, ewa inertia: 0.032201
# Minibatch iteration 201/312000: mean batch inertia: 0.040471, ewa inertia: 0.032206
# Minibatch iteration 202/312000: mean batch inertia: 0.024278, ewa inertia: 0.032201
# Minibatch iteration 203/312000: mean batch inertia: 0.054481, ewa inertia: 0.032215
# Minibatch iteration 204/312000: mean batch inertia: 0.026087, ewa inertia: 0.032211
# Minibatch iteration 205/312000: mean batch inertia: 0.029465, ewa inertia: 0.032209
# Minibatch iteration 206/312000: mean batch inertia: 0.031404, ewa inertia: 0.032209
# Minibatch iteration 207/312000: mean batch inertia: 0.034794, ewa inertia: 0.032211
# Minibatch iteration 208/312000: mean batch inertia: 0.026997, ewa inertia: 0.032207
# Minibatch iteration 209/312000: mean batch inertia: 0.031068, ewa inertia: 0.032207
# Converged (lack of improvement in inertia) at iteration 209/312000
# Computing label assignment and total inertia
# fit end
# fit time:  0.5minute
# Computing label assignment and total inertia
# drop start
# cluster number: 0
# cluster number: 1000
# cluster number: 2000
# cluster number: 3000
# cluster number: 4000
# cluster number: 5000
# cluster number: 6000
# drop end
# Drop count: 46101

# %%
len(y_boundary[y_boundary['label']==1])
# Out:
# 216609

# %%
len(y_boundary[y_boundary['label']==2])
# Out:
# 49203

# %%
center_set = pd.DataFrame(data = center)

# %%
import re
dataset = loadmat ("D:\\lab; signal processing\\forStudents\\medData\\dataset.mat",mat_dtype=True)
data = dataset ["dataset"]
cmap1 = matplotlib.colors.LinearSegmentedColormap.from_list('my_cmap',['black','green','blue'],256)
def check_resultofdropping (data,stuck,index,slices,features,selected):
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image1=target_data.reshape(target_data.shape[0],target_data.shape[1])
    target_label=data[stuck][0][0][0][index][:,:,slices]
    target_image2=target_label.reshape(target_label.shape[0],target_label.shape[1])
    plt.imshow(target_image1,cmap = matplotlib.cm.binary,alpha=0.4)
    plt.imshow(target_image2,cmap = cmap1,interpolation="bilinear",alpha=0.4)
    plt.axis("off") #close the axis number

    selected_x=[]
    selected_y=[]
    selected_matrix = selected[selected['sourceofpixel']==stuck]
    selected_matrix=pd.DataFrame.reset_index(selected_matrix).drop('index',axis=1)
    for i in range(len(selected_matrix)):
        temparr = re.findall("\d+",selected_matrix.iloc[i]['indexofpixel']) 
        if (int(temparr[2]) == slices):
            selected_x.append(int(temparr[0]))
            selected_y.append(int(temparr[1]))
    plt.scatter(selected_y,selected_x, s = 3)
    plt.show()
    
    target_data=data[stuck][0][0][0][0][:,:,slices,features]
    target_image1=target_data.reshape(target_data.shape[0],target_data.shape[1])
    target_label=data[stuck][0][0][0][index][:,:,slices]
    target_image2=target_label.reshape(target_label.shape[0],target_label.shape[1])
    plt.imshow(target_image1,cmap = matplotlib.cm.binary,alpha=0.4)
    plt.imshow(target_image2,cmap = cmap1,interpolation="bilinear",alpha=0.4)
    plt.axis("off") #close the axis number
    plt.show()

# %%
stuck,slices,index,features=4,24,1,4
check_resultofdropping(data,stuck,index,slices,features,y_boundary)

# %%
#save the result
X_boundary.to_csv("D:\\lab; signal processing\\forStudents\\medData\\train_x_boundarysel_50pergroup.csv",index=False)
y_boundary.to_csv("D:\\lab; signal processing\\forStudents\\medData\\train_y_boundarysel_50pergroup.csv",index=False)

# %% [markdown]
# # 4. Build the model

# %% [markdown]
# In the model construction part ,**our plan ** is that:
# - train servarl models
# - calculate the f1-scores,accuracy,roc_curve
# - choose the best model
# - tuning the parameters of the model

# %%
X_train=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\train_x_boundarysel_50pergroup.csv")
y_train=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\train_y_boundarysel_50pergroup.csv")
X_val=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\scaled_validation_feature.csv")
y_val=pd.read_csv("D:\\lab; signal processing\\forStudents\\medData\\validation_label.csv")
#X_train=train_set.drop(["label"],axis=1)
#y_train=train_set["label"]

# %%
X_train = X_train.drop(["predict_cluster"],axis=1)
y_train = y_train.drop(["predict_cluster"],axis=1)
X_val = X_val.drop(["Unnamed: 0"],axis=1)
y_val = y_val.drop(["Unnamed: 0"],axis=1)

# %%
#X_val = X_val.drop(["sourceofpixel"],axis=1)
y_val = y_val.drop(["sourceofpixel"],axis=1)
y_train = y_train.drop(["sourceofpixel"],axis=1)

# %%
y_val = y_val.drop(["indexofpixel"],axis=1)
y_train = y_train.drop(["indexofpixel"],axis=1)

# %%
def cal_score (y_pred,y_val):
    n11 = 0
    n12 = 0
    n21 = 0
    n22 = 0
    y_pred_array= np.array(y_pred)
    y_val_array= np.array(y_val)
    ita = np.nditer (y_pred_array)
    itb = np.nditer (y_val_array)
    while not ita.finished:
        if (ita[0]==2)&(itb[0]==2):
            n22 = n22+1
        elif (ita[0]==1)&(itb[0]==2):
            n12 = n12+1
        elif (ita[0]==2)&(itb[0]==1):
            n21 = n21+1
        else:
            n11 = n11+1
        ita.iternext()
        itb.iternext()
        
    Precall = n22 / ( n12 + n22)
    Pprecision = n22 / ( n21 + n22)
    f1_score = 2 / (1/Precall + 1/Pprecision)
    print ("n11:.."+str(n11)+"..n12:.."+str(n12)+"..n21:.."+str(n21)+"..n22:.."+str(n22))
    print ("TP:"+str(Precall))
    print ("f1 score:" + str(f1_score))
    FP = n21/(n21 + n11)
    FN = n12/(n12 +n22 )
    BER = 1/2*(FP+FN)
    print ("FP:"+ str(FP))
    print ("BER:" + str(BER))
    return Precall,f1_score,BER

# %%
#Nearest Mean algorithm
def nn_predict(X_val,X_train,y_train):
    y_pred=[]
    y_proba_1=[]
    y_proba_2=[]
    class_1=X_train[y_train['label']==1]
    class_2=X_train[y_train['label']==2]
    print(class_1.shape)
    mean_1=np.array(class_1.mean()).reshape(1,-1)
    mean_2=np.array(class_2.mean()).reshape(1,-1)
    print(mean_2.shape)
    cov_1=np.matrix(class_1.cov())
    cov_2=np.matrix(class_2.cov())
    print("NN start")
    start=time.time()
    dis_1=distance.cdist(X_val,mean_1,metric='mahalanobis',V=cov_1).ravel()
    dis_2=distance.cdist(X_val,mean_2,metric='mahalanobis',V=cov_2).ravel()
# get the k nearest mahalanobis distance
    for index in range(len(X_val)):
        #if index%1000==0:
        #    print("the index is %d and time is %5.1f second"%(index,(time.time()-start)))
        if dis_1[index]<dis_2[index]:
                y_pred.append(np.float64(1.0)) #added the weight to the vote
        else:
                y_pred.append(np.float64(2.0))
        y_proba_1.append(dis_2[index]/(dis_1[index]+dis_2[index]))
        y_proba_2.append(dis_1[index]/(dis_1[index]+dis_2[index]))
    print("NN STOP")
    y_pred=pd.Series(y_pred)
    return y_pred,y_proba_1,y_proba_2

# %%
y_pred,y_proba_1,y_proba_2=nn_predict(X_val,X_train,y_train)
# Out:
# (216609, 5)
# (1, 5)
# NN start
# NN STOP

# %%
y_pred = {"label_pred":y_pred}
y_pred = pd.DataFrame(data=y_pred)

# %%
y_pred,y_proba_1,y_proba_2=nn_predict(X_val,X_train,y_train)
# Out:
# n11:..52414..n12:..2714..n21:..8793..n22:..6106
# TP:0.6922902494331066
# f1 score:0.5148615034360638
# FP:0.14366003888444132
# BER:0.22568489472566738

# %%
y_pred_train,y_proba_1_train,y_proba_2_train=nn_predict(X_train,X_train,y_train)
# Out:
# (216609, 5)
# (1, 5)
# NN start
# NN STOP

# %%
y_pred_train = {"label_pred":y_pred_train}
y_pred_train = pd.DataFrame(data=y_pred_train)

# %%
Precall,f1_score,BER = cal_score (y_pred_train,y_train)
# Out:
# n11:..183086..n12:..14360..n21:..33523..n22:..34843
# TP:0.7081478771619617
# f1 score:0.5927242725548401
# FP:0.1547627291571449
# BER:0.22330742599759162

# %% [markdown]
# we use the f1 score to analysis our model, $$P_{f1}=2*\frac{1}{\frac{1}{P_{recall}}+\frac{1}{P_{precision}}}$$

# %%
#f1_score(y_val,y_pred)
# Out:
# 0.90872650085835815

# %%
from sklearn.neighbors.nearest_centroid import NearestCentroid
clf = NearestCentroid()
clf.fit(X_train,y_train)
NearestCentroid(metric='mahalanobis',shrink_threshold=None)
# Out:
# C:\Users\yangshanqi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# NearestCentroid(metric='mahalanobis', shrink_threshold=None)

# %%
y_pred_nnpackage = clf.predict(X_val)

# %%
y_pred_nnpackage = {"label":y_pred_nnpackage }
y_pred_nnpackage  = pd.DataFrame(data=y_pred_nnpackage )

# %%
Precall,f1_score,BER = cal_score (y_pred_nnpackage,y_val)
# Out:
# n11:..48713..n12:..1588..n21:..12494..n22:..7232
# TP:0.8199546485260771
# f1 score:0.5066909549499055
# BER:1.3014992502475822

# %%
balanced_error_rate(y_val,y_pred_nnpackage)
# Out:
# 0.2816913476230597
# 0.7183086523769403
# 0.5

# %%
clf1 = neighbors.KNeighborsClassifier()
clf1.fit(X_train,y_train)
# Out:
# C:\Users\yangshanqi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred_knnpackage = clf1.predict(X_val)

# %%
y_pred_knnpackage = {"label":y_pred_knnpackage }
y_pred_knnpackage  = pd.DataFrame(data=y_pred_knnpackage )

# %%
TPR_knn,f1_score_knn,BER_knn = cal_score(y_val,y_pred_knnpackage)
# Out:
# n11:..55663..n12:..5544..n21:..5333..n22:..3487
# TP:0.3861144945188794
# f1 score:0.39067839336731836
# FP:0.08743196275165585
# BER:0.3506587341163882

# %%
#accuracy_score(y_val,y_pred) #validation accuracy
# Out:
# 0.92834030008866775

# %%
#calculate tp amd fp
fp_nn,tp_nn,thresholds_nn=roc_curve(y_val,y_proba_2,pos_label=2)

# %%
#function plot the ROC
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

# %%
plt.title("Nearest Mean ROC")
plot_roc_curve(fp_nn,tp_nn,label='Nearest Mean')
plt.show()

# %%
def knn_predict(X_val,X_train,y_train,k_value):
    y_pred=[]
    y_proba_1=[]
    y_proba_2=[]
    cov_train=np.matrix(X_train.cov())
    print("KNN start")
    start=time.time()
    for test_index in range(len(X_val)):
        if test_index%100==0:
            print("the X_val is %d and time is %5.1f minute"%(test_index,(time.time()-start)/60))
        good=0
        bad=0
        sample=np.array(X_val.iloc[test_index]).reshape(1,-1)
        m_dis=pd.Series((distance.cdist(X_train,sample,metric='mahalanobis',V=cov_train)).ravel())\
        .sort_values(ascending=True)#average computing time 0.12s
        dis_set=m_dis[:k_value]# get the k nearest mahalanobis distance
        for index in dis_set.index:
            if y_train.loc[index] == 1.0:
                good += 1/dis_set.loc[index] #added the weight to the vote
            else:
                bad += 1/dis_set.loc[index]
        if good > bad :
            y_pred.append(np.float64(1.0))
        else:
            y_pred.append(np.float64(2.0))
        y_proba_1.append(good/(good+bad))
        y_proba_2.append(bad/(good+bad))
    print("KNN STOP")
    y_pred=pd.Series(y_pred)
    return y_pred,y_proba_1,y_proba_2

# %%
y_pred_t,y_proba_1_t,y_proba_2_t=knn_predict(X_val,X_train,y_train,5,cov_train)
# Out:
# KNN start
# the X_val is 0 and time is   0.0 minute
# 0.13538527488708496
# 0.14099836349487305
# 0.12328314781188965
# 0.12736105918884277
# 0.12127208709716797
# 0.13768291473388672
# 0.12312197685241699
# 0.12457013130187988
# 0.11896967887878418
# 0.12837600708007812
# 0.12888503074645996
# 0.13399076461791992
# 0.1268908977508545
# 0.13985300064086914
# 0.12532353401184082
# 0.12438178062438965
# 0.12375378608703613
# 0.1298820972442627
# 0.12486624717712402
# 0.12816977500915527
# 0.13303470611572266
# 0.12490034103393555
# 0.12238955497741699
# 0.1285414695739746
# 0.11782240867614746
# 0.13056445121765137
# 0.11941075325012207
# 0.1259748935699463
# 0.12488412857055664
# 0.12718796730041504
# 0.13195252418518066
# 0.1439225673675537
# 0.13043618202209473
# 0.12739062309265137
# 0.12279605865478516
# 0.12287306785583496
# 0.12891316413879395
# 0.12630581855773926
# 0.13139748573303223
# 0.13092780113220215
# 0.1243600845336914
# 0.12434911727905273
# 0.12583589553833008
# 0.12835121154785156
# 0.12785911560058594
# 0.1268458366394043
# 0.1298539638519287
# 0.128889799118042
# 0.13085460662841797
# 0.1324002742767334
# 0.1177835464477539
# 0.1295628547668457
# 0.12687397003173828
# 0.13136577606201172
# 0.12514615058898926
# 0.1277635097503662
# 0.12285971641540527
# 0.1380600929260254
# 0.12561297416687012
# 0.13179326057434082
# 0.12584280967712402
# 0.12789583206176758
# 0.1274552345275879
# 0.12433052062988281
# 0.12587738037109375
# 0.15296530723571777
# 0.12784028053283691
# 0.12742185592651367
# 0.13286495208740234
# 0.1242823600769043
# 0.12191653251647949
# 0.12665605545043945
# 0.1193387508392334
# 0.13056540489196777
# 0.12988758087158203
# 0.13890457153320312
# 0.1248321533203125
# 0.12382674217224121
# 0.1238870620727539
# 0.12231922149658203
# 0.12683701515197754
# 0.12337064743041992
# 0.12511157989501953
# 0.1283881664276123
# 0.12792038917541504
# 0.1273493766784668
# 0.12336277961730957
# 0.12659525871276855
# 0.13035368919372559
# 0.12537145614624023
# 0.13186025619506836
# 0.14341497421264648
# 0.13437533378601074
# 0.13125228881835938
# 0.12937593460083008
# 0.12750840187072754
# 0.12646102905273438
# 0.13238215446472168
# 0.1303548812866211
# 0.1519324779510498
# the X_val is 100 and time is   0.2 minute
# 0.13212060928344727
# 0.12814092636108398
# 0.12190723419189453
# 0.1296699047088623
# 0.12935829162597656
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-8ff0cf20c8c0> in <module>()
# ----> 1 y_pred_t,y_proba_1_t,y_proba_2_t=knn_predict(X_val,X_train,y_train,5,cov_train)
#
# <ipython-input-42-b54f133e877f> in knn_predict(X_val, X_train, y_train, k_value, cov_train)
#      12         sample=np.array(X_val.iloc[test_index]).reshape(1,-1)
#      13         start1=time.time()
# ---> 14         m_dis=pd.Series((distance.cdist(X_train,sample,metric='mahalanobis',V=cov_train)).ravel())        .sort_values(ascending=True)
#      15         print(time.time()-start1)
#      16         dis_set=m_dis[:k_value]# get the k nearest mahalanobis distance
#
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\spatial\distance.py in cdist(XA, XB, metric, p, V, VI, w)
#    2255             XB = _convert_to_double(XB)
#    2256             # sqrt((u-v)V^(-1)(u-v)^T)
# -> 2257             _distance_wrap.cdist_mahalanobis_wrap(XA, XB, dm, VI=VI)
#    2258         elif mstr.startswith("test_"):
#    2259             if mstr in _TEST_METRICS:
#
# KeyboardInterrupt:

# %%
y_pred_knn,y_proba_1_knn,y_proba_2_knn=knn_predict(X_val,X_train,y_train,5,cov_train)
# Out:
# KNN start
# the X_val is 0 and time is   0.0 minute
# the X_val is 100 and time is   0.2 minute
# the X_val is 200 and time is   0.5 minute
# the X_val is 300 and time is   0.7 minute
# the X_val is 400 and time is   0.9 minute
# the X_val is 500 and time is   1.1 minute
# the X_val is 600 and time is   1.3 minute
# the X_val is 700 and time is   1.5 minute
# the X_val is 800 and time is   1.7 minute
# the X_val is 900 and time is   1.9 minute
# the X_val is 1000 and time is   2.1 minute
# the X_val is 1100 and time is   2.3 minute
# the X_val is 1200 and time is   2.5 minute
# the X_val is 1300 and time is   2.7 minute
# the X_val is 1400 and time is   2.9 minute
# the X_val is 1500 and time is   3.1 minute
# the X_val is 1600 and time is   3.3 minute
# the X_val is 1700 and time is   3.6 minute
# the X_val is 1800 and time is   3.8 minute
# the X_val is 1900 and time is   4.0 minute
# the X_val is 2000 and time is   4.2 minute
# the X_val is 2100 and time is   4.4 minute
# the X_val is 2200 and time is   4.6 minute
# the X_val is 2300 and time is   4.8 minute
# the X_val is 2400 and time is   5.0 minute
# the X_val is 2500 and time is   5.2 minute
# the X_val is 2600 and time is   5.4 minute
# the X_val is 2700 and time is   5.6 minute
# the X_val is 2800 and time is   5.8 minute
# the X_val is 2900 and time is   6.0 minute
# the X_val is 3000 and time is   6.2 minute
# the X_val is 3100 and time is   6.4 minute
# the X_val is 3200 and time is   6.6 minute
# the X_val is 3300 and time is   6.9 minute
# the X_val is 3400 and time is   7.1 minute
# the X_val is 3500 and time is   7.3 minute
# the X_val is 3600 and time is   7.5 minute
# the X_val is 3700 and time is   7.7 minute
# the X_val is 3800 and time is   7.9 minute
# the X_val is 3900 and time is   8.1 minute
# the X_val is 4000 and time is   8.3 minute
# the X_val is 4100 and time is   8.5 minute
# the X_val is 4200 and time is   8.7 minute
# the X_val is 4300 and time is   8.9 minute
# the X_val is 4400 and time is   9.1 minute
# the X_val is 4500 and time is   9.3 minute
# the X_val is 4600 and time is   9.5 minute
# the X_val is 4700 and time is   9.7 minute
# the X_val is 4800 and time is   9.9 minute
# the X_val is 4900 and time is  10.2 minute
# the X_val is 5000 and time is  10.4 minute
# the X_val is 5100 and time is  10.6 minute
# the X_val is 5200 and time is  10.8 minute
# the X_val is 5300 and time is  11.0 minute
# the X_val is 5400 and time is  11.2 minute
# the X_val is 5500 and time is  11.4 minute
# the X_val is 5600 and time is  11.6 minute
# the X_val is 5700 and time is  11.8 minute
# the X_val is 5800 and time is  12.0 minute
# the X_val is 5900 and time is  12.2 minute
# the X_val is 6000 and time is  12.4 minute
# the X_val is 6100 and time is  12.6 minute
# the X_val is 6200 and time is  12.8 minute
# the X_val is 6300 and time is  13.0 minute
# the X_val is 6400 and time is  13.3 minute
# the X_val is 6500 and time is  13.5 minute
# the X_val is 6600 and time is  13.7 minute
# the X_val is 6700 and time is  13.9 minute
# the X_val is 6800 and time is  14.1 minute
# the X_val is 6900 and time is  14.3 minute
# the X_val is 7000 and time is  14.5 minute
# the X_val is 7100 and time is  14.7 minute
# the X_val is 7200 and time is  14.9 minute
# the X_val is 7300 and time is  15.1 minute
# the X_val is 7400 and time is  15.3 minute
# the X_val is 7500 and time is  15.5 minute
# the X_val is 7600 and time is  15.7 minute
# the X_val is 7700 and time is  15.9 minute
# the X_val is 7800 and time is  16.1 minute
# the X_val is 7900 and time is  16.3 minute
# the X_val is 8000 and time is  16.6 minute
# the X_val is 8100 and time is  16.8 minute
# the X_val is 8200 and time is  17.0 minute
# the X_val is 8300 and time is  17.2 minute
# the X_val is 8400 and time is  17.4 minute
# the X_val is 8500 and time is  17.6 minute
# the X_val is 8600 and time is  17.8 minute
# the X_val is 8700 and time is  18.0 minute
# the X_val is 8800 and time is  18.2 minute
# the X_val is 8900 and time is  18.4 minute
# the X_val is 9000 and time is  18.6 minute
# the X_val is 9100 and time is  18.8 minute
# the X_val is 9200 and time is  19.0 minute
# the X_val is 9300 and time is  19.2 minute
# the X_val is 9400 and time is  19.4 minute
# the X_val is 9500 and time is  19.7 minute
# the X_val is 9600 and time is  19.9 minute
# the X_val is 9700 and time is  20.1 minute
# the X_val is 9800 and time is  20.3 minute
# the X_val is 9900 and time is  20.5 minute
# the X_val is 10000 and time is  20.7 minute
# the X_val is 10100 and time is  20.9 minute
# the X_val is 10200 and time is  21.1 minute
# the X_val is 10300 and time is  21.3 minute
# the X_val is 10400 and time is  21.5 minute
# the X_val is 10500 and time is  21.7 minute
# the X_val is 10600 and time is  21.9 minute
# the X_val is 10700 and time is  22.1 minute
# the X_val is 10800 and time is  22.3 minute
# the X_val is 10900 and time is  22.6 minute
# the X_val is 11000 and time is  22.8 minute
# the X_val is 11100 and time is  23.0 minute
# the X_val is 11200 and time is  23.2 minute
# the X_val is 11300 and time is  23.4 minute
# the X_val is 11400 and time is  23.6 minute
# the X_val is 11500 and time is  23.8 minute
# the X_val is 11600 and time is  24.0 minute
# the X_val is 11700 and time is  24.2 minute
# the X_val is 11800 and time is  24.4 minute
# the X_val is 11900 and time is  24.6 minute
# the X_val is 12000 and time is  24.8 minute
# the X_val is 12100 and time is  25.0 minute
# the X_val is 12200 and time is  25.2 minute
# the X_val is 12300 and time is  25.4 minute
# the X_val is 12400 and time is  25.7 minute
# the X_val is 12500 and time is  25.9 minute
# the X_val is 12600 and time is  26.1 minute
# the X_val is 12700 and time is  26.3 minute
# the X_val is 12800 and time is  26.5 minute
# the X_val is 12900 and time is  26.7 minute
# the X_val is 13000 and time is  26.9 minute
# the X_val is 13100 and time is  27.1 minute
# the X_val is 13200 and time is  27.3 minute
# the X_val is 13300 and time is  27.5 minute
# the X_val is 13400 and time is  27.7 minute
# the X_val is 13500 and time is  27.9 minute
# the X_val is 13600 and time is  28.1 minute
# the X_val is 13700 and time is  28.3 minute
# the X_val is 13800 and time is  28.6 minute
# the X_val is 13900 and time is  28.8 minute
# the X_val is 14000 and time is  29.0 minute
# the X_val is 14100 and time is  29.2 minute
# the X_val is 14200 and time is  29.4 minute
# the X_val is 14300 and time is  29.6 minute
# the X_val is 14400 and time is  29.8 minute
# the X_val is 14500 and time is  30.0 minute
# the X_val is 14600 and time is  30.2 minute
# the X_val is 14700 and time is  30.4 minute
# the X_val is 14800 and time is  30.6 minute
# the X_val is 14900 and time is  30.8 minute
# the X_val is 15000 and time is  31.0 minute
# the X_val is 15100 and time is  31.2 minute
# the X_val is 15200 and time is  31.5 minute
# the X_val is 15300 and time is  31.7 minute
# the X_val is 15400 and time is  31.9 minute
# the X_val is 15500 and time is  32.1 minute
# the X_val is 15600 and time is  32.3 minute
# the X_val is 15700 and time is  32.5 minute
# the X_val is 15800 and time is  32.7 minute
# the X_val is 15900 and time is  32.9 minute
# the X_val is 16000 and time is  33.1 minute
# the X_val is 16100 and time is  33.3 minute
# the X_val is 16200 and time is  33.5 minute
# the X_val is 16300 and time is  33.7 minute
# the X_val is 16400 and time is  33.9 minute
# the X_val is 16500 and time is  34.1 minute
# the X_val is 16600 and time is  34.4 minute
# the X_val is 16700 and time is  34.6 minute
# the X_val is 16800 and time is  34.8 minute
# the X_val is 16900 and time is  35.0 minute
# the X_val is 17000 and time is  35.2 minute
# the X_val is 17100 and time is  35.4 minute
# the X_val is 17200 and time is  35.6 minute
# the X_val is 17300 and time is  35.8 minute
# the X_val is 17400 and time is  36.0 minute
# the X_val is 17500 and time is  36.2 minute
# the X_val is 17600 and time is  36.4 minute
# the X_val is 17700 and time is  36.6 minute
# the X_val is 17800 and time is  36.8 minute
# the X_val is 17900 and time is  37.0 minute
# the X_val is 18000 and time is  37.3 minute
# the X_val is 18100 and time is  37.5 minute
# the X_val is 18200 and time is  37.7 minute
# the X_val is 18300 and time is  37.9 minute
# the X_val is 18400 and time is  38.1 minute
# the X_val is 18500 and time is  38.3 minute
# the X_val is 18600 and time is  38.5 minute
# the X_val is 18700 and time is  38.7 minute
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning:
#
# invalid value encountered in double_scalars
# the X_val is 18800 and time is  38.9 minute
# the X_val is 18900 and time is  39.1 minute
# the X_val is 19000 and time is  39.3 minute
# the X_val is 19100 and time is  39.5 minute
# the X_val is 19200 and time is  39.7 minute
# the X_val is 19300 and time is  39.9 minute
# the X_val is 19400 and time is  40.2 minute
# the X_val is 19500 and time is  40.4 minute
# the X_val is 19600 and time is  40.6 minute
# the X_val is 19700 and time is  40.8 minute
# the X_val is 19800 and time is  41.0 minute
# the X_val is 19900 and time is  41.2 minute
# the X_val is 20000 and time is  41.4 minute
# the X_val is 20100 and time is  41.6 minute
# the X_val is 20200 and time is  41.8 minute
# the X_val is 20300 and time is  42.0 minute
# the X_val is 20400 and time is  42.2 minute
# the X_val is 20500 and time is  42.4 minute
# the X_val is 20600 and time is  42.6 minute
# the X_val is 20700 and time is  42.9 minute
# the X_val is 20800 and time is  43.1 minute
# the X_val is 20900 and time is  43.3 minute
# the X_val is 21000 and time is  43.5 minute
# the X_val is 21100 and time is  43.7 minute
# the X_val is 21200 and time is  43.9 minute
# the X_val is 21300 and time is  44.1 minute
# the X_val is 21400 and time is  44.3 minute
# the X_val is 21500 and time is  44.5 minute
# the X_val is 21600 and time is  44.7 minute
# the X_val is 21700 and time is  44.9 minute
# the X_val is 21800 and time is  45.1 minute
# the X_val is 21900 and time is  45.3 minute
# the X_val is 22000 and time is  45.5 minute
# the X_val is 22100 and time is  45.7 minute
# the X_val is 22200 and time is  46.0 minute
# the X_val is 22300 and time is  46.2 minute
# the X_val is 22400 and time is  46.4 minute
# the X_val is 22500 and time is  46.6 minute
# the X_val is 22600 and time is  46.8 minute
# the X_val is 22700 and time is  47.0 minute
# the X_val is 22800 and time is  47.2 minute
# the X_val is 22900 and time is  47.4 minute
# the X_val is 23000 and time is  47.6 minute
# the X_val is 23100 and time is  47.8 minute
# the X_val is 23200 and time is  48.0 minute
# the X_val is 23300 and time is  48.2 minute
# the X_val is 23400 and time is  48.4 minute
# the X_val is 23500 and time is  48.6 minute
# the X_val is 23600 and time is  48.9 minute
# the X_val is 23700 and time is  49.1 minute
# the X_val is 23800 and time is  49.3 minute
# the X_val is 23900 and time is  49.5 minute
# the X_val is 24000 and time is  49.7 minute
# the X_val is 24100 and time is  49.9 minute
# the X_val is 24200 and time is  50.1 minute
# the X_val is 24300 and time is  50.3 minute
# the X_val is 24400 and time is  50.5 minute
# the X_val is 24500 and time is  50.7 minute
# the X_val is 24600 and time is  50.9 minute
# the X_val is 24700 and time is  51.1 minute
# the X_val is 24800 and time is  51.3 minute
# the X_val is 24900 and time is  51.5 minute
# the X_val is 25000 and time is  51.8 minute
# the X_val is 25100 and time is  52.0 minute
# the X_val is 25200 and time is  52.2 minute
# the X_val is 25300 and time is  52.4 minute
# the X_val is 25400 and time is  52.6 minute
# the X_val is 25500 and time is  52.8 minute
# the X_val is 25600 and time is  53.0 minute
# the X_val is 25700 and time is  53.2 minute
# the X_val is 25800 and time is  53.4 minute
# the X_val is 25900 and time is  53.6 minute
# the X_val is 26000 and time is  53.8 minute
# the X_val is 26100 and time is  54.0 minute
# the X_val is 26200 and time is  54.2 minute
# the X_val is 26300 and time is  54.4 minute
# the X_val is 26400 and time is  54.7 minute
# the X_val is 26500 and time is  54.9 minute
# the X_val is 26600 and time is  55.1 minute
# the X_val is 26700 and time is  55.3 minute
# the X_val is 26800 and time is  55.5 minute
# the X_val is 26900 and time is  55.7 minute
# the X_val is 27000 and time is  55.9 minute
# the X_val is 27100 and time is  56.1 minute
# the X_val is 27200 and time is  56.3 minute
# the X_val is 27300 and time is  56.5 minute
# the X_val is 27400 and time is  56.7 minute
# the X_val is 27500 and time is  56.9 minute
# the X_val is 27600 and time is  57.1 minute
# the X_val is 27700 and time is  57.3 minute
# the X_val is 27800 and time is  57.6 minute
# the X_val is 27900 and time is  57.8 minute
# the X_val is 28000 and time is  58.0 minute
# the X_val is 28100 and time is  58.2 minute
# the X_val is 28200 and time is  58.4 minute
# the X_val is 28300 and time is  58.6 minute
# the X_val is 28400 and time is  58.8 minute
# the X_val is 28500 and time is  59.0 minute
# the X_val is 28600 and time is  59.2 minute
# the X_val is 28700 and time is  59.4 minute
# the X_val is 28800 and time is  59.6 minute
# the X_val is 28900 and time is  59.8 minute
# the X_val is 29000 and time is  60.0 minute
# the X_val is 29100 and time is  60.2 minute
# the X_val is 29200 and time is  60.5 minute
# the X_val is 29300 and time is  60.7 minute
# the X_val is 29400 and time is  60.9 minute
# the X_val is 29500 and time is  61.1 minute
# the X_val is 29600 and time is  61.3 minute
# the X_val is 29700 and time is  61.5 minute
# the X_val is 29800 and time is  61.7 minute
# the X_val is 29900 and time is  61.9 minute
# the X_val is 30000 and time is  62.1 minute
# the X_val is 30100 and time is  62.3 minute
# the X_val is 30200 and time is  62.5 minute
# the X_val is 30300 and time is  62.7 minute
# the X_val is 30400 and time is  62.9 minute
# the X_val is 30500 and time is  63.1 minute
# the X_val is 30600 and time is  63.4 minute
# the X_val is 30700 and time is  63.6 minute
# the X_val is 30800 and time is  63.8 minute
# the X_val is 30900 and time is  64.0 minute
# the X_val is 31000 and time is  64.2 minute
# the X_val is 31100 and time is  64.4 minute
# the X_val is 31200 and time is  64.6 minute
# the X_val is 31300 and time is  64.8 minute
# the X_val is 31400 and time is  65.0 minute
# the X_val is 31500 and time is  65.2 minute
# the X_val is 31600 and time is  65.4 minute
# the X_val is 31700 and time is  65.6 minute
# the X_val is 31800 and time is  65.8 minute
# the X_val is 31900 and time is  66.0 minute
# the X_val is 32000 and time is  66.3 minute
# the X_val is 32100 and time is  66.5 minute
# the X_val is 32200 and time is  66.7 minute
# the X_val is 32300 and time is  66.9 minute
# the X_val is 32400 and time is  67.1 minute
# the X_val is 32500 and time is  67.3 minute
# the X_val is 32600 and time is  67.5 minute
# the X_val is 32700 and time is  67.7 minute
# the X_val is 32800 and time is  67.9 minute
# the X_val is 32900 and time is  68.1 minute
# the X_val is 33000 and time is  68.3 minute
# the X_val is 33100 and time is  68.5 minute
# the X_val is 33200 and time is  68.7 minute
# the X_val is 33300 and time is  68.9 minute
# the X_val is 33400 and time is  69.2 minute
# the X_val is 33500 and time is  69.4 minute
# the X_val is 33600 and time is  69.6 minute
# the X_val is 33700 and time is  69.8 minute
# the X_val is 33800 and time is  70.0 minute
# the X_val is 33900 and time is  70.2 minute
# the X_val is 34000 and time is  70.4 minute
# the X_val is 34100 and time is  70.6 minute
# the X_val is 34200 and time is  70.8 minute
# the X_val is 34300 and time is  71.0 minute
# the X_val is 34400 and time is  71.2 minute
# the X_val is 34500 and time is  71.4 minute
# the X_val is 34600 and time is  71.6 minute
# the X_val is 34700 and time is  71.8 minute
# the X_val is 34800 and time is  72.1 minute
# the X_val is 34900 and time is  72.3 minute
# the X_val is 35000 and time is  72.5 minute
# the X_val is 35100 and time is  72.7 minute
# the X_val is 35200 and time is  72.9 minute
# the X_val is 35300 and time is  73.1 minute
# the X_val is 35400 and time is  73.3 minute
# the X_val is 35500 and time is  73.5 minute
# the X_val is 35600 and time is  73.7 minute
# the X_val is 35700 and time is  73.9 minute
# the X_val is 35800 and time is  74.1 minute
# the X_val is 35900 and time is  74.3 minute
# the X_val is 36000 and time is  74.5 minute
# the X_val is 36100 and time is  74.7 minute
# the X_val is 36200 and time is  75.0 minute
# the X_val is 36300 and time is  75.2 minute
# the X_val is 36400 and time is  75.4 minute
# the X_val is 36500 and time is  75.6 minute
# the X_val is 36600 and time is  75.8 minute
# the X_val is 36700 and time is  76.0 minute
# the X_val is 36800 and time is  76.2 minute
# the X_val is 36900 and time is  76.4 minute
# the X_val is 37000 and time is  76.6 minute
# the X_val is 37100 and time is  76.8 minute
# the X_val is 37200 and time is  77.0 minute
# the X_val is 37300 and time is  77.2 minute
# the X_val is 37400 and time is  77.4 minute
# the X_val is 37500 and time is  77.6 minute
# the X_val is 37600 and time is  77.9 minute
# the X_val is 37700 and time is  78.1 minute
# the X_val is 37800 and time is  78.3 minute
# the X_val is 37900 and time is  78.5 minute
# the X_val is 38000 and time is  78.7 minute
# the X_val is 38100 and time is  78.9 minute
# the X_val is 38200 and time is  79.1 minute
# the X_val is 38300 and time is  79.3 minute
# the X_val is 38400 and time is  79.5 minute
# the X_val is 38500 and time is  79.7 minute
# the X_val is 38600 and time is  79.9 minute
# the X_val is 38700 and time is  80.1 minute
# the X_val is 38800 and time is  80.3 minute
# the X_val is 38900 and time is  80.6 minute
# the X_val is 39000 and time is  80.8 minute
# the X_val is 39100 and time is  81.0 minute
# the X_val is 39200 and time is  81.2 minute
# the X_val is 39300 and time is  81.4 minute
# the X_val is 39400 and time is  81.6 minute
# the X_val is 39500 and time is  81.8 minute
# the X_val is 39600 and time is  82.0 minute
# the X_val is 39700 and time is  82.2 minute
# the X_val is 39800 and time is  82.4 minute
# the X_val is 39900 and time is  82.6 minute
# the X_val is 40000 and time is  82.8 minute
# the X_val is 40100 and time is  83.0 minute
# the X_val is 40200 and time is  83.2 minute
# the X_val is 40300 and time is  83.5 minute
# the X_val is 40400 and time is  83.7 minute
# the X_val is 40500 and time is  83.9 minute
# the X_val is 40600 and time is  84.1 minute
# the X_val is 40700 and time is  84.3 minute
# the X_val is 40800 and time is  84.5 minute
# the X_val is 40900 and time is  84.7 minute
# the X_val is 41000 and time is  84.9 minute
# the X_val is 41100 and time is  85.1 minute
# the X_val is 41200 and time is  85.3 minute
# the X_val is 41300 and time is  85.5 minute
# the X_val is 41400 and time is  85.7 minute
# the X_val is 41500 and time is  85.9 minute
# the X_val is 41600 and time is  86.1 minute
# the X_val is 41700 and time is  86.4 minute
# the X_val is 41800 and time is  86.6 minute
# the X_val is 41900 and time is  86.8 minute
# the X_val is 42000 and time is  87.0 minute
# the X_val is 42100 and time is  87.2 minute
# the X_val is 42200 and time is  87.4 minute
# the X_val is 42300 and time is  87.6 minute
# the X_val is 42400 and time is  87.8 minute
# the X_val is 42500 and time is  88.0 minute
# the X_val is 42600 and time is  88.2 minute
# the X_val is 42700 and time is  88.4 minute
# the X_val is 42800 and time is  88.6 minute
# the X_val is 42900 and time is  88.8 minute
# the X_val is 43000 and time is  89.0 minute
# the X_val is 43100 and time is  89.3 minute
# the X_val is 43200 and time is  89.5 minute
# the X_val is 43300 and time is  89.7 minute
# the X_val is 43400 and time is  89.9 minute
# the X_val is 43500 and time is  90.1 minute
# the X_val is 43600 and time is  90.3 minute
# the X_val is 43700 and time is  90.5 minute
# the X_val is 43800 and time is  90.7 minute
# the X_val is 43900 and time is  90.9 minute
# the X_val is 44000 and time is  91.1 minute
# the X_val is 44100 and time is  91.3 minute
# the X_val is 44200 and time is  91.5 minute
# the X_val is 44300 and time is  91.7 minute
# the X_val is 44400 and time is  91.9 minute
# the X_val is 44500 and time is  92.2 minute
# the X_val is 44600 and time is  92.4 minute
# the X_val is 44700 and time is  92.6 minute
# the X_val is 44800 and time is  92.8 minute
# the X_val is 44900 and time is  93.0 minute
# the X_val is 45000 and time is  93.2 minute
# the X_val is 45100 and time is  93.4 minute
# the X_val is 45200 and time is  93.6 minute
# the X_val is 45300 and time is  93.8 minute
# the X_val is 45400 and time is  94.0 minute
# the X_val is 45500 and time is  94.2 minute
# the X_val is 45600 and time is  94.4 minute
# the X_val is 45700 and time is  94.6 minute
# the X_val is 45800 and time is  94.9 minute
# the X_val is 45900 and time is  95.1 minute
# the X_val is 46000 and time is  95.3 minute
# the X_val is 46100 and time is  95.5 minute
# the X_val is 46200 and time is  95.7 minute
# the X_val is 46300 and time is  95.9 minute
# the X_val is 46400 and time is  96.1 minute
# the X_val is 46500 and time is  96.3 minute
# the X_val is 46600 and time is  96.5 minute
# the X_val is 46700 and time is  96.7 minute
# the X_val is 46800 and time is  96.9 minute
# the X_val is 46900 and time is  97.1 minute
# the X_val is 47000 and time is  97.3 minute
# the X_val is 47100 and time is  97.5 minute
# the X_val is 47200 and time is  97.8 minute
# the X_val is 47300 and time is  98.0 minute
# the X_val is 47400 and time is  98.2 minute
# the X_val is 47500 and time is  98.4 minute
# the X_val is 47600 and time is  98.6 minute
# the X_val is 47700 and time is  98.8 minute
# the X_val is 47800 and time is  99.0 minute
# the X_val is 47900 and time is  99.2 minute
# the X_val is 48000 and time is  99.4 minute
# the X_val is 48100 and time is  99.6 minute
# the X_val is 48200 and time is  99.8 minute
# the X_val is 48300 and time is 100.0 minute
# the X_val is 48400 and time is 100.2 minute
# the X_val is 48500 and time is 100.4 minute
# the X_val is 48600 and time is 100.6 minute
# the X_val is 48700 and time is 100.9 minute
# the X_val is 48800 and time is 101.1 minute
# the X_val is 48900 and time is 101.3 minute
# the X_val is 49000 and time is 101.5 minute
# the X_val is 49100 and time is 101.7 minute
# the X_val is 49200 and time is 101.9 minute
# the X_val is 49300 and time is 102.1 minute
# the X_val is 49400 and time is 102.3 minute
# the X_val is 49500 and time is 102.5 minute
# the X_val is 49600 and time is 102.7 minute
# the X_val is 49700 and time is 102.9 minute
# the X_val is 49800 and time is 103.1 minute
# the X_val is 49900 and time is 103.3 minute
# the X_val is 50000 and time is 103.6 minute
# the X_val is 50100 and time is 103.8 minute
# the X_val is 50200 and time is 104.0 minute
# the X_val is 50300 and time is 104.2 minute
# the X_val is 50400 and time is 104.4 minute
# the X_val is 50500 and time is 104.6 minute
# the X_val is 50600 and time is 104.8 minute
# the X_val is 50700 and time is 105.0 minute
# the X_val is 50800 and time is 105.2 minute
# the X_val is 50900 and time is 105.4 minute
# the X_val is 51000 and time is 105.6 minute
# the X_val is 51100 and time is 105.8 minute
# the X_val is 51200 and time is 106.0 minute
# the X_val is 51300 and time is 106.2 minute
# the X_val is 51400 and time is 106.4 minute
# the X_val is 51500 and time is 106.6 minute
# the X_val is 51600 and time is 106.9 minute
# the X_val is 51700 and time is 107.1 minute
# the X_val is 51800 and time is 107.3 minute
# the X_val is 51900 and time is 107.5 minute
# the X_val is 52000 and time is 107.7 minute
# the X_val is 52100 and time is 107.9 minute
# the X_val is 52200 and time is 108.1 minute
# the X_val is 52300 and time is 108.3 minute
# the X_val is 52400 and time is 108.5 minute
# the X_val is 52500 and time is 108.7 minute
# the X_val is 52600 and time is 108.9 minute
# the X_val is 52700 and time is 109.1 minute
# the X_val is 52800 and time is 109.3 minute
# the X_val is 52900 and time is 109.5 minute
# the X_val is 53000 and time is 109.8 minute
# the X_val is 53100 and time is 110.0 minute
# the X_val is 53200 and time is 110.2 minute
# the X_val is 53300 and time is 110.4 minute
# the X_val is 53400 and time is 110.6 minute
# the X_val is 53500 and time is 110.8 minute
# the X_val is 53600 and time is 111.0 minute
# the X_val is 53700 and time is 111.2 minute
# the X_val is 53800 and time is 111.4 minute
# the X_val is 53900 and time is 111.6 minute
# the X_val is 54000 and time is 111.8 minute
# the X_val is 54100 and time is 112.0 minute
# the X_val is 54200 and time is 112.2 minute
# the X_val is 54300 and time is 112.4 minute
# the X_val is 54400 and time is 112.7 minute
# the X_val is 54500 and time is 112.9 minute
# the X_val is 54600 and time is 113.1 minute
# the X_val is 54700 and time is 113.3 minute
# the X_val is 54800 and time is 113.5 minute
# the X_val is 54900 and time is 113.7 minute
# the X_val is 55000 and time is 113.9 minute
# the X_val is 55100 and time is 114.1 minute
# the X_val is 55200 and time is 114.3 minute
# the X_val is 55300 and time is 114.5 minute
# the X_val is 55400 and time is 114.7 minute
# the X_val is 55500 and time is 114.9 minute
# the X_val is 55600 and time is 115.1 minute
# the X_val is 55700 and time is 115.3 minute
# the X_val is 55800 and time is 115.6 minute
# the X_val is 55900 and time is 115.8 minute
# the X_val is 56000 and time is 116.0 minute
# the X_val is 56100 and time is 116.2 minute
# the X_val is 56200 and time is 116.4 minute
# the X_val is 56300 and time is 116.6 minute
# the X_val is 56400 and time is 116.8 minute
# the X_val is 56500 and time is 117.0 minute
# the X_val is 56600 and time is 117.2 minute
# the X_val is 56700 and time is 117.4 minute
# the X_val is 56800 and time is 117.6 minute
# the X_val is 56900 and time is 117.8 minute
# the X_val is 57000 and time is 118.0 minute
# the X_val is 57100 and time is 118.3 minute
# the X_val is 57200 and time is 118.5 minute
# the X_val is 57300 and time is 118.7 minute
# the X_val is 57400 and time is 118.9 minute
# the X_val is 57500 and time is 119.1 minute
# the X_val is 57600 and time is 119.3 minute
# the X_val is 57700 and time is 119.5 minute
# the X_val is 57800 and time is 119.7 minute
# the X_val is 57900 and time is 119.9 minute
# the X_val is 58000 and time is 120.1 minute
# the X_val is 58100 and time is 120.3 minute
# the X_val is 58200 and time is 120.5 minute
# the X_val is 58300 and time is 120.7 minute
# the X_val is 58400 and time is 121.0 minute
# the X_val is 58500 and time is 121.2 minute
# the X_val is 58600 and time is 121.4 minute
# the X_val is 58700 and time is 121.6 minute
# the X_val is 58800 and time is 121.8 minute
# the X_val is 58900 and time is 122.0 minute
# the X_val is 59000 and time is 122.2 minute
# the X_val is 59100 and time is 122.4 minute
# the X_val is 59200 and time is 122.6 minute
# the X_val is 59300 and time is 122.8 minute
# the X_val is 59400 and time is 123.0 minute
# the X_val is 59500 and time is 123.2 minute
# the X_val is 59600 and time is 123.4 minute
# the X_val is 59700 and time is 123.6 minute
# the X_val is 59800 and time is 123.9 minute
# the X_val is 59900 and time is 124.1 minute
# the X_val is 60000 and time is 124.3 minute
# the X_val is 60100 and time is 124.5 minute
# the X_val is 60200 and time is 124.7 minute
# the X_val is 60300 and time is 124.9 minute
# the X_val is 60400 and time is 125.1 minute
# the X_val is 60500 and time is 125.3 minute
# the X_val is 60600 and time is 125.5 minute
# the X_val is 60700 and time is 125.7 minute
# the X_val is 60800 and time is 125.9 minute
# the X_val is 60900 and time is 126.1 minute
# the X_val is 61000 and time is 126.3 minute
# the X_val is 61100 and time is 126.5 minute
# the X_val is 61200 and time is 126.8 minute
# the X_val is 61300 and time is 127.0 minute
# the X_val is 61400 and time is 127.2 minute
# the X_val is 61500 and time is 127.4 minute
# the X_val is 61600 and time is 127.6 minute
# the X_val is 61700 and time is 127.8 minute
# the X_val is 61800 and time is 128.0 minute
# the X_val is 61900 and time is 128.2 minute
# the X_val is 62000 and time is 128.4 minute
# the X_val is 62100 and time is 128.6 minute
# the X_val is 62200 and time is 128.8 minute
# the X_val is 62300 and time is 129.0 minute
# the X_val is 62400 and time is 129.2 minute
# the X_val is 62500 and time is 129.4 minute
# the X_val is 62600 and time is 129.7 minute
# the X_val is 62700 and time is 129.9 minute
# the X_val is 62800 and time is 130.1 minute
# the X_val is 62900 and time is 130.3 minute
# the X_val is 63000 and time is 130.5 minute
# the X_val is 63100 and time is 130.7 minute
# the X_val is 63200 and time is 130.9 minute
# the X_val is 63300 and time is 131.1 minute
# the X_val is 63400 and time is 131.3 minute
# the X_val is 63500 and time is 131.5 minute
# the X_val is 63600 and time is 131.7 minute
# the X_val is 63700 and time is 131.9 minute
# the X_val is 63800 and time is 132.2 minute
# the X_val is 63900 and time is 132.4 minute
# the X_val is 64000 and time is 132.6 minute
# the X_val is 64100 and time is 132.8 minute
# the X_val is 64200 and time is 133.0 minute
# the X_val is 64300 and time is 133.2 minute
# the X_val is 64400 and time is 133.4 minute
# the X_val is 64500 and time is 133.6 minute
# the X_val is 64600 and time is 133.8 minute
# the X_val is 64700 and time is 134.0 minute
# the X_val is 64800 and time is 134.2 minute
# the X_val is 64900 and time is 134.4 minute
# the X_val is 65000 and time is 134.6 minute
# the X_val is 65100 and time is 134.8 minute
# the X_val is 65200 and time is 135.1 minute
# the X_val is 65300 and time is 135.3 minute
# the X_val is 65400 and time is 135.5 minute
# the X_val is 65500 and time is 135.7 minute
# the X_val is 65600 and time is 135.9 minute
# the X_val is 65700 and time is 136.1 minute
# the X_val is 65800 and time is 136.3 minute
# the X_val is 65900 and time is 136.5 minute
# the X_val is 66000 and time is 136.7 minute
# the X_val is 66100 and time is 136.9 minute
# the X_val is 66200 and time is 137.1 minute
# the X_val is 66300 and time is 137.3 minute
# the X_val is 66400 and time is 137.5 minute
# the X_val is 66500 and time is 137.7 minute
# the X_val is 66600 and time is 138.0 minute
# the X_val is 66700 and time is 138.2 minute
# the X_val is 66800 and time is 138.4 minute
# the X_val is 66900 and time is 138.6 minute
# the X_val is 67000 and time is 138.8 minute
# the X_val is 67100 and time is 139.0 minute
# the X_val is 67200 and time is 139.2 minute
# the X_val is 67300 and time is 139.4 minute
# the X_val is 67400 and time is 139.6 minute
# the X_val is 67500 and time is 139.8 minute
# the X_val is 67600 and time is 140.0 minute
# the X_val is 67700 and time is 140.2 minute
# the X_val is 67800 and time is 140.4 minute
# the X_val is 67900 and time is 140.6 minute
# the X_val is 68000 and time is 140.9 minute
# the X_val is 68100 and time is 141.1 minute
# the X_val is 68200 and time is 141.3 minute
# the X_val is 68300 and time is 141.5 minute
# the X_val is 68400 and time is 141.7 minute
# the X_val is 68500 and time is 141.9 minute
# the X_val is 68600 and time is 142.1 minute
# the X_val is 68700 and time is 142.3 minute
# the X_val is 68800 and time is 142.5 minute
# the X_val is 68900 and time is 142.7 minute
# the X_val is 69000 and time is 142.9 minute
# the X_val is 69100 and time is 143.1 minute
# the X_val is 69200 and time is 143.3 minute
# the X_val is 69300 and time is 143.6 minute
# the X_val is 69400 and time is 143.8 minute
# the X_val is 69500 and time is 144.0 minute
# the X_val is 69600 and time is 144.2 minute
# the X_val is 69700 and time is 144.4 minute
# the X_val is 69800 and time is 144.6 minute
# the X_val is 69900 and time is 144.8 minute
# the X_val is 70000 and time is 145.0 minute
# the X_val is 70100 and time is 145.2 minute
# the X_val is 70200 and time is 145.4 minute
# the X_val is 70300 and time is 145.6 minute
# the X_val is 70400 and time is 145.8 minute
# the X_val is 70500 and time is 146.0 minute
# the X_val is 70600 and time is 146.2 minute
# the X_val is 70700 and time is 146.5 minute
# the X_val is 70800 and time is 146.7 minute
# the X_val is 70900 and time is 146.9 minute
# the X_val is 71000 and time is 147.1 minute
# the X_val is 71100 and time is 147.3 minute
# the X_val is 71200 and time is 147.5 minute
# the X_val is 71300 and time is 147.7 minute
# the X_val is 71400 and time is 147.9 minute
# the X_val is 71500 and time is 148.2 minute
# the X_val is 71600 and time is 148.4 minute
# the X_val is 71700 and time is 148.6 minute
# the X_val is 71800 and time is 148.8 minute
# the X_val is 71900 and time is 149.1 minute
# the X_val is 72000 and time is 149.3 minute
# the X_val is 72100 and time is 149.5 minute
# the X_val is 72200 and time is 149.7 minute
# the X_val is 72300 and time is 150.0 minute
# the X_val is 72400 and time is 150.2 minute
# the X_val is 72500 and time is 150.4 minute
# the X_val is 72600 and time is 150.6 minute
# the X_val is 72700 and time is 150.8 minute
# the X_val is 72800 and time is 151.0 minute
# the X_val is 72900 and time is 151.3 minute
# the X_val is 73000 and time is 151.5 minute
# the X_val is 73100 and time is 151.7 minute
# the X_val is 73200 and time is 151.9 minute
# the X_val is 73300 and time is 152.1 minute
# the X_val is 73400 and time is 152.3 minute
# the X_val is 73500 and time is 152.5 minute
# the X_val is 73600 and time is 152.7 minute
# the X_val is 73700 and time is 152.9 minute
# the X_val is 73800 and time is 153.2 minute
# the X_val is 73900 and time is 153.4 minute
# the X_val is 74000 and time is 153.6 minute
# the X_val is 74100 and time is 153.8 minute
# the X_val is 74200 and time is 154.0 minute
# the X_val is 74300 and time is 154.2 minute
# the X_val is 74400 and time is 154.4 minute
# the X_val is 74500 and time is 154.6 minute
# the X_val is 74600 and time is 154.9 minute
# the X_val is 74700 and time is 155.1 minute
# the X_val is 74800 and time is 155.3 minute
# the X_val is 74900 and time is 155.6 minute
# the X_val is 75000 and time is 155.8 minute
# the X_val is 75100 and time is 156.1 minute
# the X_val is 75200 and time is 156.3 minute
# the X_val is 75300 and time is 156.5 minute
# the X_val is 75400 and time is 156.8 minute
# the X_val is 75500 and time is 157.0 minute
# the X_val is 75600 and time is 157.2 minute
# the X_val is 75700 and time is 157.5 minute
# the X_val is 75800 and time is 157.7 minute
# the X_val is 75900 and time is 158.0 minute
# the X_val is 76000 and time is 158.2 minute
# the X_val is 76100 and time is 158.5 minute
# the X_val is 76200 and time is 158.7 minute
# the X_val is 76300 and time is 159.0 minute
# the X_val is 76400 and time is 159.2 minute
# the X_val is 76500 and time is 159.5 minute
# the X_val is 76600 and time is 159.7 minute
# the X_val is 76700 and time is 159.9 minute
# the X_val is 76800 and time is 160.1 minute
# the X_val is 76900 and time is 160.4 minute
# the X_val is 77000 and time is 160.6 minute
# the X_val is 77100 and time is 160.8 minute
# the X_val is 77200 and time is 161.0 minute
# the X_val is 77300 and time is 161.2 minute
# the X_val is 77400 and time is 161.5 minute
# the X_val is 77500 and time is 161.7 minute
# the X_val is 77600 and time is 161.9 minute
# the X_val is 77700 and time is 162.1 minute
# the X_val is 77800 and time is 162.3 minute
# the X_val is 77900 and time is 162.5 minute
# the X_val is 78000 and time is 162.8 minute
# the X_val is 78100 and time is 163.0 minute
# the X_val is 78200 and time is 163.2 minute
# the X_val is 78300 and time is 163.5 minute
# the X_val is 78400 and time is 163.7 minute
# the X_val is 78500 and time is 163.9 minute
# the X_val is 78600 and time is 164.1 minute
# the X_val is 78700 and time is 164.4 minute
# the X_val is 78800 and time is 164.6 minute
# the X_val is 78900 and time is 164.8 minute
# the X_val is 79000 and time is 165.0 minute
# the X_val is 79100 and time is 165.2 minute
# the X_val is 79200 and time is 165.4 minute
# the X_val is 79300 and time is 165.6 minute
# the X_val is 79400 and time is 165.9 minute
# the X_val is 79500 and time is 166.1 minute
# the X_val is 79600 and time is 166.3 minute
# the X_val is 79700 and time is 166.5 minute
# the X_val is 79800 and time is 166.7 minute
# the X_val is 79900 and time is 166.9 minute
# the X_val is 80000 and time is 167.1 minute
# the X_val is 80100 and time is 167.3 minute
# the X_val is 80200 and time is 167.5 minute
# the X_val is 80300 and time is 167.7 minute
# the X_val is 80400 and time is 167.9 minute
# the X_val is 80500 and time is 168.1 minute
# the X_val is 80600 and time is 168.4 minute
# the X_val is 80700 and time is 168.6 minute
# the X_val is 80800 and time is 168.8 minute
# the X_val is 80900 and time is 169.0 minute
# the X_val is 81000 and time is 169.2 minute
# the X_val is 81100 and time is 169.4 minute
# the X_val is 81200 and time is 169.6 minute
# the X_val is 81300 and time is 169.8 minute
# the X_val is 81400 and time is 170.0 minute
# the X_val is 81500 and time is 170.2 minute
# the X_val is 81600 and time is 170.4 minute
# the X_val is 81700 and time is 170.6 minute
# the X_val is 81800 and time is 170.8 minute
# the X_val is 81900 and time is 171.1 minute
# the X_val is 82000 and time is 171.3 minute
# the X_val is 82100 and time is 171.5 minute
# the X_val is 82200 and time is 171.7 minute
# the X_val is 82300 and time is 171.9 minute
# the X_val is 82400 and time is 172.1 minute
# the X_val is 82500 and time is 172.3 minute
# the X_val is 82600 and time is 172.5 minute
# the X_val is 82700 and time is 172.8 minute
# the X_val is 82800 and time is 173.0 minute
# the X_val is 82900 and time is 173.2 minute
# the X_val is 83000 and time is 173.4 minute
# the X_val is 83100 and time is 173.6 minute
# the X_val is 83200 and time is 173.8 minute
# the X_val is 83300 and time is 174.0 minute
# the X_val is 83400 and time is 174.2 minute
# the X_val is 83500 and time is 174.5 minute
# the X_val is 83600 and time is 174.7 minute
# the X_val is 83700 and time is 174.9 minute
# the X_val is 83800 and time is 175.1 minute
# the X_val is 83900 and time is 175.3 minute
# the X_val is 84000 and time is 175.5 minute
# the X_val is 84100 and time is 175.7 minute
# the X_val is 84200 and time is 176.0 minute
# the X_val is 84300 and time is 176.2 minute
# the X_val is 84400 and time is 176.4 minute
# the X_val is 84500 and time is 176.6 minute
# the X_val is 84600 and time is 176.9 minute
# the X_val is 84700 and time is 177.1 minute
# the X_val is 84800 and time is 177.3 minute
# the X_val is 84900 and time is 177.5 minute
# the X_val is 85000 and time is 177.7 minute
# the X_val is 85100 and time is 177.9 minute
# the X_val is 85200 and time is 178.2 minute
# the X_val is 85300 and time is 178.4 minute
# the X_val is 85400 and time is 178.6 minute
# the X_val is 85500 and time is 178.8 minute
# the X_val is 85600 and time is 179.0 minute
# the X_val is 85700 and time is 179.2 minute
# the X_val is 85800 and time is 179.4 minute
# the X_val is 85900 and time is 179.6 minute
# the X_val is 86000 and time is 179.8 minute
# the X_val is 86100 and time is 180.1 minute
# the X_val is 86200 and time is 180.3 minute
# the X_val is 86300 and time is 180.5 minute
# the X_val is 86400 and time is 180.7 minute
# the X_val is 86500 and time is 180.9 minute
# the X_val is 86600 and time is 181.1 minute
# the X_val is 86700 and time is 181.3 minute
# the X_val is 86800 and time is 181.5 minute
# KNN STOP

# %%
y_pred_knn=pd.Series(y_pred_knn)

# %%
#output the prediction and probability 
y_pred_knn.to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\y_pred_knn.csv",index=False)
pd.Series(y_proba_1_knn).to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\y_proba_1_knn.csv",index=False)
pd.Series(y_proba_2_knn).to_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\y_proba_2_knn.csv",index=False)

# %%
y_pred_knn=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\y_pred_knn.csv")
y_proba_1_knn=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\y_proba_1_knn.csv")
y_proba_2_knn=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\y_proba_2_knn.csv")

# %%
f1_score(y_val,y_pred_knn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7a607b159838> in <module>()
# ----> 1 f1_score(y_val,y_pred_knn)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#     690     return fbeta_score(y_true, y_pred, 1, labels=labels,
#     691                        pos_label=pos_label, average=average,
# --> 692                        sample_weight=sample_weight)
#     693
#     694
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight)
#     804                                                  average=average,
#     805                                                  warn_for=('f-score',),
# --> 806                                                  sample_weight=sample_weight)
#     807     return f
#     808
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#    1001         raise ValueError("beta should be >0 in the F-beta score")
#    1002
# -> 1003     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1004     present_labels = unique_labels(y_true, y_pred)
#    1005
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      70     y_pred : array or indicator matrix
#      71     """
# ---> 72     check_consistent_length(y_true, y_pred)
#      73     type_true = type_of_target(y_true)
#      74     type_pred = type_of_target(y_pred)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [86841, 86840]

# %%
accuracy_score(y_val,y_pred_knn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f7fd3e2e397f> in <module>()
# ----> 1 accuracy_score(y_val,y_pred_knn)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     170
#     171     # Compute accuracy for each possible representation
# --> 172     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     173     if y_type.startswith('multilabel'):
#     174         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      70     y_pred : array or indicator matrix
#      71     """
# ---> 72     check_consistent_length(y_true, y_pred)
#      73     type_true = type_of_target(y_true)
#      74     type_pred = type_of_target(y_pred)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [86841, 86840]

# %%
fp_knn,tp_knn,thresholds_knn=roc_curve(y_val,y_proba_2_knn,pos_label=2)

# %% [markdown]
# then we implement SVM,sing linearSVC which using estimator **liblinear** , will converge quickly in large dataset

# %%
rbf_kernel=RBFSampler(gamma=1,n_components=300, random_state=42)#n_components is tradeoff between the running time and accuracy
X_train_nonlinear=rbf_kernel.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a2c382ca4e5c> in <module>()
# ----> 1 rbf_kernel=RBFSampler(gamma=1,n_components=300, random_state=42)#n_components is tradeoff between the running time and accuracy
#       2 X_train_nonlinear=rbf_kernel.fit_transform(X_train)
#
# NameError: name 'RBFSampler' is not defined

# %%
X_train_nonlinear.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-21486ad4be78> in <module>()
# ----> 1 X_train_nonlinear.shape
#
# NameError: name 'X_train_nonlinear' is not defined

# %%
svm_clf=LinearSVC(C=1,loss="hinge")

# %%
svm_clf.fit(X_train_nonlinear,y_train)

# %%
X_val_nonlinear=rbf_kernel.transform(X_val)

# %%
y_pred_svm=svm_clf.predict(X_val_nonlinear)

# %%
f1_score(y_val,y_pred_svm)

# %%
accuracy_score(y_train,svm_clf.predict(X_train_nonlinear)) #training set accuracy

# %%
accuracy_score(y_val,y_pred_svm) #validation accuracy

# %%
y_score_svm=svm_clf.decision_function(X_val_nonlinear)

# %%
fp_svm,tp_svm,thresholds_svm=roc_curve(y_val,y_score_svm,pos_label=2)

# %% [markdown]
# we also try to compare with linearSVC and SVC which use **libsvm** instead

# %%
svc_clf=SVC(kernel="rbf",degree=len(X_train),coef0=1,C=1)

# %%
svc_clf.fit(X_train,y_train)
# Out:
# C:\Users\yangshanqi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# SVC(C=1, cache_size=200, class_weight=None, coef0=1,
#   decision_function_shape='ovr', degree=265812, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred_svc=svc_clf.predict(X_val)

# %%
TPR_svc, f1_score_svc, BER_svc = cal_score(y_pred_svc,y_val)
# Out:
# n11:..57892..n12:..5870..n21:..3315..n22:..2950
# TP:0.3344671201814059
# f1 score:0.39111700364600593
# FP:0.054160471841456045
# BER:0.35984667583002505

# %%
y_score_svc=svc_clf.decision_function(X_val)

# %%
fp_svc,tp_svc,thresholds_svc=roc_curve(y_val,y_score_svc,pos_label=2)

# %%
f1_score(y_val,y_pred_svc)
# Out:
# 0.97359425315828585

# %%
accuracy_score(y_val,y_pred_svc)
# Out:
# 0.95089876901463599

# %%
plt.plot(fp_svc,tp_svc,"y-",label="SVC")
plot_roc_curve(fp_svm,tp_svm,label='LinearSVC')
plt.legend()
plt.show()

# %% [markdown]
# then we try the XGBClassifier, which implement xgboost algorithm , this classifier has good performance in the Kaggle competition

# %%
xgb_clf=XGBClassifier(  n_estimators=500,
                        max_depth=4,
                        objective="binary:logistic",
                        learning_rate=0.03, 
                        subsample=.8,
                        min_child_weight=6,
                        colsample_bytree=.8,
                        scale_pos_weight=1.6,
                        gamma=10,
                        reg_alpha=8,
                        reg_lambda=1.3
                     )

# %%
xgb_clf.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=10, learning_rate=0.03, max_delta_step=0, max_depth=4,
#        min_child_weight=6, missing=None, n_estimators=500, nthread=-1,
#        objective='binary:logistic', reg_alpha=8, reg_lambda=1.3,
#        scale_pos_weight=1.6, seed=0, silent=True, subsample=0.8)

# %%
y_pred=xgb_clf.predict(X_val)

# %%
xgb_clf.feature_importances_
# Out:
# array([ 0.21690141,  0.20018779,  0.22159624,  0.21239437,  0.14892019], dtype=float32)

# %%
f1_score(y_val,y_pred)
# Out:
# 0.97769589194423667

# %%
fp_xgb,tp_xgb,thresholds_xgb=roc_curve(y_val,xgb_clf.predict_proba(X_val)[:,1],pos_label=2)
plt.plot(fp_knn,tp_knn,"b-",label="KNN")
plt.plot(fp_svm,tp_svm,"r-",label="SVM")
plt.plot(fp_xgb,tp_xgb,"y-",label="XGB")
plot_roc_curve(fp_nn,tp_nn,label='NN')
plt.legend()
plt.show()

# %%
importance_xgb=xgb_clf.feature_importances_
features=["T2 weighted","ADC","Ktrans","Kep","PET"]

# %%
#using the attribute of random forest to analysis the importances of features
def plot_feature_imp(importance,features):
    trace2 = go.Bar(
        x=importance,
        y=features,
        marker=dict(
            color=importance,
            colorscale = 'Viridis',
            reversescale = True
        ),
        name='Random Forest Feature importance',
        orientation='h',
    )
    layout = dict(
        title='Barplot of Feature importances',
         width = 700, height = 400,
        yaxis=dict(
            showgrid=False,
            showline=False,
            showticklabels=True,
#             domain=[0, 0.85],
        ))

    fig1 = go.Figure(data=[trace2])
    fig1['layout'].update(layout)
    py.iplot(fig1, filename='plots')

# %%
plot_feature_imp(importance_xgb,features)
# Out:
# <div id="9a4e955d-6444-43bf-9d86-d7fbaa99fa34" style="height: 400px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9a4e955d-6444-43bf-9d86-d7fbaa99fa34", [{"type": "bar", "x": [0.21690140664577484, 0.2001877874135971, 0.22159624099731445, 0.2123943716287613, 0.1489201933145523], "y": ["T2 weighted", "ADC", "Ktrans", "Kep", "PET"], "marker": {"color": [0.21690140664577484, 0.2001877874135971, 0.22159624099731445, 0.2123943716287613, 0.1489201933145523], "colorscale": "Viridis", "reversescale": true}, "name": "Random Forest Feature importance", "orientation": "h"}], {"title": "Barplot of Feature importances", "width": 700, "height": 400, "yaxis": {"showgrid": false, "showline": false, "showticklabels": true}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# seems importances is sensitive to classifier(XGB and RDF) better plot 2 classes of samples and seee

# %% [markdown]
# Here we try another classifier random forest

# %%
#use random forest to make a test
rdf_clf=RandomForestClassifier(random_state=42)
y_proba=cross_val_predict(rdf_clf,X_train,y_train,cv=3,method="predict_proba")

# %%
y_score=y_proba[:,1]
fp_rdf,tp_rdf,thresholds_rdf=roc_curve(y_train,y_score,pos_label=2)

# %%
plot_roc_curve(fp_rdf,tp_rdf,label='randomforest')

# %% [markdown]
# then we use the attributes of random forest **feature importance** to analysis features

# %%
rdf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=42,
#             verbose=0, warm_start=False)

# %%
importance_rdf=rdf_clf.feature_importances_
features=["T2 weighted","ADC","Ktrans","Kep","PET"]

# %%
 plot_feature_imp(importance_rdf,features)
# Out:
# <div id="0afe991f-8b65-463c-9b5d-38d165c2fc0f" style="height: 400px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0afe991f-8b65-463c-9b5d-38d165c2fc0f", [{"type": "bar", "x": [0.3680273328247416, 0.1506854141033239, 0.13552236449776972, 0.2079107374461479, 0.1378541511280169], "y": ["T2 weighted", "ADC", "Ktrans", "Kep", "PET"], "marker": {"color": [0.3680273328247416, 0.1506854141033239, 0.13552236449776972, 0.2079107374461479, 0.1378541511280169], "colorscale": "Viridis", "reversescale": true}, "name": "Random Forest Feature importance", "orientation": "h"}], {"title": "Barplot of Feature importances", "width": 700, "height": 400, "yaxis": {"showgrid": false, "showline": false, "showticklabels": true}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # 5.Feature selection

# %% [markdown]
# # 6. Prediction & Visualization

# %% [markdown]
# ## 6.1 plot prediction on the image

# %% [markdown]
# first we try to plot the prediction and plot it on the T2 weighted

# %%
#plot the test sample(image and label)
def plot_prediction(test_shape,test_sample,new_label,feature): 
    #the feature contains ['0','1','2','3','4'] represent five features respectively
    #change the dataframe to ndarray
    image_size=test_sample[feature].values.reshape(test_shape[0],test_shape[1])
    image_label=new_label.values.reshape(test_shape[0],test_shape[1])
    
    #set up cmap
    cmap1 = matplotlib.colors.LinearSegmentedColormap.\
    from_list('my_cmap',['black','red','blue'],256)
    plt.imshow(image_size,cmap = matplotlib.cm.binary,alpha=0.8)
    plt.imshow(image_label,cmap = cmap1,interpolation="bilinear",alpha=0.2)
    plt.axis("off") #close the axis number
    plt.show()

# %%
def predict_sample(X,y,MODE,clf=RandomForestClassifier(random_state=42)):
    #predict function for Random forest and SVM
    if MODE == 'SVM' or MODE == 'RF' or MODE == 'XGB':
        label=[]
        for i in range(len(X)):
            if np.int(y.iloc[i]) == 0: #the non-prostate area
                label.append(np.float64(0.0))
            else:
                label.append(np.float64(clf.predict(X.iloc[i:i+1])))#predict on every sample
        label=pd.DataFrame(label,columns=['label'])
    #prediction function for NN
    if MODE == 'NN':
        label,_,_=nn_predict(X,X_train,y_train)
        for i in range(len(X)):
            if np.int(y.iloc[i]) == 0:
                label.iloc[i] = 0.0
            else:
                continue
    #prediction function for KNN
    if MODE == 'KNN':
        label,_,_=knn_predict(X,X_train,y_train,5)
        for i in range(len(X)):
            if np.int(y.iloc[i]) == 0:
                label.iloc[i] = 0.0
            else:
                continue
        #label=pd.DataFrame(label,columns=['label'])
    return label

# %%
#set up a test_sample(one slice feature image)
test_sample=data[1][0][0][0][0][:,:,40,:]
test_sample=pd.DataFrame(test_sample.reshape(test_sample.shape[0]*test_sample.shape[1],5),\
                         columns=["0","1","2","3","4"]) #columns name needs to be changed
#test_sample.isnull()
feature_eng.transform(test_sample)
test_label=data[1][0][0][0][1][:,:,40]
test_shape=test_label.shape
test_label=pd.Series(test_label.ravel())
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:356: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.

# %%
#predict new label using Nearest mean
MODE='NN'
new_label_nn=predict_sample(test_sample,test_label,MODE=MODE)
# Out:
# KNN start
# the index is 0 and time is   0.0 second
# the index is 1000 and time is   0.0 second
# the index is 2000 and time is   0.0 second
# the index is 3000 and time is   0.0 second
# the index is 4000 and time is   0.0 second
# the index is 5000 and time is   0.0 second
# the index is 6000 and time is   0.0 second
# KNN STOP

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title("original label")
plot_prediction(test_shape,test_sample,test_label,'0')
plt.figure(figsize=(8,4))
plt.subplot(122)
plt.title("our prediction in NN")
plot_prediction(test_shape,test_sample,new_label_nn,'0')

# %%
#predict the knn
MODE='KNN'
new_label_knn=predict_sample(test_sample,test_label,MODE=MODE)
# Out:
# KNN start
# the X_val is 0 and time is   0.0 minute
# the X_val is 100 and time is   0.2 minute
# the X_val is 200 and time is   0.5 minute
# the X_val is 300 and time is   0.7 minute
# the X_val is 400 and time is   1.0 minute
# the X_val is 500 and time is   1.2 minute
# the X_val is 600 and time is   1.5 minute
# the X_val is 700 and time is   1.7 minute
# the X_val is 800 and time is   2.0 minute
# the X_val is 900 and time is   2.2 minute
# the X_val is 1000 and time is   2.5 minute
# the X_val is 1100 and time is   2.7 minute
# the X_val is 1200 and time is   3.0 minute
# the X_val is 1300 and time is   3.2 minute
# the X_val is 1400 and time is   3.5 minute
# the X_val is 1500 and time is   3.7 minute
# the X_val is 1600 and time is   4.0 minute
# the X_val is 1700 and time is   4.2 minute
# the X_val is 1800 and time is   4.4 minute
# the X_val is 1900 and time is   4.7 minute
# the X_val is 2000 and time is   4.9 minute
# the X_val is 2100 and time is   5.2 minute
# the X_val is 2200 and time is   5.4 minute
# the X_val is 2300 and time is   5.7 minute
# the X_val is 2400 and time is   5.9 minute
# the X_val is 2500 and time is   6.2 minute
# the X_val is 2600 and time is   6.4 minute
# the X_val is 2700 and time is   6.7 minute
# the X_val is 2800 and time is   6.9 minute
# the X_val is 2900 and time is   7.1 minute
# the X_val is 3000 and time is   7.4 minute
# the X_val is 3100 and time is   7.6 minute
# the X_val is 3200 and time is   7.9 minute
# the X_val is 3300 and time is   8.1 minute
# the X_val is 3400 and time is   8.4 minute
# the X_val is 3500 and time is   8.6 minute
# the X_val is 3600 and time is   8.9 minute
# the X_val is 3700 and time is   9.1 minute
# the X_val is 3800 and time is   9.4 minute
# the X_val is 3900 and time is   9.7 minute
# the X_val is 4000 and time is   9.9 minute
# the X_val is 4100 and time is  10.2 minute
# the X_val is 4200 and time is  10.4 minute
# the X_val is 4300 and time is  10.6 minute
# the X_val is 4400 and time is  10.9 minute
# the X_val is 4500 and time is  11.1 minute
# the X_val is 4600 and time is  11.4 minute
# the X_val is 4700 and time is  11.6 minute
# the X_val is 4800 and time is  11.9 minute
# the X_val is 4900 and time is  12.1 minute
# the X_val is 5000 and time is  12.4 minute
# the X_val is 5100 and time is  12.6 minute
# the X_val is 5200 and time is  12.9 minute
# the X_val is 5300 and time is  13.1 minute
# the X_val is 5400 and time is  13.4 minute
# the X_val is 5500 and time is  13.6 minute
# the X_val is 5600 and time is  13.9 minute
# the X_val is 5700 and time is  14.1 minute
# the X_val is 5800 and time is  14.4 minute
# the X_val is 5900 and time is  14.6 minute
# the X_val is 6000 and time is  14.9 minute
# the X_val is 6100 and time is  15.1 minute
# the X_val is 6200 and time is  15.3 minute
# the X_val is 6300 and time is  15.6 minute
# the X_val is 6400 and time is  15.9 minute
# the X_val is 6500 and time is  16.1 minute
# KNN STOP

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title("original label")
plot_prediction(test_shape,test_sample,test_label,'0')
plt.figure(figsize=(8,4))
plt.subplot(122)
plt.title("our prediction in KNN")
plot_prediction(test_shape,test_sample,new_label_knn,'0')

# %%
#predict using SVM
MODE='SVM'
new_label_svm=predict_sample(test_sample,test_label,MODE=MODE,clf=svm_clf)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# ...
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title("original label")
plot_prediction(test_shape,test_sample,test_label,'0')
plt.figure(figsize=(8,4))
plt.subplot(122)
plt.title("our prediction in SVM")
plot_prediction(test_shape,test_sample,new_label_svm,'0')

# %%
#predict the in XGB
MODE='XGB'
new_label_xgb=predict_sample(test_sample,test_label,MODE=MODE,clf=xgb_clf)

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title("original label")
plot_prediction(test_shape,test_sample,test_label,'0')
plt.figure(figsize=(8,4))
plt.subplot(122)
plt.title("our prediction in XGB")
plot_prediction(test_shape,test_sample,new_label_xgb,'0')

# %%
#the predicted label for Random forest and SVM
new_label=predict_sample(test_sample,test_label,rdf_clf)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# ...
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning:
#
# Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)
plt.title("original label")
plot_prediction(test_shape,test_sample,test_label,'0')
plt.figure(figsize=(8,4))
plt.subplot(122)
plt.title("our prediction")
plot_prediction(test_shape,test_sample,new_label,'0')

# %% [markdown]
# ## 6.2 plot the decision boundary on 2 features

# %%
def plot_decision_boundary(test_sample,feature,clf):
    
    step=0.01
    f0_min,f0_max=test_sample.values[:,0].min(),test_sample.values[:,0].max()
    f1_min,f1_max=test_sample.values[:,1].min(),test_sample.values[:,1].max()
    f2_min,f2_max=test_sample.values[:,2].min(),test_sample.values[:,2].max()
    f3_min,f3_max=test_sample.values[:,3].min(),test_sample.values[:,3].max()
    f4_min,f4_max=test_sample.values[:,4].min(),test_sample.values[:,4].max()
    
    f_0,f_1=np.meshgrid(np.arange(f0_min,f0_max,step),np.arange(f1_min,f1_max,step))#,\
                     #np.arange(f2_min,f2_max,step),np.arange(f3_min,f3_max,step),\
                     #np.arange(f4_min,f4_max,step))
    return f_0

# %%
step=0.1
X_min,X_max=test_sample.values[:,0].min()-1,test_sample.values[:,0].max()+1
Y_min,Y_max=test_sample.values[:,3].min()-1,test_sample.values[:,1].max()+1
xx,yy=np.meshgrid(np.arange(X_min,X_max,step),np.arange(Y_min,Y_max,step))

X_grid=np.array([xx.ravel(),yy.ravel()]).T

# %%
X_grid.shape
# Out:
# (7308, 2)

# %%
#nearst neighbour graph
X_predict=np.zeros((X_grid.shape[0],5))
X_predict[:,0]=X_grid[:,0]
X_predict[:,3]=X_grid[:,1]
X_predict[:,1],X_predict[:,2],X_predict[:,4]=1,1,2
Z=rdf_clf.predict(X_predict)
Z=Z.reshape(xx.shape)

plt.contourf(xx,yy,Z,cmap=plt.cm.coolwarm,alpha=1)

# %%
plot_decision_boundary(test_sample).shape
# Out:
# (2260, 89)

# %%
test_label.astype('int').values.ravel()
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
sample=pd.concat([test_sample,new_label],axis=1)
set_1=sample.loc[sample['label']==1]
set_2=sample.loc[sample['label']==2]

# %%
test_sample.values.min()
# Out:
# -2.497139866393371
