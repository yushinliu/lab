# %%
#all packages which will be used
import numpy as np
import pandas as pd
from scipy.io import loadmat
import time
import random

#plot
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from matplotlib.axes import Axes

#feature selection method
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from pandas.plotting import scatter_matrix
from scipy.stats import pearsonr
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
from minepy import MINE
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
X_train=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_x_resample3000_boundarysel_50pergroup.csv")
y_train=pd.read_csv("C:\\Users\\hasee\\workspace\\lab\\patRecDat\\forStudents\\medData\\train_y_resample3000_boundarysel_50pergroup.csv")

# %%
X_train=X_train.drop(X_train[['predict_cluster']],axis=1)

# %%
y_train=y_train.drop(y_train[['indexofpixel','sourceofpixel','predict_cluster']],axis=1)

# %%
X_train
# Out:
#         feature0  feature1  feature2  feature3  feature4
# 0       0.117651  0.285209 -0.302723 -0.624315 -1.479327
# 1       0.147586  0.221792 -0.305188 -0.571669 -1.616350
# 2       1.259228  0.245014 -0.304999 -0.889284 -0.615679
# 3       0.977743  0.168739 -0.307814 -0.916704 -0.865166
# 4       0.172629 -0.177533 -0.323227 -0.817478 -1.538269
# 5       0.061648 -0.209621 -0.317097 -0.826345 -1.182052
# 6      -0.127941 -0.217494 -0.314132 -0.877895 -1.665984
# 7      -0.089186 -0.265669 -0.317835 -0.927722 -1.781468
# 8      -0.051220 -0.321122 -0.318356 -0.917181 -1.925174
# 9       0.040025 -0.359712 -0.315545 -0.924859 -1.777884
# 10      0.160288 -0.393264 -0.314956 -0.932011 -1.739438
# 11      0.192331 -0.433106 -0.317775 -0.938378 -1.641955
# 12      0.386019 -0.460713 -0.319514 -0.936185 -1.342174
# 13      0.400225 -0.472855 -0.322124 -0.948786 -1.607959
# 14      1.448439  0.082605 -0.311219 -1.003047 -0.189016
# 15      1.152033 -0.043868 -0.318022 -0.985872 -0.465827
# 16      0.845107 -0.184835 -0.323059 -0.920372 -0.802791
# 17      0.448712 -0.333221 -0.329553 -0.867725 -0.803806
# 18      0.118705 -0.372172 -0.327494 -0.865706 -0.977214
# 19     -0.198165 -0.309007 -0.314584 -0.905298 -1.050021
# 20     -0.428309 -0.260877 -0.303299 -0.955125 -1.325205
# 21     -0.459250 -0.262714 -0.301869 -0.962370 -1.426058
# 22     -0.420860 -0.316122 -0.303157 -0.965184 -1.885469
# 23     -0.223313 -0.397855 -0.304038 -0.972274 -1.613907
# 24     -0.062112 -0.458310 -0.305806 -0.939036 -1.792384
# 25      0.285125 -0.494074 -0.310630 -0.936842 -1.776570
# 26      0.532682 -0.481940 -0.320686 -0.956178 -1.366830
# 27      0.527869 -0.510297 -0.327576 -0.949597 -1.795845
# 28      1.522835 -0.028747 -0.308475 -1.050584  0.029364
# 29      1.213506 -0.160325 -0.314295 -0.976001 -0.470900
# ...          ...       ...       ...       ...       ...
# 248422 -0.428932  0.090181 -0.128715 -0.175827 -0.316528
# 248423 -0.907894  0.082152 -0.175932 -0.156854 -0.535467
# 248424 -1.045099  0.107199 -0.184114  0.034121 -0.600785
# 248425 -1.576045  0.091953 -0.183634  0.232556 -0.272602
# 248426 -1.682393 -0.025140 -0.185217  0.279726 -0.254665
# 248427 -1.867729 -0.176049 -0.191378  0.308258 -0.195663
# 248428 -1.795236 -0.274151 -0.198179  0.195853 -0.774327
# 248429 -0.886260 -0.747587 -0.283365 -0.966125 -1.516685
# 248430 -0.403591 -0.666342 -0.274411 -0.920104 -1.238921
# 248431 -0.248125 -0.074371 -0.102765 -0.867521 -0.427034
# 248432 -0.042804  0.312362  0.394473 -0.796231 -0.899133
# 248433  0.521482  0.185244  0.048731 -0.411751  0.374868
# 248434 -0.422945  0.010702 -0.153059 -0.398403  0.023149
# 248435 -0.600378  0.034060 -0.163581 -0.268640 -0.675780
# 248436 -0.907398  0.025681 -0.149025 -0.067263 -0.319320
# 248437 -1.420062 -0.025250 -0.143538  0.112185 -0.273994
# 248438 -0.948371 -0.096394 -0.147321  0.096451 -0.349132
# 248439 -1.493136 -0.167050 -0.154891  0.134492  0.017862
# 248440 -0.682979 -0.630442 -0.260611 -0.946476 -0.753270
# 248441 -0.269157 -0.159703 -0.128130 -0.922321  0.130828
# 248442 -0.440537  0.323648  0.522798 -0.729719 -1.097740
# 248443 -0.524749  0.236179  0.299115 -0.483843 -0.470654
# 248444  0.527469  0.057955 -0.044238 -0.470494  0.506151
# 248445 -0.462676 -0.039751 -0.162826 -0.345786 -0.374283
# 248446 -0.751415 -0.106848 -0.121872 -0.148711 -0.234780
# 248447 -0.686041 -0.201468 -0.090835 -0.076490 -0.363643
# 248448 -0.725539  0.088665  0.017449 -0.542586 -1.027009
# 248449  0.899093 -0.049392 -0.150487 -0.596451  0.706511
# 248450 -0.679602 -0.073922 -0.203510 -0.601505  1.156466
# 248451 -0.201922 -0.049809 -0.161370 -0.427234 -0.216379
#
# [248452 rows x 5 columns]

# %% [markdown]
# # 1. Filter

# %% [markdown]
# Filter method according to the correlation between features ,set up the threshold , make scores and select features

# %% [markdown]
# ## 1.1 Variance selection

# %% [markdown]
# calcualte the variance of each features and set up threshold variance and select the target features

# %%
VarianceThreshold(threshold=0.7).fit_transform(X_train) #feature 1,2,3' variacne larger than 0.7
# Out:
# array([[ 0.28520941, -0.30272278, -0.62431527],
#        [ 0.22179158, -0.30518775, -0.57166857],
#        [ 0.24501414, -0.30499875, -0.88928403],
#        ...,
#        [-0.04939204, -0.15048746, -0.59645052],
#        [-0.07392238, -0.20351038, -0.60150487],
#        [-0.0498093 , -0.16137017, -0.42723377]])

# %% [markdown]
# ## 1.2 Correlation selection

# %%
features=['feature0','feature1','feature2','feature3','feature4']
scatter_matrix(X_train[features],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F55625D0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5562CCB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F55632D320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F557BBDF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F557C26908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F557EAFD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F557F42278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F557F53358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F55835E0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5583B6780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F558420EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F558674BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5563574A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F5563B2898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556A35400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F556A9BF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556ADE2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556B65908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556B78E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556C30748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F556C80E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556F1E588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556F7C828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F556FF74E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F557052E10>]], dtype=object)

# %%
SelectKBest(lambda X, Y: np.array(map(lambda x:pearsonr(x, Y), X.T)).T, k=2).fit_transform(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c86772182f15> in <module>()
# ----> 1 SelectKBest(lambda X, Y: np.array(map(lambda x:pearsonr(x, Y), X.T)).T, k=2).fit_transform(X_train, y_train)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
# --> 497             return self.fit(X, y, **fit_params).transform(X)
#     498
#     499
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\base.py in transform(self, X)
#      74         """
#      75         X = check_array(X, accept_sparse='csr')
# ---> 76         mask = self.get_support()
#      77         if not mask.any():
#      78             warn("No features were selected: either the data is"
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\base.py in get_support(self, indices)
#      45             values are indices into the input feature vector.
#      46         """
# ---> 47         mask = self._get_support_mask()
#      48         return mask if not indices else np.where(mask)[0]
#      49
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in _get_support_mask(self)
#     482             return np.zeros(self.scores_.shape, dtype=bool)
#     483         else:
# --> 484             scores = _clean_nans(self.scores_)
#     485             mask = np.zeros(scores.shape, dtype=bool)
#     486
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in _clean_nans(scores)
#      28     # XXX where should this function be called? fit? scoring functions
#      29     # themselves?
# ---> 30     scores = as_float_array(scores, copy=True)
#      31     scores[np.isnan(scores)] = np.finfo(scores.dtype).min
#      32     return scores
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in as_float_array(X, copy, force_all_finite)
#      99         return X.copy('F' if X.flags['F_CONTIGUOUS'] else 'C') if copy else X
#     100     else:
# --> 101         return X.astype(np.float32 if X.dtype == np.int32 else np.float64)
#     102
#     103
#
# TypeError: float() argument must be a string or a number, not 'map'

# %% [markdown]
# ## 1.3 Chi Squared selection

# %%
X_train_scaled=MinMaxScaler().fit_transform(X_train)
SelectKBest(chi2,k=3).fit_transform(X_train_scaled,y_train)#feature 0 and 4 are selected
# Out:
# array([[ 0.65234287,  0.15971101,  0.10317642],
#        [ 0.65902621,  0.15249117,  0.10847818],
#        [ 0.90721302,  0.15513496,  0.07649288],
#        ...,
#        [ 0.82680868,  0.12161809,  0.10598253],
#        [ 0.47434694,  0.11882541,  0.10547353],
#        [ 0.58099452,  0.12157058,  0.12302341]])

# %%
X_train_scaled
# Out:
# array([[ 0.65234287,  0.15971101,  0.00578201,  0.10317642,  0.17655379],
#        [ 0.65902621,  0.15249117,  0.00555821,  0.10847818,  0.14811877],
#        [ 0.90721302,  0.15513496,  0.00557537,  0.07649288,  0.3557779 ],
#        ...,
#        [ 0.82680868,  0.12161809,  0.0196035 ,  0.10598253,  0.63015833],
#        [ 0.47434694,  0.11882541,  0.01478953,  0.10547353,  0.72353276],
#        [ 0.58099452,  0.12157058,  0.01861545,  0.12302341,  0.43864049]])

# %% [markdown]
# ## 1.4 Mutual Information selection

# %% [markdown]
# $$I(X,Y)=\sum_{x\in X}\sum_{y\in Y}p(x,y)log\frac{p(x,y)}{p(x)p(y)}$$

# %%
 def mic(x, y):
    m = MINE()
    m.compute_score(x, y)
    return (m.mic(), 0.5)

# %%
    SelectKBest(lambda X, Y: np.array(map(lambda x:mic(x, Y), X.T)).T, k=2).fit_transform(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-4d50694612c0> in <module>()
# ----> 1 SelectKBest(lambda X, Y: np.array(map(lambda x:mic(x, Y), X.T)).T, k=2).fit_transform(X_train, y_train)
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     495         else:
#     496             # fit method of arity 2 (supervised transformation)
# --> 497             return self.fit(X, y, **fit_params).transform(X)
#     498
#     499
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\base.py in transform(self, X)
#      74         """
#      75         X = check_array(X, accept_sparse='csr')
# ---> 76         mask = self.get_support()
#      77         if not mask.any():
#      78             warn("No features were selected: either the data is"
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\base.py in get_support(self, indices)
#      45             values are indices into the input feature vector.
#      46         """
# ---> 47         mask = self._get_support_mask()
#      48         return mask if not indices else np.where(mask)[0]
#      49
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in _get_support_mask(self)
#     482             return np.zeros(self.scores_.shape, dtype=bool)
#     483         else:
# --> 484             scores = _clean_nans(self.scores_)
#     485             mask = np.zeros(scores.shape, dtype=bool)
#     486
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in _clean_nans(scores)
#      28     # XXX where should this function be called? fit? scoring functions
#      29     # themselves?
# ---> 30     scores = as_float_array(scores, copy=True)
#      31     scores[np.isnan(scores)] = np.finfo(scores.dtype).min
#      32     return scores
#
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in as_float_array(X, copy, force_all_finite)
#      99         return X.copy('F' if X.flags['F_CONTIGUOUS'] else 'C') if copy else X
#     100     else:
# --> 101         return X.astype(np.float32 if X.dtype == np.int32 else np.float64)
#     102
#     103
#
# TypeError: float() argument must be a string or a number, not 'map'

# %% [markdown]
# # 1.5 plot the class

# %%
X_train_all=pd.concat([X_train,y_train],axis=1)

# %%
X_train_1=X_train_all.loc[X_train_all['label']==1.0]

# %%
X_train_1.shape
# Out:
# (199249, 6)

# %%
X_train_2=X_train_all.loc[X_train_all['label']==2.0]
X_train_2.shape
# Out:
# (49203, 6)

# %%
def plot_label(feature1,feature2,X_train_1,X_train_2):
    feature_1="feature"+str(feature1)
    feature_2="feature"+str(feature2)
    
    plt.figure(figsize=(14,8))
    plt.title("the plot of "+feature_1+" and "+feature_2,fontsize=30)
    plt.scatter(X_train_1[feature_1],X_train_1[feature_2],c='r',label="class 1")
    plt.scatter(X_train_2[feature_1],X_train_2[feature_2],c='b',label="class 2")
    plt.legend()
    plt.show()

# %%
plot_label(0,3,X_train_1,X_train_2)

# %%
for feature1 in range(5):
    for feature2 in range(5):
        if feature1 == feature2:
            continue
        else:
            plot_label(feature1,feature2,X_train_1,X_train_2)
