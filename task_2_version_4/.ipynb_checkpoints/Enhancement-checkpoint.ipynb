# %%
from Speaker_identification import Speaker_identification
from density_func import density_func, naive_G_U
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from process_bar import ShowProcess
from scipy.io import loadmat,savemat

'''
Import features
'''

#save_path="D:\\LAB\\lab\\task_2_version_4\\features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

#save_path="D:\\LAB\\lab\\task_2_version_4\\unknown_features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/unknown_feature.txt"
f = open(save_path,'rb')
b_new_test=pickle.load(f)
#print(b_new_test.shape)
f.close()

'''
Import UBM model
'''

ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz",mat_dtype=True)
#ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
name_set.append("unknown")
correct_sum=0
false_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
        
    test_file_set.append(b_new_test)
    
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples+1,num_samples+1))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=1,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples+1):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)
    '''
    Enhancement : added the unknown detection part
    '''
    for index in range(num_samples+1):
        b_test=np.array(test_file_set[index])
        T_value=b_test.shape[1]
        unknown_score=Speaker_identification(b_test,ubm_means,ubm_var,ubm_weights,T_value)
        #scores_set[index,num_samples]=unknown_score
        scores_set[index,num_samples]=(1/T_value)*unknown_score
        
        
    '''
    Calculate the detection rate
    '''
    for index in range(num_samples+1):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
        else:
            false_num +=1
            false_sum +=1
            print('')
            print("error ! True: "+name_set[index]+" False: "+name_set[test_index])
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()

    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num+1)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.60%
# /Users/Mata/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: unknown False: fawf0
# done
# crossvalidation 1 compeleted
# cost time   4.7 minute
# the crossval 1 detection_rate is 0.9940828402366864
# the total detection rate is  0.9940828402366864
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a1044a1d73bb> in <module>()
#     144 save_path="/Users/Mata/Documents/lab/task_2_version_4/confusion_matrix.txt"
#     145 f = open(save_path,'wb')
# --> 146 features=pickle.dump(confusion_matrix,f)
#     147 f.close()
#
# NameError: name 'confusion_matrix' is not defined

# %%
from Speaker_identification import Speaker_identification
from density_func import density_func, naive_G_U
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from process_bar import ShowProcess
from scipy.io import loadmat,savemat

'''
Import features
'''

#save_path="D:\\LAB\\lab\\task_2_version_4\\features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

#save_path="D:\\LAB\\lab\\task_2_version_4\\unknown_features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/unknown_feature.txt"
f = open(save_path,'rb')
b_new_test=pickle.load(f)
#print(b_new_test.shape)
f.close()

'''
Import UBM model
'''

ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz",mat_dtype=True)
#ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
name_set.append("unknown")
correct_sum=0
false_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
        
    test_file_set.append(b_new_test)
    
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples+1,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=1,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples+1):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

        
    '''
    Calculate the detection rate
    '''
    for index in range(num_samples+1):
        if max(scores_set[index,:])>(-34.8):
            test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
            if index == test_index:
                correct_num +=1
                correct_sum +=1
            else:
                false_num +=1
                false_sum +=1
                print('')
                print("error ! True: "+name_set[index]+" False: "+name_set[test_index])
        else:
            if index==num_samples:
                correct_num +=1
                correct_sum +=1
            else:
                false_num+=1
                false_sum+=1
                print('')
                print("error ! True: "+name_set[index]+" False: unknowns")
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()

    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num+1)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.60%
# /Users/Mata/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: faks0 False: unknowns
#
# error ! True: fdac1 False: unknowns
#
# error ! True: felc0 False: unknowns
#
# error ! True: fjem0 False: unknowns
#
# error ! True: mdab0 False: unknowns
#
# error ! True: mjsw0 False: unknowns
#
# error ! True: mreb0 False: unknowns
#
# error ! True: mrjo0 False: unknowns
#
# error ! True: msjs1 False: unknowns
#
# error ! True: mstk0 False: unknowns
#
# error ! True: mwbt0 False: unknowns
#
# error ! True: fcmr0 False: unknowns
#
# error ! True: fdrd1 False: unknowns
#
# error ! True: fjas0 False: unknowns
#
# error ! True: fjre0 False: unknowns
#
# error ! True: fjwb0 False: unknowns
#
# error ! True: fpas0 False: unknowns
#
# error ! True: fram1 False: unknowns
#
# error ! True: fslb1 False: unknowns
#
# error ! True: mabw0 False: unknowns
#
# error ! True: mbjk0 False: unknowns
#
# error ! True: mccs0 False: unknowns
#
# error ! True: mcem0 False: unknowns
#
# error ! True: mdbb0 False: unknowns
#
# error ! True: mdld0 False: unknowns
#
# error ! True: mgwt0 False: unknowns
#
# error ! True: mjar0 False: unknowns
#
# error ! True: mmdb1 False: unknowns
#
# error ! True: mmdm2 False: unknowns
#
# error ! True: mpdf0 False: unknowns
#
# error ! True: mpgl0 False: unknowns
#
# error ! True: mrcz0 False: unknowns
#
# error ! True: mrgg0 False: unknowns
#
# error ! True: mtas1 False: unknowns
#
# error ! True: mtmr0 False: unknowns
#
# error ! True: mwew0 False: unknowns
#
# error ! True: mwvw0 False: unknowns
#
# error ! True: fcmh0 False: unknowns
#
# error ! True: fkms0 False: unknowns
#
# error ! True: fpkt0 False: unknowns
#
# error ! True: mbdg0 False: unknowns
#
# error ! True: mbwm0 False: unknowns
#
# error ! True: mcsh0 False: unknowns
#
# error ! True: mctw0 False: unknowns
#
# error ! True: mgjf0 False: unknowns
#
# error ! True: mglb0 False: unknowns
#
# error ! True: mhpg0 False: unknowns
#
# error ! True: mjbr0 False: unknowns
#
# error ! True: mjes0 False: unknowns
#
# error ! True: mjjg0 False: unknowns
#
# error ! True: mjmp0 False: unknowns
#
# error ! True: mjvw0 False: unknowns
#
# error ! True: mkch0 False: unknowns
#
# error ! True: mlnt0 False: unknowns
#
# error ! True: mmab0 False: unknowns
#
# error ! True: mmdh0 False: unknowns
#
# error ! True: mmjr0 False: unknowns
#
# error ! True: mmwh0 False: unknowns
#
# error ! True: mrtk0 False: unknowns
#
# error ! True: mtaa0 False: unknowns
#
# error ! True: mtdt0 False: unknowns
#
# error ! True: mthc0 False: unknowns
#
# error ! True: mwjg0 False: unknowns
#
# error ! True: fadg0 False: unknowns
#
# error ! True: fcft0 False: unknowns
#
# error ! True: fcrh0 False: unknowns
#
# error ! True: fdms0 False: unknowns
#
# error ! True: fedw0 False: unknowns
#
# error ! True: fgjd0 False: unknowns
#
# error ! True: fjlm0 False: unknowns
#
# error ! True: fjmg0 False: unknowns
#
# error ! True: flbw0 False: unknowns
#
# error ! True: flkd0 False: unknowns
#
# error ! True: fmaf0 False: unknowns
#
# error ! True: fmcm0 False: unknowns
#
# error ! True: fnmr0 False: unknowns
#
# error ! True: frew0 False: unknowns
#
# error ! True: frng0 False: unknowns
#
# error ! True: fsem0 False: unknowns
#
# error ! True: mbns0 False: unknowns
#
# error ! True: mdls0 False: unknowns
#
# error ! True: mdrm0 False: unknowns
#
# error ! True: mgmm0 False: unknowns
#
# error ! True: mjdm1 False: unknowns
#
# error ! True: mjrf0 False: unknowns
#
# error ! True: mkcl0 False: unknowns
#
# error ! True: mljb0 False: unknowns
#
# error ! True: mlll0 False: unknowns
#
# error ! True: mpcs0 False: unknowns
#
# error ! True: mplb0 False: unknowns
#
# error ! True: mpwm0 False: unknowns
#
# error ! True: mrko0 False: unknowns
#
# error ! True: mroa0 False: unknowns
#
# error ! True: mteb0 False: unknowns
#
# error ! True: mtls0 False: unknowns
#
# error ! True: fasw0 False: unknowns
#
# error ! True: fawf0 False: unknowns
#
# error ! True: fcal1 False: unknowns
#
# error ! True: fgmd0 False: unknowns
#
# error ! True: fhes0 False: unknowns
#
# error ! True: fhew0 False: unknowns
#
# error ! True: fjcs0 False: unknowns
#
# error ! True: fjsa0 False: unknowns
#
# error ! True: fmah0 False: unknowns
#
# error ! True: fnlp0 False: unknowns
#
# error ! True: futb0 False: unknowns
#
# error ! True: mahh0 False: unknowns
#
# error ! True: mbpm0 False: unknowns
#
# error ! True: mcmb0 False: unknowns
#
# error ! True: mcrc0 False: unknowns
#
# error ! True: mctt0 False: unknowns
#
# error ! True: mdac2 False: unknowns
#
# error ! True: mdrb0 False: unknowns
#
# error ! True: mdwa0 False: unknowns
#
# error ! True: mdwk0 False: unknowns
#
# error ! True: mfgk0 False: unknowns
#
# error ! True: mklt0 False: unknowns
#
# error ! True: mlih0 False: unknowns
#
# error ! True: mrjm3 False: unknowns
#
# error ! True: mrpp0 False: unknowns
#
# error ! True: mrrk0 False: unknowns
#
# error ! True: mrws1 False: unknowns
#
# error ! True: msfh1 False: unknowns
#
# error ! True: fdrw0 False: unknowns
#
# error ! True: flnh0 False: unknowns
#
# error ! True: fmgd0 False: unknowns
#
# error ! True: mcmj0 False: unknowns
#
# error ! True: mdsc0 False: unknowns
#
# error ! True: mesd0 False: unknowns
#
# error ! True: mjdh0 False: unknowns
#
# error ! True: mjfc0 False: unknowns
#
# error ! True: mpam1 False: unknowns
#
# error ! True: mrjr0 False: unknowns
#
# error ! True: mrjs0 False: unknowns
#
# error ! True: fcau0 False: unknowns
#
# error ! True: fdhc0 False: unknowns
#
# error ! True: fgwr0 False: unknowns
#
# error ! True: fisb0 False: unknowns
#
# error ! True: flas0 False: unknowns
#
# error ! True: fmml0 False: unknowns
#
# error ! True: fsxa0 False: unknowns
#
# error ! True: ftlh0 False: unknowns
#
# error ! True: mchh0 False: unknowns
#
# error ! True: mdlf0 False: unknowns
#
# error ! True: mdvc0 False: unknowns
#
# error ! True: mers0 False: unknowns
#
# error ! True: mgrt0 False: unknowns
#
# error ! True: mkdr0 False: unknowns
#
# error ! True: mkjl0 False: unknowns
#
# error ! True: mnjm0 False: unknowns
#
# error ! True: mnls0 False: unknowns
#
# error ! True: mpab0 False: unknowns
#
# error ! True: mrcs0 False: unknowns
#
# error ! True: mrjm4 False: unknowns
#
# error ! True: mrms1 False: unknowns
#
# error ! True: mrpc0 False: unknowns
#
# error ! True: mtwh0 False: unknowns
#
# error ! True: fcmh1 False: unknowns
#
# error ! True: fjsj0 False: unknowns
#
# error ! True: fmld0 False: unknowns
#
# error ! True: majc0 False: unknowns
#
# error ! True: mdaw1 False: unknowns
#
# error ! True: mjln0 False: unknowns
#
# error ! True: mjtc0 False: unknowns
#
# error ! True: mjth0 False: unknowns
#
# error ! True: mpam0 False: unknowns
#
# error ! True: mres0 False: unknowns
#
# error ! True: mslb0 False: unknowns
# done
# crossvalidation 1 compeleted
# cost time   2.7 minute
# the crossval 1 detection_rate is 0.005917159763313609
# crossvalidation 2 start
# [>>>>>>--------------------------------------------]13.10%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-a331e2f21b4d> in <module>()
#     103             #print("now test set "+str(index_1)+" is testing "+str(index_2))
#     104             b_test=np.array(test_file_set[index_1])
# --> 105             scores_set[index_1,index_2]=gmm.score(b_test.T)
#     106
#     107
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py in score(self, X, y)
#     320             Log likelihood of the Gaussian mixture given X.
#     321         """
# --> 322         return self.score_samples(X).mean()
#     323
#     324     def predict(self, X):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py in score_samples(self, X)
#     304         X = _check_X(X, None, self.means_.shape[1])
#     305
# --> 306         return logsumexp(self._estimate_weighted_log_prob(X), axis=1)
#     307
#     308     def score(self, X, y=None):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py in _estimate_weighted_log_prob(self, X)
#     420         weighted_log_prob : array, shape (n_samples, n_component)
#     421         """
# --> 422         return self._estimate_log_prob(X) + self._estimate_log_weights()
#     423
#     424     @abstractmethod
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/gaussian_mixture.py in _estimate_log_prob(self, X)
#     673     def _estimate_log_prob(self, X):
#     674         return _estimate_log_gaussian_prob(
# --> 675             X, self.means_, self.precisions_cholesky_, self.covariance_type)
#     676
#     677     def _estimate_log_weights(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/gaussian_mixture.py in _estimate_log_gaussian_prob(X, means, precisions_chol, covariance_type)
#     410         log_prob = np.empty((n_samples, n_components))
#     411         for k, (mu, prec_chol) in enumerate(zip(means, precisions_chol)):
# --> 412             y = np.dot(X, prec_chol) - np.dot(mu, prec_chol)
#     413             log_prob[:, k] = np.sum(np.square(y), axis=1)
#     414
#
# KeyboardInterrupt:

# %%
test=[]
for index in range(num_samples):
    test.append(scores_set[index,index])
print(min(test))
# Out:
# -34.5477372316
