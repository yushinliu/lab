# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 1
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=1,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -47.5695707105
# crossvalidation 1 compeleted
# cost time   3.2 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -46.8335426086
# crossvalidation 2 compeleted
# cost time   5.9 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -48.2013024608
# crossvalidation 3 compeleted
# cost time   9.0 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# error ! True: mgrt0 False: mtmr0
# done
# -47.9894747121
# crossvalidation 4 compeleted
# cost time  11.9 minute
# the crossval 3 detection_rate is 0.9823529411764705
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -48.8556305522
# crossvalidation 5 compeleted
# cost time  15.0 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# error ! True: fdrw0 False: fsem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -48.0976846662
# crossvalidation 6 compeleted
# cost time  17.8 minute
# the crossval 5 detection_rate is 0.9941176470588236
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fcau0 False: fisb0
# done
# -48.0466419211
# crossvalidation 7 compeleted
# cost time  20.6 minute
# the crossval 6 detection_rate is 0.9882352941176471
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -45.6650562443
# crossvalidation 8 compeleted
# cost time  23.6 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# error ! True: fgjd0 False: fcau0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -48.1179540825
# crossvalidation 9 compeleted
# cost time  27.1 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -47.8723191292
# crossvalidation 10 compeleted
# cost time  29.9 minute
# the crossval 9 detection_rate is 1.0
# the total detection rate is  0.9952941176470588
# overall expected scores -47.7249177087

# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 5
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=5,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7027540488
# crossvalidation 1 compeleted
# cost time   4.2 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3544794329
# crossvalidation 2 compeleted
# cost time   7.9 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7327408861
# crossvalidation 3 compeleted
# cost time  12.1 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# done
# -53.2836296974
# crossvalidation 4 compeleted
# cost time  15.9 minute
# the crossval 3 detection_rate is 0.9882352941176471
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2793045139
# crossvalidation 5 compeleted
# cost time  20.1 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.3141494942
# crossvalidation 6 compeleted
# cost time  23.8 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mrms1 False: mgmm0
# done
# -52.7564530319
# crossvalidation 7 compeleted
# cost time  27.7 minute
# the crossval 6 detection_rate is 0.9882352941176471
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.5927123495
# crossvalidation 8 compeleted
# cost time  31.7 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2190872621
# crossvalidation 9 compeleted
# cost time  36.2 minute
# the crossval 8 detection_rate is 1.0
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.9835968807
# crossvalidation 10 compeleted
# cost time  40.0 minute
# the crossval 9 detection_rate is 1.0
# the total detection rate is  0.9970588235294118
# overall expected scores -53.0218907598

# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 10
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=10,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5786696427
# crossvalidation 1 compeleted
# cost time   6.6 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# error ! True: mrtk0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -51.4374551961
# crossvalidation 2 compeleted
# cost time  12.6 minute
# the crossval 1 detection_rate is 0.9941176470588236
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6102440671
# crossvalidation 3 compeleted
# cost time  18.8 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: fjmg0 False: fadg0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mkcl0 False: mtmr0
# error ! True: mgrt0 False: mdls0
# done
# -53.1993123302
# crossvalidation 4 compeleted
# cost time  23.8 minute
# the crossval 3 detection_rate is 0.9823529411764705
# crossvalidation 5 start
# error ! True: fcft0 False: fmah0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mrrk0 False: mcrc0
# done
# -53.1547827407
# crossvalidation 5 compeleted
# cost time  29.1 minute
# the crossval 4 detection_rate is 0.9882352941176471
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.171592673
# crossvalidation 6 compeleted
# cost time  34.1 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mtls0 False: mrws1
# error ! True: fcau0 False: fisb0
# done
# -52.6849010586
# crossvalidation 7 compeleted
# cost time  39.2 minute
# the crossval 6 detection_rate is 0.9823529411764705
# crossvalidation 8 start
# error ! True: mccs0 False: majc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.4670913739
# crossvalidation 8 compeleted
# cost time  44.4 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mctw0 False: mrgg0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mdrb0
# error ! True: fgmd0 False: fkms0
# done
# -53.138915786
# crossvalidation 9 compeleted
# cost time  50.2 minute
# the crossval 8 detection_rate is 0.9823529411764705
# crossvalidation 10 start
# error ! True: fdrw0 False: fpas0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.8639949676
# crossvalidation 10 compeleted
# cost time  56.4 minute
# the crossval 9 detection_rate is 0.9941176470588236
# the total detection rate is  0.991764705882353
# overall expected scores -52.9306959836

# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 15
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=15,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6886082543
# crossvalidation 1 compeleted
# cost time   7.1 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# error ! True: mrtk0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -51.581866771
# crossvalidation 2 compeleted
# cost time  13.4 minute
# the crossval 1 detection_rate is 0.9941176470588236
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6535178868
# crossvalidation 3 compeleted
# cost time  19.9 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mjdh0 False: mhpg0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2707222762
# crossvalidation 4 compeleted
# cost time  26.2 minute
# the crossval 3 detection_rate is 0.9941176470588236
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1984275645
# crossvalidation 5 compeleted
# cost time  32.6 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2493666109
# crossvalidation 6 compeleted
# cost time  38.9 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mtls0 False: mrws1>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.7527332317
# crossvalidation 7 compeleted
# cost time 474.3 minute
# the crossval 6 detection_rate is 0.9941176470588236
# crossvalidation 8 start
# error ! True: mccs0 False: majc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.5538861224
# crossvalidation 8 compeleted
# cost time 480.7 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mctw0 False: mrgg0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mlnt0
# done
# -53.1783647443
# crossvalidation 9 compeleted
# cost time 487.6 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# error ! True: fdrw0 False: fpas0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.9047343767
# crossvalidation 10 compeleted
# cost time 494.6 minute
# the crossval 9 detection_rate is 0.9941176470588236
# the total detection rate is  0.9952941176470588
# overall expected scores -53.0032227839

# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 20
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=20,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6628346729
# crossvalidation 1 compeleted
# cost time   8.2 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# error ! True: mrtk0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -51.566496504
# crossvalidation 2 compeleted
# cost time  16.2 minute
# the crossval 1 detection_rate is 0.9941176470588236
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.599005983
# crossvalidation 3 compeleted
# cost time  24.1 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mjdh0 False: mhpg0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2251439152
# crossvalidation 4 compeleted
# cost time  32.6 minute
# the crossval 3 detection_rate is 0.9941176470588236
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1556042326
# crossvalidation 5 compeleted
# cost time  42.0 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2234093369
# crossvalidation 6 compeleted
# cost time  50.8 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.7255185064
# crossvalidation 7 compeleted
# cost time  59.6 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.5161658279
# crossvalidation 8 compeleted
# cost time  68.6 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mbjk0 False: mgwt0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1725072906
# crossvalidation 9 compeleted
# cost time  78.1 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# error ! True: fdrw0 False: fpas0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.8436690353
# crossvalidation 10 compeleted
# cost time  86.9 minute
# the crossval 9 detection_rate is 0.9941176470588236
# the total detection rate is  0.9964705882352941
# overall expected scores -52.9690355305

# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 25
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=25,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6291740609
# crossvalidation 1 compeleted
# cost time   9.7 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.5062548128
# crossvalidation 2 compeleted
# cost time  19.6 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5165567075
# crossvalidation 3 compeleted
# cost time  28.8 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1490297128
# crossvalidation 4 compeleted
# cost time  37.0 minute
# the crossval 3 detection_rate is 1.0
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.0859752657
# crossvalidation 5 compeleted
# cost time  45.2 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2112270182
# crossvalidation 6 compeleted
# cost time 244.0 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.6753639051
# crossvalidation 7 compeleted
# cost time 252.6 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.430819316
# crossvalidation 8 compeleted
# cost time 261.5 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mroa0 False: mlnt0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.120305601
# crossvalidation 9 compeleted
# cost time 270.7 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# error ! True: msjs1 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fdrw0 False: fpas0
# done
# -52.7699617953
# crossvalidation 10 compeleted
# cost time 279.4 minute
# the crossval 9 detection_rate is 0.9882352941176471
# the total detection rate is  0.9970588235294118
# overall expected scores -52.9094668195

# %%
'''
tuning the convergence 1,5,10,15,20,25,30
'''

'''
convergence 30
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=30,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)

#save_path="D:\\LAB\\lab\\task_2_version_4\\confusion_matrix.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
#f = open(save_path,'wb')
#features=pickle.dump(confusion_matrix,f)
#f.close()
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]1.76%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5867858758
# crossvalidation 1 compeleted
# cost time   9.6 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.4443221901
# crossvalidation 2 compeleted
# cost time  19.0 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.4646911543
# crossvalidation 3 compeleted
# cost time  28.7 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.0946177788
# crossvalidation 4 compeleted
# cost time  37.8 minute
# the crossval 3 detection_rate is 1.0
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.0272631975
# crossvalidation 5 compeleted
# cost time  46.3 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1095258664
# crossvalidation 6 compeleted
# cost time  73.5 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.6332690156
# crossvalidation 7 compeleted
# cost time  84.4 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.3733016051
# crossvalidation 8 compeleted
# cost time  93.8 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mroa0 False: mlnt0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.0857811241
# crossvalidation 9 compeleted
# cost time 105.5 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# error ! True: msjs1 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fdrw0 False: fpas0
# done
# -52.7220247672
# crossvalidation 10 compeleted
# cost time 116.1 minute
# the crossval 9 detection_rate is 0.9882352941176471
# the total detection rate is  0.9970588235294118
# overall expected scores -52.8541582575

# %%
'''
Now start grid search on the covariance type
'''
'''
convergence 40
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=40,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]1.76%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7202194436
# crossvalidation 1 compeleted
# cost time   9.9 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.5512152165
# crossvalidation 2 compeleted
# cost time  19.8 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.587040715
# crossvalidation 3 compeleted
# cost time  30.4 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2124943729
# crossvalidation 4 compeleted
# cost time  40.7 minute
# the crossval 3 detection_rate is 1.0
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1689932278
# crossvalidation 5 compeleted
# cost time  50.6 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1665226286
# crossvalidation 6 compeleted
# cost time  60.3 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.7790358863
# crossvalidation 7 compeleted
# cost time  70.3 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.2955798166
# crossvalidation 8 compeleted
# cost time  80.2 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mmwh0 False: mmab0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mlnt0
# done
# -53.1177514542
# crossvalidation 9 compeleted
# cost time  90.5 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# error ! True: msjs1 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fdrw0 False: fpas0
# done
# -52.8232824345
# crossvalidation 10 compeleted
# cost time 100.8 minute
# the crossval 9 detection_rate is 0.9882352941176471
# the total detection rate is  0.9964705882352941
# overall expected scores -52.9422135196

# %%
'''
Now start grid search on the covariance type
'''
'''
convergence 50
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=50,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)
# Out:
# crossvalidation 1 start
# [>>>>>>>-------------------------------------------]15.29%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7315898532
# crossvalidation 1 compeleted
# cost time  10.9 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.5575377718
# crossvalidation 2 compeleted
# cost time  21.7 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5899504315
# crossvalidation 3 compeleted
# cost time  32.9 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2195881094
# crossvalidation 4 compeleted
# cost time  43.7 minute
# the crossval 3 detection_rate is 1.0
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1738074174
# crossvalidation 5 compeleted
# cost time  54.5 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1701878539
# crossvalidation 6 compeleted
# cost time  65.0 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.79166509
# crossvalidation 7 compeleted
# cost time  75.4 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.4536013666
# crossvalidation 8 compeleted
# cost time  86.1 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mmwh0 False: mmab0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mlnt0
# done
# -53.1642761803
# crossvalidation 9 compeleted
# cost time  97.1 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# error ! True: msjs1 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fdrw0 False: fpas0
# done
# -52.8414345725
# crossvalidation 10 compeleted
# cost time 108.5 minute
# the crossval 9 detection_rate is 0.9882352941176471
# the total detection rate is  0.9964705882352941
# overall expected scores -52.9693638647

# %%
'''
Now start grid search on the covariance type
'''
'''
convergence 100
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=100,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)
# Out:
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7331403846
# crossvalidation 1 compeleted
# cost time  11.5 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.5591834252
# crossvalidation 2 compeleted
# cost time  22.1 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5888292196
# crossvalidation 3 compeleted
# cost time  33.9 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mglb0 False: mpab0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2201128475
# crossvalidation 4 compeleted
# cost time  50.3 minute
# the crossval 3 detection_rate is 0.9941176470588236
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.172626679
# crossvalidation 5 compeleted
# cost time  66.0 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1706628867
# crossvalidation 6 compeleted
# cost time  80.3 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.792978656
# crossvalidation 7 compeleted
# cost time  94.6 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.4555598075
# crossvalidation 8 compeleted
# cost time 107.5 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mmwh0 False: mmab0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mlnt0
# done
# -53.1684520281
# crossvalidation 9 compeleted
# cost time 118.7 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# error ! True: msjs1 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fdrw0 False: fpas0
# done
# -52.8421586993
# crossvalidation 10 compeleted
# cost time 129.6 minute
# the crossval 9 detection_rate is 0.9882352941176471
# the total detection rate is  0.9958823529411764
# overall expected scores -52.9703704633

# %%
'''
Now start grid search on the covariance type
'''
'''
convergence 200
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
confusion_matrix=np.zeros((num_samples,num_samples))
correct_sum=0
false_sum=0
scores_sum=0
for cross_num in range(10):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples,num_samples))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=200,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

    '''
    Calculate the detection rate
    '''
    for index in range(num_samples):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
            confusion_matrix[index,index] +=1
        else:
            false_num +=1
            false_sum +=1
            confusion_matrix[index,test_index] +=1
            print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()
    scores_sum +=np.sum(scores_set)/(num_samples**2)
    print(np.sum(scores_set)/(num_samples**2))
    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("overall expected scores",scores_sum/10)
# Out:
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7331403846
# crossvalidation 1 compeleted
# cost time  14.9 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.5591834252
# crossvalidation 2 compeleted
# cost time  28.6 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5888292196
# crossvalidation 3 compeleted
# cost time  42.2 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mglb0 False: mpab0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2201128475
# crossvalidation 4 compeleted
# cost time  54.5 minute
# the crossval 3 detection_rate is 0.9941176470588236
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.172626679
# crossvalidation 5 compeleted
# cost time  64.8 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1706628867
# crossvalidation 6 compeleted
# cost time  74.3 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.792978656
# crossvalidation 7 compeleted
# cost time  84.1 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: mccs0 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.4555598075
# crossvalidation 8 compeleted
# cost time  94.9 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mmwh0 False: mmab0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mlnt0
# done
# -53.1684520281
# crossvalidation 9 compeleted
# cost time 108.2 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# error ! True: msjs1 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fdrw0 False: fpas0
# done
# -52.8421586993
# crossvalidation 10 compeleted
# cost time 122.6 minute
# the crossval 9 detection_rate is 0.9882352941176471
# the total detection rate is  0.9958823529411764
# overall expected scores -52.9703704633

# %%
'''
Now start grid search on the covariance type
'''
'''
convergence 1-10
'''
from process_bar import ShowProcess
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features_10.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_3/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())
for MAX_ITER in range(10):
    '''
    Start Crossvalidation
    '''
    #process_bar=ShowProcess(10)
    detection_rate_set=[]
    start=time.time()
    error_set={}  
    num_samples=len(features.keys())
    name_set=list(features.keys())
    confusion_matrix=np.zeros((num_samples,num_samples))
    correct_sum=0
    false_sum=0
    scores_sum=0
    for cross_num in range(10):
        #process_bar.show_process()
        train_file_set=[]
        test_file_set=[]
        correct_num=0
        false_num=0
        '''
        Split the test and train set
        '''
        for name in features.keys():
            whole_set=features.get(name,'no such file').copy()
            test_file=whole_set[cross_num]
            train_num=list(range(10))
            train_num.remove(cross_num)
            test_file_set.append(test_file)
            #name_set.append(name)
            train_set=[]
            for num in train_num:
                train_set.append(whole_set[num])
            train_set=np.concatenate(train_set,axis=1)
            train_file_set.append(train_set)
        '''
        Start modeling and identification
        '''
        print("crossvalidation "+str(cross_num+1)+" start")
        process_bar_2=ShowProcess(num_samples)
        scores_set=np.zeros((num_samples,num_samples))
        for index_2 in range(num_samples):
            process_bar_2.show_process()
            b_train=train_file_set[index_2]
            gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=MAX_ITER+1,weights_init=ubm_weights,\
                                means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
            gmm.fit(b_train.T)
            for index_1 in range(num_samples):
                #print("now test set "+str(index_1)+" is testing "+str(index_2))
                b_test=np.array(test_file_set[index_1])
                scores_set[index_1,index_2]=gmm.score(b_test.T)

        '''
        Calculate the detection rate
        '''
        for index in range(num_samples):
            test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
            if index == test_index:
                correct_num +=1
                correct_sum +=1
                confusion_matrix[index,index] +=1
            else:
                false_num +=1
                false_sum +=1
                confusion_matrix[index,test_index] +=1
                print("error ! True: "+str(name_set[index])+" False: "+str(name_set[test_index]))
            #print("time cost %5.1f second"%((time.time()-start)/60))

        process_bar_2.close()
        scores_sum +=np.sum(scores_set)/(num_samples**2)
        print(np.sum(scores_set)/(num_samples**2))
        detection_rate=correct_num/(correct_num+false_num)
        print("crossvalidation "+str(cross_num+1)+" compeleted")
        print("cost time %5.1f minute"%((time.time()-start)/60))
        detection_rate=correct_num/(false_num+correct_num)
        detection_rate_set.append(detection_rate)
        print("the crossval "+str(cross_num)+" detection_rate is "+str(detection_rate))
    print("MAX_iter ",str(MAX_ITER+1))
    print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
    print("overall expected scores",scores_sum/10)
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.59%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -47.5695707105
# crossvalidation 1 compeleted
# cost time   4.3 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -46.8335426086
# crossvalidation 2 compeleted
# cost time   7.9 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -48.2013024608
# crossvalidation 3 compeleted
# cost time  12.1 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# error ! True: mgrt0 False: mtmr0
# done
# -47.9894747121
# crossvalidation 4 compeleted
# cost time  16.1 minute
# the crossval 3 detection_rate is 0.9823529411764705
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -48.8556305522
# crossvalidation 5 compeleted
# cost time  20.1 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# error ! True: fdrw0 False: fsem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -48.0976846662
# crossvalidation 6 compeleted
# cost time  23.7 minute
# the crossval 5 detection_rate is 0.9941176470588236
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fcau0 False: fisb0
# done
# -48.0466419211
# crossvalidation 7 compeleted
# cost time  27.1 minute
# the crossval 6 detection_rate is 0.9882352941176471
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -45.6650562443
# crossvalidation 8 compeleted
# cost time  30.9 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# error ! True: fgjd0 False: fcau0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -48.1179540825
# crossvalidation 9 compeleted
# cost time  35.4 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -47.8723191292
# crossvalidation 10 compeleted
# cost time  39.2 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  1
# the total detection rate is  0.9952941176470588
# overall expected scores -47.7249177087
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6617318844
# crossvalidation 1 compeleted
# cost time   4.5 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.2289218127
# crossvalidation 2 compeleted
# cost time   8.3 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6725206011
# crossvalidation 3 compeleted
# cost time  12.5 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# done
# -53.215706613
# crossvalidation 4 compeleted
# cost time  16.0 minute
# the crossval 3 detection_rate is 0.9882352941176471
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2184697158
# crossvalidation 5 compeleted
# cost time  19.9 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2758743879
# crossvalidation 6 compeleted
# cost time  23.3 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.6962412176
# crossvalidation 7 compeleted
# cost time  26.7 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# error ! True: fdrw0 False: fsem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.5252883099
# crossvalidation 8 compeleted
# cost time  30.4 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: fgjd0 False: fcau0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1634114031
# crossvalidation 9 compeleted
# cost time  34.5 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.9260169816
# crossvalidation 10 compeleted
# cost time  38.0 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  2
# the total detection rate is  0.9970588235294118
# overall expected scores -52.9584182927
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7130960186
# crossvalidation 1 compeleted
# cost time   4.1 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3082571363
# crossvalidation 2 compeleted
# cost time   7.8 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7386573891
# crossvalidation 3 compeleted
# cost time  11.7 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# done
# -53.2844465611
# crossvalidation 4 compeleted
# cost time  15.6 minute
# the crossval 3 detection_rate is 0.9882352941176471
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2886951744
# crossvalidation 5 compeleted
# cost time  19.7 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.3330649019
# crossvalidation 6 compeleted
# cost time  23.4 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.7531994016
# crossvalidation 7 compeleted
# cost time  27.0 minute
# the crossval 6 detection_rate is 1.0
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.5973324575
# crossvalidation 8 compeleted
# cost time  30.9 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# error ! True: fgjd0 False: fcau0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.22507986
# crossvalidation 9 compeleted
# cost time  35.2 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.9902417386
# crossvalidation 10 compeleted
# cost time  38.8 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  3
# the total detection rate is  0.9976470588235294
# overall expected scores -53.0232070639
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7198588745
# crossvalidation 1 compeleted
# cost time   4.4 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3350215125
# crossvalidation 2 compeleted
# cost time   8.2 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7474586963
# crossvalidation 3 compeleted
# cost time  12.5 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# done
# -53.2930874347
# crossvalidation 4 compeleted
# cost time  16.5 minute
# the crossval 3 detection_rate is 0.9882352941176471
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2945494969
# crossvalidation 5 compeleted
# cost time  20.8 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.3314940161
# crossvalidation 6 compeleted
# cost time  24.7 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mrms1 False: mgmm0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.7609119893
# crossvalidation 7 compeleted
# cost time  28.4 minute
# the crossval 6 detection_rate is 0.9941176470588236
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.6038099236
# crossvalidation 8 compeleted
# cost time  32.6 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# error ! True: fgjd0 False: fcau0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2316400344
# crossvalidation 9 compeleted
# cost time  37.1 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.9976706347
# crossvalidation 10 compeleted
# cost time  41.1 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  4
# the total detection rate is  0.9970588235294118
# overall expected scores -53.0315502613
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7027540488
# crossvalidation 1 compeleted
# cost time   4.6 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3544794329
# crossvalidation 2 compeleted
# cost time   8.6 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7327408861
# crossvalidation 3 compeleted
# cost time  13.0 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# done
# -53.2836296974
# crossvalidation 4 compeleted
# cost time  17.3 minute
# the crossval 3 detection_rate is 0.9882352941176471
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2793045139
# crossvalidation 5 compeleted
# cost time  21.8 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.3141494942
# crossvalidation 6 compeleted
# cost time  25.8 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mrms1 False: mgmm0
# done
# -52.7564530319
# crossvalidation 7 compeleted
# cost time  29.9 minute
# the crossval 6 detection_rate is 0.9882352941176471
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.5927123495
# crossvalidation 8 compeleted
# cost time  34.3 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2190872621
# crossvalidation 9 compeleted
# cost time  39.0 minute
# the crossval 8 detection_rate is 1.0
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.9835968807
# crossvalidation 10 compeleted
# cost time  43.2 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  5
# the total detection rate is  0.9970588235294118
# overall expected scores -53.0218907598
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6699318265
# crossvalidation 1 compeleted
# cost time   4.8 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3691465555
# crossvalidation 2 compeleted
# cost time   9.1 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.7072840395
# crossvalidation 3 compeleted
# cost time  13.8 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# error ! True: mrrk0 False: mtmr0
# error ! True: mgrt0 False: mdls0
# done
# -53.2623263455
# crossvalidation 4 compeleted
# cost time  18.2 minute
# the crossval 3 detection_rate is 0.9764705882352941
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2500805307
# crossvalidation 5 compeleted
# cost time  22.9 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.2677125384
# crossvalidation 6 compeleted
# cost time  27.2 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mtls0 False: mmwh0
# done
# -52.745412163
# crossvalidation 7 compeleted
# cost time  31.5 minute
# the crossval 6 detection_rate is 0.9882352941176471
# crossvalidation 8 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.5738778578
# crossvalidation 8 compeleted
# cost time  36.1 minute
# the crossval 7 detection_rate is 1.0
# crossvalidation 9 start
# error ! True: mroa0 False: mdrb0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.1993890068
# crossvalidation 9 compeleted
# cost time  41.2 minute
# the crossval 8 detection_rate is 0.9941176470588236
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.958277916
# crossvalidation 10 compeleted
# cost time  46.0 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  6
# the total detection rate is  0.9952941176470588
# overall expected scores -53.000343878
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6197572789
# crossvalidation 1 compeleted
# cost time   6.1 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3755499462
# crossvalidation 2 compeleted
# cost time  11.2 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6653912912
# crossvalidation 3 compeleted
# cost time  16.7 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# error ! True: mrrk0 False: mtmr0
# error ! True: mgrt0 False: mdls0
# done
# -53.2325264244
# crossvalidation 4 compeleted
# cost time  22.0 minute
# the crossval 3 detection_rate is 0.9764705882352941
# crossvalidation 5 start
# error ! True: mrrk0 False: mcrc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -53.2054528196
# crossvalidation 5 compeleted
# cost time  27.6 minute
# the crossval 4 detection_rate is 0.9941176470588236
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.205744146
# crossvalidation 6 compeleted
# cost time  33.5 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mtls0 False: mmwh0
# done
# -52.7181073459
# crossvalidation 7 compeleted
# cost time  40.1 minute
# the crossval 6 detection_rate is 0.9882352941176471
# crossvalidation 8 start
# error ! True: mccs0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.5499494635
# crossvalidation 8 compeleted
# cost time  46.9 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mroa0 False: mdrb0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fgmd0 False: fkms0
# done
# -53.1705753401
# crossvalidation 9 compeleted
# cost time  53.8 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.9207372408
# crossvalidation 10 compeleted
# cost time  60.0 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  7
# the total detection rate is  0.9941176470588236
# overall expected scores -52.9663791297
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5764344752
# crossvalidation 1 compeleted
# cost time   7.4 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -51.3844496959
# crossvalidation 2 compeleted
# cost time  14.1 minute
# the crossval 1 detection_rate is 1.0
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6270913422
# crossvalidation 3 compeleted
# cost time  19.9 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mlnt0 False: mdrb0
# error ! True: fjmg0 False: fadg0
# error ! True: mkcl0 False: mtmr0
# error ! True: mgrt0 False: mdls0
# done
# -53.2055782373
# crossvalidation 4 compeleted
# cost time  25.2 minute
# the crossval 3 detection_rate is 0.9705882352941176
# crossvalidation 5 start
# error ! True: fcft0 False: fmah0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mrrk0 False: mcrc0
# done
# -53.1685390803
# crossvalidation 5 compeleted
# cost time  30.7 minute
# the crossval 4 detection_rate is 0.9882352941176471
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1637381106
# crossvalidation 6 compeleted
# cost time  36.1 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mtls0 False: mmwh0
# error ! True: fcau0 False: fisb0
# done
# -52.6842567877
# crossvalidation 7 compeleted
# cost time  41.4 minute
# the crossval 6 detection_rate is 0.9823529411764705
# crossvalidation 8 start
# error ! True: mccs0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.5153601344
# crossvalidation 8 compeleted
# cost time  46.5 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mroa0 False: mdrb0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fgmd0 False: fkms0
# done
# -53.1437597031
# crossvalidation 9 compeleted
# cost time  52.0 minute
# the crossval 8 detection_rate is 0.9882352941176471
# crossvalidation 10 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -52.8837425338
# crossvalidation 10 compeleted
# cost time  57.1 minute
# the crossval 9 detection_rate is 1.0
# MAX_iter  8
# the total detection rate is  0.9923529411764705
# overall expected scores -52.93529501
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5644332706
# crossvalidation 1 compeleted
# cost time   6.2 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# error ! True: mrtk0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -51.4061558539
# crossvalidation 2 compeleted
# cost time  12.0 minute
# the crossval 1 detection_rate is 0.9941176470588236
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6116576054
# crossvalidation 3 compeleted
# cost time  18.3 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: mbwm0 False: mklt0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: fjmg0 False: fadg0
# error ! True: mkcl0 False: mtmr0
# error ! True: mgrt0 False: mdls0
# done
# -53.1961739164
# crossvalidation 4 compeleted
# cost time  24.2 minute
# the crossval 3 detection_rate is 0.9764705882352941
# crossvalidation 5 start
# error ! True: fcft0 False: fmah0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mrrk0 False: mcrc0
# done
# -53.1553009873
# crossvalidation 5 compeleted
# cost time  30.7 minute
# the crossval 4 detection_rate is 0.9882352941176471
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.1552688579
# crossvalidation 6 compeleted
# cost time  36.6 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mtls0 False: mmwh0
# error ! True: fcau0 False: fisb0
# done
# -52.6749734997
# crossvalidation 7 compeleted
# cost time  41.6 minute
# the crossval 6 detection_rate is 0.9823529411764705
# crossvalidation 8 start
# error ! True: mccs0 False: majc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.4809366177
# crossvalidation 8 compeleted
# cost time  47.1 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mctw0 False: mrgg0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mdrb0
# error ! True: fgmd0 False: fkms0
# done
# -53.1358752552
# crossvalidation 9 compeleted
# cost time  53.4 minute
# the crossval 8 detection_rate is 0.9823529411764705
# crossvalidation 10 start
# error ! True: fdrw0 False: fpas0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.8657280973
# crossvalidation 10 compeleted
# cost time  59.2 minute
# the crossval 9 detection_rate is 0.9941176470588236
# MAX_iter  9
# the total detection rate is  0.9911764705882353
# overall expected scores -52.9246503961
# crossvalidation 1 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.5786696427
# crossvalidation 1 compeleted
# cost time   6.4 minute
# the crossval 0 detection_rate is 1.0
# crossvalidation 2 start
# error ! True: mrtk0 False: mcem0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -51.4374551961
# crossvalidation 2 compeleted
# cost time  12.3 minute
# the crossval 1 detection_rate is 0.9941176470588236
# crossvalidation 3 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.6102440671
# crossvalidation 3 compeleted
# cost time  18.6 minute
# the crossval 2 detection_rate is 1.0
# crossvalidation 4 start
# error ! True: fjmg0 False: fadg0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mkcl0 False: mtmr0
# error ! True: mgrt0 False: mdls0
# done
# -53.1993123302
# crossvalidation 4 compeleted
# cost time  24.7 minute
# the crossval 3 detection_rate is 0.9823529411764705
# crossvalidation 5 start
# error ! True: fcft0 False: fmah0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mrrk0 False: mcrc0
# done
# -53.1547827407
# crossvalidation 5 compeleted
# cost time  30.9 minute
# the crossval 4 detection_rate is 0.9882352941176471
# crossvalidation 6 start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# -53.171592673
# crossvalidation 6 compeleted
# cost time  36.9 minute
# the crossval 5 detection_rate is 1.0
# crossvalidation 7 start
# error ! True: mgmm0 False: mjdm1>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mtls0 False: mrws1
# error ! True: fcau0 False: fisb0
# done
# -52.6849010586
# crossvalidation 7 compeleted
# cost time  42.8 minute
# the crossval 6 detection_rate is 0.9823529411764705
# crossvalidation 8 start
# error ! True: mccs0 False: majc0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.4670913739
# crossvalidation 8 compeleted
# cost time  48.9 minute
# the crossval 7 detection_rate is 0.9941176470588236
# crossvalidation 9 start
# error ! True: mctw0 False: mrgg0>>>>>>>>>>>>>>>>>>>]100.00%
# error ! True: mroa0 False: mdrb0
# error ! True: fgmd0 False: fkms0
# done
# -53.138915786
# crossvalidation 9 compeleted
# cost time  55.6 minute
# the crossval 8 detection_rate is 0.9823529411764705
# crossvalidation 10 start
# error ! True: fdrw0 False: fpas0>>>>>>>>>>>>>>>>>>>]100.00%
# done
# -52.8639949676
# crossvalidation 10 compeleted
# cost time  61.5 minute
# the crossval 9 detection_rate is 0.9941176470588236
# MAX_iter  10
# the total detection rate is  0.991764705882353
# overall expected scores -52.9306959836
