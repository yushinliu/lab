# %%
from Speaker_identification import Speaker_identification
from density_func import density_func, naive_G_U
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from process_bar import ShowProcess
from scipy.io import loadmat,savemat

'''
Import features
'''

#save_path="D:\\LAB\\lab\\task_2_version_4\\features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

#save_path="D:\\LAB\\lab\\task_2_version_4\\unknown_features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/unknown_feature.txt"
f = open(save_path,'rb')
b_new_test=pickle.load(f)
#print(b_new_test.shape)
f.close()

'''
Import UBM model
'''

ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz",mat_dtype=True)
#ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_samples=len(features.keys())
name_set=list(features.keys())
name_set.append("unknown")
correct_sum=0
false_sum=0
for cross_num in range(1):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
        
    test_file_set.append(b_new_test)
    
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_samples)
    scores_set=np.zeros((num_samples+1,num_samples+1))
    for index_2 in range(num_samples):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=1,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_samples+1):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)
    '''
    Enhancement : added the unknown detection part
    '''
    for index in range(num_samples+1):
        b_test=np.array(test_file_set[index])
        T_value=b_test.shape[1]
        unknown_score=Speaker_identification(b_test,ubm_means,ubm_var,ubm_weights,T_value)
        #scores_set[index,num_samples]=unknown_score
        scores_set[index,num_samples]=(1/T_value)*unknown_score
        
        
    '''
    Calculate the detection rate
    '''
    for index in range(num_samples+1):
        test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
        if index == test_index:
            correct_num +=1
            correct_sum +=1
        else:
            false_num +=1
            false_sum +=1
            print('')
            print("error ! True: "+name_set[index]+" False: "+name_set[test_index])
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()

    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num+1)+" detection_rate is "+str(detection_rate))

print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.60%
# /Users/Mata/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# [>>>>>>>>>>>---------------------------------------]22.02%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-40cdadd678d0> in <module>()
#     103             #print("now test set "+str(index_1)+" is testing "+str(index_2))
#     104             b_test=np.array(test_file_set[index_1])
# --> 105             scores_set[index_1,index_2]=gmm.score(b_test.T)
#     106     '''
#     107     Enhancement : added the unknown detection part
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py in score(self, X, y)
#     320             Log likelihood of the Gaussian mixture given X.
#     321         """
# --> 322         return self.score_samples(X).mean()
#     323
#     324     def predict(self, X):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py in score_samples(self, X)
#     304         X = _check_X(X, None, self.means_.shape[1])
#     305
# --> 306         return logsumexp(self._estimate_weighted_log_prob(X), axis=1)
#     307
#     308     def score(self, X, y=None):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/special/_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#     108         tmp = b * np.exp(a - a_max)
#     109     else:
# --> 110         tmp = np.exp(a - a_max)
#     111
#     112     # suppress warnings about log of zero
#
# KeyboardInterrupt:

# %%
scores_set[168,:]

# %%
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from process_bar import ShowProcess
from scipy.io import loadmat,savemat

'''
Import features
'''

save_path="D:\\LAB\\lab\\task_2_version_4\\features.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_4/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

save_path="D:\\LAB\\lab\\task_2_version_4\\unknown_features.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_4/unknown_features.txt"
f = open(save_path,'rb')
unknown_features=pickle.load(f)  #190 unregisterd user
#print(b_new_test.shape)
f.close()

'''
Import UBM model
'''

#ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz",mat_dtype=True)
ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
start=time.time()
error_set={}  
num_registered=len(features.keys())
num_unregistered=len(unknown_features.keys())
name_set=list(features.keys())
#name_set.append("unknown")
correct_sum=0
false_sum=0
ml_error_sum=0
fr_error_sum=0
fa_error_sum=0
threshold=-34.8
for cross_num in range(1):
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    correct_num=0
    false_num=0
    ml_error=0
    fr_error=0
    fa_error=0
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
        
    for name in unknown_features.keys():
        whole_set=unknown_features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        test_file_set.append(test_file)

    
    '''
    Start modeling and identification
    '''
    print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_registered)
    scores_set=np.zeros((num_registered+num_unregistered,num_registered))
    for index_2 in range(num_registered):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=1,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_registered+num_unregistered):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

        
    '''
    Calculate the detection rate and error rate
    '''
    for index in range(num_registered+num_unregistered):
        if index < num_registered :
            if max(scores_set[index,:])>threshold*ubm:
                test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
                if index == test_index:
                    correct_num +=1
                    correct_sum +=1
                else:
                    false_num +=1
                    false_sum +=1
                    ml_error +=1
                    ml_error_sum +=1
                    print('')
                    print("error ! True: "+name_set[index]+" False: "+name_set[test_index])
            else:
                    false_num+=1
                    false_sum+=1
                    fr_error+=1
                    fr_error_sum+=1
                    print('')
                    print("error ! True: "+name_set[index]+" False: unknowns")
        else:
            if max(scores_set[index,:])<=threshold:
                correct_num +=1
                correct_sum +=1
            else:
                false_num+=1
                false_sum+=1
                fa_error+=1
                fa_error_sum+=1
                print('')
                print("error ! Unknown misidentified")
                
            
        #print("time cost %5.1f second"%((time.time()-start)/60))

    process_bar_2.close()

    detection_rate=correct_num/(correct_num+false_num)
    print("crossvalidation "+str(cross_num+1)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    ml_rate=100*ml_error/(num_registered)
    fr_rate=100*fr_error/(num_registered)
    fa_rate=100*fa_error/(num_unregistered)
    aer_rate=100*(ml_error+fr_error+fa_error)/(num_registered+num_unregistered)
    #detection_rate_set.append(detection_rate)
    print("the crossval "+str(cross_num+1)+" detection_rate is "+str(detection_rate))
    print("ML %5.1f, FR, %5.1f , FA, %5.1f, AER, %5.1f"%(ml_rate,fr_rate,fa_rate,aer_rate))
print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
print("the total detection rate is ",correct_sum/(correct_sum+false_sum))
# Out:
# crossvalidation 1 start
# [--------------------------------------------------]0.60%
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
#
# error ! Unknown misidentified
# done
# crossvalidation 1 compeleted
# cost time   7.5 minute
# the crossval 1 detection_rate is 0.553072625698324
# ML   0.0, FR,   0.0 , FA,  84.2, AER,  44.7
# the total detection rate is  0.553072625698324
# the total detection rate is  0.553072625698324

# %%
from Speaker_identification import Speaker_identification
from density_func import density_func, naive_G_U
from sklearn.mixture import GaussianMixture
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
#default

import pickle
import numpy as np
import time

#loadmat
from process_bar import ShowProcess
from scipy.io import loadmat,savemat

'''
Import features
'''

#save_path="D:\\LAB\\lab\\task_2_version_4\\features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/features.txt"
f = open(save_path,'rb')
features=pickle.load(f)
f.close()

#save_path="D:\\LAB\\lab\\task_2_version_4\\unknown_features.txt"
save_path="/Users/Mata/Documents/lab/task_2_version_4/unknown_features.txt"
f = open(save_path,'rb')
unknown_features=pickle.load(f)  #190 unregisterd user
#print(b_new_test.shape)
f.close()

'''
Import UBM model
'''

ubm_dataset=loadmat("/Users/Mata/Documents/2017/学习/ws2017:18/PUL/forStudents/ubm/UBM_GMMNaive_MFCC_Spectrum0to8000Hz",mat_dtype=True)
#ubm_dataset=loadmat("C:\\Users\\hasee\\workspace\\workspace\\lab\\patRecDat\\forStudents\\ubm\\UBM_GMMNaive_MFCC_Spectrum0to8000Hz.mat",mat_dtype=True)
ubm_means=ubm_dataset['means']
ubm_var = ubm_dataset['var']
ubm_weights = ubm_dataset['weights'].ravel()
ubm_var_set=[]
K_value=49
gamma_UBM=1

#transfer variance of UBM to cov
for k in range(K_value):
    ubm_var_set.append(np.diag(ubm_var[k]))
ubm_var_set=np.array(ubm_var_set)
ubm_var=ubm_var_set

num_people=len(features.keys())

'''
Start Crossvalidation
'''
#process_bar=ShowProcess(10)
detection_rate_set=[]
ml_rate_set=np.zeros((10,41))
fr_rate_set=np.zeros((10,41))
fa_rate_set=np.zeros((10,41))
aer_rate_set=np.zeros((10,41))
start=time.time()
error_set={}  
num_registered=len(features.keys())
num_unregistered=len(unknown_features.keys())
name_set=list(features.keys())
#name_set.append("unknown")
for cross_num in range(10):
    print("crossvalidation "+str(cross_num)+" start")
    #process_bar.show_process()
    train_file_set=[]
    test_file_set=[]
    '''
    Split the test and train set
    '''
    for name in features.keys():
        whole_set=features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        train_num=list(range(10))
        train_num.remove(cross_num)
        test_file_set.append(test_file)
        #name_set.append(name)
        train_set=[]
        for num in train_num:
            train_set.append(whole_set[num])
        train_set=np.concatenate(train_set,axis=1)
        train_file_set.append(train_set)
        
    for name in unknown_features.keys():
        whole_set=unknown_features.get(name,'no such file').copy()
        test_file=whole_set[cross_num]
        test_file_set.append(test_file)

    
        '''
    Enhancement : added the unknown detection part
    '''
    ubm_scores=[]
    print("ubm model start")
    process_bar_1=ShowProcess(num_registered+num_unregistered)
    for index in range(num_registered+num_unregistered):
        process_bar_1.show_process()
        b_test=np.array(test_file_set[index])
        T_value=b_test.shape[1]
        unknown_score=Speaker_identification(b_test,ubm_means,ubm_var,ubm_weights,T_value)
        #scores_set[index,num_samples]=unknown_score
        ubm_scores.append((1/T_value)*unknown_score)
    process_bar_1.close()
    '''
    Start modeling and identification
    '''
    #print("crossvalidation "+str(cross_num+1)+" start")
    process_bar_2=ShowProcess(num_registered)
    scores_set=np.zeros((num_registered+num_unregistered,num_registered))
    for index_2 in range(num_registered):
        process_bar_2.show_process()
        b_train=train_file_set[index_2]
        gmm=GaussianMixture(n_components=K_value,covariance_type='full',max_iter=1,weights_init=ubm_weights,\
                            means_init=ubm_means,precisions_init=np.linalg.inv(ubm_var))
        gmm.fit(b_train.T)
        for index_1 in range(num_registered+num_unregistered):
            #print("now test set "+str(index_1)+" is testing "+str(index_2))
            b_test=np.array(test_file_set[index_1])
            scores_set[index_1,index_2]=gmm.score(b_test.T)

        
    '''
    Calculate the detection rate and error rate
    '''
    for index_1,threshold in enumerate([0.3,0.31,0.32,0.33,0.34,0.35,0.36,0.37,0.38,0.39,0.40,\
                     0.41,0.42,0.43,0.44,0.45,0.46,0.47,0.48,0.49,0.50,\
                     0.51,0.52,0.53,0.54,0.55,0.56,0.57,0.58,0.59,0.60,\
                     0.61,0.62,0.63,0.64,0.65,0.66,0.67,0.68,0.69,0.70]):
    #process_bar.show_process()
        correct_num=0
        false_num=0
        ml_error=0
        fr_error=0
        fa_error=0
        for index in range(num_registered+num_unregistered):
            if index < num_registered :
                if max(scores_set[index,:])>threshold*ubm_scores[index]:
                    test_index=np.int(np.argwhere(scores_set[index,:]==max(scores_set[index,:])))
                    if index == test_index:
                        correct_num +=1
                    else:
                        false_num +=1
                        ml_error +=1
                        #print('')
                        #print("error ! True: "+name_set[index]+" False: "+name_set[test_index])
                else:
                        false_num+=1
                        fr_error+=1
                        #print('')
                        #print("error ! True: "+name_set[index]+" False: unknowns")
            else:
                if max(scores_set[index,:])<=threshold*ubm_scores[index]:
                    correct_num +=1
                else:
                    false_num+=1
                    fa_error+=1
                    #print('')
                    #print("error ! Unknown misidentified")
        ml_rate=100*ml_error/(num_registered)
        fr_rate=100*fr_error/(num_registered)
        fa_rate=100*fa_error/(num_unregistered)
        aer_rate=100*(ml_error+fr_error+fa_error)/(num_registered+num_unregistered)
        ml_rate_set[cross_num,index_1]=ml_rate
        fr_rate_set[cross_num,index_1]=fr_rate
        fa_rate_set[cross_num,index_1]=fa_rate
        aer_rate_set[cross_num,index_1]=aer_rate
        print("threshold "+str(threshold)+" compeleted")
        #print("time cost %5.1f second"%((time.time()-start)/60))
        print("ML %5.1f, FR, %5.1f , FA, %5.1f, AER, %5.1f"%(ml_rate,fr_rate,fa_rate,aer_rate))
    process_bar_2.close()

    detection_rate=correct_num/(correct_num+false_num)
    print("cross_validation "+str(cross_num)+" compeleted")
    print("cost time %5.1f minute"%((time.time()-start)/60))
    detection_rate=correct_num/(false_num+correct_num)
    #detection_rate_set.append(detection_rate)
    print("cross validation "+str(cross_num)+" detection_rate is "+str(detection_rate))
#print("the total detection rate is ",correct_sum/(correct_sum+false_sum))

#save the error rate 
error_rate_set={}
error_rate_set.setdefault('ml')
error_rate_set.setdefault('fr')
error_rate_set.setdefault('fa')
error_rate_set.setdefault('aer')
error_rate_set['ml']=ml_rate_set
error_rate_set['fr']=fr_rate_set
error_rate_set['fa']=fa_rate_set
error_rate_set['aer']=aer_rate_set
save_path="/Users/Mata/Documents/lab/task_2_version_4/error_rate_set.txt"
f = open(save_path,'wb')
pickle.dump(error_rate_set,f)
f.close()
# Out:
# crossvalidation 0 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# [--------------------------------------------------]0.60%
# /Users/Mata/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.39 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.41 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.42 compeleted
# ML   0.0, FR,  98.2 , FA,   0.5, AER,  46.4
# threshold 0.43 compeleted
# ML   0.0, FR,  97.0 , FA,   1.1, AER,  46.1
# threshold 0.44 compeleted
# ML   0.0, FR,  96.4 , FA,   2.1, AER,  46.4
# threshold 0.45 compeleted
# ML   0.0, FR,  93.5 , FA,   2.6, AER,  45.3
# threshold 0.46 compeleted
# ML   0.0, FR,  91.1 , FA,   3.7, AER,  44.7
# threshold 0.47 compeleted
# ML   0.0, FR,  85.1 , FA,   6.3, AER,  43.3
# threshold 0.48 compeleted
# ML   0.0, FR,  80.4 , FA,   9.5, AER,  42.7
# threshold 0.49 compeleted
# ML   0.0, FR,  75.0 , FA,  13.7, AER,  42.5
# threshold 0.5 compeleted
# ML   0.0, FR,  69.0 , FA,  18.4, AER,  42.2
# threshold 0.51 compeleted
# ML   0.0, FR,  62.5 , FA,  22.6, AER,  41.3
# threshold 0.52 compeleted
# ML   0.0, FR,  58.3 , FA,  27.4, AER,  41.9
# threshold 0.53 compeleted
# ML   0.0, FR,  54.8 , FA,  32.6, AER,  43.0
# threshold 0.54 compeleted
# ML   0.0, FR,  50.0 , FA,  36.8, AER,  43.0
# threshold 0.55 compeleted
# ML   0.0, FR,  42.9 , FA,  41.6, AER,  42.2
# threshold 0.56 compeleted
# ML   0.0, FR,  38.1 , FA,  47.4, AER,  43.0
# threshold 0.57 compeleted
# ML   0.0, FR,  35.7 , FA,  50.0, AER,  43.3
# threshold 0.58 compeleted
# ML   0.0, FR,  33.3 , FA,  55.8, AER,  45.3
# threshold 0.59 compeleted
# ML   0.0, FR,  29.8 , FA,  59.5, AER,  45.5
# threshold 0.6 compeleted
# ML   0.0, FR,  25.6 , FA,  65.8, AER,  46.9
# threshold 0.61 compeleted
# ML   0.0, FR,  23.8 , FA,  71.1, AER,  48.9
# threshold 0.62 compeleted
# ML   0.0, FR,  19.0 , FA,  73.7, AER,  48.0
# threshold 0.63 compeleted
# ML   0.0, FR,  16.7 , FA,  77.4, AER,  48.9
# threshold 0.64 compeleted
# ML   0.0, FR,  14.9 , FA,  78.9, AER,  48.9
# threshold 0.65 compeleted
# ML   0.0, FR,  10.7 , FA,  82.1, AER,  48.6
# threshold 0.66 compeleted
# ML   0.0, FR,   9.5 , FA,  83.7, AER,  48.9
# threshold 0.67 compeleted
# ML   0.0, FR,   7.7 , FA,  85.3, AER,  48.9
# threshold 0.68 compeleted
# ML   0.0, FR,   7.1 , FA,  86.3, AER,  49.2
# threshold 0.69 compeleted
# ML   0.0, FR,   6.0 , FA,  88.4, AER,  49.7
# threshold 0.7 compeleted
# ML   0.0, FR,   4.2 , FA,  90.5, AER,  50.0
# done
# cross_validation 0 compeleted
# cost time  10.4 minute
# cross validation 0 detection_rate is 0.5
# crossvalidation 1 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.39 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.41 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.42 compeleted
# ML   0.0, FR,  96.4 , FA,   1.1, AER,  45.8
# threshold 0.43 compeleted
# ML   0.0, FR,  94.6 , FA,   2.1, AER,  45.5
# threshold 0.44 compeleted
# ML   0.0, FR,  92.3 , FA,   3.2, AER,  45.0
# threshold 0.45 compeleted
# ML   0.0, FR,  88.1 , FA,   6.3, AER,  44.7
# threshold 0.46 compeleted
# ML   0.0, FR,  85.1 , FA,   7.4, AER,  43.9
# threshold 0.47 compeleted
# ML   0.0, FR,  82.7 , FA,  12.1, AER,  45.3
# threshold 0.48 compeleted
# ML   0.0, FR,  79.2 , FA,  14.2, AER,  44.7
# threshold 0.49 compeleted
# ML   0.0, FR,  75.0 , FA,  16.8, AER,  44.1
# threshold 0.5 compeleted
# ML   0.0, FR,  70.8 , FA,  22.6, AER,  45.3
# threshold 0.51 compeleted
# ML   0.0, FR,  66.7 , FA,  24.7, AER,  44.4
# threshold 0.52 compeleted
# ML   0.0, FR,  62.5 , FA,  27.4, AER,  43.9
# threshold 0.53 compeleted
# ML   0.0, FR,  56.0 , FA,  29.5, AER,  41.9
# threshold 0.54 compeleted
# ML   0.0, FR,  54.2 , FA,  32.6, AER,  42.7
# threshold 0.55 compeleted
# ML   0.0, FR,  50.0 , FA,  39.5, AER,  44.4
# threshold 0.56 compeleted
# ML   0.0, FR,  45.8 , FA,  46.3, AER,  46.1
# threshold 0.57 compeleted
# ML   0.0, FR,  42.9 , FA,  53.7, AER,  48.6
# threshold 0.58 compeleted
# ML   0.0, FR,  39.3 , FA,  58.4, AER,  49.4
# threshold 0.59 compeleted
# ML   0.0, FR,  35.1 , FA,  60.5, AER,  48.6
# threshold 0.6 compeleted
# ML   0.0, FR,  33.3 , FA,  63.7, AER,  49.4
# threshold 0.61 compeleted
# ML   0.0, FR,  32.1 , FA,  65.3, AER,  49.7
# threshold 0.62 compeleted
# ML   0.0, FR,  26.8 , FA,  68.9, AER,  49.2
# threshold 0.63 compeleted
# ML   0.0, FR,  25.0 , FA,  70.5, AER,  49.2
# threshold 0.64 compeleted
# ML   0.0, FR,  22.0 , FA,  72.6, AER,  48.9
# threshold 0.65 compeleted
# ML   0.0, FR,  19.0 , FA,  75.3, AER,  48.9
# threshold 0.66 compeleted
# ML   0.0, FR,  15.5 , FA,  77.9, AER,  48.6
# threshold 0.67 compeleted
# ML   0.0, FR,  13.7 , FA,  82.1, AER,  50.0
# threshold 0.68 compeleted
# ML   0.0, FR,  10.1 , FA,  83.2, AER,  48.9
# threshold 0.69 compeleted
# ML   0.0, FR,   9.5 , FA,  84.2, AER,  49.2
# threshold 0.7 compeleted
# ML   0.0, FR,   8.9 , FA,  85.8, AER,  49.7
# done
# cross_validation 1 compeleted
# cost time  17.7 minute
# cross validation 1 detection_rate is 0.5027932960893855
# crossvalidation 2 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.37 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.38 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.39 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.4 compeleted
# ML   0.0, FR,  98.2 , FA,   0.5, AER,  46.4
# threshold 0.41 compeleted
# ML   0.0, FR,  98.2 , FA,   0.5, AER,  46.4
# threshold 0.42 compeleted
# ML   0.0, FR,  97.6 , FA,   0.5, AER,  46.1
# threshold 0.43 compeleted
# ML   0.0, FR,  95.2 , FA,   1.1, AER,  45.3
# threshold 0.44 compeleted
# ML   0.0, FR,  94.0 , FA,   1.6, AER,  45.0
# threshold 0.45 compeleted
# ML   0.0, FR,  91.7 , FA,   2.1, AER,  44.1
# threshold 0.46 compeleted
# ML   0.0, FR,  89.9 , FA,   3.7, AER,  44.1
# threshold 0.47 compeleted
# ML   0.0, FR,  87.5 , FA,   7.9, AER,  45.3
# threshold 0.48 compeleted
# ML   0.0, FR,  84.5 , FA,  12.1, AER,  46.1
# threshold 0.49 compeleted
# ML   0.0, FR,  80.4 , FA,  16.3, AER,  46.4
# threshold 0.5 compeleted
# ML   0.0, FR,  75.6 , FA,  20.0, AER,  46.1
# threshold 0.51 compeleted
# ML   0.0, FR,  73.2 , FA,  22.1, AER,  46.1
# threshold 0.52 compeleted
# ML   0.0, FR,  67.9 , FA,  24.2, AER,  44.7
# threshold 0.53 compeleted
# ML   0.0, FR,  62.5 , FA,  27.4, AER,  43.9
# threshold 0.54 compeleted
# ML   0.0, FR,  58.9 , FA,  32.6, AER,  45.0
# threshold 0.55 compeleted
# ML   0.0, FR,  56.0 , FA,  34.7, AER,  44.7
# threshold 0.56 compeleted
# ML   0.0, FR,  53.6 , FA,  40.0, AER,  46.4
# threshold 0.57 compeleted
# ML   0.0, FR,  50.0 , FA,  44.2, AER,  46.9
# threshold 0.58 compeleted
# ML   0.0, FR,  45.2 , FA,  49.5, AER,  47.5
# threshold 0.59 compeleted
# ML   0.0, FR,  40.5 , FA,  53.7, AER,  47.5
# threshold 0.6 compeleted
# ML   0.0, FR,  34.5 , FA,  57.4, AER,  46.6
# threshold 0.61 compeleted
# ML   0.0, FR,  29.8 , FA,  59.5, AER,  45.5
# threshold 0.62 compeleted
# ML   0.0, FR,  26.2 , FA,  62.1, AER,  45.3
# threshold 0.63 compeleted
# ML   0.0, FR,  24.4 , FA,  69.5, AER,  48.3
# threshold 0.64 compeleted
# ML   0.0, FR,  20.2 , FA,  73.7, AER,  48.6
# threshold 0.65 compeleted
# ML   0.0, FR,  15.5 , FA,  77.9, AER,  48.6
# threshold 0.66 compeleted
# ML   0.0, FR,  13.1 , FA,  78.9, AER,  48.0
# threshold 0.67 compeleted
# ML   0.0, FR,  11.3 , FA,  81.1, AER,  48.3
# threshold 0.68 compeleted
# ML   0.0, FR,  10.7 , FA,  82.6, AER,  48.9
# threshold 0.69 compeleted
# ML   0.0, FR,   6.5 , FA,  84.2, AER,  47.8
# threshold 0.7 compeleted
# ML   0.0, FR,   4.2 , FA,  86.8, AER,  48.0
# done
# cross_validation 2 compeleted
# cost time  27.2 minute
# cross validation 2 detection_rate is 0.5195530726256983
# crossvalidation 3 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.39 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.4 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.41 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.42 compeleted
# ML   0.0, FR,  97.6 , FA,   0.5, AER,  46.1
# threshold 0.43 compeleted
# ML   0.6, FR,  96.4 , FA,   1.1, AER,  46.1
# threshold 0.44 compeleted
# ML   0.6, FR,  95.8 , FA,   1.6, AER,  46.1
# threshold 0.45 compeleted
# ML   0.6, FR,  94.0 , FA,   2.6, AER,  45.8
# threshold 0.46 compeleted
# ML   0.6, FR,  91.1 , FA,   3.7, AER,  45.0
# threshold 0.47 compeleted
# ML   0.6, FR,  86.3 , FA,   6.3, AER,  44.1
# threshold 0.48 compeleted
# ML   0.6, FR,  83.3 , FA,   7.9, AER,  43.6
# threshold 0.49 compeleted
# ML   0.6, FR,  79.8 , FA,  11.1, AER,  43.6
# threshold 0.5 compeleted
# ML   0.6, FR,  75.6 , FA,  15.8, AER,  44.1
# threshold 0.51 compeleted
# ML   1.2, FR,  71.4 , FA,  20.5, AER,  45.0
# threshold 0.52 compeleted
# ML   1.2, FR,  67.3 , FA,  24.2, AER,  45.0
# threshold 0.53 compeleted
# ML   1.2, FR,  61.3 , FA,  28.9, AER,  44.7
# threshold 0.54 compeleted
# ML   1.8, FR,  52.4 , FA,  32.1, AER,  42.5
# threshold 0.55 compeleted
# ML   1.8, FR,  50.0 , FA,  35.8, AER,  43.3
# threshold 0.56 compeleted
# ML   1.8, FR,  45.8 , FA,  38.9, AER,  43.0
# threshold 0.57 compeleted
# ML   1.8, FR,  44.0 , FA,  43.2, AER,  44.4
# threshold 0.58 compeleted
# ML   1.8, FR,  38.1 , FA,  47.9, AER,  44.1
# threshold 0.59 compeleted
# ML   1.8, FR,  35.7 , FA,  52.6, AER,  45.5
# threshold 0.6 compeleted
# ML   1.8, FR,  30.4 , FA,  57.9, AER,  45.8
# threshold 0.61 compeleted
# ML   1.8, FR,  26.8 , FA,  61.6, AER,  46.1
# threshold 0.62 compeleted
# ML   1.8, FR,  25.0 , FA,  66.8, AER,  48.0
# threshold 0.63 compeleted
# ML   1.8, FR,  20.8 , FA,  67.9, AER,  46.6
# threshold 0.64 compeleted
# ML   1.8, FR,  19.6 , FA,  73.2, AER,  48.9
# threshold 0.65 compeleted
# ML   1.8, FR,  15.5 , FA,  76.8, AER,  48.9
# threshold 0.66 compeleted
# ML   1.8, FR,  14.3 , FA,  79.5, AER,  49.7
# threshold 0.67 compeleted
# ML   1.8, FR,  12.5 , FA,  82.1, AER,  50.3
# threshold 0.68 compeleted
# ML   1.8, FR,  11.3 , FA,  84.7, AER,  51.1
# threshold 0.69 compeleted
# ML   1.8, FR,   9.5 , FA,  87.4, AER,  51.7
# threshold 0.7 compeleted
# ML   1.8, FR,   8.3 , FA,  89.5, AER,  52.2
# done
# cross_validation 3 compeleted
# cost time  35.3 minute
# cross validation 3 detection_rate is 0.4776536312849162
# crossvalidation 4 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.38 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.39 compeleted
# ML   0.0, FR,  99.4 , FA,   0.5, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR,  99.4 , FA,   0.5, AER,  46.9
# threshold 0.41 compeleted
# ML   0.0, FR,  98.2 , FA,   0.5, AER,  46.4
# threshold 0.42 compeleted
# ML   0.0, FR,  97.0 , FA,   1.1, AER,  46.1
# threshold 0.43 compeleted
# ML   0.0, FR,  95.2 , FA,   1.1, AER,  45.3
# threshold 0.44 compeleted
# ML   0.0, FR,  93.5 , FA,   1.6, AER,  44.7
# threshold 0.45 compeleted
# ML   0.6, FR,  91.7 , FA,   2.6, AER,  44.7
# threshold 0.46 compeleted
# ML   0.6, FR,  88.7 , FA,   3.2, AER,  43.6
# threshold 0.47 compeleted
# ML   0.6, FR,  83.3 , FA,   5.3, AER,  42.2
# threshold 0.48 compeleted
# ML   0.6, FR,  79.2 , FA,   7.9, AER,  41.6
# threshold 0.49 compeleted
# ML   0.6, FR,  73.8 , FA,   9.5, AER,  39.9
# threshold 0.5 compeleted
# ML   0.6, FR,  70.2 , FA,  14.7, AER,  41.1
# threshold 0.51 compeleted
# ML   0.6, FR,  64.9 , FA,  17.9, AER,  40.2
# threshold 0.52 compeleted
# ML   0.6, FR,  59.5 , FA,  22.1, AER,  39.9
# threshold 0.53 compeleted
# ML   0.6, FR,  54.2 , FA,  26.8, AER,  39.9
# threshold 0.54 compeleted
# ML   0.6, FR,  48.8 , FA,  33.2, AER,  40.8
# threshold 0.55 compeleted
# ML   0.6, FR,  46.4 , FA,  41.1, AER,  43.9
# threshold 0.56 compeleted
# ML   0.6, FR,  38.1 , FA,  45.8, AER,  42.5
# threshold 0.57 compeleted
# ML   0.6, FR,  32.7 , FA,  49.5, AER,  41.9
# threshold 0.58 compeleted
# ML   0.6, FR,  31.5 , FA,  54.7, AER,  44.1
# threshold 0.59 compeleted
# ML   0.6, FR,  26.8 , FA,  57.4, AER,  43.3
# threshold 0.6 compeleted
# ML   0.6, FR,  23.8 , FA,  60.0, AER,  43.3
# threshold 0.61 compeleted
# ML   0.6, FR,  22.0 , FA,  66.3, AER,  45.8
# threshold 0.62 compeleted
# ML   0.6, FR,  19.6 , FA,  72.6, AER,  48.0
# threshold 0.63 compeleted
# ML   0.6, FR,  17.3 , FA,  74.7, AER,  48.0
# threshold 0.64 compeleted
# ML   0.6, FR,  15.5 , FA,  77.9, AER,  48.9
# threshold 0.65 compeleted
# ML   0.6, FR,  12.5 , FA,  79.5, AER,  48.3
# threshold 0.66 compeleted
# ML   0.6, FR,  10.7 , FA,  82.1, AER,  48.9
# threshold 0.67 compeleted
# ML   0.6, FR,   8.3 , FA,  86.3, AER,  50.0
# threshold 0.68 compeleted
# ML   0.6, FR,   6.5 , FA,  90.5, AER,  51.4
# threshold 0.69 compeleted
# ML   0.6, FR,   5.4 , FA,  92.1, AER,  51.7
# threshold 0.7 compeleted
# ML   0.6, FR,   4.2 , FA,  92.1, AER,  51.1
# done
# cross_validation 4 compeleted
# cost time  44.0 minute
# cross validation 4 detection_rate is 0.4888268156424581
# crossvalidation 5 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.39 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.41 compeleted
# ML   0.0, FR,  99.4 , FA,   1.1, AER,  47.2
# threshold 0.42 compeleted
# ML   0.6, FR,  98.8 , FA,   1.1, AER,  47.2
# threshold 0.43 compeleted
# ML   0.6, FR,  98.2 , FA,   1.6, AER,  47.2
# threshold 0.44 compeleted
# ML   0.6, FR,  98.2 , FA,   1.6, AER,  47.2
# threshold 0.45 compeleted
# ML   0.6, FR,  96.4 , FA,   2.6, AER,  46.9
# threshold 0.46 compeleted
# ML   0.6, FR,  91.7 , FA,   4.2, AER,  45.5
# threshold 0.47 compeleted
# ML   0.6, FR,  88.7 , FA,   6.3, AER,  45.3
# threshold 0.48 compeleted
# ML   0.6, FR,  86.3 , FA,  10.5, AER,  46.4
# threshold 0.49 compeleted
# ML   0.6, FR,  82.1 , FA,  14.7, AER,  46.6
# threshold 0.5 compeleted
# ML   0.6, FR,  77.4 , FA,  17.9, AER,  46.1
# threshold 0.51 compeleted
# ML   0.6, FR,  71.4 , FA,  22.6, AER,  45.8
# threshold 0.52 compeleted
# ML   0.6, FR,  63.7 , FA,  25.8, AER,  43.9
# threshold 0.53 compeleted
# ML   0.6, FR,  58.9 , FA,  31.1, AER,  44.4
# threshold 0.54 compeleted
# ML   0.6, FR,  54.8 , FA,  35.8, AER,  45.0
# threshold 0.55 compeleted
# ML   0.6, FR,  50.0 , FA,  40.5, AER,  45.3
# threshold 0.56 compeleted
# ML   0.6, FR,  46.4 , FA,  44.2, AER,  45.5
# threshold 0.57 compeleted
# ML   0.6, FR,  43.5 , FA,  49.5, AER,  46.9
# threshold 0.58 compeleted
# ML   0.6, FR,  36.9 , FA,  55.8, AER,  47.2
# threshold 0.59 compeleted
# ML   0.6, FR,  35.1 , FA,  60.0, AER,  48.6
# threshold 0.6 compeleted
# ML   0.6, FR,  28.6 , FA,  66.8, AER,  49.2
# threshold 0.61 compeleted
# ML   0.6, FR,  23.8 , FA,  72.6, AER,  50.0
# threshold 0.62 compeleted
# ML   0.6, FR,  21.4 , FA,  75.8, AER,  50.6
# threshold 0.63 compeleted
# ML   0.6, FR,  16.7 , FA,  76.3, AER,  48.6
# threshold 0.64 compeleted
# ML   0.6, FR,  14.9 , FA,  77.9, AER,  48.6
# threshold 0.65 compeleted
# ML   0.6, FR,  12.5 , FA,  82.1, AER,  49.7
# threshold 0.66 compeleted
# ML   0.6, FR,  10.7 , FA,  85.3, AER,  50.6
# threshold 0.67 compeleted
# ML   0.6, FR,   9.5 , FA,  87.9, AER,  51.4
# threshold 0.68 compeleted
# ML   0.6, FR,   8.3 , FA,  88.9, AER,  51.4
# threshold 0.69 compeleted
# ML   0.6, FR,   7.1 , FA,  89.5, AER,  51.1
# threshold 0.7 compeleted
# ML   0.6, FR,   5.4 , FA,  90.0, AER,  50.6
# done
# cross_validation 5 compeleted
# cost time  51.5 minute
# cross validation 5 detection_rate is 0.49441340782122906
# crossvalidation 6 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.39 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.41 compeleted
# ML   0.0, FR,  98.8 , FA,   0.0, AER,  46.4
# threshold 0.42 compeleted
# ML   0.0, FR,  98.2 , FA,   0.5, AER,  46.4
# threshold 0.43 compeleted
# ML   0.0, FR,  95.8 , FA,   0.5, AER,  45.3
# threshold 0.44 compeleted
# ML   0.0, FR,  93.5 , FA,   1.1, AER,  44.4
# threshold 0.45 compeleted
# ML   0.0, FR,  91.7 , FA,   2.1, AER,  44.1
# threshold 0.46 compeleted
# ML   0.0, FR,  88.7 , FA,   3.7, AER,  43.6
# threshold 0.47 compeleted
# ML   0.0, FR,  84.5 , FA,   5.8, AER,  42.7
# threshold 0.48 compeleted
# ML   0.6, FR,  81.0 , FA,  12.1, AER,  44.7
# threshold 0.49 compeleted
# ML   0.6, FR,  73.8 , FA,  15.3, AER,  43.0
# threshold 0.5 compeleted
# ML   0.6, FR,  69.6 , FA,  20.5, AER,  43.9
# threshold 0.51 compeleted
# ML   1.2, FR,  63.1 , FA,  23.7, AER,  42.7
# threshold 0.52 compeleted
# ML   1.2, FR,  57.1 , FA,  27.9, AER,  42.2
# threshold 0.53 compeleted
# ML   1.2, FR,  53.0 , FA,  31.6, AER,  42.2
# threshold 0.54 compeleted
# ML   1.2, FR,  47.0 , FA,  36.3, AER,  41.9
# threshold 0.55 compeleted
# ML   1.2, FR,  43.5 , FA,  42.1, AER,  43.3
# threshold 0.56 compeleted
# ML   1.2, FR,  36.9 , FA,  47.4, AER,  43.0
# threshold 0.57 compeleted
# ML   1.2, FR,  34.5 , FA,  52.1, AER,  44.4
# threshold 0.58 compeleted
# ML   1.2, FR,  31.0 , FA,  57.9, AER,  45.8
# threshold 0.59 compeleted
# ML   1.2, FR,  26.8 , FA,  63.2, AER,  46.6
# threshold 0.6 compeleted
# ML   1.2, FR,  23.2 , FA,  66.3, AER,  46.6
# threshold 0.61 compeleted
# ML   1.2, FR,  22.0 , FA,  71.1, AER,  48.6
# threshold 0.62 compeleted
# ML   1.2, FR,  19.6 , FA,  76.3, AER,  50.3
# threshold 0.63 compeleted
# ML   1.2, FR,  14.3 , FA,  77.4, AER,  48.3
# threshold 0.64 compeleted
# ML   1.2, FR,  12.5 , FA,  78.9, AER,  48.3
# threshold 0.65 compeleted
# ML   1.2, FR,  10.1 , FA,  82.1, AER,  48.9
# threshold 0.66 compeleted
# ML   1.2, FR,   8.9 , FA,  84.2, AER,  49.4
# threshold 0.67 compeleted
# ML   1.2, FR,   7.7 , FA,  86.3, AER,  50.0
# threshold 0.68 compeleted
# ML   1.2, FR,   6.5 , FA,  88.9, AER,  50.8
# threshold 0.69 compeleted
# ML   1.2, FR,   5.4 , FA,  91.1, AER,  51.4
# threshold 0.7 compeleted
# ML   1.2, FR,   3.6 , FA,  91.6, AER,  50.8
# done
# cross_validation 6 compeleted
# cost time  58.7 minute
# cross validation 6 detection_rate is 0.49162011173184356
# crossvalidation 7 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.39 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.4 compeleted
# ML   0.0, FR,  98.8 , FA,   0.5, AER,  46.6
# threshold 0.41 compeleted
# ML   0.0, FR,  97.6 , FA,   0.5, AER,  46.1
# threshold 0.42 compeleted
# ML   0.0, FR,  96.4 , FA,   1.1, AER,  45.8
# threshold 0.43 compeleted
# ML   0.0, FR,  94.6 , FA,   1.1, AER,  45.0
# threshold 0.44 compeleted
# ML   0.0, FR,  92.3 , FA,   1.1, AER,  43.9
# threshold 0.45 compeleted
# ML   0.0, FR,  89.9 , FA,   1.6, AER,  43.0
# threshold 0.46 compeleted
# ML   0.0, FR,  85.1 , FA,   3.7, AER,  41.9
# threshold 0.47 compeleted
# ML   0.0, FR,  82.7 , FA,   5.8, AER,  41.9
# threshold 0.48 compeleted
# ML   0.0, FR,  77.4 , FA,   7.4, AER,  40.2
# threshold 0.49 compeleted
# ML   0.0, FR,  73.2 , FA,  10.5, AER,  39.9
# threshold 0.5 compeleted
# ML   0.0, FR,  69.0 , FA,  15.8, AER,  40.8
# threshold 0.51 compeleted
# ML   0.0, FR,  64.9 , FA,  22.6, AER,  42.5
# threshold 0.52 compeleted
# ML   0.0, FR,  60.7 , FA,  27.9, AER,  43.3
# threshold 0.53 compeleted
# ML   0.0, FR,  54.2 , FA,  32.6, AER,  42.7
# threshold 0.54 compeleted
# ML   0.0, FR,  51.2 , FA,  34.2, AER,  42.2
# threshold 0.55 compeleted
# ML   0.0, FR,  46.4 , FA,  39.5, AER,  42.7
# threshold 0.56 compeleted
# ML   0.0, FR,  39.9 , FA,  45.8, AER,  43.0
# threshold 0.57 compeleted
# ML   0.0, FR,  36.3 , FA,  49.5, AER,  43.3
# threshold 0.58 compeleted
# ML   0.0, FR,  31.0 , FA,  53.7, AER,  43.0
# threshold 0.59 compeleted
# ML   0.0, FR,  26.2 , FA,  60.0, AER,  44.1
# threshold 0.6 compeleted
# ML   0.0, FR,  22.0 , FA,  64.2, AER,  44.4
# threshold 0.61 compeleted
# ML   0.0, FR,  18.5 , FA,  67.9, AER,  44.7
# threshold 0.62 compeleted
# ML   0.0, FR,  15.5 , FA,  71.6, AER,  45.3
# threshold 0.63 compeleted
# ML   0.0, FR,  14.9 , FA,  73.7, AER,  46.1
# threshold 0.64 compeleted
# ML   0.0, FR,  11.9 , FA,  77.9, AER,  46.9
# threshold 0.65 compeleted
# ML   0.0, FR,   9.5 , FA,  81.6, AER,  47.8
# threshold 0.66 compeleted
# ML   0.0, FR,   7.1 , FA,  85.8, AER,  48.9
# threshold 0.67 compeleted
# ML   0.0, FR,   6.0 , FA,  88.4, AER,  49.7
# threshold 0.68 compeleted
# ML   0.0, FR,   5.4 , FA,  89.5, AER,  50.0
# threshold 0.69 compeleted
# ML   0.0, FR,   4.2 , FA,  90.0, AER,  49.7
# threshold 0.7 compeleted
# ML   0.0, FR,   2.4 , FA,  92.1, AER,  50.0
# done
# cross_validation 7 compeleted
# cost time  66.5 minute
# cross validation 7 detection_rate is 0.5
# crossvalidation 8 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.38 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.39 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR, 100.0 , FA,   0.5, AER,  47.2
# threshold 0.41 compeleted
# ML   0.0, FR, 100.0 , FA,   0.5, AER,  47.2
# threshold 0.42 compeleted
# ML   0.0, FR,  98.8 , FA,   1.1, AER,  46.9
# threshold 0.43 compeleted
# ML   0.0, FR,  97.6 , FA,   1.6, AER,  46.6
# threshold 0.44 compeleted
# ML   0.0, FR,  96.4 , FA,   1.6, AER,  46.1
# threshold 0.45 compeleted
# ML   0.0, FR,  93.5 , FA,   4.2, AER,  46.1
# threshold 0.46 compeleted
# ML   0.0, FR,  90.5 , FA,   6.8, AER,  46.1
# threshold 0.47 compeleted
# ML   0.0, FR,  85.7 , FA,   8.9, AER,  45.0
# threshold 0.48 compeleted
# ML   0.6, FR,  81.5 , FA,  12.6, AER,  45.3
# threshold 0.49 compeleted
# ML   0.6, FR,  78.0 , FA,  14.7, AER,  44.7
# threshold 0.5 compeleted
# ML   0.6, FR,  72.6 , FA,  17.4, AER,  43.6
# threshold 0.51 compeleted
# ML   0.6, FR,  64.9 , FA,  20.0, AER,  41.3
# threshold 0.52 compeleted
# ML   0.6, FR,  60.7 , FA,  23.2, AER,  41.1
# threshold 0.53 compeleted
# ML   0.6, FR,  53.0 , FA,  27.9, AER,  39.9
# threshold 0.54 compeleted
# ML   0.6, FR,  48.8 , FA,  32.1, AER,  40.2
# threshold 0.55 compeleted
# ML   0.6, FR,  42.9 , FA,  37.9, AER,  40.5
# threshold 0.56 compeleted
# ML   0.6, FR,  38.7 , FA,  44.7, AER,  42.2
# threshold 0.57 compeleted
# ML   0.6, FR,  31.0 , FA,  48.9, AER,  40.8
# threshold 0.58 compeleted
# ML   0.6, FR,  25.0 , FA,  52.6, AER,  39.9
# threshold 0.59 compeleted
# ML   0.6, FR,  19.6 , FA,  56.3, AER,  39.4
# threshold 0.6 compeleted
# ML   0.6, FR,  16.1 , FA,  58.4, AER,  38.8
# threshold 0.61 compeleted
# ML   0.6, FR,  14.3 , FA,  64.7, AER,  41.3
# threshold 0.62 compeleted
# ML   0.6, FR,  13.1 , FA,  66.8, AER,  41.9
# threshold 0.63 compeleted
# ML   0.6, FR,  12.5 , FA,  70.5, AER,  43.6
# threshold 0.64 compeleted
# ML   0.6, FR,  10.7 , FA,  74.7, AER,  45.0
# threshold 0.65 compeleted
# ML   0.6, FR,   8.9 , FA,  76.8, AER,  45.3
# threshold 0.66 compeleted
# ML   0.6, FR,   7.1 , FA,  81.1, AER,  46.6
# threshold 0.67 compeleted
# ML   0.6, FR,   6.0 , FA,  83.2, AER,  47.2
# threshold 0.68 compeleted
# ML   0.6, FR,   6.0 , FA,  83.7, AER,  47.5
# threshold 0.69 compeleted
# ML   0.6, FR,   6.0 , FA,  86.3, AER,  48.9
# threshold 0.7 compeleted
# ML   0.6, FR,   4.8 , FA,  86.8, AER,  48.6
# done
# cross_validation 8 compeleted
# cost time  74.8 minute
# cross validation 8 detection_rate is 0.5139664804469274
# crossvalidation 9 start
# ubm model start
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# threshold 0.3 compeleted>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.31 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.32 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.33 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.34 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.35 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.36 compeleted
# ML   0.0, FR, 100.0 , FA,   0.0, AER,  46.9
# threshold 0.37 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.38 compeleted
# ML   0.0, FR,  99.4 , FA,   0.0, AER,  46.6
# threshold 0.39 compeleted
# ML   0.0, FR,  99.4 , FA,   0.5, AER,  46.9
# threshold 0.4 compeleted
# ML   0.0, FR,  98.2 , FA,   1.1, AER,  46.6
# threshold 0.41 compeleted
# ML   0.0, FR,  97.0 , FA,   1.1, AER,  46.1
# threshold 0.42 compeleted
# ML   0.0, FR,  97.0 , FA,   1.1, AER,  46.1
# threshold 0.43 compeleted
# ML   0.0, FR,  95.2 , FA,   2.6, AER,  46.1
# threshold 0.44 compeleted
# ML   0.0, FR,  92.3 , FA,   4.7, AER,  45.8
# threshold 0.45 compeleted
# ML   0.0, FR,  90.5 , FA,   4.7, AER,  45.0
# threshold 0.46 compeleted
# ML   0.0, FR,  87.5 , FA,   6.8, AER,  44.7
# threshold 0.47 compeleted
# ML   0.0, FR,  86.3 , FA,   6.8, AER,  44.1
# threshold 0.48 compeleted
# ML   0.0, FR,  83.3 , FA,  11.1, AER,  45.0
# threshold 0.49 compeleted
# ML   0.0, FR,  79.2 , FA,  13.7, AER,  44.4
# threshold 0.5 compeleted
# ML   0.0, FR,  75.6 , FA,  17.9, AER,  45.0
# threshold 0.51 compeleted
# ML   0.0, FR,  70.8 , FA,  21.6, AER,  44.7
# threshold 0.52 compeleted
# ML   0.0, FR,  67.9 , FA,  24.2, AER,  44.7
# threshold 0.53 compeleted
# ML   0.0, FR,  61.9 , FA,  28.9, AER,  44.4
# threshold 0.54 compeleted
# ML   0.0, FR,  58.3 , FA,  34.7, AER,  45.8
# threshold 0.55 compeleted
# ML   0.0, FR,  51.8 , FA,  37.9, AER,  44.4
# threshold 0.56 compeleted
# ML   0.0, FR,  47.0 , FA,  43.2, AER,  45.0
# threshold 0.57 compeleted
# ML   0.0, FR,  43.5 , FA,  45.8, AER,  44.7
# threshold 0.58 compeleted
# ML   0.0, FR,  35.7 , FA,  52.1, AER,  44.4
# threshold 0.59 compeleted
# ML   0.0, FR,  28.0 , FA,  57.4, AER,  43.6
# threshold 0.6 compeleted
# ML   0.0, FR,  24.4 , FA,  59.5, AER,  43.0
# threshold 0.61 compeleted
# ML   0.0, FR,  22.6 , FA,  62.1, AER,  43.6
# threshold 0.62 compeleted
# ML   0.0, FR,  20.2 , FA,  66.3, AER,  44.7
# threshold 0.63 compeleted
# ML   0.0, FR,  19.0 , FA,  70.5, AER,  46.4
# threshold 0.64 compeleted
# ML   0.0, FR,  17.9 , FA,  74.2, AER,  47.8
# threshold 0.65 compeleted
# ML   0.0, FR,  13.1 , FA,  77.4, AER,  47.2
# threshold 0.66 compeleted
# ML   0.0, FR,  10.1 , FA,  82.1, AER,  48.3
# threshold 0.67 compeleted
# ML   0.0, FR,   7.7 , FA,  83.7, AER,  48.0
# threshold 0.68 compeleted
# ML   0.0, FR,   7.1 , FA,  86.3, AER,  49.2
# threshold 0.69 compeleted
# ML   0.0, FR,   6.5 , FA,  87.4, AER,  49.4
# threshold 0.7 compeleted
# ML   0.0, FR,   6.5 , FA,  89.5, AER,  50.6
# done
# cross_validation 9 compeleted
# cost time  83.2 minute
# cross validation 9 detection_rate is 0.49441340782122906

# %%
'''
Plot the error rate

'''
import numpy as np
from matplotlib.axes import Axes
import pickle
save_path="D:\\LAB\\lab\\task_2_version_4\\error_rate_set.txt"
#save_path="/Users/Mata/Documents/lab/task_2_version_4/features.txt"
f = open(save_path,'rb')
error_rate_set=pickle.load(f)
f.close()

# %%
aer_rate_set=error_rate_set['aer']
ml_rate_set=error_rate_set['ml']
fa_rate_set=error_rate_set['fa']
fr_rate_set=error_rate_set['fr']

# %%
fr_rate_set[0]
# Out:
# array([ 100.        ,  100.        ,  100.        ,  100.        ,
#         100.        ,  100.        ,  100.        ,  100.        ,
#         100.        ,  100.        ,  100.        ,  100.        ,
#          98.21428571,   97.02380952,   96.42857143,   93.45238095,
#          91.07142857,   85.11904762,   80.35714286,   75.        ,
#          69.04761905,   62.5       ,   58.33333333,   54.76190476,
#          50.        ,   42.85714286,   38.0952381 ,   35.71428571,
#          33.33333333,   29.76190476,   25.5952381 ,   23.80952381,
#          19.04761905,   16.66666667,   14.88095238,   10.71428571,
#           9.52380952,    7.73809524,    7.14285714,    5.95238095,
#           4.16666667])

# %%
threshold=[0.3,0.31,0.32,0.33,0.34,0.35,0.36,0.37,0.38,0.39,0.40,\
                     0.41,0.42,0.43,0.44,0.45,0.46,0.47,0.48,0.49,0.50,\
                     0.51,0.52,0.53,0.54,0.55,0.56,0.57,0.58,0.59,0.60,\
                     0.61,0.62,0.63,0.64,0.65,0.66,0.67,0.68,0.69,0.70]
import matplotlib.pyplot as plt
for cross_num in range(10):
    plt.plot(threshold,fr_rate_set[cross_num])
    plt.plot(threshold,fa_rate_set[cross_num])
    plt.plot(threshold,ml_rate_set[cross_num])
    plt.plot(threshold,aer_rate_set[cross_num])
    plt.xlabel("threshold")
    plt.ylabel("error rate")
    plt.show()

# %%
minimum_error=np.min(np.sum(aer_rate_set,axis=0)/10)
min_threshold=threshold[np.int(np.argwhere(np.sum(aer_rate_set,axis=0)/10==minimum_error))]

# %%
min_threshold
# Out:
# 0.53

# %%
plt.figure(figsize=(16,12))
plt.title(" Variation of error rates in OSTI-SI with the threshold ",fontsize=25)
plt.plot(threshold,np.sum(fr_rate_set,axis=0)/10,'b--',label='FRR')
plt.plot(threshold,np.sum(fa_rate_set,axis=0)/10,'g:',label='FAR')
plt.plot(threshold,np.sum(ml_rate_set,axis=0)/10,linewidth=1,label='MLR')
plt.plot(threshold,np.sum(aer_rate_set,axis=0)/10,'r-',linewidth=2,label='AER')
plt.plot(min_threshold,minimum_error,'ko')
plt.annotate('Minimum Error', fontsize=20,xy=(min_threshold, minimum_error), xytext=(0.45, 30),
            arrowprops=dict(facecolor='black', shrink=0.05),)
plt.xlabel("threshold",fontsize=20)
plt.ylabel("error rate",fontsize=20)
plt.legend()#loc='upper right', bbox_to_anchor=(0.5, 0.5))
plt.show()
