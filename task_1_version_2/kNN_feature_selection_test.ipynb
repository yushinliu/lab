# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat
import matplotlib.pyplot as plt
import sys
sys.path.append(r"C:\Users\yangshanqi\Documents\lab\labgithubcopy\task_1_version_2")

# %%
from kNN_function import kNN_feature_selection_wrap
from plot_prediction import kNN_plot_prediction

# %%
X_scaled_CNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\X_scaled_CNN.csv")
y_scaled_CNN=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\y_scaled_CNN.csv")
X_val=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\scaled_validation_feature.csv")
y_val=pd.read_csv("C:\\Users\\yangshanqi\\Documents\\lab\\labgithubcopy\\task_1_version_2\\result\\validation_label.csv")
X_val=X_val.drop("Unnamed: 0",1)
y_val=y_val.drop("Unnamed: 0",1)

# %%
kNN_feature_selection_wrap (X_scaled_CNN,y_scaled_CNN,X_val,y_val,100)
# Out:
# current feature choosen:
# ('feature0', 'feature1')
#
# the total executing time:  0.6minute
# label_1_amount            20000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.000000
# f1_score                      0.445331
# TPR                           0.562075
# FPR                           0.138644
# BER                           0.288285
# time                          0.042061
# Name: 4, dtype: float64
#
# current feature choosen:
# ('feature0', 'feature2')
#
# the total executing time:  0.6minute
# label_1_amount            25000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.250000
# f1_score                      0.410844
# TPR                           0.467404
# FPR                           0.116416
# BER                           0.324506
# time                          0.039469
# Name: 3, dtype: float64
#
# current feature choosen:
# ('feature0', 'feature3')
#
# the total executing time:  0.6minute
# label_1_amount            20000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.000000
# f1_score                      0.484248
# TPR                           0.665703
# FPR                           0.156159
# BER                           0.245228
# time                          0.041353
# Name: 4, dtype: float64
#
# current feature choosen:
# ('feature0', 'feature4')
#
# the total executing time:  0.6minute
# label_1_amount            25000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.250000
# f1_score                      0.410226
# TPR                           0.461224
# FPR                           0.113467
# BER                           0.326121
# time                          0.039391
# Name: 3, dtype: float64
#
# current feature choosen:
# ('feature1', 'feature2')
#
# the total executing time:  0.6minute
# label_1_amount            30000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.500000
# f1_score                      0.383308
# TPR                           0.624320
# FPR                           0.235333
# BER                           0.305506
# time                          0.039963
# Name: 2, dtype: float64
#
# current feature choosen:
# ('feature1', 'feature3')
#
# the total executing time:  0.6minute
# label_1_amount            35000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.750000
# f1_score                      0.517752
# TPR                           0.632937
# FPR                           0.117013
# BER                           0.242038
# time                          0.041736
# Name: 1, dtype: float64
#
# current feature choosen:
# ('feature1', 'feature4')
#
# the total executing time:  0.6minute
# label_1_amount            40000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        2.000000
# f1_score                      0.340450
# TPR                           0.443481
# FPR                           0.167415
# BER                           0.361967
# time                          0.040789
# Name: 0, dtype: float64
#
# current feature choosen:
# ('feature2', 'feature3')
#
# the total executing time:  0.6minute
# label_1_amount            35000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.750000
# f1_score                      0.535680
# TPR                           0.648810
# FPR                           0.111491
# BER                           0.231340
# time                          0.043422
# Name: 1, dtype: float64
#
# current feature choosen:
# ('feature2', 'feature4')
#
# the total executing time:  0.6minute
# label_1_amount            15000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        0.750000
# f1_score                      0.255282
# TPR                           0.648639
# FPR                           0.494715
# BER                           0.423038
# time                          0.039098
# Name: 5, dtype: float64
#
# current feature choosen:
# ('feature3', 'feature4')
#
# the total executing time:  0.6minute
# label_1_amount            35000.000000
# label_2_amount            20000.000000
# label 1: label 2 ratio        1.750000
# f1_score                      0.456550
# TPR                           0.555499
# FPR                           0.126530
# BER                           0.285515
# time                          0.042478
# Name: 1, dtype: float64

# %%
stuck,slices,features=11,22,3
kNN_plot_prediction(stuck,slices,features,X_scaled_CNN.loc[:,['feature2','feature3']],y_scaled_CNN,X_val.loc[:,['feature2','feature3']],y_val,500,1.75)

# %%
stuck,slices,features=11,22,3
kNN_plot_prediction(stuck,slices,features,X_scaled_CNN.loc[:,['feature2','feature3']],y_scaled_CNN,X_val.loc[:,['feature2','feature3']],y_val,100,1.75)
